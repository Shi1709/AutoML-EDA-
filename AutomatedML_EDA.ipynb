# %% [markdown]
# <a href="https://colab.research.google.com/github/Shi1709/AutoML-EDA-/blob/main/AutomatedML_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# selecting file data type
def InputDataType():
    options=['Csv', 'Excel','Xml','Json','Sql','Sql_Table']
    print(f"Please choose your file extension from the below options:\n{', '.join(options)}")

    while True:
        choice= input('Enter your file extension: ').strip().title()
        if choice in options:
            print(f"You selected: {choice}")
            return choice
        else:
            print(" ❌ Invalid choice. Please choose exactly from the above list.")

FileType=InputDataType()
RESULT={}
# Out:
# Please choose your file extension from the below options:
# Csv, Excel, Xml, Json, Sql, Sql_Table
# Enter your file extension: csv
# You selected: Csv

# %%
FileName=input('Enter the dataset file name(Exactly as in file) or link:')
import pandas as pd


if FileType == 'Csv':
    FileTypePd=pd.read_csv
    FileName=FileName + ".csv"
if FileType == 'Excel':
    FileTypePd=pd.read_excel
    FileName=FileName + ".xlsx"
if FileType == 'Json':
    FileTypePd=pd.read_json
    FileName=FileName + ".json"
if FileType == 'Xml':
    FileTypePd=pd.read_xml
    FileName=FileName + ".xml"

RESULT["FILE NAME: "]= FileName
df=FileTypePd(FileName)
df
# Out:
# Enter the dataset file name(Exactly as in file) or link:breast_cancer_dataframe
#      Unnamed: 0  mean radius  mean texture  mean perimeter  mean area  \
# 0             0        17.99         10.38          122.80     1001.0
# 1             1        20.57         17.77          132.90     1326.0
# 2             2        19.69         21.25          130.00     1203.0
# 3             3        11.42         20.38           77.58      386.1
# 4             4        20.29         14.34          135.10     1297.0
# ..          ...          ...           ...             ...        ...
# 564         564        21.56         22.39          142.00     1479.0
# 565         565        20.13         28.25          131.20     1261.0
# 566         566        16.60         28.08          108.30      858.1
# 567         567        20.60         29.33          140.10     1265.0
# 568         568         7.76         24.54           47.92      181.0
#
#      mean smoothness  mean compactness  mean concavity  mean concave points  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      mean symmetry  ...  worst texture  worst perimeter  worst area  \
# 0           0.2419  ...          17.33           184.60      2019.0
# 1           0.1812  ...          23.41           158.80      1956.0
# 2           0.2069  ...          25.53           152.50      1709.0
# 3           0.2597  ...          26.50            98.87       567.7
# 4           0.1809  ...          16.67           152.20      1575.0
# ..             ...  ...            ...              ...         ...
# 564         0.1726  ...          26.40           166.10      2027.0
# 565         0.1752  ...          38.25           155.00      1731.0
# 566         0.1590  ...          34.12           126.70      1124.0
# 567         0.2397  ...          39.42           184.60      1821.0
# 568         0.1587  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890     0.0
# 1                  0.1860          0.2750                  0.08902     0.0
# 2                  0.2430          0.3613                  0.08758     0.0
# 3                  0.2575          0.6638                  0.17300     0.0
# 4                  0.1625          0.2364                  0.07678     0.0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115     0.0
# 565                0.1628          0.2572                  0.06637     0.0
# 566                0.1418          0.2218                  0.07820     0.0
# 567                0.2650          0.4087                  0.12400     0.0
# 568                0.0000          0.2871                  0.07039     1.0
#
# [569 rows x 32 columns]

# %%
# EDA

import numpy as np

# Null values
NullValues = df.isnull().sum().tolist()
for i in NullValues:
    if i != 0:
        print(df.isnull().sum())
        ClearNull=input("Do you want to remove null values(Y=yes, N=no):").capitalize()
        if ClearNull == 'Y':
            RESULT["NULL VALUES: "]= "NULL VALUES DROPED. ✅"
            print(f"Null values: \n{df.isnull().sum()}")
            df.dropna(inplace=True)
            print(f"\n\nNull values droped:✅ \n{df.isnull().sum()}")
            break
        if ClearNull == 'N':
            RESULT["NULL VALUES: "]= "NULL VALUES FILLED. ✅"
            for col in df.columns:
                if np.issubdtype(df[col].dtype, np.number):
                    # print(col, df[col].dtype)
                    df[col]=df[col].fillna(df[col].median())
                    print(f"mean for {df[col].head(0)} value filled ✅ ")
                if df[col].dtype == 'object' or df[col].dtype == 'string':
                    # print(col, df[col].dtype)
                    df[col]=df[col].fillna(df[col].mode().iloc[0])
                    print(f"mode for {df[col].head(0)} value filled ✅")
            break
    if i ==0:
        print("No Null Values ✅")
        RESULT["NULL VALUES: "]= "NO NULL VALUES. ✅"

print(df.isnull().sum())
# Out:
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# No Null Values ✅
# Unnamed: 0                 0
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
# a=len(df.columns)/2
# int(a+1)

# %%
# By heatmap remove multy co-related columns
import seaborn as sns
import matplotlib.pyplot as plt

# print(sns.heatmap(CoRelationDF,annot=True))
# HighlyCorelatedColumns=[]
lenght={}
while True:
    CoRelationDF=df.select_dtypes(include=np.number).corr()
    HighlyCorelatedColumns=[]
    for i in CoRelationDF.index:
        for j in CoRelationDF.columns:
            if CoRelationDF[i][j] == 1:
                continue
            if CoRelationDF[i][j] > 0.85:
                if i not in HighlyCorelatedColumns:
                    HighlyCorelatedColumns.append(i)
                    lenght[i]=len(HighlyCorelatedColumns)
    print(f"Highly Co-Related Columns : \n{HighlyCorelatedColumns}\n\n")
    if len(HighlyCorelatedColumns) !=0:
        print('Choose the columns that you want to remove: ')
        for i,v in enumerate(HighlyCorelatedColumns):
            print(f"{i+1} : {v}")
        RemoveColumn=int(input("Column number want to remove:"))
        RemoveColumn = RemoveColumn -1
        df=df.drop(HighlyCorelatedColumns[RemoveColumn],axis=1)
        if HighlyCorelatedColumns[RemoveColumn] not in df.columns:
            print(f"The column {HighlyCorelatedColumns[RemoveColumn]} is Removed: ❌")
            RESULT["MULTI-COLLINEATIY : "]= "Highly Co-Related Columns are Droped. ✅"

    if len(HighlyCorelatedColumns) >=2:
        continue
    else:
        print("No Highly Co-Related Column ✅")
        if len(lenght) == 0 :
            RESULT["MULTI-COLLINEATIY : "]= "No Highly Co-Related Column. ✅"
        break


# CoRelationDF=df.select_dtypes(include=np.number).corr()
# # # print(sns.heatmap(CoRelationDF,annot=True))
# HighlyCorelatedColumns=["Highly_Corelated_Columns"]
# while "Highly_Corelated_Columns" in HighlyCorelatedColumns:
#     for i in CoRelationDF.index:
#         for j in CoRelationDF.columns:
#             if CoRelationDF[i][j] == 1:
#                 continue
#             if CoRelationDF[i][j] > 0.85:
#                 if i not in HighlyCorelatedColumns:
#                     HighlyCorelatedColumns.append(i)
#     print(f"Highly Co-Related Columns : \n{HighlyCorelatedColumns}\n\n")
#     if len(HighlyCorelatedColumns) !=0:
#         print('Choose the columns that you want to remove: ')
#         for i,v in enumerate(HighlyCorelatedColumns):
#             if i == 0:
#                 continue
#             print(f"{i} : {v}")
#         RemoveColumn=int(input("Column number want to remove:"))
#         df=df.drop(HighlyCorelatedColumns[RemoveColumn],axis=1)
#         if HighlyCorelatedColumns[RemoveColumn] not in df.columns:
#             print(f"The column {HighlyCorelatedColumns[RemoveColumn]} is Removed: ❌")
#         else:
#             print("No Highly Co-Related Column ✅")
#             break
# Out:
# Highly Co-Related Columns :
# ['mean radius', 'mean texture', 'mean perimeter', 'mean area', 'mean compactness', 'mean concavity', 'mean concave points', 'radius error', 'perimeter error', 'area error', 'worst radius', 'worst texture', 'worst perimeter', 'worst area', 'worst compactness', 'worst concavity', 'worst concave points']
#
#
# Choose the columns that you want to remove:
# 1 : mean radius
# 2 : mean texture
# 3 : mean perimeter
# 4 : mean area
# 5 : mean compactness
# 6 : mean concavity
# 7 : mean concave points
# 8 : radius error
# 9 : perimeter error
# 10 : area error
# 11 : worst radius
# 12 : worst texture
# 13 : worst perimeter
# 14 : worst area
# 15 : worst compactness
# 16 : worst concavity
# 17 : worst concave points
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4013176264.py in <cell line: 0>()
#      22         for i,v in enumerate(HighlyCorelatedColumns):
#      23             print(f"{i+1} : {v}")
# ---> 24         RemoveColumn=int(input("Column number want to remove:"))
#      25         RemoveColumn = RemoveColumn -1
#      26         df=df.drop(HighlyCorelatedColumns[RemoveColumn],axis=1)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# a=[1,2,3,4,5]
# while 1 in a:
#     print(a)
#     inp=int(input("value to remove"))
#     a.pop(inp)
#     print(a)
#     continue

# %%
print(f"Do you want to remove any unwanted columns.\nSelect the represent number along with below column name or you don't want to remove press N")
BeforeRemove=len(df.columns)
while True:
    for i, v in enumerate(df.columns):
        print(f"{i+1}: {v}")

    RemoveColumn = input("\nEnter column number to remove, or press N to finish: ").capitalize()

    if RemoveColumn == "N":
        AfterRemove=len(df.columns)
        if BeforeRemove == AfterRemove:
            RESULT["UNWANTED COLUMNS: "] = "NO COLUMNS REMOVED. ✅"
        break

    if RemoveColumn.isdigit():  # check if input is a number
        RemoveColumn = int(RemoveColumn)
        if 1 <= RemoveColumn <= len(df.columns):
            columnName = df.columns[RemoveColumn - 1]
            df.drop(columnName, axis=1, inplace=True)
            print(f"✅ Removed column: {columnName}\n")
            RESULT["UNWANTED COLUMNS: "] = "UNWANTED COLUMNS ARE REMOVED. ✅"
        else:
            print("❌ Invalid Input: Number out of range.\n")
    else:
        print("❌ Invalid Input: Please enter a number or N.\n")

print("Final Dataframe:")
for i, v in enumerate(df.columns):
        print(f"{i+1}: {v}")
# Out:
# Do you want to remove any unwanted columns.
# Select the represent number along with below column name or you don't want to remove press N
# 1: Unnamed: 0
# 2: mean radius
# 3: mean texture
# 4: mean perimeter
# 5: mean area
# 6: mean smoothness
# 7: mean compactness
# 8: mean concavity
# 9: mean concave points
# 10: mean symmetry
# 11: mean fractal dimension
# 12: radius error
# 13: texture error
# 14: perimeter error
# 15: area error
# 16: smoothness error
# 17: compactness error
# 18: concavity error
# 19: concave points error
# 20: symmetry error
# 21: fractal dimension error
# 22: worst radius
# 23: worst texture
# 24: worst perimeter
# 25: worst area
# 26: worst smoothness
# 27: worst compactness
# 28: worst concavity
# 29: worst concave points
# 30: worst symmetry
# 31: worst fractal dimension
# 32: target
#
# Enter column number to remove, or press N to finish: n
# Final Dataframe:
# 1: Unnamed: 0
# 2: mean radius
# 3: mean texture
# 4: mean perimeter
# 5: mean area
# 6: mean smoothness
# 7: mean compactness
# 8: mean concavity
# 9: mean concave points
# 10: mean symmetry
# 11: mean fractal dimension
# 12: radius error
# 13: texture error
# 14: perimeter error
# 15: area error
# 16: smoothness error
# 17: compactness error
# 18: concavity error
# 19: concave points error
# 20: symmetry error
# 21: fractal dimension error
# 22: worst radius
# 23: worst texture
# 24: worst perimeter
# 25: worst area
# 26: worst smoothness
# 27: worst compactness
# 28: worst concavity
# 29: worst concave points
# 30: worst symmetry
# 31: worst fractal dimension
# 32: target

# %%
# Encoding

if not df.select_dtypes(include="object").empty:
    from sklearn.preprocessing import LabelEncoder
    print(f"1 : Lable Encoding\n2 : One-hot Encoding\n\n")
    EncodingType=int(input("Enter number related to encoding type: "))

    if EncodingType == 1:
        print("Performing Lable Encoding ✅: \n\n")
        for col in df.select_dtypes(include="object").columns:
            lable_encode=LabelEncoder()
            df[col]=lable_encode.fit_transform(df[col])
            RESULT["ENCODING TYPE: "] = "LABLE ENCODING. ✅"
        print(df.info())

    if EncodingType == 2:
        print("Performing One-Hot Encoding ✅: \n\n")
        RESULT["ENCODING TYPE: "] = "ONE-HOT ENCODING. ✅"

    # print(df)
else:
    print("No Object/String/Catogorical variable in the data set ✅")
    RESULT["ENCODING TYPE: "] = "NO ENCODING PERFORMED. ✅"
ClearedDataFrame=df
ClearedDataFrame = ClearedDataFrame.replace([np.inf, -np.inf], np.nan)
ClearedDataFrame=ClearedDataFrame.dropna()
# Out:
# No Object/String/Catogorical variable in the data set ✅

# %%
# import numpy as np
# np.isnan(ClearedDataFrame).sum()

# %%
# Choosing target column

for i,v in enumerate(df.columns):
    print(f"{i+1} : {v}")
choosenColNum=int(input("Enter the represent number for Target Column: "))
choosenColNum=choosenColNum-1
for i,v in enumerate(df.columns):
    if i==choosenColNum:
        TargetColumn=v

print(f"\n\n\nThe choosen target column : {TargetColumn} ✅")
x=df.drop(TargetColumn,axis=1)
y=df[TargetColumn]

# spliting training data and testing data

from sklearn.model_selection import train_test_split
print("Enter the float value from 0.6 to 0.9 to split the train data:")
while True:
    TrainSize=float(input("Enter the float value from 0.6 to 0.9 to split the train data:"))
    if TrainSize >= 0.6:
        if TrainSize <=0.9:
            # Removed stratify=y because target 'id' has all unique values, making stratification impossible.
            ORGxTrain,ORGxTest,ORGyTrain,ORGyTest = train_test_split(x,y,train_size=TrainSize,random_state=44)
            print(f"In total data {round(TrainSize * 100,1)}% was splited into training data and {round((1-TrainSize)* 100,1)}% was splited into testing data ✅")
            RESULT["TARGET: "] = TargetColumn
            RESULT["TRAINING DATA: "] = round(TrainSize * 100,1)
            RESULT["TESTING DATA: "] = round((1-TrainSize)* 100,1)

            break
        else:
            print("INVALID INPUT\nTO REDUCE OVER-FITTING ENTER VALUE BELOW 0.9 ❌")
    else:
        print("INVALID INPUT\nTO REDUCE UNDER-FITTING ENTER VALUE ABOVE 0.5 ❌")
# Out:
# 1 : Unnamed: 0
# 2 : mean radius
# 3 : mean texture
# 4 : mean perimeter
# 5 : mean area
# 6 : mean smoothness
# 7 : mean compactness
# 8 : mean concavity
# 9 : mean concave points
# 10 : mean symmetry
# 11 : mean fractal dimension
# 12 : radius error
# 13 : texture error
# 14 : perimeter error
# 15 : area error
# 16 : smoothness error
# 17 : compactness error
# 18 : concavity error
# 19 : concave points error
# 20 : symmetry error
# 21 : fractal dimension error
# 22 : worst radius
# 23 : worst texture
# 24 : worst perimeter
# 25 : worst area
# 26 : worst smoothness
# 27 : worst compactness
# 28 : worst concavity
# 29 : worst concave points
# 30 : worst symmetry
# 31 : worst fractal dimension
# 32 : target
# Enter the represent number for Target Column: 32
#
#
#
# The choosen target column : target ✅
# Enter the float value from 0.6 to 0.9 to split the train data:
# Enter the float value from 0.6 to 0.9 to split the train data:0.7
# In total data 70.0% was splited into training data and 30.0% was splited into testing data ✅

# %%
# Calculating the target is regression or classification

targetCount=df[TargetColumn].unique()

if len(targetCount) > 10:
    print("The target type is Regression")
    ModelType="Regression"
else:
    print("The target type is Classification")
    ModelType="Classification"

print("Do you want to change target type press 1 or to continue press 0")
change=int(input(""))
if change ==1:
    if ModelType == "Classification":
        ModelType="Regression"
    if ModelType == "Regression":
        ModelType="Classification"
    print(f"Target type changed to {ModelType} ✅")

print(F"Performing {ModelType} Algorithms : ")
RESULT["MODEL TYPE: "] = ModelType
# Out:
# The target type is Classification
# Do you want to change target type press 1 or to continue press 0
# 0
# Performing Classification Algorithms :

# %%
# yTrain

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.12/dist-packages (1.2.8)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.2.5)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (8.5.0)

# %%
# Training


from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor,GradientBoostingClassifier,GradientBoostingRegressor,AdaBoostClassifier,AdaBoostRegressor
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from xgboost import XGBClassifier,XGBRegressor
from catboost import CatBoostClassifier,CatBoostRegressor
from sklearn.metrics import r2_score,accuracy_score
linReg=LinearRegression()
logReg=LogisticRegression()
RandomReg=RandomForestRegressor()
RandomCla=RandomForestClassifier()
GradBoostCla=GradientBoostingClassifier()
GradBoostReg=GradientBoostingRegressor()
AdaBoostReg=AdaBoostRegressor()
AdaBoostCla=AdaBoostClassifier()
DecReg=DecisionTreeRegressor()
DecCla=DecisionTreeClassifier()
XGBCla=XGBClassifier()
XGBReg=XGBRegressor()
CatBoostCla=CatBoostClassifier()
CatBoostReg=CatBoostRegressor()

Predictions = {}
# Training model based on target type

if ModelType == "Regression":
    xTrain, xTest, yTrain, yTest = ORGxTrain,ORGxTest,ORGyTrain,ORGyTest
    # regression training
    linReg.fit(xTrain,yTrain)
    DecReg.fit(xTrain,yTrain)
    RandomReg.fit(xTrain,yTrain)
    AdaBoostReg.fit(xTrain,yTrain)
    CatBoostReg.fit(xTrain,yTrain)
    GradBoostReg.fit(xTrain,yTrain)
    XGBReg.fit(xTrain,yTrain)

    # regression Y predit
    Predictions['linRegPredit001']=linReg.predict(xTest)
    Predictions['DecRegPredit001']=DecReg.predict(xTest)
    Predictions['RandomRegPredit001']=RandomReg.predict(xTest)
    Predictions['AdaBoostRegPredit001']=AdaBoostReg.predict(xTest)
    Predictions['CatBoostRegPredit001']=CatBoostReg.predict(xTest)
    Predictions['GradBoostRegPredit001']=GradBoostReg.predict(xTest)
    Predictions['XGBRegPredit001']=XGBReg.predict(xTest)


    # R2 score
    linRegR2Score001=r2_score(yTest,Predictions['linRegPredit001'])
    DecRegR2Score001=r2_score(yTest,Predictions['DecRegPredit001'])
    RandomRegR2Score001=r2_score(yTest,Predictions['RandomRegPredit001'])
    AdaBoostRegR2Score001=r2_score(yTest,Predictions['AdaBoostRegPredit001'])
    CatBoostRegR2Score001=r2_score(yTest,Predictions['CatBoostRegPredit001'])
    GradBoostRegR2Score001=r2_score(yTest,Predictions['GradBoostRegPredit001'])
    XGBRegR2Score001=r2_score(yTest,Predictions['XGBRegPredit001'])

    print(f"Linear Regression 001: {linRegR2Score001}\nDecision tree 001: {DecRegR2Score001}\nRandom forest 001: {RandomRegR2Score001}\nAda Boosting 001: {AdaBoostRegR2Score001} \nCat Boosting 001: {CatBoostRegR2Score001}\nGradient Boosting 001: {GradBoostRegR2Score001}\nXG Boosting 001: {XGBRegR2Score001}")
    PerfomanceDF=pd.DataFrame()
    PerfomanceDF.index=['Linear Regression','Decision tree','Random forest','Ada Boosting','Cat Boosting','Gradient Boosting','XG Boosting']
    # a.columns=['Naked Model','With LOG','PCA','Tuning']
    PerfomanceDF['No_Tuning']= [linRegR2Score001,DecRegR2Score001,RandomRegR2Score001,AdaBoostRegR2Score001,CatBoostRegR2Score001,GradBoostRegR2Score001,XGBRegR2Score001]
    print(PerfomanceDF)


if ModelType == "Classification":

    xTrain, xTest, yTrain, yTest = ORGxTrain,ORGxTest,ORGyTrain,ORGyTest
    # Balancing the classification data
    print("Performing Over sampling")
    print(f"Before SMOTE:\n{yTrain.value_counts()}")
    from imblearn.over_sampling import SMOTE
    smote=SMOTE(random_state=42)
    xTrain,yTrain = smote.fit_resample(xTrain,yTrain)
    print(f"✅ After SMOTE:\n{yTrain.value_counts()}")



    # regression training
    logReg.fit(xTrain,yTrain)
    DecCla.fit(xTrain,yTrain)
    RandomCla.fit(xTrain,yTrain)
    AdaBoostCla.fit(xTrain,yTrain)
    CatBoostCla.fit(xTrain,yTrain)
    GradBoostCla.fit(xTrain,yTrain)
    XGBCla.fit(xTrain,yTrain)

    # Claression Y predit
    Predictions['logRegPredit001']=logReg.predict(xTest)
    Predictions['DecClaPredit001']=DecCla.predict(xTest)
    Predictions['RandomClaPredit001']=RandomCla.predict(xTest)
    Predictions['AdaBoostClaPredit001']=AdaBoostCla.predict(xTest)
    Predictions['CatBoostClaPredit001']=CatBoostCla.predict(xTest)
    Predictions['GradBoostClaPredit001']=GradBoostCla.predict(xTest)
    Predictions['XGBClaPredit001']=XGBCla.predict(xTest)


    # Accuracy score
    logRegAccuracyScore001=accuracy_score(yTest,Predictions['logRegPredit001'])
    DecClaAccuracyScore001=accuracy_score(yTest,Predictions['DecClaPredit001'])
    RandomClaAccuracyScore001=accuracy_score(yTest,Predictions['RandomClaPredit001'])
    AdaBoostClaAccuracyScore001=accuracy_score(yTest,Predictions['AdaBoostClaPredit001'])
    CatBoostClaAccuracyScore001=accuracy_score(yTest,Predictions['CatBoostClaPredit001'])
    GradBoostClaAccuracyScore001=accuracy_score(yTest,Predictions['GradBoostClaPredit001'])
    XGBClaAccuracyScore001=accuracy_score(yTest,Predictions['XGBClaPredit001'])

    print(f"Logistic Regression 001: {logRegAccuracyScore001}\nDecision tree 001: {DecClaAccuracyScore001}\nRandom forest 001: {RandomClaAccuracyScore001}\nAda Boosting 001: {AdaBoostClaAccuracyScore001} \nCat Boosting 001: {CatBoostClaAccuracyScore001}\nGradient Boosting 001: {GradBoostClaAccuracyScore001}\nXG Boosting 001: {XGBClaAccuracyScore001}")
    PerfomanceDF=pd.DataFrame()
    PerfomanceDF.index=['Logistic Regression','Decision tree','Random forest','Ada Boosting','Cat Boosting','Gradient Boosting','XG Boosting']
    # a.columns=['Naked Model','With LOG','PCA','Tuning']
    PerfomanceDF['No_Tuning']= [logRegAccuracyScore001,DecClaAccuracyScore001,RandomClaAccuracyScore001,AdaBoostClaAccuracyScore001,CatBoostClaAccuracyScore001,GradBoostClaAccuracyScore001,XGBClaAccuracyScore001]
    print(PerfomanceDF)
# Out:
# Performing Over sampling
# Before SMOTE:
# target
# 1.0    249
# 0.0    149
# Name: count, dtype: int64
# ✅ After SMOTE:
# target
# 1.0    249
# 0.0    249
# Name: count, dtype: int64
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Learning rate set to 0.00765
# 0:	learn: 0.6807356	total: 74.8ms	remaining: 1m 14s
# 1:	learn: 0.6678282	total: 90.9ms	remaining: 45.3s
# 2:	learn: 0.6567597	total: 111ms	remaining: 36.8s
# 3:	learn: 0.6454944	total: 118ms	remaining: 29.4s
# 4:	learn: 0.6350532	total: 124ms	remaining: 24.7s
# 5:	learn: 0.6235771	total: 138ms	remaining: 22.9s
# 6:	learn: 0.6115719	total: 158ms	remaining: 22.4s
# 7:	learn: 0.6030365	total: 171ms	remaining: 21.2s
# 8:	learn: 0.5909793	total: 189ms	remaining: 20.8s
# 9:	learn: 0.5795955	total: 202ms	remaining: 20s
# 10:	learn: 0.5681827	total: 213ms	remaining: 19.1s
# 11:	learn: 0.5580966	total: 222ms	remaining: 18.3s
# 12:	learn: 0.5492765	total: 231ms	remaining: 17.5s
# 13:	learn: 0.5406970	total: 240ms	remaining: 16.9s
# 14:	learn: 0.5310496	total: 249ms	remaining: 16.4s
# 15:	learn: 0.5218397	total: 268ms	remaining: 16.5s
# 16:	learn: 0.5135459	total: 286ms	remaining: 16.6s
# 17:	learn: 0.5036331	total: 304ms	remaining: 16.6s
# 18:	learn: 0.4946976	total: 313ms	remaining: 16.2s
# 19:	learn: 0.4858772	total: 332ms	remaining: 16.2s
# 20:	learn: 0.4787651	total: 346ms	remaining: 16.1s
# 21:	learn: 0.4708036	total: 359ms	remaining: 16s
# 22:	learn: 0.4628082	total: 373ms	remaining: 15.8s
# 23:	learn: 0.4539493	total: 385ms	remaining: 15.7s
# 24:	learn: 0.4470413	total: 397ms	remaining: 15.5s
# 25:	learn: 0.4391871	total: 408ms	remaining: 15.3s
# 26:	learn: 0.4314337	total: 424ms	remaining: 15.3s
# 27:	learn: 0.4242156	total: 435ms	remaining: 15.1s
# 28:	learn: 0.4168384	total: 451ms	remaining: 15.1s
# 29:	learn: 0.4091245	total: 466ms	remaining: 15.1s
# 30:	learn: 0.4020771	total: 478ms	remaining: 14.9s
# 31:	learn: 0.3955305	total: 491ms	remaining: 14.9s
# 32:	learn: 0.3881271	total: 505ms	remaining: 14.8s
# 33:	learn: 0.3826720	total: 522ms	remaining: 14.8s
# 34:	learn: 0.3758615	total: 536ms	remaining: 14.8s
# 35:	learn: 0.3689812	total: 550ms	remaining: 14.7s
# 36:	learn: 0.3636520	total: 561ms	remaining: 14.6s
# 37:	learn: 0.3578108	total: 573ms	remaining: 14.5s
# 38:	learn: 0.3517489	total: 586ms	remaining: 14.4s
# 39:	learn: 0.3461235	total: 602ms	remaining: 14.4s
# 40:	learn: 0.3413196	total: 617ms	remaining: 14.4s
# 41:	learn: 0.3364509	total: 630ms	remaining: 14.4s
# 42:	learn: 0.3314065	total: 646ms	remaining: 14.4s
# 43:	learn: 0.3266402	total: 660ms	remaining: 14.3s
# 44:	learn: 0.3219889	total: 673ms	remaining: 14.3s
# 45:	learn: 0.3165826	total: 685ms	remaining: 14.2s
# 46:	learn: 0.3119179	total: 697ms	remaining: 14.1s
# 47:	learn: 0.3068986	total: 710ms	remaining: 14.1s
# 48:	learn: 0.3020894	total: 722ms	remaining: 14s
# 49:	learn: 0.2975581	total: 732ms	remaining: 13.9s
# 50:	learn: 0.2931695	total: 746ms	remaining: 13.9s
# 51:	learn: 0.2888433	total: 759ms	remaining: 13.8s
# 52:	learn: 0.2851837	total: 771ms	remaining: 13.8s
# 53:	learn: 0.2805818	total: 781ms	remaining: 13.7s
# 54:	learn: 0.2767680	total: 793ms	remaining: 13.6s
# 55:	learn: 0.2733590	total: 806ms	remaining: 13.6s
# 56:	learn: 0.2695540	total: 818ms	remaining: 13.5s
# 57:	learn: 0.2652833	total: 827ms	remaining: 13.4s
# 58:	learn: 0.2616599	total: 835ms	remaining: 13.3s
# 59:	learn: 0.2582422	total: 851ms	remaining: 13.3s
# 60:	learn: 0.2545351	total: 867ms	remaining: 13.4s
# 61:	learn: 0.2514733	total: 884ms	remaining: 13.4s
# 62:	learn: 0.2480313	total: 911ms	remaining: 13.6s
# 63:	learn: 0.2444069	total: 923ms	remaining: 13.5s
# 64:	learn: 0.2409965	total: 934ms	remaining: 13.4s
# 65:	learn: 0.2369983	total: 943ms	remaining: 13.4s
# 66:	learn: 0.2343607	total: 960ms	remaining: 13.4s
# 67:	learn: 0.2306880	total: 969ms	remaining: 13.3s
# 68:	learn: 0.2274790	total: 983ms	remaining: 13.3s
# 69:	learn: 0.2249192	total: 994ms	remaining: 13.2s
# 70:	learn: 0.2219531	total: 1.01s	remaining: 13.2s
# 71:	learn: 0.2191030	total: 1.02s	remaining: 13.2s
# 72:	learn: 0.2165758	total: 1.04s	remaining: 13.2s
# 73:	learn: 0.2140323	total: 1.05s	remaining: 13.1s
# 74:	learn: 0.2109780	total: 1.06s	remaining: 13.1s
# 75:	learn: 0.2083616	total: 1.07s	remaining: 13.1s
# 76:	learn: 0.2059309	total: 1.09s	remaining: 13.1s
# 77:	learn: 0.2031046	total: 1.1s	remaining: 13s
# 78:	learn: 0.2006227	total: 1.11s	remaining: 13s
# 79:	learn: 0.1978358	total: 1.13s	remaining: 13s
# 80:	learn: 0.1953918	total: 1.14s	remaining: 13s
# 81:	learn: 0.1930286	total: 1.16s	remaining: 12.9s
# 82:	learn: 0.1912606	total: 1.17s	remaining: 12.9s
# 83:	learn: 0.1893246	total: 1.19s	remaining: 12.9s
# 84:	learn: 0.1870736	total: 1.2s	remaining: 12.9s
# 85:	learn: 0.1846050	total: 1.21s	remaining: 12.9s
# 86:	learn: 0.1825785	total: 1.22s	remaining: 12.9s
# 87:	learn: 0.1804650	total: 1.24s	remaining: 12.8s
# 88:	learn: 0.1783248	total: 1.25s	remaining: 12.8s
# 89:	learn: 0.1767195	total: 1.27s	remaining: 12.8s
# 90:	learn: 0.1748082	total: 1.28s	remaining: 12.8s
# 91:	learn: 0.1729402	total: 1.29s	remaining: 12.8s
# 92:	learn: 0.1709100	total: 1.31s	remaining: 12.8s
# 93:	learn: 0.1692031	total: 1.32s	remaining: 12.7s
# 94:	learn: 0.1671510	total: 1.34s	remaining: 12.7s
# 95:	learn: 0.1652904	total: 1.35s	remaining: 12.7s
# 96:	learn: 0.1631752	total: 1.36s	remaining: 12.7s
# 97:	learn: 0.1612502	total: 1.38s	remaining: 12.7s
# 98:	learn: 0.1597053	total: 1.39s	remaining: 12.7s
# 99:	learn: 0.1579598	total: 1.4s	remaining: 12.6s
# 100:	learn: 0.1564818	total: 1.42s	remaining: 12.6s
# 101:	learn: 0.1548748	total: 1.43s	remaining: 12.6s
# 102:	learn: 0.1532935	total: 1.44s	remaining: 12.5s
# 103:	learn: 0.1517242	total: 1.46s	remaining: 12.6s
# 104:	learn: 0.1499974	total: 1.48s	remaining: 12.6s
# 105:	learn: 0.1486288	total: 1.48s	remaining: 12.5s
# 106:	learn: 0.1469299	total: 1.5s	remaining: 12.5s
# 107:	learn: 0.1458360	total: 1.51s	remaining: 12.5s
# 108:	learn: 0.1443275	total: 1.52s	remaining: 12.4s
# 109:	learn: 0.1429395	total: 1.53s	remaining: 12.4s
# 110:	learn: 0.1414696	total: 1.54s	remaining: 12.4s
# 111:	learn: 0.1400508	total: 1.55s	remaining: 12.3s
# 112:	learn: 0.1383720	total: 1.57s	remaining: 12.3s
# 113:	learn: 0.1372528	total: 1.57s	remaining: 12.2s
# 114:	learn: 0.1357581	total: 1.58s	remaining: 12.2s
# 115:	learn: 0.1345522	total: 1.6s	remaining: 12.2s
# 116:	learn: 0.1336527	total: 1.61s	remaining: 12.2s
# 117:	learn: 0.1322134	total: 1.63s	remaining: 12.2s
# 118:	learn: 0.1308538	total: 1.64s	remaining: 12.1s
# 119:	learn: 0.1299079	total: 1.65s	remaining: 12.1s
# 120:	learn: 0.1283952	total: 1.66s	remaining: 12s
# 121:	learn: 0.1274008	total: 1.67s	remaining: 12s
# 122:	learn: 0.1260169	total: 1.69s	remaining: 12s
# 123:	learn: 0.1247906	total: 1.7s	remaining: 12s
# 124:	learn: 0.1236367	total: 1.71s	remaining: 12s
# 125:	learn: 0.1226146	total: 1.73s	remaining: 12s
# 126:	learn: 0.1215882	total: 1.74s	remaining: 12s
# 127:	learn: 0.1208149	total: 1.75s	remaining: 12s
# 128:	learn: 0.1195076	total: 1.76s	remaining: 11.9s
# 129:	learn: 0.1183999	total: 1.78s	remaining: 11.9s
# 130:	learn: 0.1173604	total: 1.79s	remaining: 11.9s
# 131:	learn: 0.1163585	total: 1.8s	remaining: 11.9s
# 132:	learn: 0.1152112	total: 1.81s	remaining: 11.8s
# 133:	learn: 0.1142651	total: 1.82s	remaining: 11.8s
# 134:	learn: 0.1134354	total: 1.83s	remaining: 11.7s
# 135:	learn: 0.1125216	total: 1.85s	remaining: 11.7s
# 136:	learn: 0.1115011	total: 1.86s	remaining: 11.7s
# 137:	learn: 0.1106921	total: 1.88s	remaining: 11.7s
# 138:	learn: 0.1097965	total: 1.89s	remaining: 11.7s
# 139:	learn: 0.1087198	total: 1.91s	remaining: 11.7s
# 140:	learn: 0.1077670	total: 1.93s	remaining: 11.7s
# 141:	learn: 0.1068694	total: 1.94s	remaining: 11.7s
# 142:	learn: 0.1059915	total: 1.95s	remaining: 11.7s
# 143:	learn: 0.1053804	total: 1.96s	remaining: 11.7s
# 144:	learn: 0.1042563	total: 1.97s	remaining: 11.6s
# 145:	learn: 0.1034013	total: 2s	remaining: 11.7s
# 146:	learn: 0.1025994	total: 2.02s	remaining: 11.7s
# 147:	learn: 0.1017246	total: 2.04s	remaining: 11.7s
# 148:	learn: 0.1008641	total: 2.04s	remaining: 11.7s
# 149:	learn: 0.1002601	total: 2.06s	remaining: 11.7s
# 150:	learn: 0.0996596	total: 2.08s	remaining: 11.7s
# 151:	learn: 0.0988412	total: 2.08s	remaining: 11.6s
# 152:	learn: 0.0982182	total: 2.1s	remaining: 11.6s
# 153:	learn: 0.0970873	total: 2.11s	remaining: 11.6s
# 154:	learn: 0.0963212	total: 2.12s	remaining: 11.6s
# 155:	learn: 0.0952925	total: 2.13s	remaining: 11.5s
# 156:	learn: 0.0947387	total: 2.14s	remaining: 11.5s
# 157:	learn: 0.0940067	total: 2.15s	remaining: 11.5s
# 158:	learn: 0.0934122	total: 2.16s	remaining: 11.4s
# 159:	learn: 0.0927815	total: 2.17s	remaining: 11.4s
# 160:	learn: 0.0920698	total: 2.19s	remaining: 11.4s
# 161:	learn: 0.0913954	total: 2.2s	remaining: 11.4s
# 162:	learn: 0.0907470	total: 2.21s	remaining: 11.4s
# 163:	learn: 0.0899761	total: 2.23s	remaining: 11.4s
# 164:	learn: 0.0893239	total: 2.25s	remaining: 11.4s
# 165:	learn: 0.0888433	total: 2.26s	remaining: 11.4s
# 166:	learn: 0.0882934	total: 2.27s	remaining: 11.3s
# 167:	learn: 0.0875610	total: 2.28s	remaining: 11.3s
# 168:	learn: 0.0869309	total: 2.3s	remaining: 11.3s
# 169:	learn: 0.0862221	total: 2.34s	remaining: 11.4s
# 170:	learn: 0.0855720	total: 2.36s	remaining: 11.4s
# 171:	learn: 0.0850140	total: 2.37s	remaining: 11.4s
# 172:	learn: 0.0846500	total: 2.38s	remaining: 11.4s
# 173:	learn: 0.0840158	total: 2.4s	remaining: 11.4s
# 174:	learn: 0.0834019	total: 2.42s	remaining: 11.4s
# 175:	learn: 0.0828348	total: 2.43s	remaining: 11.4s
# 176:	learn: 0.0821249	total: 2.45s	remaining: 11.4s
# 177:	learn: 0.0815234	total: 2.46s	remaining: 11.4s
# 178:	learn: 0.0808761	total: 2.48s	remaining: 11.4s
# 179:	learn: 0.0802197	total: 2.49s	remaining: 11.4s
# 180:	learn: 0.0795909	total: 2.51s	remaining: 11.4s
# 181:	learn: 0.0789693	total: 2.53s	remaining: 11.4s
# 182:	learn: 0.0784730	total: 2.54s	remaining: 11.3s
# 183:	learn: 0.0778971	total: 2.56s	remaining: 11.4s
# 184:	learn: 0.0773680	total: 2.57s	remaining: 11.3s
# 185:	learn: 0.0769220	total: 2.59s	remaining: 11.3s
# 186:	learn: 0.0763768	total: 2.6s	remaining: 11.3s
# 187:	learn: 0.0759389	total: 2.61s	remaining: 11.3s
# 188:	learn: 0.0753941	total: 2.62s	remaining: 11.3s
# 189:	learn: 0.0749824	total: 2.64s	remaining: 11.3s
# 190:	learn: 0.0744068	total: 2.65s	remaining: 11.2s
# 191:	learn: 0.0739279	total: 2.67s	remaining: 11.3s
# 192:	learn: 0.0735136	total: 2.69s	remaining: 11.2s
# 193:	learn: 0.0730877	total: 2.7s	remaining: 11.2s
# 194:	learn: 0.0726106	total: 2.72s	remaining: 11.2s
# 195:	learn: 0.0721169	total: 2.73s	remaining: 11.2s
# 196:	learn: 0.0716937	total: 2.75s	remaining: 11.2s
# 197:	learn: 0.0713525	total: 2.77s	remaining: 11.2s
# 198:	learn: 0.0708627	total: 2.78s	remaining: 11.2s
# 199:	learn: 0.0704203	total: 2.79s	remaining: 11.2s
# 200:	learn: 0.0699829	total: 2.8s	remaining: 11.1s
# 201:	learn: 0.0694565	total: 2.82s	remaining: 11.1s
# 202:	learn: 0.0690237	total: 2.83s	remaining: 11.1s
# 203:	learn: 0.0684802	total: 2.85s	remaining: 11.1s
# 204:	learn: 0.0679161	total: 2.86s	remaining: 11.1s
# 205:	learn: 0.0676214	total: 2.87s	remaining: 11.1s
# 206:	learn: 0.0671346	total: 2.88s	remaining: 11.1s
# 207:	learn: 0.0668201	total: 2.89s	remaining: 11s
# 208:	learn: 0.0664425	total: 2.9s	remaining: 11s
# 209:	learn: 0.0659393	total: 2.9s	remaining: 10.9s
# 210:	learn: 0.0655007	total: 2.92s	remaining: 10.9s
# 211:	learn: 0.0650844	total: 2.94s	remaining: 10.9s
# 212:	learn: 0.0648533	total: 2.96s	remaining: 10.9s
# 213:	learn: 0.0644056	total: 3s	remaining: 11s
# 214:	learn: 0.0639302	total: 3.02s	remaining: 11s
# 215:	learn: 0.0636056	total: 3.04s	remaining: 11s
# 216:	learn: 0.0632125	total: 3.06s	remaining: 11s
# 217:	learn: 0.0627924	total: 3.07s	remaining: 11s
# 218:	learn: 0.0624578	total: 3.08s	remaining: 11s
# 219:	learn: 0.0620511	total: 3.1s	remaining: 11s
# 220:	learn: 0.0617175	total: 3.12s	remaining: 11s
# 221:	learn: 0.0613960	total: 3.13s	remaining: 11s
# 222:	learn: 0.0610501	total: 3.15s	remaining: 11s
# 223:	learn: 0.0606922	total: 3.16s	remaining: 11s
# 224:	learn: 0.0603803	total: 3.17s	remaining: 10.9s
# 225:	learn: 0.0599571	total: 3.18s	remaining: 10.9s
# 226:	learn: 0.0596856	total: 3.19s	remaining: 10.9s
# 227:	learn: 0.0593793	total: 3.19s	remaining: 10.8s
# 228:	learn: 0.0590779	total: 3.2s	remaining: 10.8s
# 229:	learn: 0.0586581	total: 3.22s	remaining: 10.8s
# 230:	learn: 0.0582183	total: 3.24s	remaining: 10.8s
# 231:	learn: 0.0579915	total: 3.25s	remaining: 10.8s
# 232:	learn: 0.0576436	total: 3.27s	remaining: 10.8s
# 233:	learn: 0.0572532	total: 3.28s	remaining: 10.7s
# 234:	learn: 0.0570757	total: 3.29s	remaining: 10.7s
# 235:	learn: 0.0567911	total: 3.3s	remaining: 10.7s
# 236:	learn: 0.0564462	total: 3.31s	remaining: 10.7s
# 237:	learn: 0.0559941	total: 3.33s	remaining: 10.7s
# 238:	learn: 0.0557432	total: 3.34s	remaining: 10.6s
# 239:	learn: 0.0554631	total: 3.35s	remaining: 10.6s
# 240:	learn: 0.0551477	total: 3.36s	remaining: 10.6s
# 241:	learn: 0.0548167	total: 3.37s	remaining: 10.5s
# 242:	learn: 0.0545728	total: 3.37s	remaining: 10.5s
# 243:	learn: 0.0542781	total: 3.38s	remaining: 10.5s
# 244:	learn: 0.0539773	total: 3.39s	remaining: 10.4s
# 245:	learn: 0.0537711	total: 3.4s	remaining: 10.4s
# 246:	learn: 0.0534530	total: 3.4s	remaining: 10.4s
# 247:	learn: 0.0532343	total: 3.42s	remaining: 10.4s
# 248:	learn: 0.0529096	total: 3.44s	remaining: 10.4s
# 249:	learn: 0.0526528	total: 3.46s	remaining: 10.4s
# 250:	learn: 0.0523594	total: 3.48s	remaining: 10.4s
# 251:	learn: 0.0521178	total: 3.49s	remaining: 10.4s
# 252:	learn: 0.0517791	total: 3.5s	remaining: 10.3s
# 253:	learn: 0.0515906	total: 3.51s	remaining: 10.3s
# 254:	learn: 0.0513882	total: 3.52s	remaining: 10.3s
# 255:	learn: 0.0511342	total: 3.52s	remaining: 10.2s
# 256:	learn: 0.0509063	total: 3.53s	remaining: 10.2s
# 257:	learn: 0.0507115	total: 3.54s	remaining: 10.2s
# 258:	learn: 0.0504266	total: 3.55s	remaining: 10.2s
# 259:	learn: 0.0502259	total: 3.56s	remaining: 10.1s
# 260:	learn: 0.0499764	total: 3.57s	remaining: 10.1s
# 261:	learn: 0.0497736	total: 3.58s	remaining: 10.1s
# 262:	learn: 0.0496104	total: 3.59s	remaining: 10.1s
# 263:	learn: 0.0493318	total: 3.6s	remaining: 10s
# 264:	learn: 0.0491197	total: 3.61s	remaining: 10s
# 265:	learn: 0.0488913	total: 3.63s	remaining: 10s
# 266:	learn: 0.0486553	total: 3.66s	remaining: 10s
# 267:	learn: 0.0484308	total: 3.67s	remaining: 10s
# 268:	learn: 0.0481721	total: 3.68s	remaining: 10s
# 269:	learn: 0.0479104	total: 3.69s	remaining: 9.98s
# 270:	learn: 0.0476419	total: 3.7s	remaining: 9.95s
# 271:	learn: 0.0473687	total: 3.71s	remaining: 9.93s
# 272:	learn: 0.0471597	total: 3.73s	remaining: 9.92s
# 273:	learn: 0.0470486	total: 3.75s	remaining: 9.93s
# 274:	learn: 0.0468429	total: 3.76s	remaining: 9.92s
# 275:	learn: 0.0466202	total: 3.78s	remaining: 9.92s
# 276:	learn: 0.0463757	total: 3.81s	remaining: 9.94s
# 277:	learn: 0.0462088	total: 3.81s	remaining: 9.91s
# 278:	learn: 0.0459507	total: 3.83s	remaining: 9.89s
# 279:	learn: 0.0457255	total: 3.84s	remaining: 9.87s
# 280:	learn: 0.0455184	total: 3.85s	remaining: 9.85s
# 281:	learn: 0.0452593	total: 3.86s	remaining: 9.82s
# 282:	learn: 0.0450487	total: 3.86s	remaining: 9.79s
# 283:	learn: 0.0448369	total: 3.87s	remaining: 9.77s
# 284:	learn: 0.0446254	total: 3.9s	remaining: 9.78s
# 285:	learn: 0.0443803	total: 3.92s	remaining: 9.8s
# 286:	learn: 0.0441308	total: 3.96s	remaining: 9.83s
# 287:	learn: 0.0439152	total: 3.99s	remaining: 9.86s
# 288:	learn: 0.0437008	total: 4s	remaining: 9.84s
# 289:	learn: 0.0434606	total: 4.02s	remaining: 9.84s
# 290:	learn: 0.0432914	total: 4.04s	remaining: 9.84s
# 291:	learn: 0.0431052	total: 4.05s	remaining: 9.83s
# 292:	learn: 0.0429426	total: 4.07s	remaining: 9.81s
# 293:	learn: 0.0428161	total: 4.08s	remaining: 9.79s
# 294:	learn: 0.0426717	total: 4.09s	remaining: 9.78s
# 295:	learn: 0.0425577	total: 4.12s	remaining: 9.8s
# 296:	learn: 0.0423944	total: 4.15s	remaining: 9.82s
# 297:	learn: 0.0422004	total: 4.18s	remaining: 9.85s
# 298:	learn: 0.0419535	total: 4.2s	remaining: 9.86s
# 299:	learn: 0.0418162	total: 4.22s	remaining: 9.86s
# 300:	learn: 0.0416570	total: 4.25s	remaining: 9.86s
# 301:	learn: 0.0415368	total: 4.27s	remaining: 9.86s
# 302:	learn: 0.0412988	total: 4.29s	remaining: 9.86s
# 303:	learn: 0.0411570	total: 4.3s	remaining: 9.84s
# 304:	learn: 0.0409708	total: 4.31s	remaining: 9.82s
# 305:	learn: 0.0408085	total: 4.32s	remaining: 9.8s
# 306:	learn: 0.0406117	total: 4.33s	remaining: 9.77s
# 307:	learn: 0.0404022	total: 4.35s	remaining: 9.77s
# 308:	learn: 0.0402204	total: 4.37s	remaining: 9.77s
# 309:	learn: 0.0400113	total: 4.38s	remaining: 9.75s
# 310:	learn: 0.0398732	total: 4.4s	remaining: 9.75s
# 311:	learn: 0.0397008	total: 4.42s	remaining: 9.74s
# 312:	learn: 0.0395567	total: 4.43s	remaining: 9.73s
# 313:	learn: 0.0393971	total: 4.45s	remaining: 9.71s
# 314:	learn: 0.0391810	total: 4.46s	remaining: 9.7s
# 315:	learn: 0.0390463	total: 4.49s	remaining: 9.71s
# 316:	learn: 0.0388531	total: 4.51s	remaining: 9.71s
# 317:	learn: 0.0386552	total: 4.52s	remaining: 9.7s
# 318:	learn: 0.0385320	total: 4.54s	remaining: 9.69s
# 319:	learn: 0.0384133	total: 4.55s	remaining: 9.68s
# 320:	learn: 0.0382804	total: 4.57s	remaining: 9.67s
# 321:	learn: 0.0381348	total: 4.58s	remaining: 9.65s
# 322:	learn: 0.0379882	total: 4.59s	remaining: 9.63s
# 323:	learn: 0.0378093	total: 4.61s	remaining: 9.61s
# 324:	learn: 0.0376998	total: 4.62s	remaining: 9.59s
# 325:	learn: 0.0375768	total: 4.63s	remaining: 9.57s
# 326:	learn: 0.0373875	total: 4.64s	remaining: 9.55s
# 327:	learn: 0.0372237	total: 4.65s	remaining: 9.53s
# 328:	learn: 0.0370822	total: 4.67s	remaining: 9.54s
# 329:	learn: 0.0369460	total: 4.7s	remaining: 9.54s
# 330:	learn: 0.0367923	total: 4.74s	remaining: 9.57s
# 331:	learn: 0.0366598	total: 4.76s	remaining: 9.58s
# 332:	learn: 0.0364905	total: 4.78s	remaining: 9.58s
# 333:	learn: 0.0363249	total: 4.8s	remaining: 9.57s
# 334:	learn: 0.0361484	total: 4.82s	remaining: 9.57s
# 335:	learn: 0.0359815	total: 4.83s	remaining: 9.55s
# 336:	learn: 0.0358519	total: 4.86s	remaining: 9.57s
# 337:	learn: 0.0357594	total: 4.87s	remaining: 9.54s
# 338:	learn: 0.0356094	total: 4.91s	remaining: 9.57s
# 339:	learn: 0.0354596	total: 4.93s	remaining: 9.57s
# 340:	learn: 0.0352914	total: 4.93s	remaining: 9.54s
# 341:	learn: 0.0351542	total: 4.95s	remaining: 9.51s
# 342:	learn: 0.0350288	total: 4.95s	remaining: 9.49s
# 343:	learn: 0.0349168	total: 4.97s	remaining: 9.49s
# 344:	learn: 0.0348162	total: 5s	remaining: 9.5s
# 345:	learn: 0.0346732	total: 5.03s	remaining: 9.5s
# 346:	learn: 0.0345539	total: 5.04s	remaining: 9.48s
# 347:	learn: 0.0343888	total: 5.06s	remaining: 9.49s
# 348:	learn: 0.0343413	total: 5.08s	remaining: 9.47s
# 349:	learn: 0.0342192	total: 5.1s	remaining: 9.48s
# 350:	learn: 0.0340967	total: 5.12s	remaining: 9.47s
# 351:	learn: 0.0339756	total: 5.13s	remaining: 9.45s
# 352:	learn: 0.0338952	total: 5.15s	remaining: 9.43s
# 353:	learn: 0.0337756	total: 5.16s	remaining: 9.42s
# 354:	learn: 0.0336284	total: 5.17s	remaining: 9.4s
# 355:	learn: 0.0335014	total: 5.18s	remaining: 9.38s
# 356:	learn: 0.0333606	total: 5.2s	remaining: 9.36s
# 357:	learn: 0.0332153	total: 5.2s	remaining: 9.33s
# 358:	learn: 0.0330864	total: 5.21s	remaining: 9.31s
# 359:	learn: 0.0329728	total: 5.22s	remaining: 9.29s
# 360:	learn: 0.0328304	total: 5.23s	remaining: 9.26s
# 361:	learn: 0.0327258	total: 5.24s	remaining: 9.24s
# 362:	learn: 0.0326359	total: 5.26s	remaining: 9.23s
# 363:	learn: 0.0324584	total: 5.28s	remaining: 9.22s
# 364:	learn: 0.0323463	total: 5.29s	remaining: 9.2s
# 365:	learn: 0.0322075	total: 5.3s	remaining: 9.18s
# 366:	learn: 0.0320671	total: 5.31s	remaining: 9.16s
# 367:	learn: 0.0319160	total: 5.32s	remaining: 9.14s
# 368:	learn: 0.0318123	total: 5.33s	remaining: 9.12s
# 369:	learn: 0.0316894	total: 5.35s	remaining: 9.11s
# 370:	learn: 0.0316041	total: 5.37s	remaining: 9.11s
# 371:	learn: 0.0315081	total: 5.39s	remaining: 9.1s
# 372:	learn: 0.0314145	total: 5.4s	remaining: 9.08s
# 373:	learn: 0.0313491	total: 5.42s	remaining: 9.07s
# 374:	learn: 0.0312781	total: 5.44s	remaining: 9.07s
# 375:	learn: 0.0311646	total: 5.46s	remaining: 9.07s
# 376:	learn: 0.0310166	total: 5.48s	remaining: 9.06s
# 377:	learn: 0.0309089	total: 5.5s	remaining: 9.05s
# 378:	learn: 0.0307873	total: 5.51s	remaining: 9.02s
# 379:	learn: 0.0306780	total: 5.53s	remaining: 9.03s
# 380:	learn: 0.0305704	total: 5.54s	remaining: 9.01s
# 381:	learn: 0.0304711	total: 5.55s	remaining: 8.99s
# 382:	learn: 0.0303813	total: 5.56s	remaining: 8.96s
# 383:	learn: 0.0302823	total: 5.57s	remaining: 8.94s
# 384:	learn: 0.0301501	total: 5.59s	remaining: 8.93s
# 385:	learn: 0.0300256	total: 5.6s	remaining: 8.9s
# 386:	learn: 0.0299369	total: 5.6s	remaining: 8.88s
# 387:	learn: 0.0298475	total: 5.61s	remaining: 8.85s
# 388:	learn: 0.0297244	total: 5.62s	remaining: 8.82s
# 389:	learn: 0.0296561	total: 5.62s	remaining: 8.8s
# 390:	learn: 0.0295785	total: 5.63s	remaining: 8.77s
# 391:	learn: 0.0294667	total: 5.64s	remaining: 8.75s
# 392:	learn: 0.0293629	total: 5.66s	remaining: 8.74s
# 393:	learn: 0.0292651	total: 5.71s	remaining: 8.78s
# 394:	learn: 0.0291856	total: 5.73s	remaining: 8.77s
# 395:	learn: 0.0290800	total: 5.74s	remaining: 8.76s
# 396:	learn: 0.0289944	total: 5.75s	remaining: 8.74s
# 397:	learn: 0.0289487	total: 5.76s	remaining: 8.71s
# 398:	learn: 0.0288737	total: 5.77s	remaining: 8.69s
# 399:	learn: 0.0287847	total: 5.78s	remaining: 8.66s
# 400:	learn: 0.0286926	total: 5.79s	remaining: 8.65s
# 401:	learn: 0.0286280	total: 5.8s	remaining: 8.62s
# 402:	learn: 0.0285026	total: 5.81s	remaining: 8.6s
# 403:	learn: 0.0284087	total: 5.82s	remaining: 8.58s
# 404:	learn: 0.0283363	total: 5.83s	remaining: 8.56s
# 405:	learn: 0.0282261	total: 5.83s	remaining: 8.54s
# 406:	learn: 0.0281244	total: 5.84s	remaining: 8.51s
# 407:	learn: 0.0280127	total: 5.85s	remaining: 8.48s
# 408:	learn: 0.0278973	total: 5.86s	remaining: 8.46s
# 409:	learn: 0.0278102	total: 5.86s	remaining: 8.44s
# 410:	learn: 0.0277417	total: 5.87s	remaining: 8.41s
# 411:	learn: 0.0276336	total: 5.88s	remaining: 8.4s
# 412:	learn: 0.0275558	total: 5.89s	remaining: 8.37s
# 413:	learn: 0.0274865	total: 5.91s	remaining: 8.37s
# 414:	learn: 0.0273979	total: 5.92s	remaining: 8.35s
# 415:	learn: 0.0272756	total: 5.94s	remaining: 8.34s
# 416:	learn: 0.0271881	total: 5.95s	remaining: 8.32s
# 417:	learn: 0.0270935	total: 5.96s	remaining: 8.3s
# 418:	learn: 0.0270066	total: 5.98s	remaining: 8.29s
# 419:	learn: 0.0269224	total: 5.99s	remaining: 8.27s
# 420:	learn: 0.0268784	total: 6s	remaining: 8.25s
# 421:	learn: 0.0268244	total: 6.01s	remaining: 8.24s
# 422:	learn: 0.0267290	total: 6.04s	remaining: 8.24s
# 423:	learn: 0.0266438	total: 6.05s	remaining: 8.22s
# 424:	learn: 0.0265823	total: 6.07s	remaining: 8.21s
# 425:	learn: 0.0265093	total: 6.07s	remaining: 8.19s
# 426:	learn: 0.0263864	total: 6.08s	remaining: 8.16s
# 427:	learn: 0.0263068	total: 6.1s	remaining: 8.15s
# 428:	learn: 0.0262605	total: 6.11s	remaining: 8.13s
# 429:	learn: 0.0262183	total: 6.12s	remaining: 8.11s
# 430:	learn: 0.0260971	total: 6.13s	remaining: 8.09s
# 431:	learn: 0.0260145	total: 6.15s	remaining: 8.09s
# 432:	learn: 0.0259517	total: 6.17s	remaining: 8.07s
# 433:	learn: 0.0258898	total: 6.17s	remaining: 8.05s
# 434:	learn: 0.0258264	total: 6.19s	remaining: 8.04s
# 435:	learn: 0.0257717	total: 6.2s	remaining: 8.02s
# 436:	learn: 0.0256776	total: 6.22s	remaining: 8.02s
# 437:	learn: 0.0255851	total: 6.24s	remaining: 8s
# 438:	learn: 0.0255044	total: 6.25s	remaining: 7.98s
# 439:	learn: 0.0254116	total: 6.25s	remaining: 7.96s
# 440:	learn: 0.0253489	total: 6.26s	remaining: 7.94s
# 441:	learn: 0.0252617	total: 6.27s	remaining: 7.91s
# 442:	learn: 0.0251615	total: 6.28s	remaining: 7.89s
# 443:	learn: 0.0251082	total: 6.28s	remaining: 7.87s
# 444:	learn: 0.0250171	total: 6.29s	remaining: 7.85s
# 445:	learn: 0.0249845	total: 6.3s	remaining: 7.83s
# 446:	learn: 0.0248968	total: 6.31s	remaining: 7.8s
# 447:	learn: 0.0248327	total: 6.32s	remaining: 7.78s
# 448:	learn: 0.0247665	total: 6.32s	remaining: 7.76s
# 449:	learn: 0.0246925	total: 6.33s	remaining: 7.74s
# 450:	learn: 0.0246095	total: 6.34s	remaining: 7.72s
# 451:	learn: 0.0245351	total: 6.36s	remaining: 7.71s
# 452:	learn: 0.0244790	total: 6.38s	remaining: 7.7s
# 453:	learn: 0.0244136	total: 6.39s	remaining: 7.69s
# 454:	learn: 0.0243584	total: 6.41s	remaining: 7.68s
# 455:	learn: 0.0242981	total: 6.43s	remaining: 7.67s
# 456:	learn: 0.0242202	total: 6.44s	remaining: 7.65s
# 457:	learn: 0.0241667	total: 6.45s	remaining: 7.63s
# 458:	learn: 0.0241075	total: 6.45s	remaining: 7.61s
# 459:	learn: 0.0240433	total: 6.46s	remaining: 7.58s
# 460:	learn: 0.0239713	total: 6.47s	remaining: 7.57s
# 461:	learn: 0.0239005	total: 6.48s	remaining: 7.54s
# 462:	learn: 0.0237989	total: 6.49s	remaining: 7.53s
# 463:	learn: 0.0237018	total: 6.5s	remaining: 7.51s
# 464:	learn: 0.0236270	total: 6.52s	remaining: 7.5s
# 465:	learn: 0.0235781	total: 6.54s	remaining: 7.49s
# 466:	learn: 0.0235094	total: 6.55s	remaining: 7.47s
# 467:	learn: 0.0234400	total: 6.56s	remaining: 7.46s
# 468:	learn: 0.0233884	total: 6.58s	remaining: 7.44s
# 469:	learn: 0.0233176	total: 6.59s	remaining: 7.43s
# 470:	learn: 0.0232551	total: 6.6s	remaining: 7.41s
# 471:	learn: 0.0232169	total: 6.61s	remaining: 7.4s
# 472:	learn: 0.0231620	total: 6.63s	remaining: 7.38s
# 473:	learn: 0.0230914	total: 6.64s	remaining: 7.37s
# 474:	learn: 0.0230233	total: 6.65s	remaining: 7.35s
# 475:	learn: 0.0229504	total: 6.67s	remaining: 7.34s
# 476:	learn: 0.0229010	total: 6.69s	remaining: 7.33s
# 477:	learn: 0.0228448	total: 6.7s	remaining: 7.32s
# 478:	learn: 0.0227690	total: 6.71s	remaining: 7.3s
# 479:	learn: 0.0227223	total: 6.73s	remaining: 7.29s
# 480:	learn: 0.0226734	total: 6.74s	remaining: 7.28s
# 481:	learn: 0.0225972	total: 6.76s	remaining: 7.27s
# 482:	learn: 0.0225369	total: 6.77s	remaining: 7.25s
# 483:	learn: 0.0224902	total: 6.79s	remaining: 7.23s
# 484:	learn: 0.0224058	total: 6.8s	remaining: 7.22s
# 485:	learn: 0.0223299	total: 6.81s	remaining: 7.21s
# 486:	learn: 0.0222706	total: 6.83s	remaining: 7.19s
# 487:	learn: 0.0221957	total: 6.84s	remaining: 7.17s
# 488:	learn: 0.0221448	total: 6.84s	remaining: 7.15s
# 489:	learn: 0.0220927	total: 6.85s	remaining: 7.13s
# 490:	learn: 0.0220209	total: 6.87s	remaining: 7.13s
# 491:	learn: 0.0219670	total: 6.88s	remaining: 7.11s
# 492:	learn: 0.0219154	total: 6.91s	remaining: 7.1s
# 493:	learn: 0.0218686	total: 6.93s	remaining: 7.1s
# 494:	learn: 0.0218145	total: 6.94s	remaining: 7.08s
# 495:	learn: 0.0217658	total: 6.96s	remaining: 7.07s
# 496:	learn: 0.0217087	total: 6.97s	remaining: 7.05s
# 497:	learn: 0.0216653	total: 6.98s	remaining: 7.03s
# 498:	learn: 0.0216238	total: 7s	remaining: 7.03s
# 499:	learn: 0.0215761	total: 7.01s	remaining: 7.01s
# 500:	learn: 0.0214893	total: 7.03s	remaining: 7s
# 501:	learn: 0.0214394	total: 7.05s	remaining: 7s
# 502:	learn: 0.0213728	total: 7.09s	remaining: 7s
# 503:	learn: 0.0212872	total: 7.11s	remaining: 7s
# 504:	learn: 0.0212108	total: 7.13s	remaining: 6.99s
# 505:	learn: 0.0211336	total: 7.15s	remaining: 6.98s
# 506:	learn: 0.0210957	total: 7.18s	remaining: 6.98s
# 507:	learn: 0.0210287	total: 7.2s	remaining: 6.97s
# 508:	learn: 0.0209807	total: 7.23s	remaining: 6.97s
# 509:	learn: 0.0208981	total: 7.24s	remaining: 6.96s
# 510:	learn: 0.0208468	total: 7.25s	remaining: 6.94s
# 511:	learn: 0.0208018	total: 7.27s	remaining: 6.92s
# 512:	learn: 0.0207465	total: 7.28s	remaining: 6.91s
# 513:	learn: 0.0206827	total: 7.29s	remaining: 6.89s
# 514:	learn: 0.0206337	total: 7.3s	remaining: 6.88s
# 515:	learn: 0.0205748	total: 7.32s	remaining: 6.87s
# 516:	learn: 0.0205410	total: 7.35s	remaining: 6.86s
# 517:	learn: 0.0204719	total: 7.36s	remaining: 6.85s
# 518:	learn: 0.0204382	total: 7.37s	remaining: 6.83s
# 519:	learn: 0.0203807	total: 7.39s	remaining: 6.83s
# 520:	learn: 0.0203147	total: 7.4s	remaining: 6.8s
# 521:	learn: 0.0202501	total: 7.45s	remaining: 6.82s
# 522:	learn: 0.0202044	total: 7.47s	remaining: 6.81s
# 523:	learn: 0.0201532	total: 7.49s	remaining: 6.8s
# 524:	learn: 0.0201026	total: 7.51s	remaining: 6.79s
# 525:	learn: 0.0200917	total: 7.53s	remaining: 6.79s
# 526:	learn: 0.0200102	total: 7.55s	remaining: 6.78s
# 527:	learn: 0.0199602	total: 7.57s	remaining: 6.77s
# 528:	learn: 0.0199192	total: 7.58s	remaining: 6.75s
# 529:	learn: 0.0198667	total: 7.6s	remaining: 6.74s
# 530:	learn: 0.0198148	total: 7.62s	remaining: 6.73s
# 531:	learn: 0.0197776	total: 7.64s	remaining: 6.72s
# 532:	learn: 0.0196889	total: 7.67s	remaining: 6.72s
# 533:	learn: 0.0196434	total: 7.68s	remaining: 6.71s
# 534:	learn: 0.0195791	total: 7.7s	remaining: 6.69s
# 535:	learn: 0.0195342	total: 7.73s	remaining: 6.69s
# 536:	learn: 0.0195052	total: 7.75s	remaining: 6.68s
# 537:	learn: 0.0194489	total: 7.76s	remaining: 6.67s
# 538:	learn: 0.0193977	total: 7.79s	remaining: 6.66s
# 539:	learn: 0.0193503	total: 7.8s	remaining: 6.65s
# 540:	learn: 0.0192912	total: 7.83s	remaining: 6.64s
# 541:	learn: 0.0192466	total: 7.85s	remaining: 6.63s
# 542:	learn: 0.0191920	total: 7.88s	remaining: 6.63s
# 543:	learn: 0.0191481	total: 7.9s	remaining: 6.62s
# 544:	learn: 0.0191119	total: 7.92s	remaining: 6.61s
# 545:	learn: 0.0190399	total: 7.95s	remaining: 6.61s
# 546:	learn: 0.0189995	total: 7.97s	remaining: 6.6s
# 547:	learn: 0.0189610	total: 7.99s	remaining: 6.59s
# 548:	learn: 0.0189205	total: 8.01s	remaining: 6.58s
# 549:	learn: 0.0188706	total: 8.02s	remaining: 6.56s
# 550:	learn: 0.0188181	total: 8.09s	remaining: 6.59s
# 551:	learn: 0.0187627	total: 8.12s	remaining: 6.59s
# 552:	learn: 0.0187054	total: 8.14s	remaining: 6.58s
# 553:	learn: 0.0186571	total: 8.16s	remaining: 6.57s
# 554:	learn: 0.0185896	total: 8.17s	remaining: 6.55s
# 555:	learn: 0.0185598	total: 8.2s	remaining: 6.54s
# 556:	learn: 0.0185082	total: 8.21s	remaining: 6.53s
# 557:	learn: 0.0184366	total: 8.22s	remaining: 6.51s
# 558:	learn: 0.0183940	total: 8.24s	remaining: 6.5s
# 559:	learn: 0.0183224	total: 8.26s	remaining: 6.49s
# 560:	learn: 0.0182843	total: 8.28s	remaining: 6.48s
# 561:	learn: 0.0182441	total: 8.29s	remaining: 6.46s
# 562:	learn: 0.0182013	total: 8.31s	remaining: 6.45s
# 563:	learn: 0.0181461	total: 8.33s	remaining: 6.44s
# 564:	learn: 0.0181149	total: 8.34s	remaining: 6.42s
# 565:	learn: 0.0180751	total: 8.35s	remaining: 6.4s
# 566:	learn: 0.0180176	total: 8.37s	remaining: 6.39s
# 567:	learn: 0.0179789	total: 8.39s	remaining: 6.38s
# 568:	learn: 0.0179165	total: 8.41s	remaining: 6.37s
# 569:	learn: 0.0178850	total: 8.43s	remaining: 6.36s
# 570:	learn: 0.0178416	total: 8.44s	remaining: 6.34s
# 571:	learn: 0.0177895	total: 8.45s	remaining: 6.32s
# 572:	learn: 0.0177465	total: 8.46s	remaining: 6.3s
# 573:	learn: 0.0177089	total: 8.47s	remaining: 6.28s
# 574:	learn: 0.0176785	total: 8.48s	remaining: 6.27s
# 575:	learn: 0.0176402	total: 8.5s	remaining: 6.26s
# 576:	learn: 0.0175662	total: 8.52s	remaining: 6.24s
# 577:	learn: 0.0175011	total: 8.53s	remaining: 6.23s
# 578:	learn: 0.0174622	total: 8.55s	remaining: 6.22s
# 579:	learn: 0.0174129	total: 8.57s	remaining: 6.21s
# 580:	learn: 0.0173757	total: 8.6s	remaining: 6.2s
# 581:	learn: 0.0173397	total: 8.62s	remaining: 6.19s
# 582:	learn: 0.0172585	total: 8.64s	remaining: 6.18s
# 583:	learn: 0.0172227	total: 8.65s	remaining: 6.16s
# 584:	learn: 0.0171909	total: 8.68s	remaining: 6.16s
# 585:	learn: 0.0171515	total: 8.71s	remaining: 6.15s
# 586:	learn: 0.0170921	total: 8.72s	remaining: 6.13s
# 587:	learn: 0.0170386	total: 8.73s	remaining: 6.12s
# 588:	learn: 0.0170006	total: 8.74s	remaining: 6.1s
# 589:	learn: 0.0169414	total: 8.76s	remaining: 6.08s
# 590:	learn: 0.0169021	total: 8.77s	remaining: 6.07s
# 591:	learn: 0.0168576	total: 8.78s	remaining: 6.05s
# 592:	learn: 0.0168000	total: 8.79s	remaining: 6.03s
# 593:	learn: 0.0167437	total: 8.79s	remaining: 6.01s
# 594:	learn: 0.0167070	total: 8.8s	remaining: 5.99s
# 595:	learn: 0.0166763	total: 8.82s	remaining: 5.98s
# 596:	learn: 0.0166391	total: 8.83s	remaining: 5.96s
# 597:	learn: 0.0166173	total: 8.85s	remaining: 5.95s
# 598:	learn: 0.0165925	total: 8.86s	remaining: 5.93s
# 599:	learn: 0.0165726	total: 8.88s	remaining: 5.92s
# 600:	learn: 0.0165427	total: 8.89s	remaining: 5.91s
# 601:	learn: 0.0164991	total: 8.91s	remaining: 5.89s
# 602:	learn: 0.0164500	total: 8.92s	remaining: 5.87s
# 603:	learn: 0.0163997	total: 8.93s	remaining: 5.85s
# 604:	learn: 0.0163632	total: 8.93s	remaining: 5.83s
# 605:	learn: 0.0163206	total: 8.94s	remaining: 5.81s
# 606:	learn: 0.0162676	total: 8.95s	remaining: 5.79s
# 607:	learn: 0.0162431	total: 8.95s	remaining: 5.77s
# 608:	learn: 0.0161959	total: 8.96s	remaining: 5.75s
# 609:	learn: 0.0161455	total: 8.97s	remaining: 5.73s
# 610:	learn: 0.0161167	total: 8.97s	remaining: 5.71s
# 611:	learn: 0.0160973	total: 8.98s	remaining: 5.69s
# 612:	learn: 0.0160396	total: 8.99s	remaining: 5.67s
# 613:	learn: 0.0160013	total: 8.99s	remaining: 5.65s
# 614:	learn: 0.0159811	total: 9.01s	remaining: 5.64s
# 615:	learn: 0.0159341	total: 9.01s	remaining: 5.62s
# 616:	learn: 0.0159021	total: 9.02s	remaining: 5.6s
# 617:	learn: 0.0158646	total: 9.03s	remaining: 5.58s
# 618:	learn: 0.0158357	total: 9.05s	remaining: 5.57s
# 619:	learn: 0.0158054	total: 9.06s	remaining: 5.56s
# 620:	learn: 0.0157756	total: 9.08s	remaining: 5.54s
# 621:	learn: 0.0157469	total: 9.09s	remaining: 5.52s
# 622:	learn: 0.0157064	total: 9.1s	remaining: 5.51s
# 623:	learn: 0.0156786	total: 9.11s	remaining: 5.49s
# 624:	learn: 0.0156344	total: 9.13s	remaining: 5.48s
# 625:	learn: 0.0155940	total: 9.15s	remaining: 5.46s
# 626:	learn: 0.0155555	total: 9.16s	remaining: 5.45s
# 627:	learn: 0.0155161	total: 9.16s	remaining: 5.43s
# 628:	learn: 0.0154848	total: 9.18s	remaining: 5.41s
# 629:	learn: 0.0154654	total: 9.19s	remaining: 5.39s
# 630:	learn: 0.0154467	total: 9.2s	remaining: 5.38s
# 631:	learn: 0.0154006	total: 9.21s	remaining: 5.36s
# 632:	learn: 0.0153592	total: 9.22s	remaining: 5.35s
# 633:	learn: 0.0153446	total: 9.24s	remaining: 5.33s
# 634:	learn: 0.0153073	total: 9.25s	remaining: 5.32s
# 635:	learn: 0.0152535	total: 9.26s	remaining: 5.3s
# 636:	learn: 0.0152273	total: 9.28s	remaining: 5.29s
# 637:	learn: 0.0151896	total: 9.29s	remaining: 5.27s
# 638:	learn: 0.0151412	total: 9.31s	remaining: 5.26s
# 639:	learn: 0.0151028	total: 9.32s	remaining: 5.24s
# 640:	learn: 0.0150608	total: 9.33s	remaining: 5.23s
# 641:	learn: 0.0150239	total: 9.34s	remaining: 5.21s
# 642:	learn: 0.0149891	total: 9.36s	remaining: 5.2s
# 643:	learn: 0.0149546	total: 9.38s	remaining: 5.18s
# 644:	learn: 0.0149231	total: 9.39s	remaining: 5.17s
# 645:	learn: 0.0149019	total: 9.4s	remaining: 5.15s
# 646:	learn: 0.0148760	total: 9.41s	remaining: 5.13s
# 647:	learn: 0.0148426	total: 9.42s	remaining: 5.12s
# 648:	learn: 0.0148100	total: 9.44s	remaining: 5.1s
# 649:	learn: 0.0147659	total: 9.45s	remaining: 5.09s
# 650:	learn: 0.0147239	total: 9.46s	remaining: 5.07s
# 651:	learn: 0.0146996	total: 9.47s	remaining: 5.06s
# 652:	learn: 0.0146706	total: 9.49s	remaining: 5.04s
# 653:	learn: 0.0146343	total: 9.5s	remaining: 5.03s
# 654:	learn: 0.0145926	total: 9.52s	remaining: 5.01s
# 655:	learn: 0.0145648	total: 9.53s	remaining: 5s
# 656:	learn: 0.0145310	total: 9.54s	remaining: 4.98s
# 657:	learn: 0.0144921	total: 9.56s	remaining: 4.97s
# 658:	learn: 0.0144623	total: 9.58s	remaining: 4.96s
# 659:	learn: 0.0144270	total: 9.59s	remaining: 4.94s
# 660:	learn: 0.0143747	total: 9.6s	remaining: 4.92s
# 661:	learn: 0.0143342	total: 9.62s	remaining: 4.91s
# 662:	learn: 0.0143040	total: 9.63s	remaining: 4.9s
# 663:	learn: 0.0142507	total: 9.65s	remaining: 4.88s
# 664:	learn: 0.0142261	total: 9.66s	remaining: 4.87s
# 665:	learn: 0.0141882	total: 9.68s	remaining: 4.85s
# 666:	learn: 0.0141627	total: 9.69s	remaining: 4.84s
# 667:	learn: 0.0141336	total: 9.7s	remaining: 4.82s
# 668:	learn: 0.0141023	total: 9.71s	remaining: 4.8s
# 669:	learn: 0.0140636	total: 9.72s	remaining: 4.79s
# 670:	learn: 0.0140230	total: 9.73s	remaining: 4.77s
# 671:	learn: 0.0139893	total: 9.74s	remaining: 4.75s
# 672:	learn: 0.0139450	total: 9.76s	remaining: 4.74s
# 673:	learn: 0.0139182	total: 9.77s	remaining: 4.73s
# 674:	learn: 0.0138947	total: 9.79s	remaining: 4.71s
# 675:	learn: 0.0138659	total: 9.8s	remaining: 4.7s
# 676:	learn: 0.0138375	total: 9.81s	remaining: 4.68s
# 677:	learn: 0.0138063	total: 9.84s	remaining: 4.67s
# 678:	learn: 0.0137742	total: 9.85s	remaining: 4.66s
# 679:	learn: 0.0137470	total: 9.86s	remaining: 4.64s
# 680:	learn: 0.0137180	total: 9.87s	remaining: 4.63s
# 681:	learn: 0.0136843	total: 9.88s	remaining: 4.61s
# 682:	learn: 0.0136580	total: 9.89s	remaining: 4.59s
# 683:	learn: 0.0136136	total: 9.9s	remaining: 4.58s
# 684:	learn: 0.0135680	total: 9.92s	remaining: 4.56s
# 685:	learn: 0.0135525	total: 9.93s	remaining: 4.54s
# 686:	learn: 0.0135375	total: 9.94s	remaining: 4.53s
# 687:	learn: 0.0135107	total: 9.97s	remaining: 4.52s
# 688:	learn: 0.0134734	total: 9.99s	remaining: 4.51s
# 689:	learn: 0.0134543	total: 10s	remaining: 4.49s
# 690:	learn: 0.0134238	total: 10s	remaining: 4.47s
# 691:	learn: 0.0133898	total: 10s	remaining: 4.46s
# 692:	learn: 0.0133646	total: 10s	remaining: 4.44s
# 693:	learn: 0.0133344	total: 10s	remaining: 4.42s
# 694:	learn: 0.0133162	total: 10s	remaining: 4.41s
# 695:	learn: 0.0132948	total: 10.1s	remaining: 4.39s
# 696:	learn: 0.0132647	total: 10.1s	remaining: 4.38s
# 697:	learn: 0.0132235	total: 10.1s	remaining: 4.37s
# 698:	learn: 0.0132127	total: 10.1s	remaining: 4.35s
# 699:	learn: 0.0131855	total: 10.1s	remaining: 4.33s
# 700:	learn: 0.0131605	total: 10.1s	remaining: 4.32s
# 701:	learn: 0.0131189	total: 10.2s	remaining: 4.31s
# 702:	learn: 0.0130799	total: 10.2s	remaining: 4.3s
# 703:	learn: 0.0130550	total: 10.2s	remaining: 4.29s
# 704:	learn: 0.0130176	total: 10.2s	remaining: 4.28s
# 705:	learn: 0.0129884	total: 10.3s	remaining: 4.27s
# 706:	learn: 0.0129806	total: 10.3s	remaining: 4.25s
# 707:	learn: 0.0129505	total: 10.3s	remaining: 4.24s
# 708:	learn: 0.0129061	total: 10.3s	remaining: 4.23s
# 709:	learn: 0.0128783	total: 10.3s	remaining: 4.21s
# 710:	learn: 0.0128483	total: 10.3s	remaining: 4.2s
# 711:	learn: 0.0128182	total: 10.3s	remaining: 4.18s
# 712:	learn: 0.0127913	total: 10.4s	remaining: 4.17s
# 713:	learn: 0.0127588	total: 10.4s	remaining: 4.15s
# 714:	learn: 0.0127211	total: 10.4s	remaining: 4.13s
# 715:	learn: 0.0126896	total: 10.4s	remaining: 4.12s
# 716:	learn: 0.0126552	total: 10.4s	remaining: 4.1s
# 717:	learn: 0.0126240	total: 10.4s	remaining: 4.08s
# 718:	learn: 0.0126146	total: 10.4s	remaining: 4.07s
# 719:	learn: 0.0125967	total: 10.4s	remaining: 4.05s
# 720:	learn: 0.0125596	total: 10.4s	remaining: 4.03s
# 721:	learn: 0.0125301	total: 10.4s	remaining: 4.02s
# 722:	learn: 0.0125033	total: 10.4s	remaining: 4s
# 723:	learn: 0.0124706	total: 10.4s	remaining: 3.98s
# 724:	learn: 0.0124479	total: 10.5s	remaining: 3.96s
# 725:	learn: 0.0124198	total: 10.5s	remaining: 3.95s
# 726:	learn: 0.0124048	total: 10.5s	remaining: 3.93s
# 727:	learn: 0.0123644	total: 10.5s	remaining: 3.92s
# 728:	learn: 0.0123352	total: 10.5s	remaining: 3.91s
# 729:	learn: 0.0123038	total: 10.5s	remaining: 3.89s
# 730:	learn: 0.0122876	total: 10.5s	remaining: 3.88s
# 731:	learn: 0.0122548	total: 10.5s	remaining: 3.86s
# 732:	learn: 0.0122228	total: 10.6s	remaining: 3.84s
# 733:	learn: 0.0121938	total: 10.6s	remaining: 3.83s
# 734:	learn: 0.0121594	total: 10.6s	remaining: 3.82s
# 735:	learn: 0.0121335	total: 10.6s	remaining: 3.81s
# 736:	learn: 0.0121016	total: 10.6s	remaining: 3.79s
# 737:	learn: 0.0120818	total: 10.6s	remaining: 3.78s
# 738:	learn: 0.0120659	total: 10.6s	remaining: 3.76s
# 739:	learn: 0.0120332	total: 10.7s	remaining: 3.74s
# 740:	learn: 0.0119939	total: 10.7s	remaining: 3.73s
# 741:	learn: 0.0119659	total: 10.7s	remaining: 3.71s
# 742:	learn: 0.0119342	total: 10.7s	remaining: 3.7s
# 743:	learn: 0.0119133	total: 10.7s	remaining: 3.68s
# 744:	learn: 0.0118878	total: 10.7s	remaining: 3.66s
# 745:	learn: 0.0118612	total: 10.7s	remaining: 3.65s
# 746:	learn: 0.0118430	total: 10.7s	remaining: 3.63s
# 747:	learn: 0.0118219	total: 10.7s	remaining: 3.62s
# 748:	learn: 0.0117873	total: 10.7s	remaining: 3.6s
# 749:	learn: 0.0117613	total: 10.7s	remaining: 3.58s
# 750:	learn: 0.0117366	total: 10.8s	remaining: 3.56s
# 751:	learn: 0.0117326	total: 10.8s	remaining: 3.55s
# 752:	learn: 0.0117011	total: 10.8s	remaining: 3.53s
# 753:	learn: 0.0116847	total: 10.8s	remaining: 3.52s
# 754:	learn: 0.0116574	total: 10.8s	remaining: 3.51s
# 755:	learn: 0.0116356	total: 10.8s	remaining: 3.49s
# 756:	learn: 0.0116018	total: 10.8s	remaining: 3.48s
# 757:	learn: 0.0115815	total: 10.9s	remaining: 3.47s
# 758:	learn: 0.0115479	total: 10.9s	remaining: 3.45s
# 759:	learn: 0.0115249	total: 10.9s	remaining: 3.44s
# 760:	learn: 0.0115134	total: 10.9s	remaining: 3.42s
# 761:	learn: 0.0115077	total: 10.9s	remaining: 3.41s
# 762:	learn: 0.0114849	total: 10.9s	remaining: 3.39s
# 763:	learn: 0.0114551	total: 10.9s	remaining: 3.38s
# 764:	learn: 0.0114346	total: 11s	remaining: 3.36s
# 765:	learn: 0.0114025	total: 11s	remaining: 3.35s
# 766:	learn: 0.0113704	total: 11s	remaining: 3.33s
# 767:	learn: 0.0113495	total: 11s	remaining: 3.32s
# 768:	learn: 0.0113440	total: 11s	remaining: 3.31s
# 769:	learn: 0.0113223	total: 11s	remaining: 3.29s
# 770:	learn: 0.0113028	total: 11s	remaining: 3.28s
# 771:	learn: 0.0112686	total: 11.1s	remaining: 3.27s
# 772:	learn: 0.0112482	total: 11.1s	remaining: 3.25s
# 773:	learn: 0.0112268	total: 11.1s	remaining: 3.24s
# 774:	learn: 0.0111931	total: 11.1s	remaining: 3.22s
# 775:	learn: 0.0111762	total: 11.1s	remaining: 3.21s
# 776:	learn: 0.0111390	total: 11.1s	remaining: 3.19s
# 777:	learn: 0.0111215	total: 11.1s	remaining: 3.18s
# 778:	learn: 0.0111031	total: 11.2s	remaining: 3.16s
# 779:	learn: 0.0110931	total: 11.2s	remaining: 3.15s
# 780:	learn: 0.0110846	total: 11.2s	remaining: 3.14s
# 781:	learn: 0.0110454	total: 11.2s	remaining: 3.12s
# 782:	learn: 0.0110184	total: 11.2s	remaining: 3.11s
# 783:	learn: 0.0109958	total: 11.2s	remaining: 3.09s
# 784:	learn: 0.0109732	total: 11.2s	remaining: 3.08s
# 785:	learn: 0.0109613	total: 11.3s	remaining: 3.06s
# 786:	learn: 0.0109464	total: 11.3s	remaining: 3.05s
# 787:	learn: 0.0109124	total: 11.3s	remaining: 3.03s
# 788:	learn: 0.0108933	total: 11.3s	remaining: 3.02s
# 789:	learn: 0.0108716	total: 11.3s	remaining: 3s
# 790:	learn: 0.0108489	total: 11.3s	remaining: 2.99s
# 791:	learn: 0.0108182	total: 11.3s	remaining: 2.98s
# 792:	learn: 0.0107996	total: 11.3s	remaining: 2.96s
# 793:	learn: 0.0107701	total: 11.3s	remaining: 2.94s
# 794:	learn: 0.0107573	total: 11.4s	remaining: 2.93s
# 795:	learn: 0.0107370	total: 11.4s	remaining: 2.91s
# 796:	learn: 0.0107335	total: 11.4s	remaining: 2.9s
# 797:	learn: 0.0107073	total: 11.4s	remaining: 2.88s
# 798:	learn: 0.0106837	total: 11.4s	remaining: 2.87s
# 799:	learn: 0.0106674	total: 11.4s	remaining: 2.85s
# 800:	learn: 0.0106470	total: 11.4s	remaining: 2.84s
# 801:	learn: 0.0106405	total: 11.4s	remaining: 2.83s
# 802:	learn: 0.0106125	total: 11.5s	remaining: 2.81s
# 803:	learn: 0.0105916	total: 11.5s	remaining: 2.79s
# 804:	learn: 0.0105754	total: 11.5s	remaining: 2.78s
# 805:	learn: 0.0105663	total: 11.5s	remaining: 2.77s
# 806:	learn: 0.0105561	total: 11.5s	remaining: 2.75s
# 807:	learn: 0.0105378	total: 11.5s	remaining: 2.74s
# 808:	learn: 0.0105336	total: 11.5s	remaining: 2.72s
# 809:	learn: 0.0105126	total: 11.5s	remaining: 2.71s
# 810:	learn: 0.0104947	total: 11.6s	remaining: 2.69s
# 811:	learn: 0.0104752	total: 11.6s	remaining: 2.68s
# 812:	learn: 0.0104525	total: 11.6s	remaining: 2.66s
# 813:	learn: 0.0104439	total: 11.6s	remaining: 2.65s
# 814:	learn: 0.0104183	total: 11.6s	remaining: 2.64s
# 815:	learn: 0.0104012	total: 11.6s	remaining: 2.62s
# 816:	learn: 0.0103828	total: 11.6s	remaining: 2.6s
# 817:	learn: 0.0103621	total: 11.6s	remaining: 2.59s
# 818:	learn: 0.0103534	total: 11.7s	remaining: 2.58s
# 819:	learn: 0.0103263	total: 11.7s	remaining: 2.56s
# 820:	learn: 0.0103071	total: 11.7s	remaining: 2.55s
# 821:	learn: 0.0102915	total: 11.7s	remaining: 2.54s
# 822:	learn: 0.0102752	total: 11.7s	remaining: 2.52s
# 823:	learn: 0.0102580	total: 11.7s	remaining: 2.51s
# 824:	learn: 0.0102527	total: 11.8s	remaining: 2.49s
# 825:	learn: 0.0102473	total: 11.8s	remaining: 2.48s
# 826:	learn: 0.0102134	total: 11.8s	remaining: 2.46s
# 827:	learn: 0.0101883	total: 11.8s	remaining: 2.45s
# 828:	learn: 0.0101770	total: 11.8s	remaining: 2.43s
# 829:	learn: 0.0101627	total: 11.8s	remaining: 2.42s
# 830:	learn: 0.0101482	total: 11.8s	remaining: 2.4s
# 831:	learn: 0.0101275	total: 11.8s	remaining: 2.39s
# 832:	learn: 0.0101021	total: 11.8s	remaining: 2.38s
# 833:	learn: 0.0100729	total: 11.9s	remaining: 2.36s
# 834:	learn: 0.0100482	total: 11.9s	remaining: 2.35s
# 835:	learn: 0.0100264	total: 11.9s	remaining: 2.33s
# 836:	learn: 0.0100048	total: 11.9s	remaining: 2.32s
# 837:	learn: 0.0099954	total: 11.9s	remaining: 2.3s
# 838:	learn: 0.0099943	total: 11.9s	remaining: 2.29s
# 839:	learn: 0.0099736	total: 11.9s	remaining: 2.27s
# 840:	learn: 0.0099454	total: 11.9s	remaining: 2.26s
# 841:	learn: 0.0099212	total: 12s	remaining: 2.24s
# 842:	learn: 0.0098985	total: 12s	remaining: 2.23s
# 843:	learn: 0.0098836	total: 12s	remaining: 2.21s
# 844:	learn: 0.0098652	total: 12s	remaining: 2.2s
# 845:	learn: 0.0098439	total: 12s	remaining: 2.19s
# 846:	learn: 0.0098263	total: 12s	remaining: 2.17s
# 847:	learn: 0.0098211	total: 12s	remaining: 2.16s
# 848:	learn: 0.0098029	total: 12s	remaining: 2.14s
# 849:	learn: 0.0097854	total: 12.1s	remaining: 2.13s
# 850:	learn: 0.0097609	total: 12.1s	remaining: 2.11s
# 851:	learn: 0.0097404	total: 12.1s	remaining: 2.1s
# 852:	learn: 0.0097213	total: 12.1s	remaining: 2.09s
# 853:	learn: 0.0097033	total: 12.1s	remaining: 2.07s
# 854:	learn: 0.0096805	total: 12.2s	remaining: 2.06s
# 855:	learn: 0.0096605	total: 12.2s	remaining: 2.05s
# 856:	learn: 0.0096561	total: 12.2s	remaining: 2.03s
# 857:	learn: 0.0096346	total: 12.2s	remaining: 2.02s
# 858:	learn: 0.0096098	total: 12.2s	remaining: 2.01s
# 859:	learn: 0.0095794	total: 12.2s	remaining: 1.99s
# 860:	learn: 0.0095695	total: 12.3s	remaining: 1.98s
# 861:	learn: 0.0095343	total: 12.3s	remaining: 1.96s
# 862:	learn: 0.0095184	total: 12.3s	remaining: 1.95s
# 863:	learn: 0.0094948	total: 12.3s	remaining: 1.93s
# 864:	learn: 0.0094715	total: 12.3s	remaining: 1.92s
# 865:	learn: 0.0094484	total: 12.3s	remaining: 1.9s
# 866:	learn: 0.0094320	total: 12.3s	remaining: 1.89s
# 867:	learn: 0.0094220	total: 12.3s	remaining: 1.87s
# 868:	learn: 0.0094052	total: 12.3s	remaining: 1.86s
# 869:	learn: 0.0093857	total: 12.3s	remaining: 1.84s
# 870:	learn: 0.0093643	total: 12.3s	remaining: 1.83s
# 871:	learn: 0.0093492	total: 12.4s	remaining: 1.81s
# 872:	learn: 0.0093330	total: 12.4s	remaining: 1.8s
# 873:	learn: 0.0093074	total: 12.4s	remaining: 1.78s
# 874:	learn: 0.0092897	total: 12.4s	remaining: 1.77s
# 875:	learn: 0.0092817	total: 12.4s	remaining: 1.76s
# 876:	learn: 0.0092638	total: 12.4s	remaining: 1.74s
# 877:	learn: 0.0092427	total: 12.4s	remaining: 1.73s
# 878:	learn: 0.0092304	total: 12.5s	remaining: 1.71s
# 879:	learn: 0.0092061	total: 12.5s	remaining: 1.7s
# 880:	learn: 0.0091854	total: 12.5s	remaining: 1.68s
# 881:	learn: 0.0091646	total: 12.5s	remaining: 1.67s
# 882:	learn: 0.0091513	total: 12.5s	remaining: 1.66s
# 883:	learn: 0.0091304	total: 12.5s	remaining: 1.64s
# 884:	learn: 0.0091232	total: 12.5s	remaining: 1.63s
# 885:	learn: 0.0091217	total: 12.6s	remaining: 1.61s
# 886:	learn: 0.0090985	total: 12.6s	remaining: 1.6s
# 887:	learn: 0.0090790	total: 12.6s	remaining: 1.59s
# 888:	learn: 0.0090562	total: 12.6s	remaining: 1.57s
# 889:	learn: 0.0090498	total: 12.6s	remaining: 1.56s
# 890:	learn: 0.0090408	total: 12.6s	remaining: 1.54s
# 891:	learn: 0.0090242	total: 12.6s	remaining: 1.53s
# 892:	learn: 0.0090220	total: 12.7s	remaining: 1.51s
# 893:	learn: 0.0089963	total: 12.7s	remaining: 1.5s
# 894:	learn: 0.0089802	total: 12.7s	remaining: 1.49s
# 895:	learn: 0.0089632	total: 12.7s	remaining: 1.47s
# 896:	learn: 0.0089496	total: 12.7s	remaining: 1.46s
# 897:	learn: 0.0089352	total: 12.7s	remaining: 1.44s
# 898:	learn: 0.0089174	total: 12.7s	remaining: 1.43s
# 899:	learn: 0.0089001	total: 12.7s	remaining: 1.41s
# 900:	learn: 0.0088868	total: 12.7s	remaining: 1.4s
# 901:	learn: 0.0088787	total: 12.7s	remaining: 1.38s
# 902:	learn: 0.0088498	total: 12.7s	remaining: 1.37s
# 903:	learn: 0.0088396	total: 12.7s	remaining: 1.35s
# 904:	learn: 0.0088146	total: 12.8s	remaining: 1.34s
# 905:	learn: 0.0088036	total: 12.8s	remaining: 1.32s
# 906:	learn: 0.0088020	total: 12.8s	remaining: 1.31s
# 907:	learn: 0.0087876	total: 12.8s	remaining: 1.29s
# 908:	learn: 0.0087687	total: 12.8s	remaining: 1.28s
# 909:	learn: 0.0087552	total: 12.8s	remaining: 1.27s
# 910:	learn: 0.0087385	total: 12.8s	remaining: 1.25s
# 911:	learn: 0.0087149	total: 12.9s	remaining: 1.24s
# 912:	learn: 0.0086990	total: 12.9s	remaining: 1.23s
# 913:	learn: 0.0086802	total: 12.9s	remaining: 1.21s
# 914:	learn: 0.0086657	total: 12.9s	remaining: 1.2s
# 915:	learn: 0.0086451	total: 12.9s	remaining: 1.18s
# 916:	learn: 0.0086344	total: 12.9s	remaining: 1.17s
# 917:	learn: 0.0086151	total: 12.9s	remaining: 1.15s
# 918:	learn: 0.0085912	total: 12.9s	remaining: 1.14s
# 919:	learn: 0.0085840	total: 12.9s	remaining: 1.12s
# 920:	learn: 0.0085729	total: 12.9s	remaining: 1.11s
# 921:	learn: 0.0085526	total: 13s	remaining: 1.1s
# 922:	learn: 0.0085408	total: 13s	remaining: 1.08s
# 923:	learn: 0.0085233	total: 13s	remaining: 1.07s
# 924:	learn: 0.0085188	total: 13s	remaining: 1.05s
# 925:	learn: 0.0085179	total: 13s	remaining: 1.04s
# 926:	learn: 0.0085044	total: 13s	remaining: 1.03s
# 927:	learn: 0.0084921	total: 13s	remaining: 1.01s
# 928:	learn: 0.0084776	total: 13s	remaining: 997ms
# 929:	learn: 0.0084641	total: 13.1s	remaining: 983ms
# 930:	learn: 0.0084499	total: 13.1s	remaining: 969ms
# 931:	learn: 0.0084364	total: 13.1s	remaining: 955ms
# 932:	learn: 0.0084250	total: 13.1s	remaining: 940ms
# 933:	learn: 0.0084108	total: 13.1s	remaining: 926ms
# 934:	learn: 0.0084017	total: 13.1s	remaining: 912ms
# 935:	learn: 0.0083885	total: 13.1s	remaining: 898ms
# 936:	learn: 0.0083758	total: 13.1s	remaining: 884ms
# 937:	learn: 0.0083741	total: 13.2s	remaining: 870ms
# 938:	learn: 0.0083644	total: 13.2s	remaining: 856ms
# 939:	learn: 0.0083500	total: 13.2s	remaining: 842ms
# 940:	learn: 0.0083311	total: 13.2s	remaining: 828ms
# 941:	learn: 0.0083292	total: 13.2s	remaining: 814ms
# 942:	learn: 0.0083274	total: 13.2s	remaining: 800ms
# 943:	learn: 0.0083069	total: 13.3s	remaining: 786ms
# 944:	learn: 0.0082926	total: 13.3s	remaining: 772ms
# 945:	learn: 0.0082803	total: 13.3s	remaining: 758ms
# 946:	learn: 0.0082675	total: 13.3s	remaining: 744ms
# 947:	learn: 0.0082539	total: 13.3s	remaining: 730ms
# 948:	learn: 0.0082426	total: 13.3s	remaining: 716ms
# 949:	learn: 0.0082368	total: 13.3s	remaining: 702ms
# 950:	learn: 0.0082240	total: 13.4s	remaining: 688ms
# 951:	learn: 0.0082138	total: 13.4s	remaining: 674ms
# 952:	learn: 0.0081962	total: 13.4s	remaining: 660ms
# 953:	learn: 0.0081734	total: 13.4s	remaining: 646ms
# 954:	learn: 0.0081535	total: 13.4s	remaining: 631ms
# 955:	learn: 0.0081320	total: 13.4s	remaining: 617ms
# 956:	learn: 0.0081137	total: 13.4s	remaining: 603ms
# 957:	learn: 0.0081083	total: 13.4s	remaining: 589ms
# 958:	learn: 0.0080936	total: 13.4s	remaining: 574ms
# 959:	learn: 0.0080870	total: 13.4s	remaining: 560ms
# 960:	learn: 0.0080817	total: 13.5s	remaining: 546ms
# 961:	learn: 0.0080800	total: 13.5s	remaining: 532ms
# 962:	learn: 0.0080678	total: 13.5s	remaining: 517ms
# 963:	learn: 0.0080658	total: 13.5s	remaining: 503ms
# 964:	learn: 0.0080541	total: 13.5s	remaining: 489ms
# 965:	learn: 0.0080412	total: 13.5s	remaining: 475ms
# 966:	learn: 0.0080323	total: 13.5s	remaining: 461ms
# 967:	learn: 0.0080213	total: 13.5s	remaining: 447ms
# 968:	learn: 0.0080039	total: 13.5s	remaining: 432ms
# 969:	learn: 0.0079789	total: 13.5s	remaining: 418ms
# 970:	learn: 0.0079621	total: 13.5s	remaining: 404ms
# 971:	learn: 0.0079468	total: 13.6s	remaining: 391ms
# 972:	learn: 0.0079341	total: 13.6s	remaining: 377ms
# 973:	learn: 0.0079237	total: 13.6s	remaining: 363ms
# 974:	learn: 0.0079229	total: 13.6s	remaining: 349ms
# 975:	learn: 0.0079181	total: 13.6s	remaining: 335ms
# 976:	learn: 0.0079097	total: 13.7s	remaining: 321ms
# 977:	learn: 0.0078860	total: 13.7s	remaining: 307ms
# 978:	learn: 0.0078665	total: 13.7s	remaining: 293ms
# 979:	learn: 0.0078512	total: 13.7s	remaining: 279ms
# 980:	learn: 0.0078412	total: 13.7s	remaining: 266ms
# 981:	learn: 0.0078213	total: 13.7s	remaining: 252ms
# 982:	learn: 0.0078021	total: 13.7s	remaining: 238ms
# 983:	learn: 0.0077889	total: 13.8s	remaining: 224ms
# 984:	learn: 0.0077751	total: 13.8s	remaining: 210ms
# 985:	learn: 0.0077660	total: 13.8s	remaining: 196ms
# 986:	learn: 0.0077544	total: 13.8s	remaining: 182ms
# 987:	learn: 0.0077359	total: 13.8s	remaining: 168ms
# 988:	learn: 0.0077335	total: 13.9s	remaining: 154ms
# 989:	learn: 0.0077170	total: 13.9s	remaining: 140ms
# 990:	learn: 0.0077150	total: 13.9s	remaining: 126ms
# 991:	learn: 0.0077004	total: 13.9s	remaining: 112ms
# 992:	learn: 0.0076892	total: 13.9s	remaining: 98.2ms
# 993:	learn: 0.0076760	total: 13.9s	remaining: 84.2ms
# 994:	learn: 0.0076699	total: 14s	remaining: 70.1ms
# 995:	learn: 0.0076490	total: 14s	remaining: 56.1ms
# 996:	learn: 0.0076340	total: 14s	remaining: 42.1ms
# 997:	learn: 0.0076210	total: 14s	remaining: 28.1ms
# 998:	learn: 0.0076187	total: 14s	remaining: 14.1ms
# 999:	learn: 0.0076081	total: 14.1s	remaining: 0us
# Logistic Regression 001: 0.9707602339181286
# Decision tree 001: 0.9707602339181286
# Random forest 001: 0.9590643274853801
# Ada Boosting 001: 0.9473684210526315
# Cat Boosting 001: 0.9590643274853801
# Gradient Boosting 001: 0.9649122807017544
# XG Boosting 001: 0.9649122807017544
#                      No_Tuning
# Logistic Regression   0.970760
# Decision tree         0.970760
# Random forest         0.959064
# Ada Boosting          0.947368
# Cat Boosting          0.959064
# Gradient Boosting     0.964912
# XG Boosting           0.964912

# %%
# TargetColumn

# %%
# Applying Log and Removing Outlayers
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor,GradientBoostingClassifier,GradientBoostingRegressor,AdaBoostClassifier,AdaBoostRegressor
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from xgboost import XGBClassifier,XGBRegressor
from catboost import CatBoostClassifier,CatBoostRegressor
from sklearn.metrics import r2_score,accuracy_score
linRegRawData=LinearRegression()
logRegRawData=LogisticRegression()
RandomRegRawData=RandomForestRegressor()
RandomClaRawData=RandomForestClassifier()
GradBoostClaRawData=GradientBoostingClassifier()
GradBoostRegRawData=GradientBoostingRegressor()
AdaBoostRegRawData=AdaBoostRegressor()
AdaBoostClaRawData=AdaBoostClassifier()
DecRegRawData=DecisionTreeRegressor()
DecClaRawData=DecisionTreeClassifier()
XGBClaRawData=XGBClassifier()
XGBRegRawData=XGBRegressor()
CatBoostClaRawData=CatBoostClassifier()
CatBoostRegRawData=CatBoostRegressor()
if ModelType == "Regression":
    ClearedDataFrame[TargetColumn]=np.log(ClearedDataFrame[TargetColumn])
    Q1 = ClearedDataFrame[TargetColumn].quantile(0.25)
    Q3 = ClearedDataFrame[TargetColumn].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df_no_outlier= ClearedDataFrame[(ClearedDataFrame[TargetColumn] >= lower_bound) & (ClearedDataFrame[TargetColumn] <= upper_bound)]


    # Training algorithm after aplying log and removed outlayers

    xLog=df_no_outlier.drop([TargetColumn],axis=1)
    yLog=df_no_outlier[TargetColumn]
    xTrainLog,xTestLog,yTrainLog,yTestLog = train_test_split(xLog,yLog,train_size=TrainSize,random_state=44)
    ClearedDataFrame



    # Training model based on target type

    if ModelType == "Regression":
        # regression training
        linRegRawData.fit(xTrainLog,yTrainLog)
        DecRegRawData.fit(xTrainLog,yTrainLog)
        RandomRegRawData.fit(xTrainLog,yTrainLog)
        AdaBoostRegRawData.fit(xTrainLog,yTrainLog)
        CatBoostRegRawData.fit(xTrainLog,yTrainLog)
        GradBoostRegRawData.fit(xTrainLog,yTrainLog)
        XGBRegRawData.fit(xTrainLog,yTrainLog)

        # regression Y predit
        Predictions['linRegPredit002']=linRegRawData.predict(xTestLog)
        Predictions['DecRegPredit002']=DecRegRawData.predict(xTestLog)
        Predictions['RandomRegPredit002']=RandomRegRawData.predict(xTestLog)
        Predictions['AdaBoostRegPredit002']=AdaBoostRegRawData.predict(xTestLog)
        Predictions['CatBoostRegPredit002']=CatBoostRegRawData.predict(xTestLog)
        Predictions['GradBoostRegPredit002']=GradBoostRegRawData.predict(xTestLog)
        Predictions['XGBRegPredit002']=XGBRegRawData.predict(xTestLog)


        # R2 score
        linRegR2Score002=r2_score(yTestLog,Predictions['linRegPredit002'])
        DecRegR2Score002=r2_score(yTestLog,Predictions['DecRegPredit002'])
        RandomRegR2Score002=r2_score(yTestLog,Predictions['RandomRegPredit002'])
        AdaBoostRegR2Score002=r2_score(yTestLog,Predictions['AdaBoostRegPredit002'])
        CatBoostRegR2Score002=r2_score(yTestLog,Predictions['CatBoostRegPredit002'])
        GradBoostRegR2Score002=r2_score(yTestLog,Predictions['GradBoostRegPredit002'])
        XGBRegR2Score002=r2_score(yTestLog,Predictions['XGBRegPredit002'])

        print(f"Linear Regression 002: {linRegR2Score002}\nDecision tree 002: {DecRegR2Score002}\nRandom forest 002: {RandomRegR2Score002}\nAda Boosting 002: {AdaBoostRegR2Score002} \nCat Boosting 002: {CatBoostRegR2Score002}\nGradient Boosting 002: {GradBoostRegR2Score002}\nXG Boosting 002: {XGBRegR2Score002}")
        PerfomanceDF['LOG_Applyed_&_Outlayers_Removed']= [linRegR2Score002,DecRegR2Score002,RandomRegR2Score002,AdaBoostRegR2Score002,CatBoostRegR2Score002,GradBoostRegR2Score002,XGBRegR2Score002]
        print(PerfomanceDF)


if ModelType == "Classification":
    Q1 = ClearedDataFrame[TargetColumn].quantile(0.25)
    Q3 = ClearedDataFrame[TargetColumn].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df_no_outlier= ClearedDataFrame[(ClearedDataFrame[TargetColumn] >= lower_bound) & (ClearedDataFrame[TargetColumn] <= upper_bound)]


    # Training algorithm after aplying log and removed outlayers

    xLog=df_no_outlier.drop([TargetColumn],axis=1)
    yLog=df_no_outlier[TargetColumn]
    xTrainLog,xTestLog,yTrainLog,yTestLog = train_test_split(xLog,yLog,train_size=TrainSize,random_state=44)
    ClearedDataFrame


    if ModelType == "Classification":

        # Balancing the classification data
        print("Performing Over sampling")
        print(f"Before SMOTE:\n{yTrainLog.value_counts()}")
        from imblearn.over_sampling import SMOTE
        smote=SMOTE(random_state=42)
        xTrainLog,yTrainLog = smote.fit_resample(xTrainLog,yTrainLog)
        print(f"✅ After SMOTE:\n{yTrainLog.value_counts()}")



        # Classification training
        logRegRawData.fit(xTrainLog,yTrainLog)
        DecClaRawData.fit(xTrainLog,yTrainLog)
        RandomClaRawData.fit(xTrainLog,yTrainLog)
        AdaBoostClaRawData.fit(xTrainLog,yTrainLog)
        CatBoostClaRawData.fit(xTrainLog,yTrainLog)
        GradBoostClaRawData.fit(xTrainLog,yTrainLog)
        XGBClaRawData.fit(xTrainLog,yTrainLog)

        # Claression Y predit
        Predictions['logRegPredit002']=logRegRawData.predict(xTestLog)
        Predictions['DecClaPredit002']=DecClaRawData.predict(xTestLog)
        Predictions['RandomClaPredit002']=RandomClaRawData.predict(xTestLog)
        Predictions['AdaBoostClaPredit002']=AdaBoostClaRawData.predict(xTestLog)
        Predictions['CatBoostClaPredit002']=CatBoostClaRawData.predict(xTestLog)
        Predictions['GradBoostClaPredit002']=GradBoostClaRawData.predict(xTestLog)
        Predictions['XGBClaPredit002']=XGBClaRawData.predict(xTestLog)


        # Accuracy score
        logRegAccuracyScore002=accuracy_score(yTestLog,Predictions['logRegPredit002'])
        DecClaAccuracyScore002=accuracy_score(yTestLog,Predictions['DecClaPredit002'])
        RandomClaAccuracyScore002=accuracy_score(yTestLog,Predictions['RandomClaPredit002'])
        AdaBoostClaAccuracyScore002=accuracy_score(yTestLog,Predictions['AdaBoostClaPredit002'])
        CatBoostClaAccuracyScore002=accuracy_score(yTestLog,Predictions['CatBoostClaPredit002'])
        GradBoostClaAccuracyScore002=accuracy_score(yTestLog,Predictions['GradBoostClaPredit002'])
        XGBClaAccuracyScore002=accuracy_score(yTestLog,Predictions['XGBClaPredit002'])

        print(f"Logistic Regression 002: {logRegAccuracyScore002}\nDecision tree 002: {DecClaAccuracyScore002}\nRandom forest 002: {RandomClaAccuracyScore002}\nAda Boosting 002: {AdaBoostClaAccuracyScore002} \nCat Boosting 002: {CatBoostClaAccuracyScore002}\nGradient Boosting 002: {GradBoostClaAccuracyScore002}\nXG Boosting 002: {XGBClaAccuracyScore002}")
        PerfomanceDF['Outlayers_Removed']= [logRegAccuracyScore002,DecClaAccuracyScore002,RandomClaAccuracyScore002,AdaBoostClaAccuracyScore002,CatBoostClaAccuracyScore002,GradBoostClaAccuracyScore002,XGBClaAccuracyScore002]
        print(PerfomanceDF)
# Out:
# Performing Over sampling
# Before SMOTE:
# target
# 1.0    249
# 0.0    149
# Name: count, dtype: int64
# ✅ After SMOTE:
# target
# 1.0    249
# 0.0    249
# Name: count, dtype: int64
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Learning rate set to 0.00765
# 0:	learn: 0.6807356	total: 5.68ms	remaining: 5.67s
# 1:	learn: 0.6678282	total: 10.9ms	remaining: 5.44s
# 2:	learn: 0.6567597	total: 19.7ms	remaining: 6.53s
# 3:	learn: 0.6454944	total: 31.6ms	remaining: 7.87s
# 4:	learn: 0.6350532	total: 36.6ms	remaining: 7.28s
# 5:	learn: 0.6235771	total: 41.9ms	remaining: 6.93s
# 6:	learn: 0.6115719	total: 47.4ms	remaining: 6.73s
# 7:	learn: 0.6030365	total: 52.3ms	remaining: 6.49s
# 8:	learn: 0.5909793	total: 57.2ms	remaining: 6.3s
# 9:	learn: 0.5795955	total: 62.3ms	remaining: 6.17s
# 10:	learn: 0.5681827	total: 67.4ms	remaining: 6.06s
# 11:	learn: 0.5580966	total: 72.4ms	remaining: 5.96s
# 12:	learn: 0.5492765	total: 77.3ms	remaining: 5.87s
# 13:	learn: 0.5406970	total: 82.3ms	remaining: 5.8s
# 14:	learn: 0.5310496	total: 87.3ms	remaining: 5.74s
# 15:	learn: 0.5218397	total: 92.1ms	remaining: 5.66s
# 16:	learn: 0.5135459	total: 97.3ms	remaining: 5.62s
# 17:	learn: 0.5036331	total: 102ms	remaining: 5.57s
# 18:	learn: 0.4946976	total: 107ms	remaining: 5.53s
# 19:	learn: 0.4858772	total: 112ms	remaining: 5.48s
# 20:	learn: 0.4787651	total: 117ms	remaining: 5.46s
# 21:	learn: 0.4708036	total: 122ms	remaining: 5.42s
# 22:	learn: 0.4628082	total: 127ms	remaining: 5.39s
# 23:	learn: 0.4539493	total: 132ms	remaining: 5.37s
# 24:	learn: 0.4470413	total: 137ms	remaining: 5.35s
# 25:	learn: 0.4391871	total: 142ms	remaining: 5.32s
# 26:	learn: 0.4314337	total: 147ms	remaining: 5.29s
# 27:	learn: 0.4242156	total: 152ms	remaining: 5.26s
# 28:	learn: 0.4168384	total: 157ms	remaining: 5.25s
# 29:	learn: 0.4091245	total: 162ms	remaining: 5.24s
# 30:	learn: 0.4020771	total: 167ms	remaining: 5.21s
# 31:	learn: 0.3955305	total: 172ms	remaining: 5.19s
# 32:	learn: 0.3881271	total: 177ms	remaining: 5.18s
# 33:	learn: 0.3826720	total: 182ms	remaining: 5.17s
# 34:	learn: 0.3758615	total: 187ms	remaining: 5.15s
# 35:	learn: 0.3689812	total: 192ms	remaining: 5.13s
# 36:	learn: 0.3636520	total: 197ms	remaining: 5.12s
# 37:	learn: 0.3578108	total: 204ms	remaining: 5.16s
# 38:	learn: 0.3517489	total: 209ms	remaining: 5.14s
# 39:	learn: 0.3461235	total: 214ms	remaining: 5.13s
# 40:	learn: 0.3413196	total: 219ms	remaining: 5.12s
# 41:	learn: 0.3364509	total: 224ms	remaining: 5.11s
# 42:	learn: 0.3314065	total: 229ms	remaining: 5.1s
# 43:	learn: 0.3266402	total: 234ms	remaining: 5.08s
# 44:	learn: 0.3219889	total: 239ms	remaining: 5.07s
# 45:	learn: 0.3165826	total: 244ms	remaining: 5.06s
# 46:	learn: 0.3119179	total: 249ms	remaining: 5.05s
# 47:	learn: 0.3068986	total: 254ms	remaining: 5.04s
# 48:	learn: 0.3020894	total: 259ms	remaining: 5.03s
# 49:	learn: 0.2975581	total: 264ms	remaining: 5.02s
# 50:	learn: 0.2931695	total: 269ms	remaining: 5.01s
# 51:	learn: 0.2888433	total: 274ms	remaining: 5s
# 52:	learn: 0.2851837	total: 279ms	remaining: 4.99s
# 53:	learn: 0.2805818	total: 284ms	remaining: 4.97s
# 54:	learn: 0.2767680	total: 289ms	remaining: 4.97s
# 55:	learn: 0.2733590	total: 294ms	remaining: 4.95s
# 56:	learn: 0.2695540	total: 299ms	remaining: 4.94s
# 57:	learn: 0.2652833	total: 304ms	remaining: 4.94s
# 58:	learn: 0.2616599	total: 309ms	remaining: 4.93s
# 59:	learn: 0.2582422	total: 314ms	remaining: 4.92s
# 60:	learn: 0.2545351	total: 319ms	remaining: 4.91s
# 61:	learn: 0.2514733	total: 324ms	remaining: 4.9s
# 62:	learn: 0.2480313	total: 329ms	remaining: 4.9s
# 63:	learn: 0.2444069	total: 334ms	remaining: 4.88s
# 64:	learn: 0.2409965	total: 339ms	remaining: 4.88s
# 65:	learn: 0.2369983	total: 344ms	remaining: 4.87s
# 66:	learn: 0.2343607	total: 349ms	remaining: 4.87s
# 67:	learn: 0.2306880	total: 355ms	remaining: 4.86s
# 68:	learn: 0.2274790	total: 361ms	remaining: 4.87s
# 69:	learn: 0.2249192	total: 366ms	remaining: 4.87s
# 70:	learn: 0.2219531	total: 372ms	remaining: 4.87s
# 71:	learn: 0.2191030	total: 377ms	remaining: 4.86s
# 72:	learn: 0.2165758	total: 385ms	remaining: 4.89s
# 73:	learn: 0.2140323	total: 392ms	remaining: 4.91s
# 74:	learn: 0.2109780	total: 400ms	remaining: 4.93s
# 75:	learn: 0.2083616	total: 407ms	remaining: 4.95s
# 76:	learn: 0.2059309	total: 413ms	remaining: 4.95s
# 77:	learn: 0.2031046	total: 418ms	remaining: 4.94s
# 78:	learn: 0.2006227	total: 423ms	remaining: 4.93s
# 79:	learn: 0.1978358	total: 428ms	remaining: 4.92s
# 80:	learn: 0.1953918	total: 434ms	remaining: 4.92s
# 81:	learn: 0.1930286	total: 439ms	remaining: 4.91s
# 82:	learn: 0.1912606	total: 444ms	remaining: 4.91s
# 83:	learn: 0.1893246	total: 450ms	remaining: 4.9s
# 84:	learn: 0.1870736	total: 455ms	remaining: 4.9s
# 85:	learn: 0.1846050	total: 460ms	remaining: 4.89s
# 86:	learn: 0.1825785	total: 468ms	remaining: 4.91s
# 87:	learn: 0.1804650	total: 473ms	remaining: 4.9s
# 88:	learn: 0.1783248	total: 478ms	remaining: 4.89s
# 89:	learn: 0.1767195	total: 483ms	remaining: 4.88s
# 90:	learn: 0.1748082	total: 488ms	remaining: 4.88s
# 91:	learn: 0.1729402	total: 493ms	remaining: 4.87s
# 92:	learn: 0.1709100	total: 499ms	remaining: 4.86s
# 93:	learn: 0.1692031	total: 504ms	remaining: 4.86s
# 94:	learn: 0.1671510	total: 509ms	remaining: 4.85s
# 95:	learn: 0.1652904	total: 514ms	remaining: 4.84s
# 96:	learn: 0.1631752	total: 520ms	remaining: 4.84s
# 97:	learn: 0.1612502	total: 525ms	remaining: 4.83s
# 98:	learn: 0.1597053	total: 534ms	remaining: 4.86s
# 99:	learn: 0.1579598	total: 546ms	remaining: 4.91s
# 100:	learn: 0.1564818	total: 556ms	remaining: 4.95s
# 101:	learn: 0.1548748	total: 562ms	remaining: 4.94s
# 102:	learn: 0.1532935	total: 567ms	remaining: 4.93s
# 103:	learn: 0.1517242	total: 572ms	remaining: 4.93s
# 104:	learn: 0.1499974	total: 577ms	remaining: 4.92s
# 105:	learn: 0.1486288	total: 584ms	remaining: 4.92s
# 106:	learn: 0.1469299	total: 589ms	remaining: 4.92s
# 107:	learn: 0.1458360	total: 594ms	remaining: 4.91s
# 108:	learn: 0.1443275	total: 599ms	remaining: 4.9s
# 109:	learn: 0.1429395	total: 604ms	remaining: 4.89s
# 110:	learn: 0.1414696	total: 611ms	remaining: 4.89s
# 111:	learn: 0.1400508	total: 616ms	remaining: 4.89s
# 112:	learn: 0.1383720	total: 622ms	remaining: 4.88s
# 113:	learn: 0.1372528	total: 626ms	remaining: 4.87s
# 114:	learn: 0.1357581	total: 631ms	remaining: 4.86s
# 115:	learn: 0.1345522	total: 637ms	remaining: 4.85s
# 116:	learn: 0.1336527	total: 642ms	remaining: 4.84s
# 117:	learn: 0.1322134	total: 647ms	remaining: 4.83s
# 118:	learn: 0.1308538	total: 652ms	remaining: 4.83s
# 119:	learn: 0.1299079	total: 657ms	remaining: 4.82s
# 120:	learn: 0.1283952	total: 662ms	remaining: 4.81s
# 121:	learn: 0.1274008	total: 667ms	remaining: 4.8s
# 122:	learn: 0.1260169	total: 672ms	remaining: 4.79s
# 123:	learn: 0.1247906	total: 679ms	remaining: 4.79s
# 124:	learn: 0.1236367	total: 684ms	remaining: 4.79s
# 125:	learn: 0.1226146	total: 690ms	remaining: 4.78s
# 126:	learn: 0.1215882	total: 695ms	remaining: 4.78s
# 127:	learn: 0.1208149	total: 700ms	remaining: 4.77s
# 128:	learn: 0.1195076	total: 705ms	remaining: 4.76s
# 129:	learn: 0.1183999	total: 711ms	remaining: 4.76s
# 130:	learn: 0.1173604	total: 716ms	remaining: 4.75s
# 131:	learn: 0.1163585	total: 721ms	remaining: 4.74s
# 132:	learn: 0.1152112	total: 726ms	remaining: 4.73s
# 133:	learn: 0.1142651	total: 731ms	remaining: 4.73s
# 134:	learn: 0.1134354	total: 737ms	remaining: 4.72s
# 135:	learn: 0.1125216	total: 742ms	remaining: 4.71s
# 136:	learn: 0.1115011	total: 747ms	remaining: 4.71s
# 137:	learn: 0.1106921	total: 752ms	remaining: 4.7s
# 138:	learn: 0.1097965	total: 757ms	remaining: 4.69s
# 139:	learn: 0.1087198	total: 762ms	remaining: 4.68s
# 140:	learn: 0.1077670	total: 768ms	remaining: 4.68s
# 141:	learn: 0.1068694	total: 773ms	remaining: 4.67s
# 142:	learn: 0.1059915	total: 778ms	remaining: 4.66s
# 143:	learn: 0.1053804	total: 783ms	remaining: 4.65s
# 144:	learn: 0.1042563	total: 788ms	remaining: 4.65s
# 145:	learn: 0.1034013	total: 793ms	remaining: 4.64s
# 146:	learn: 0.1025994	total: 798ms	remaining: 4.63s
# 147:	learn: 0.1017246	total: 804ms	remaining: 4.63s
# 148:	learn: 0.1008641	total: 809ms	remaining: 4.62s
# 149:	learn: 0.1002601	total: 816ms	remaining: 4.63s
# 150:	learn: 0.0996596	total: 822ms	remaining: 4.62s
# 151:	learn: 0.0988412	total: 827ms	remaining: 4.61s
# 152:	learn: 0.0982182	total: 832ms	remaining: 4.61s
# 153:	learn: 0.0970873	total: 837ms	remaining: 4.6s
# 154:	learn: 0.0963212	total: 843ms	remaining: 4.59s
# 155:	learn: 0.0952925	total: 848ms	remaining: 4.59s
# 156:	learn: 0.0947387	total: 853ms	remaining: 4.58s
# 157:	learn: 0.0940067	total: 859ms	remaining: 4.58s
# 158:	learn: 0.0934122	total: 864ms	remaining: 4.57s
# 159:	learn: 0.0927815	total: 870ms	remaining: 4.57s
# 160:	learn: 0.0920698	total: 875ms	remaining: 4.56s
# 161:	learn: 0.0913954	total: 880ms	remaining: 4.55s
# 162:	learn: 0.0907470	total: 885ms	remaining: 4.54s
# 163:	learn: 0.0899761	total: 890ms	remaining: 4.54s
# 164:	learn: 0.0893239	total: 896ms	remaining: 4.53s
# 165:	learn: 0.0888433	total: 901ms	remaining: 4.53s
# 166:	learn: 0.0882934	total: 906ms	remaining: 4.52s
# 167:	learn: 0.0875610	total: 911ms	remaining: 4.51s
# 168:	learn: 0.0869309	total: 917ms	remaining: 4.51s
# 169:	learn: 0.0862221	total: 922ms	remaining: 4.5s
# 170:	learn: 0.0855720	total: 927ms	remaining: 4.49s
# 171:	learn: 0.0850140	total: 932ms	remaining: 4.49s
# 172:	learn: 0.0846500	total: 937ms	remaining: 4.48s
# 173:	learn: 0.0840158	total: 943ms	remaining: 4.47s
# 174:	learn: 0.0834019	total: 948ms	remaining: 4.47s
# 175:	learn: 0.0828348	total: 953ms	remaining: 4.46s
# 176:	learn: 0.0821249	total: 958ms	remaining: 4.45s
# 177:	learn: 0.0815234	total: 963ms	remaining: 4.45s
# 178:	learn: 0.0808761	total: 968ms	remaining: 4.44s
# 179:	learn: 0.0802197	total: 973ms	remaining: 4.43s
# 180:	learn: 0.0795909	total: 978ms	remaining: 4.43s
# 181:	learn: 0.0789693	total: 983ms	remaining: 4.42s
# 182:	learn: 0.0784730	total: 989ms	remaining: 4.41s
# 183:	learn: 0.0778971	total: 994ms	remaining: 4.41s
# 184:	learn: 0.0773680	total: 999ms	remaining: 4.4s
# 185:	learn: 0.0769220	total: 1s	remaining: 4.4s
# 186:	learn: 0.0763768	total: 1.01s	remaining: 4.4s
# 187:	learn: 0.0759389	total: 1.02s	remaining: 4.4s
# 188:	learn: 0.0753941	total: 1.02s	remaining: 4.39s
# 189:	learn: 0.0749824	total: 1.03s	remaining: 4.39s
# 190:	learn: 0.0744068	total: 1.03s	remaining: 4.38s
# 191:	learn: 0.0739279	total: 1.04s	remaining: 4.38s
# 192:	learn: 0.0735136	total: 1.04s	remaining: 4.37s
# 193:	learn: 0.0730877	total: 1.05s	remaining: 4.36s
# 194:	learn: 0.0726106	total: 1.05s	remaining: 4.36s
# 195:	learn: 0.0721169	total: 1.06s	remaining: 4.35s
# 196:	learn: 0.0716937	total: 1.07s	remaining: 4.34s
# 197:	learn: 0.0713525	total: 1.07s	remaining: 4.34s
# 198:	learn: 0.0708627	total: 1.08s	remaining: 4.33s
# 199:	learn: 0.0704203	total: 1.08s	remaining: 4.33s
# 200:	learn: 0.0699829	total: 1.09s	remaining: 4.32s
# 201:	learn: 0.0694565	total: 1.09s	remaining: 4.31s
# 202:	learn: 0.0690237	total: 1.1s	remaining: 4.3s
# 203:	learn: 0.0684802	total: 1.1s	remaining: 4.3s
# 204:	learn: 0.0679161	total: 1.11s	remaining: 4.29s
# 205:	learn: 0.0676214	total: 1.11s	remaining: 4.29s
# 206:	learn: 0.0671346	total: 1.12s	remaining: 4.28s
# 207:	learn: 0.0668201	total: 1.12s	remaining: 4.28s
# 208:	learn: 0.0664425	total: 1.13s	remaining: 4.27s
# 209:	learn: 0.0659393	total: 1.13s	remaining: 4.26s
# 210:	learn: 0.0655007	total: 1.14s	remaining: 4.25s
# 211:	learn: 0.0650844	total: 1.14s	remaining: 4.25s
# 212:	learn: 0.0648533	total: 1.15s	remaining: 4.24s
# 213:	learn: 0.0644056	total: 1.15s	remaining: 4.24s
# 214:	learn: 0.0639302	total: 1.16s	remaining: 4.23s
# 215:	learn: 0.0636056	total: 1.16s	remaining: 4.22s
# 216:	learn: 0.0632125	total: 1.17s	remaining: 4.21s
# 217:	learn: 0.0627924	total: 1.17s	remaining: 4.21s
# 218:	learn: 0.0624578	total: 1.18s	remaining: 4.2s
# 219:	learn: 0.0620511	total: 1.18s	remaining: 4.19s
# 220:	learn: 0.0617175	total: 1.19s	remaining: 4.19s
# 221:	learn: 0.0613960	total: 1.19s	remaining: 4.18s
# 222:	learn: 0.0610501	total: 1.2s	remaining: 4.17s
# 223:	learn: 0.0606922	total: 1.2s	remaining: 4.17s
# 224:	learn: 0.0603803	total: 1.21s	remaining: 4.16s
# 225:	learn: 0.0599571	total: 1.21s	remaining: 4.16s
# 226:	learn: 0.0596856	total: 1.22s	remaining: 4.15s
# 227:	learn: 0.0593793	total: 1.22s	remaining: 4.15s
# 228:	learn: 0.0590779	total: 1.23s	remaining: 4.14s
# 229:	learn: 0.0586581	total: 1.23s	remaining: 4.13s
# 230:	learn: 0.0582183	total: 1.24s	remaining: 4.13s
# 231:	learn: 0.0579915	total: 1.25s	remaining: 4.12s
# 232:	learn: 0.0576436	total: 1.25s	remaining: 4.12s
# 233:	learn: 0.0572532	total: 1.25s	remaining: 4.11s
# 234:	learn: 0.0570757	total: 1.26s	remaining: 4.1s
# 235:	learn: 0.0567911	total: 1.26s	remaining: 4.1s
# 236:	learn: 0.0564462	total: 1.27s	remaining: 4.09s
# 237:	learn: 0.0559941	total: 1.27s	remaining: 4.08s
# 238:	learn: 0.0557432	total: 1.28s	remaining: 4.08s
# 239:	learn: 0.0554631	total: 1.28s	remaining: 4.07s
# 240:	learn: 0.0551477	total: 1.29s	remaining: 4.07s
# 241:	learn: 0.0548167	total: 1.3s	remaining: 4.06s
# 242:	learn: 0.0545728	total: 1.3s	remaining: 4.05s
# 243:	learn: 0.0542781	total: 1.31s	remaining: 4.05s
# 244:	learn: 0.0539773	total: 1.31s	remaining: 4.05s
# 245:	learn: 0.0537711	total: 1.32s	remaining: 4.04s
# 246:	learn: 0.0534530	total: 1.32s	remaining: 4.04s
# 247:	learn: 0.0532343	total: 1.33s	remaining: 4.03s
# 248:	learn: 0.0529096	total: 1.33s	remaining: 4.03s
# 249:	learn: 0.0526528	total: 1.34s	remaining: 4.02s
# 250:	learn: 0.0523594	total: 1.35s	remaining: 4.02s
# 251:	learn: 0.0521178	total: 1.35s	remaining: 4.01s
# 252:	learn: 0.0517791	total: 1.36s	remaining: 4.01s
# 253:	learn: 0.0515906	total: 1.36s	remaining: 4s
# 254:	learn: 0.0513882	total: 1.37s	remaining: 4s
# 255:	learn: 0.0511342	total: 1.37s	remaining: 3.99s
# 256:	learn: 0.0509063	total: 1.38s	remaining: 3.99s
# 257:	learn: 0.0507115	total: 1.39s	remaining: 3.98s
# 258:	learn: 0.0504266	total: 1.39s	remaining: 3.98s
# 259:	learn: 0.0502259	total: 1.4s	remaining: 3.97s
# 260:	learn: 0.0499764	total: 1.4s	remaining: 3.97s
# 261:	learn: 0.0497736	total: 1.41s	remaining: 3.96s
# 262:	learn: 0.0496104	total: 1.41s	remaining: 3.96s
# 263:	learn: 0.0493318	total: 1.42s	remaining: 3.96s
# 264:	learn: 0.0491197	total: 1.43s	remaining: 3.95s
# 265:	learn: 0.0488913	total: 1.43s	remaining: 3.95s
# 266:	learn: 0.0486553	total: 1.44s	remaining: 3.94s
# 267:	learn: 0.0484308	total: 1.44s	remaining: 3.94s
# 268:	learn: 0.0481721	total: 1.45s	remaining: 3.93s
# 269:	learn: 0.0479104	total: 1.45s	remaining: 3.93s
# 270:	learn: 0.0476419	total: 1.46s	remaining: 3.92s
# 271:	learn: 0.0473687	total: 1.46s	remaining: 3.92s
# 272:	learn: 0.0471597	total: 1.47s	remaining: 3.91s
# 273:	learn: 0.0470486	total: 1.47s	remaining: 3.9s
# 274:	learn: 0.0468429	total: 1.48s	remaining: 3.9s
# 275:	learn: 0.0466202	total: 1.48s	remaining: 3.9s
# 276:	learn: 0.0463757	total: 1.49s	remaining: 3.89s
# 277:	learn: 0.0462088	total: 1.5s	remaining: 3.88s
# 278:	learn: 0.0459507	total: 1.5s	remaining: 3.88s
# 279:	learn: 0.0457255	total: 1.51s	remaining: 3.87s
# 280:	learn: 0.0455184	total: 1.51s	remaining: 3.87s
# 281:	learn: 0.0452593	total: 1.52s	remaining: 3.86s
# 282:	learn: 0.0450487	total: 1.52s	remaining: 3.86s
# 283:	learn: 0.0448369	total: 1.53s	remaining: 3.86s
# 284:	learn: 0.0446254	total: 1.54s	remaining: 3.85s
# 285:	learn: 0.0443803	total: 1.55s	remaining: 3.87s
# 286:	learn: 0.0441308	total: 1.56s	remaining: 3.87s
# 287:	learn: 0.0439152	total: 1.56s	remaining: 3.87s
# 288:	learn: 0.0437008	total: 1.57s	remaining: 3.86s
# 289:	learn: 0.0434606	total: 1.57s	remaining: 3.86s
# 290:	learn: 0.0432914	total: 1.58s	remaining: 3.85s
# 291:	learn: 0.0431052	total: 1.59s	remaining: 3.85s
# 292:	learn: 0.0429426	total: 1.59s	remaining: 3.84s
# 293:	learn: 0.0428161	total: 1.6s	remaining: 3.84s
# 294:	learn: 0.0426717	total: 1.6s	remaining: 3.83s
# 295:	learn: 0.0425577	total: 1.61s	remaining: 3.83s
# 296:	learn: 0.0423944	total: 1.62s	remaining: 3.83s
# 297:	learn: 0.0422004	total: 1.62s	remaining: 3.82s
# 298:	learn: 0.0419535	total: 1.63s	remaining: 3.81s
# 299:	learn: 0.0418162	total: 1.63s	remaining: 3.81s
# 300:	learn: 0.0416570	total: 1.64s	remaining: 3.81s
# 301:	learn: 0.0415368	total: 1.64s	remaining: 3.8s
# 302:	learn: 0.0412988	total: 1.65s	remaining: 3.79s
# 303:	learn: 0.0411570	total: 1.65s	remaining: 3.79s
# 304:	learn: 0.0409708	total: 1.66s	remaining: 3.78s
# 305:	learn: 0.0408085	total: 1.67s	remaining: 3.78s
# 306:	learn: 0.0406117	total: 1.67s	remaining: 3.77s
# 307:	learn: 0.0404022	total: 1.68s	remaining: 3.77s
# 308:	learn: 0.0402204	total: 1.68s	remaining: 3.76s
# 309:	learn: 0.0400113	total: 1.69s	remaining: 3.75s
# 310:	learn: 0.0398732	total: 1.69s	remaining: 3.75s
# 311:	learn: 0.0397008	total: 1.7s	remaining: 3.74s
# 312:	learn: 0.0395567	total: 1.7s	remaining: 3.74s
# 313:	learn: 0.0393971	total: 1.71s	remaining: 3.73s
# 314:	learn: 0.0391810	total: 1.71s	remaining: 3.73s
# 315:	learn: 0.0390463	total: 1.72s	remaining: 3.72s
# 316:	learn: 0.0388531	total: 1.72s	remaining: 3.72s
# 317:	learn: 0.0386552	total: 1.73s	remaining: 3.71s
# 318:	learn: 0.0385320	total: 1.74s	remaining: 3.7s
# 319:	learn: 0.0384133	total: 1.74s	remaining: 3.7s
# 320:	learn: 0.0382804	total: 1.75s	remaining: 3.69s
# 321:	learn: 0.0381348	total: 1.75s	remaining: 3.69s
# 322:	learn: 0.0379882	total: 1.76s	remaining: 3.68s
# 323:	learn: 0.0378093	total: 1.76s	remaining: 3.68s
# 324:	learn: 0.0376998	total: 1.77s	remaining: 3.67s
# 325:	learn: 0.0375768	total: 1.77s	remaining: 3.67s
# 326:	learn: 0.0373875	total: 1.78s	remaining: 3.66s
# 327:	learn: 0.0372237	total: 1.78s	remaining: 3.65s
# 328:	learn: 0.0370822	total: 1.79s	remaining: 3.65s
# 329:	learn: 0.0369460	total: 1.79s	remaining: 3.64s
# 330:	learn: 0.0367923	total: 1.8s	remaining: 3.64s
# 331:	learn: 0.0366598	total: 1.8s	remaining: 3.63s
# 332:	learn: 0.0364905	total: 1.81s	remaining: 3.63s
# 333:	learn: 0.0363249	total: 1.82s	remaining: 3.63s
# 334:	learn: 0.0361484	total: 1.82s	remaining: 3.62s
# 335:	learn: 0.0359815	total: 1.83s	remaining: 3.61s
# 336:	learn: 0.0358519	total: 1.83s	remaining: 3.61s
# 337:	learn: 0.0357594	total: 1.84s	remaining: 3.6s
# 338:	learn: 0.0356094	total: 1.84s	remaining: 3.6s
# 339:	learn: 0.0354596	total: 1.85s	remaining: 3.59s
# 340:	learn: 0.0352914	total: 1.85s	remaining: 3.59s
# 341:	learn: 0.0351542	total: 1.86s	remaining: 3.58s
# 342:	learn: 0.0350288	total: 1.87s	remaining: 3.58s
# 343:	learn: 0.0349168	total: 1.87s	remaining: 3.57s
# 344:	learn: 0.0348162	total: 1.88s	remaining: 3.56s
# 345:	learn: 0.0346732	total: 1.88s	remaining: 3.56s
# 346:	learn: 0.0345539	total: 1.89s	remaining: 3.55s
# 347:	learn: 0.0343888	total: 1.89s	remaining: 3.55s
# 348:	learn: 0.0343413	total: 1.9s	remaining: 3.54s
# 349:	learn: 0.0342192	total: 1.9s	remaining: 3.54s
# 350:	learn: 0.0340967	total: 1.91s	remaining: 3.53s
# 351:	learn: 0.0339756	total: 1.91s	remaining: 3.52s
# 352:	learn: 0.0338952	total: 1.92s	remaining: 3.52s
# 353:	learn: 0.0337756	total: 1.93s	remaining: 3.51s
# 354:	learn: 0.0336284	total: 1.93s	remaining: 3.51s
# 355:	learn: 0.0335014	total: 1.94s	remaining: 3.5s
# 356:	learn: 0.0333606	total: 1.94s	remaining: 3.5s
# 357:	learn: 0.0332153	total: 1.96s	remaining: 3.51s
# 358:	learn: 0.0330864	total: 1.97s	remaining: 3.52s
# 359:	learn: 0.0329728	total: 1.99s	remaining: 3.54s
# 360:	learn: 0.0328304	total: 2s	remaining: 3.55s
# 361:	learn: 0.0327258	total: 2.02s	remaining: 3.57s
# 362:	learn: 0.0326359	total: 2.04s	remaining: 3.58s
# 363:	learn: 0.0324584	total: 2.05s	remaining: 3.58s
# 364:	learn: 0.0323463	total: 2.07s	remaining: 3.6s
# 365:	learn: 0.0322075	total: 2.08s	remaining: 3.6s
# 366:	learn: 0.0320671	total: 2.09s	remaining: 3.6s
# 367:	learn: 0.0319160	total: 2.09s	remaining: 3.59s
# 368:	learn: 0.0318123	total: 2.1s	remaining: 3.58s
# 369:	learn: 0.0316894	total: 2.1s	remaining: 3.58s
# 370:	learn: 0.0316041	total: 2.11s	remaining: 3.57s
# 371:	learn: 0.0315081	total: 2.11s	remaining: 3.57s
# 372:	learn: 0.0314145	total: 2.12s	remaining: 3.56s
# 373:	learn: 0.0313491	total: 2.12s	remaining: 3.55s
# 374:	learn: 0.0312781	total: 2.13s	remaining: 3.55s
# 375:	learn: 0.0311646	total: 2.13s	remaining: 3.54s
# 376:	learn: 0.0310166	total: 2.14s	remaining: 3.53s
# 377:	learn: 0.0309089	total: 2.14s	remaining: 3.53s
# 378:	learn: 0.0307873	total: 2.15s	remaining: 3.52s
# 379:	learn: 0.0306780	total: 2.15s	remaining: 3.51s
# 380:	learn: 0.0305704	total: 2.16s	remaining: 3.51s
# 381:	learn: 0.0304711	total: 2.16s	remaining: 3.5s
# 382:	learn: 0.0303813	total: 2.17s	remaining: 3.49s
# 383:	learn: 0.0302823	total: 2.17s	remaining: 3.49s
# 384:	learn: 0.0301501	total: 2.18s	remaining: 3.48s
# 385:	learn: 0.0300256	total: 2.18s	remaining: 3.47s
# 386:	learn: 0.0299369	total: 2.19s	remaining: 3.47s
# 387:	learn: 0.0298475	total: 2.19s	remaining: 3.46s
# 388:	learn: 0.0297244	total: 2.2s	remaining: 3.45s
# 389:	learn: 0.0296561	total: 2.2s	remaining: 3.45s
# 390:	learn: 0.0295785	total: 2.21s	remaining: 3.44s
# 391:	learn: 0.0294667	total: 2.21s	remaining: 3.44s
# 392:	learn: 0.0293629	total: 2.22s	remaining: 3.43s
# 393:	learn: 0.0292651	total: 2.23s	remaining: 3.43s
# 394:	learn: 0.0291856	total: 2.23s	remaining: 3.42s
# 395:	learn: 0.0290800	total: 2.24s	remaining: 3.42s
# 396:	learn: 0.0289944	total: 2.24s	remaining: 3.41s
# 397:	learn: 0.0289487	total: 2.25s	remaining: 3.4s
# 398:	learn: 0.0288737	total: 2.25s	remaining: 3.4s
# 399:	learn: 0.0287847	total: 2.26s	remaining: 3.39s
# 400:	learn: 0.0286926	total: 2.27s	remaining: 3.38s
# 401:	learn: 0.0286280	total: 2.27s	remaining: 3.38s
# 402:	learn: 0.0285026	total: 2.28s	remaining: 3.37s
# 403:	learn: 0.0284087	total: 2.28s	remaining: 3.37s
# 404:	learn: 0.0283363	total: 2.29s	remaining: 3.36s
# 405:	learn: 0.0282261	total: 2.29s	remaining: 3.35s
# 406:	learn: 0.0281244	total: 2.3s	remaining: 3.35s
# 407:	learn: 0.0280127	total: 2.3s	remaining: 3.34s
# 408:	learn: 0.0278973	total: 2.31s	remaining: 3.33s
# 409:	learn: 0.0278102	total: 2.31s	remaining: 3.33s
# 410:	learn: 0.0277417	total: 2.32s	remaining: 3.32s
# 411:	learn: 0.0276336	total: 2.32s	remaining: 3.32s
# 412:	learn: 0.0275558	total: 2.33s	remaining: 3.31s
# 413:	learn: 0.0274865	total: 2.33s	remaining: 3.3s
# 414:	learn: 0.0273979	total: 2.34s	remaining: 3.3s
# 415:	learn: 0.0272756	total: 2.34s	remaining: 3.29s
# 416:	learn: 0.0271881	total: 2.35s	remaining: 3.28s
# 417:	learn: 0.0270935	total: 2.35s	remaining: 3.28s
# 418:	learn: 0.0270066	total: 2.36s	remaining: 3.27s
# 419:	learn: 0.0269224	total: 2.37s	remaining: 3.27s
# 420:	learn: 0.0268784	total: 2.37s	remaining: 3.26s
# 421:	learn: 0.0268244	total: 2.38s	remaining: 3.25s
# 422:	learn: 0.0267290	total: 2.38s	remaining: 3.25s
# 423:	learn: 0.0266438	total: 2.39s	remaining: 3.24s
# 424:	learn: 0.0265823	total: 2.39s	remaining: 3.24s
# 425:	learn: 0.0265093	total: 2.4s	remaining: 3.23s
# 426:	learn: 0.0263864	total: 2.4s	remaining: 3.23s
# 427:	learn: 0.0263068	total: 2.41s	remaining: 3.22s
# 428:	learn: 0.0262605	total: 2.41s	remaining: 3.21s
# 429:	learn: 0.0262183	total: 2.42s	remaining: 3.21s
# 430:	learn: 0.0260971	total: 2.42s	remaining: 3.2s
# 431:	learn: 0.0260145	total: 2.43s	remaining: 3.19s
# 432:	learn: 0.0259517	total: 2.44s	remaining: 3.19s
# 433:	learn: 0.0258898	total: 2.44s	remaining: 3.19s
# 434:	learn: 0.0258264	total: 2.45s	remaining: 3.18s
# 435:	learn: 0.0257717	total: 2.45s	remaining: 3.17s
# 436:	learn: 0.0256776	total: 2.46s	remaining: 3.17s
# 437:	learn: 0.0255851	total: 2.47s	remaining: 3.17s
# 438:	learn: 0.0255044	total: 2.47s	remaining: 3.16s
# 439:	learn: 0.0254116	total: 2.48s	remaining: 3.15s
# 440:	learn: 0.0253489	total: 2.48s	remaining: 3.15s
# 441:	learn: 0.0252617	total: 2.49s	remaining: 3.14s
# 442:	learn: 0.0251615	total: 2.49s	remaining: 3.14s
# 443:	learn: 0.0251082	total: 2.5s	remaining: 3.13s
# 444:	learn: 0.0250171	total: 2.5s	remaining: 3.12s
# 445:	learn: 0.0249845	total: 2.51s	remaining: 3.12s
# 446:	learn: 0.0248968	total: 2.52s	remaining: 3.11s
# 447:	learn: 0.0248327	total: 2.52s	remaining: 3.11s
# 448:	learn: 0.0247665	total: 2.53s	remaining: 3.1s
# 449:	learn: 0.0246925	total: 2.53s	remaining: 3.1s
# 450:	learn: 0.0246095	total: 2.54s	remaining: 3.09s
# 451:	learn: 0.0245351	total: 2.54s	remaining: 3.08s
# 452:	learn: 0.0244790	total: 2.55s	remaining: 3.08s
# 453:	learn: 0.0244136	total: 2.56s	remaining: 3.08s
# 454:	learn: 0.0243584	total: 2.57s	remaining: 3.08s
# 455:	learn: 0.0242981	total: 2.58s	remaining: 3.07s
# 456:	learn: 0.0242202	total: 2.58s	remaining: 3.07s
# 457:	learn: 0.0241667	total: 2.59s	remaining: 3.06s
# 458:	learn: 0.0241075	total: 2.59s	remaining: 3.06s
# 459:	learn: 0.0240433	total: 2.6s	remaining: 3.05s
# 460:	learn: 0.0239713	total: 2.6s	remaining: 3.04s
# 461:	learn: 0.0239005	total: 2.61s	remaining: 3.04s
# 462:	learn: 0.0237989	total: 2.61s	remaining: 3.03s
# 463:	learn: 0.0237018	total: 2.62s	remaining: 3.02s
# 464:	learn: 0.0236270	total: 2.62s	remaining: 3.02s
# 465:	learn: 0.0235781	total: 2.63s	remaining: 3.01s
# 466:	learn: 0.0235094	total: 2.64s	remaining: 3.01s
# 467:	learn: 0.0234400	total: 2.64s	remaining: 3s
# 468:	learn: 0.0233884	total: 2.65s	remaining: 3s
# 469:	learn: 0.0233176	total: 2.65s	remaining: 2.99s
# 470:	learn: 0.0232551	total: 2.66s	remaining: 2.99s
# 471:	learn: 0.0232169	total: 2.67s	remaining: 2.98s
# 472:	learn: 0.0231620	total: 2.67s	remaining: 2.98s
# 473:	learn: 0.0230914	total: 2.68s	remaining: 2.97s
# 474:	learn: 0.0230233	total: 2.68s	remaining: 2.96s
# 475:	learn: 0.0229504	total: 2.69s	remaining: 2.96s
# 476:	learn: 0.0229010	total: 2.69s	remaining: 2.95s
# 477:	learn: 0.0228448	total: 2.7s	remaining: 2.95s
# 478:	learn: 0.0227690	total: 2.7s	remaining: 2.94s
# 479:	learn: 0.0227223	total: 2.71s	remaining: 2.94s
# 480:	learn: 0.0226734	total: 2.72s	remaining: 2.93s
# 481:	learn: 0.0225972	total: 2.72s	remaining: 2.92s
# 482:	learn: 0.0225369	total: 2.73s	remaining: 2.92s
# 483:	learn: 0.0224902	total: 2.73s	remaining: 2.91s
# 484:	learn: 0.0224058	total: 2.74s	remaining: 2.91s
# 485:	learn: 0.0223299	total: 2.74s	remaining: 2.9s
# 486:	learn: 0.0222706	total: 2.75s	remaining: 2.89s
# 487:	learn: 0.0221957	total: 2.75s	remaining: 2.89s
# 488:	learn: 0.0221448	total: 2.76s	remaining: 2.88s
# 489:	learn: 0.0220927	total: 2.76s	remaining: 2.88s
# 490:	learn: 0.0220209	total: 2.77s	remaining: 2.87s
# 491:	learn: 0.0219670	total: 2.77s	remaining: 2.87s
# 492:	learn: 0.0219154	total: 2.78s	remaining: 2.86s
# 493:	learn: 0.0218686	total: 2.79s	remaining: 2.85s
# 494:	learn: 0.0218145	total: 2.79s	remaining: 2.85s
# 495:	learn: 0.0217658	total: 2.8s	remaining: 2.84s
# 496:	learn: 0.0217087	total: 2.8s	remaining: 2.83s
# 497:	learn: 0.0216653	total: 2.81s	remaining: 2.83s
# 498:	learn: 0.0216238	total: 2.81s	remaining: 2.82s
# 499:	learn: 0.0215761	total: 2.82s	remaining: 2.82s
# 500:	learn: 0.0214893	total: 2.82s	remaining: 2.81s
# 501:	learn: 0.0214394	total: 2.83s	remaining: 2.81s
# 502:	learn: 0.0213728	total: 2.83s	remaining: 2.8s
# 503:	learn: 0.0212872	total: 2.84s	remaining: 2.79s
# 504:	learn: 0.0212108	total: 2.85s	remaining: 2.79s
# 505:	learn: 0.0211336	total: 2.85s	remaining: 2.78s
# 506:	learn: 0.0210957	total: 2.86s	remaining: 2.78s
# 507:	learn: 0.0210287	total: 2.86s	remaining: 2.77s
# 508:	learn: 0.0209807	total: 2.87s	remaining: 2.77s
# 509:	learn: 0.0208981	total: 2.87s	remaining: 2.76s
# 510:	learn: 0.0208468	total: 2.88s	remaining: 2.75s
# 511:	learn: 0.0208018	total: 2.88s	remaining: 2.75s
# 512:	learn: 0.0207465	total: 2.89s	remaining: 2.74s
# 513:	learn: 0.0206827	total: 2.9s	remaining: 2.74s
# 514:	learn: 0.0206337	total: 2.9s	remaining: 2.73s
# 515:	learn: 0.0205748	total: 2.91s	remaining: 2.73s
# 516:	learn: 0.0205410	total: 2.91s	remaining: 2.72s
# 517:	learn: 0.0204719	total: 2.92s	remaining: 2.71s
# 518:	learn: 0.0204382	total: 2.92s	remaining: 2.71s
# 519:	learn: 0.0203807	total: 2.93s	remaining: 2.7s
# 520:	learn: 0.0203147	total: 2.93s	remaining: 2.7s
# 521:	learn: 0.0202501	total: 2.94s	remaining: 2.69s
# 522:	learn: 0.0202044	total: 2.94s	remaining: 2.69s
# 523:	learn: 0.0201532	total: 2.95s	remaining: 2.68s
# 524:	learn: 0.0201026	total: 2.96s	remaining: 2.67s
# 525:	learn: 0.0200917	total: 2.96s	remaining: 2.67s
# 526:	learn: 0.0200102	total: 2.97s	remaining: 2.66s
# 527:	learn: 0.0199602	total: 2.97s	remaining: 2.66s
# 528:	learn: 0.0199192	total: 2.98s	remaining: 2.65s
# 529:	learn: 0.0198667	total: 2.98s	remaining: 2.65s
# 530:	learn: 0.0198148	total: 2.99s	remaining: 2.64s
# 531:	learn: 0.0197776	total: 3s	remaining: 2.64s
# 532:	learn: 0.0196889	total: 3s	remaining: 2.63s
# 533:	learn: 0.0196434	total: 3.01s	remaining: 2.62s
# 534:	learn: 0.0195791	total: 3.01s	remaining: 2.62s
# 535:	learn: 0.0195342	total: 3.02s	remaining: 2.61s
# 536:	learn: 0.0195052	total: 3.02s	remaining: 2.61s
# 537:	learn: 0.0194489	total: 3.03s	remaining: 2.6s
# 538:	learn: 0.0193977	total: 3.04s	remaining: 2.6s
# 539:	learn: 0.0193503	total: 3.04s	remaining: 2.59s
# 540:	learn: 0.0192912	total: 3.05s	remaining: 2.59s
# 541:	learn: 0.0192466	total: 3.05s	remaining: 2.58s
# 542:	learn: 0.0191920	total: 3.06s	remaining: 2.58s
# 543:	learn: 0.0191481	total: 3.06s	remaining: 2.57s
# 544:	learn: 0.0191119	total: 3.07s	remaining: 2.56s
# 545:	learn: 0.0190399	total: 3.08s	remaining: 2.56s
# 546:	learn: 0.0189995	total: 3.08s	remaining: 2.55s
# 547:	learn: 0.0189610	total: 3.08s	remaining: 2.54s
# 548:	learn: 0.0189205	total: 3.09s	remaining: 2.54s
# 549:	learn: 0.0188706	total: 3.1s	remaining: 2.53s
# 550:	learn: 0.0188181	total: 3.1s	remaining: 2.53s
# 551:	learn: 0.0187627	total: 3.11s	remaining: 2.52s
# 552:	learn: 0.0187054	total: 3.11s	remaining: 2.52s
# 553:	learn: 0.0186571	total: 3.12s	remaining: 2.51s
# 554:	learn: 0.0185896	total: 3.12s	remaining: 2.5s
# 555:	learn: 0.0185598	total: 3.13s	remaining: 2.5s
# 556:	learn: 0.0185082	total: 3.13s	remaining: 2.49s
# 557:	learn: 0.0184366	total: 3.14s	remaining: 2.49s
# 558:	learn: 0.0183940	total: 3.14s	remaining: 2.48s
# 559:	learn: 0.0183224	total: 3.15s	remaining: 2.47s
# 560:	learn: 0.0182843	total: 3.15s	remaining: 2.47s
# 561:	learn: 0.0182441	total: 3.16s	remaining: 2.46s
# 562:	learn: 0.0182013	total: 3.17s	remaining: 2.46s
# 563:	learn: 0.0181461	total: 3.17s	remaining: 2.45s
# 564:	learn: 0.0181149	total: 3.17s	remaining: 2.44s
# 565:	learn: 0.0180751	total: 3.18s	remaining: 2.44s
# 566:	learn: 0.0180176	total: 3.19s	remaining: 2.43s
# 567:	learn: 0.0179789	total: 3.19s	remaining: 2.43s
# 568:	learn: 0.0179165	total: 3.2s	remaining: 2.42s
# 569:	learn: 0.0178850	total: 3.2s	remaining: 2.42s
# 570:	learn: 0.0178416	total: 3.21s	remaining: 2.41s
# 571:	learn: 0.0177895	total: 3.21s	remaining: 2.4s
# 572:	learn: 0.0177465	total: 3.22s	remaining: 2.4s
# 573:	learn: 0.0177089	total: 3.22s	remaining: 2.39s
# 574:	learn: 0.0176785	total: 3.23s	remaining: 2.39s
# 575:	learn: 0.0176402	total: 3.23s	remaining: 2.38s
# 576:	learn: 0.0175662	total: 3.24s	remaining: 2.37s
# 577:	learn: 0.0175011	total: 3.25s	remaining: 2.37s
# 578:	learn: 0.0174622	total: 3.25s	remaining: 2.37s
# 579:	learn: 0.0174129	total: 3.26s	remaining: 2.36s
# 580:	learn: 0.0173757	total: 3.27s	remaining: 2.35s
# 581:	learn: 0.0173397	total: 3.27s	remaining: 2.35s
# 582:	learn: 0.0172585	total: 3.27s	remaining: 2.34s
# 583:	learn: 0.0172227	total: 3.28s	remaining: 2.34s
# 584:	learn: 0.0171909	total: 3.29s	remaining: 2.33s
# 585:	learn: 0.0171515	total: 3.29s	remaining: 2.32s
# 586:	learn: 0.0170921	total: 3.29s	remaining: 2.32s
# 587:	learn: 0.0170386	total: 3.3s	remaining: 2.31s
# 588:	learn: 0.0170006	total: 3.31s	remaining: 2.31s
# 589:	learn: 0.0169414	total: 3.31s	remaining: 2.3s
# 590:	learn: 0.0169021	total: 3.32s	remaining: 2.29s
# 591:	learn: 0.0168576	total: 3.32s	remaining: 2.29s
# 592:	learn: 0.0168000	total: 3.33s	remaining: 2.28s
# 593:	learn: 0.0167437	total: 3.33s	remaining: 2.28s
# 594:	learn: 0.0167070	total: 3.34s	remaining: 2.27s
# 595:	learn: 0.0166763	total: 3.34s	remaining: 2.27s
# 596:	learn: 0.0166391	total: 3.35s	remaining: 2.26s
# 597:	learn: 0.0166173	total: 3.35s	remaining: 2.25s
# 598:	learn: 0.0165925	total: 3.36s	remaining: 2.25s
# 599:	learn: 0.0165726	total: 3.36s	remaining: 2.24s
# 600:	learn: 0.0165427	total: 3.37s	remaining: 2.24s
# 601:	learn: 0.0164991	total: 3.37s	remaining: 2.23s
# 602:	learn: 0.0164500	total: 3.38s	remaining: 2.23s
# 603:	learn: 0.0163997	total: 3.38s	remaining: 2.22s
# 604:	learn: 0.0163632	total: 3.39s	remaining: 2.21s
# 605:	learn: 0.0163206	total: 3.4s	remaining: 2.21s
# 606:	learn: 0.0162676	total: 3.4s	remaining: 2.2s
# 607:	learn: 0.0162431	total: 3.41s	remaining: 2.2s
# 608:	learn: 0.0161959	total: 3.41s	remaining: 2.19s
# 609:	learn: 0.0161455	total: 3.42s	remaining: 2.18s
# 610:	learn: 0.0161167	total: 3.42s	remaining: 2.18s
# 611:	learn: 0.0160973	total: 3.43s	remaining: 2.17s
# 612:	learn: 0.0160396	total: 3.43s	remaining: 2.17s
# 613:	learn: 0.0160013	total: 3.44s	remaining: 2.16s
# 614:	learn: 0.0159811	total: 3.44s	remaining: 2.15s
# 615:	learn: 0.0159341	total: 3.45s	remaining: 2.15s
# 616:	learn: 0.0159021	total: 3.46s	remaining: 2.15s
# 617:	learn: 0.0158646	total: 3.46s	remaining: 2.14s
# 618:	learn: 0.0158357	total: 3.47s	remaining: 2.13s
# 619:	learn: 0.0158054	total: 3.47s	remaining: 2.13s
# 620:	learn: 0.0157756	total: 3.48s	remaining: 2.12s
# 621:	learn: 0.0157469	total: 3.48s	remaining: 2.12s
# 622:	learn: 0.0157064	total: 3.49s	remaining: 2.11s
# 623:	learn: 0.0156786	total: 3.49s	remaining: 2.1s
# 624:	learn: 0.0156344	total: 3.5s	remaining: 2.1s
# 625:	learn: 0.0155940	total: 3.5s	remaining: 2.09s
# 626:	learn: 0.0155555	total: 3.51s	remaining: 2.09s
# 627:	learn: 0.0155161	total: 3.52s	remaining: 2.08s
# 628:	learn: 0.0154848	total: 3.52s	remaining: 2.08s
# 629:	learn: 0.0154654	total: 3.53s	remaining: 2.07s
# 630:	learn: 0.0154467	total: 3.53s	remaining: 2.06s
# 631:	learn: 0.0154006	total: 3.54s	remaining: 2.06s
# 632:	learn: 0.0153592	total: 3.54s	remaining: 2.05s
# 633:	learn: 0.0153446	total: 3.55s	remaining: 2.05s
# 634:	learn: 0.0153073	total: 3.55s	remaining: 2.04s
# 635:	learn: 0.0152535	total: 3.56s	remaining: 2.04s
# 636:	learn: 0.0152273	total: 3.58s	remaining: 2.04s
# 637:	learn: 0.0151896	total: 3.58s	remaining: 2.03s
# 638:	learn: 0.0151412	total: 3.59s	remaining: 2.03s
# 639:	learn: 0.0151028	total: 3.59s	remaining: 2.02s
# 640:	learn: 0.0150608	total: 3.6s	remaining: 2.01s
# 641:	learn: 0.0150239	total: 3.6s	remaining: 2.01s
# 642:	learn: 0.0149891	total: 3.61s	remaining: 2s
# 643:	learn: 0.0149546	total: 3.61s	remaining: 2s
# 644:	learn: 0.0149231	total: 3.62s	remaining: 1.99s
# 645:	learn: 0.0149019	total: 3.62s	remaining: 1.99s
# 646:	learn: 0.0148760	total: 3.63s	remaining: 1.98s
# 647:	learn: 0.0148426	total: 3.63s	remaining: 1.97s
# 648:	learn: 0.0148100	total: 3.64s	remaining: 1.97s
# 649:	learn: 0.0147659	total: 3.64s	remaining: 1.96s
# 650:	learn: 0.0147239	total: 3.65s	remaining: 1.96s
# 651:	learn: 0.0146996	total: 3.66s	remaining: 1.95s
# 652:	learn: 0.0146706	total: 3.66s	remaining: 1.95s
# 653:	learn: 0.0146343	total: 3.67s	remaining: 1.94s
# 654:	learn: 0.0145926	total: 3.67s	remaining: 1.93s
# 655:	learn: 0.0145648	total: 3.68s	remaining: 1.93s
# 656:	learn: 0.0145310	total: 3.68s	remaining: 1.92s
# 657:	learn: 0.0144921	total: 3.69s	remaining: 1.92s
# 658:	learn: 0.0144623	total: 3.69s	remaining: 1.91s
# 659:	learn: 0.0144270	total: 3.7s	remaining: 1.91s
# 660:	learn: 0.0143747	total: 3.71s	remaining: 1.9s
# 661:	learn: 0.0143342	total: 3.71s	remaining: 1.89s
# 662:	learn: 0.0143040	total: 3.71s	remaining: 1.89s
# 663:	learn: 0.0142507	total: 3.72s	remaining: 1.88s
# 664:	learn: 0.0142261	total: 3.73s	remaining: 1.88s
# 665:	learn: 0.0141882	total: 3.73s	remaining: 1.87s
# 666:	learn: 0.0141627	total: 3.74s	remaining: 1.86s
# 667:	learn: 0.0141336	total: 3.74s	remaining: 1.86s
# 668:	learn: 0.0141023	total: 3.75s	remaining: 1.85s
# 669:	learn: 0.0140636	total: 3.75s	remaining: 1.85s
# 670:	learn: 0.0140230	total: 3.76s	remaining: 1.84s
# 671:	learn: 0.0139893	total: 3.76s	remaining: 1.84s
# 672:	learn: 0.0139450	total: 3.77s	remaining: 1.83s
# 673:	learn: 0.0139182	total: 3.77s	remaining: 1.82s
# 674:	learn: 0.0138947	total: 3.78s	remaining: 1.82s
# 675:	learn: 0.0138659	total: 3.78s	remaining: 1.81s
# 676:	learn: 0.0138375	total: 3.79s	remaining: 1.81s
# 677:	learn: 0.0138063	total: 3.79s	remaining: 1.8s
# 678:	learn: 0.0137742	total: 3.8s	remaining: 1.8s
# 679:	learn: 0.0137470	total: 3.8s	remaining: 1.79s
# 680:	learn: 0.0137180	total: 3.81s	remaining: 1.78s
# 681:	learn: 0.0136843	total: 3.81s	remaining: 1.78s
# 682:	learn: 0.0136580	total: 3.82s	remaining: 1.77s
# 683:	learn: 0.0136136	total: 3.83s	remaining: 1.77s
# 684:	learn: 0.0135680	total: 3.83s	remaining: 1.76s
# 685:	learn: 0.0135525	total: 3.84s	remaining: 1.75s
# 686:	learn: 0.0135375	total: 3.84s	remaining: 1.75s
# 687:	learn: 0.0135107	total: 3.85s	remaining: 1.74s
# 688:	learn: 0.0134734	total: 3.85s	remaining: 1.74s
# 689:	learn: 0.0134543	total: 3.87s	remaining: 1.74s
# 690:	learn: 0.0134238	total: 3.88s	remaining: 1.74s
# 691:	learn: 0.0133898	total: 3.88s	remaining: 1.73s
# 692:	learn: 0.0133646	total: 3.89s	remaining: 1.72s
# 693:	learn: 0.0133344	total: 3.9s	remaining: 1.72s
# 694:	learn: 0.0133162	total: 3.9s	remaining: 1.71s
# 695:	learn: 0.0132948	total: 3.91s	remaining: 1.71s
# 696:	learn: 0.0132647	total: 3.91s	remaining: 1.7s
# 697:	learn: 0.0132235	total: 3.92s	remaining: 1.69s
# 698:	learn: 0.0132127	total: 3.92s	remaining: 1.69s
# 699:	learn: 0.0131855	total: 3.93s	remaining: 1.68s
# 700:	learn: 0.0131605	total: 3.93s	remaining: 1.68s
# 701:	learn: 0.0131189	total: 3.94s	remaining: 1.67s
# 702:	learn: 0.0130799	total: 3.94s	remaining: 1.67s
# 703:	learn: 0.0130550	total: 3.95s	remaining: 1.66s
# 704:	learn: 0.0130176	total: 3.95s	remaining: 1.65s
# 705:	learn: 0.0129884	total: 3.96s	remaining: 1.65s
# 706:	learn: 0.0129806	total: 3.96s	remaining: 1.64s
# 707:	learn: 0.0129505	total: 3.97s	remaining: 1.64s
# 708:	learn: 0.0129061	total: 3.98s	remaining: 1.63s
# 709:	learn: 0.0128783	total: 3.98s	remaining: 1.63s
# 710:	learn: 0.0128483	total: 3.98s	remaining: 1.62s
# 711:	learn: 0.0128182	total: 3.99s	remaining: 1.61s
# 712:	learn: 0.0127913	total: 4s	remaining: 1.61s
# 713:	learn: 0.0127588	total: 4s	remaining: 1.6s
# 714:	learn: 0.0127211	total: 4.01s	remaining: 1.6s
# 715:	learn: 0.0126896	total: 4.01s	remaining: 1.59s
# 716:	learn: 0.0126552	total: 4.02s	remaining: 1.58s
# 717:	learn: 0.0126240	total: 4.02s	remaining: 1.58s
# 718:	learn: 0.0126146	total: 4.03s	remaining: 1.57s
# 719:	learn: 0.0125967	total: 4.03s	remaining: 1.57s
# 720:	learn: 0.0125596	total: 4.04s	remaining: 1.56s
# 721:	learn: 0.0125301	total: 4.04s	remaining: 1.56s
# 722:	learn: 0.0125033	total: 4.05s	remaining: 1.55s
# 723:	learn: 0.0124706	total: 4.05s	remaining: 1.54s
# 724:	learn: 0.0124479	total: 4.06s	remaining: 1.54s
# 725:	learn: 0.0124198	total: 4.07s	remaining: 1.53s
# 726:	learn: 0.0124048	total: 4.07s	remaining: 1.53s
# 727:	learn: 0.0123644	total: 4.08s	remaining: 1.52s
# 728:	learn: 0.0123352	total: 4.08s	remaining: 1.52s
# 729:	learn: 0.0123038	total: 4.09s	remaining: 1.51s
# 730:	learn: 0.0122876	total: 4.1s	remaining: 1.51s
# 731:	learn: 0.0122548	total: 4.1s	remaining: 1.5s
# 732:	learn: 0.0122228	total: 4.11s	remaining: 1.5s
# 733:	learn: 0.0121938	total: 4.11s	remaining: 1.49s
# 734:	learn: 0.0121594	total: 4.12s	remaining: 1.48s
# 735:	learn: 0.0121335	total: 4.12s	remaining: 1.48s
# 736:	learn: 0.0121016	total: 4.13s	remaining: 1.47s
# 737:	learn: 0.0120818	total: 4.13s	remaining: 1.47s
# 738:	learn: 0.0120659	total: 4.14s	remaining: 1.46s
# 739:	learn: 0.0120332	total: 4.14s	remaining: 1.46s
# 740:	learn: 0.0119939	total: 4.15s	remaining: 1.45s
# 741:	learn: 0.0119659	total: 4.15s	remaining: 1.44s
# 742:	learn: 0.0119342	total: 4.16s	remaining: 1.44s
# 743:	learn: 0.0119133	total: 4.17s	remaining: 1.43s
# 744:	learn: 0.0118878	total: 4.17s	remaining: 1.43s
# 745:	learn: 0.0118612	total: 4.18s	remaining: 1.42s
# 746:	learn: 0.0118430	total: 4.18s	remaining: 1.42s
# 747:	learn: 0.0118219	total: 4.19s	remaining: 1.41s
# 748:	learn: 0.0117873	total: 4.19s	remaining: 1.4s
# 749:	learn: 0.0117613	total: 4.2s	remaining: 1.4s
# 750:	learn: 0.0117366	total: 4.2s	remaining: 1.39s
# 751:	learn: 0.0117326	total: 4.21s	remaining: 1.39s
# 752:	learn: 0.0117011	total: 4.21s	remaining: 1.38s
# 753:	learn: 0.0116847	total: 4.22s	remaining: 1.38s
# 754:	learn: 0.0116574	total: 4.22s	remaining: 1.37s
# 755:	learn: 0.0116356	total: 4.23s	remaining: 1.36s
# 756:	learn: 0.0116018	total: 4.23s	remaining: 1.36s
# 757:	learn: 0.0115815	total: 4.24s	remaining: 1.35s
# 758:	learn: 0.0115479	total: 4.24s	remaining: 1.35s
# 759:	learn: 0.0115249	total: 4.25s	remaining: 1.34s
# 760:	learn: 0.0115134	total: 4.26s	remaining: 1.34s
# 761:	learn: 0.0115077	total: 4.26s	remaining: 1.33s
# 762:	learn: 0.0114849	total: 4.27s	remaining: 1.33s
# 763:	learn: 0.0114551	total: 4.28s	remaining: 1.32s
# 764:	learn: 0.0114346	total: 4.28s	remaining: 1.31s
# 765:	learn: 0.0114025	total: 4.29s	remaining: 1.31s
# 766:	learn: 0.0113704	total: 4.29s	remaining: 1.3s
# 767:	learn: 0.0113495	total: 4.3s	remaining: 1.3s
# 768:	learn: 0.0113440	total: 4.3s	remaining: 1.29s
# 769:	learn: 0.0113223	total: 4.31s	remaining: 1.29s
# 770:	learn: 0.0113028	total: 4.31s	remaining: 1.28s
# 771:	learn: 0.0112686	total: 4.32s	remaining: 1.27s
# 772:	learn: 0.0112482	total: 4.32s	remaining: 1.27s
# 773:	learn: 0.0112268	total: 4.33s	remaining: 1.26s
# 774:	learn: 0.0111931	total: 4.33s	remaining: 1.26s
# 775:	learn: 0.0111762	total: 4.34s	remaining: 1.25s
# 776:	learn: 0.0111390	total: 4.34s	remaining: 1.25s
# 777:	learn: 0.0111215	total: 4.35s	remaining: 1.24s
# 778:	learn: 0.0111031	total: 4.35s	remaining: 1.24s
# 779:	learn: 0.0110931	total: 4.36s	remaining: 1.23s
# 780:	learn: 0.0110846	total: 4.37s	remaining: 1.22s
# 781:	learn: 0.0110454	total: 4.37s	remaining: 1.22s
# 782:	learn: 0.0110184	total: 4.38s	remaining: 1.21s
# 783:	learn: 0.0109958	total: 4.38s	remaining: 1.21s
# 784:	learn: 0.0109732	total: 4.39s	remaining: 1.2s
# 785:	learn: 0.0109613	total: 4.39s	remaining: 1.2s
# 786:	learn: 0.0109464	total: 4.4s	remaining: 1.19s
# 787:	learn: 0.0109124	total: 4.4s	remaining: 1.18s
# 788:	learn: 0.0108933	total: 4.41s	remaining: 1.18s
# 789:	learn: 0.0108716	total: 4.41s	remaining: 1.17s
# 790:	learn: 0.0108489	total: 4.42s	remaining: 1.17s
# 791:	learn: 0.0108182	total: 4.42s	remaining: 1.16s
# 792:	learn: 0.0107996	total: 4.43s	remaining: 1.16s
# 793:	learn: 0.0107701	total: 4.43s	remaining: 1.15s
# 794:	learn: 0.0107573	total: 4.44s	remaining: 1.14s
# 795:	learn: 0.0107370	total: 4.44s	remaining: 1.14s
# 796:	learn: 0.0107335	total: 4.45s	remaining: 1.13s
# 797:	learn: 0.0107073	total: 4.45s	remaining: 1.13s
# 798:	learn: 0.0106837	total: 4.46s	remaining: 1.12s
# 799:	learn: 0.0106674	total: 4.47s	remaining: 1.12s
# 800:	learn: 0.0106470	total: 4.47s	remaining: 1.11s
# 801:	learn: 0.0106405	total: 4.48s	remaining: 1.1s
# 802:	learn: 0.0106125	total: 4.48s	remaining: 1.1s
# 803:	learn: 0.0105916	total: 4.49s	remaining: 1.09s
# 804:	learn: 0.0105754	total: 4.5s	remaining: 1.09s
# 805:	learn: 0.0105663	total: 4.5s	remaining: 1.08s
# 806:	learn: 0.0105561	total: 4.5s	remaining: 1.08s
# 807:	learn: 0.0105378	total: 4.51s	remaining: 1.07s
# 808:	learn: 0.0105336	total: 4.52s	remaining: 1.07s
# 809:	learn: 0.0105126	total: 4.52s	remaining: 1.06s
# 810:	learn: 0.0104947	total: 4.53s	remaining: 1.05s
# 811:	learn: 0.0104752	total: 4.53s	remaining: 1.05s
# 812:	learn: 0.0104525	total: 4.54s	remaining: 1.04s
# 813:	learn: 0.0104439	total: 4.54s	remaining: 1.04s
# 814:	learn: 0.0104183	total: 4.55s	remaining: 1.03s
# 815:	learn: 0.0104012	total: 4.55s	remaining: 1.03s
# 816:	learn: 0.0103828	total: 4.56s	remaining: 1.02s
# 817:	learn: 0.0103621	total: 4.57s	remaining: 1.02s
# 818:	learn: 0.0103534	total: 4.57s	remaining: 1.01s
# 819:	learn: 0.0103263	total: 4.59s	remaining: 1.01s
# 820:	learn: 0.0103071	total: 4.59s	remaining: 1s
# 821:	learn: 0.0102915	total: 4.6s	remaining: 996ms
# 822:	learn: 0.0102752	total: 4.6s	remaining: 990ms
# 823:	learn: 0.0102580	total: 4.61s	remaining: 985ms
# 824:	learn: 0.0102527	total: 4.62s	remaining: 979ms
# 825:	learn: 0.0102473	total: 4.62s	remaining: 973ms
# 826:	learn: 0.0102134	total: 4.63s	remaining: 968ms
# 827:	learn: 0.0101883	total: 4.63s	remaining: 962ms
# 828:	learn: 0.0101770	total: 4.63s	remaining: 956ms
# 829:	learn: 0.0101627	total: 4.64s	remaining: 951ms
# 830:	learn: 0.0101482	total: 4.65s	remaining: 945ms
# 831:	learn: 0.0101275	total: 4.65s	remaining: 939ms
# 832:	learn: 0.0101021	total: 4.66s	remaining: 934ms
# 833:	learn: 0.0100729	total: 4.66s	remaining: 928ms
# 834:	learn: 0.0100482	total: 4.67s	remaining: 923ms
# 835:	learn: 0.0100264	total: 4.67s	remaining: 917ms
# 836:	learn: 0.0100048	total: 4.68s	remaining: 912ms
# 837:	learn: 0.0099954	total: 4.69s	remaining: 906ms
# 838:	learn: 0.0099943	total: 4.69s	remaining: 900ms
# 839:	learn: 0.0099736	total: 4.7s	remaining: 895ms
# 840:	learn: 0.0099454	total: 4.7s	remaining: 889ms
# 841:	learn: 0.0099212	total: 4.71s	remaining: 883ms
# 842:	learn: 0.0098985	total: 4.71s	remaining: 878ms
# 843:	learn: 0.0098836	total: 4.72s	remaining: 872ms
# 844:	learn: 0.0098652	total: 4.72s	remaining: 866ms
# 845:	learn: 0.0098439	total: 4.73s	remaining: 861ms
# 846:	learn: 0.0098263	total: 4.73s	remaining: 855ms
# 847:	learn: 0.0098211	total: 4.74s	remaining: 849ms
# 848:	learn: 0.0098029	total: 4.74s	remaining: 844ms
# 849:	learn: 0.0097854	total: 4.75s	remaining: 838ms
# 850:	learn: 0.0097609	total: 4.75s	remaining: 832ms
# 851:	learn: 0.0097404	total: 4.76s	remaining: 827ms
# 852:	learn: 0.0097213	total: 4.76s	remaining: 821ms
# 853:	learn: 0.0097033	total: 4.77s	remaining: 816ms
# 854:	learn: 0.0096805	total: 4.78s	remaining: 810ms
# 855:	learn: 0.0096605	total: 4.78s	remaining: 805ms
# 856:	learn: 0.0096561	total: 4.79s	remaining: 799ms
# 857:	learn: 0.0096346	total: 4.79s	remaining: 793ms
# 858:	learn: 0.0096098	total: 4.8s	remaining: 788ms
# 859:	learn: 0.0095794	total: 4.8s	remaining: 782ms
# 860:	learn: 0.0095695	total: 4.81s	remaining: 776ms
# 861:	learn: 0.0095343	total: 4.81s	remaining: 771ms
# 862:	learn: 0.0095184	total: 4.82s	remaining: 765ms
# 863:	learn: 0.0094948	total: 4.82s	remaining: 759ms
# 864:	learn: 0.0094715	total: 4.83s	remaining: 754ms
# 865:	learn: 0.0094484	total: 4.83s	remaining: 748ms
# 866:	learn: 0.0094320	total: 4.84s	remaining: 742ms
# 867:	learn: 0.0094220	total: 4.84s	remaining: 737ms
# 868:	learn: 0.0094052	total: 4.85s	remaining: 731ms
# 869:	learn: 0.0093857	total: 4.86s	remaining: 726ms
# 870:	learn: 0.0093643	total: 4.86s	remaining: 720ms
# 871:	learn: 0.0093492	total: 4.87s	remaining: 715ms
# 872:	learn: 0.0093330	total: 4.87s	remaining: 709ms
# 873:	learn: 0.0093074	total: 4.88s	remaining: 703ms
# 874:	learn: 0.0092897	total: 4.88s	remaining: 698ms
# 875:	learn: 0.0092817	total: 4.89s	remaining: 692ms
# 876:	learn: 0.0092638	total: 4.89s	remaining: 687ms
# 877:	learn: 0.0092427	total: 4.9s	remaining: 681ms
# 878:	learn: 0.0092304	total: 4.91s	remaining: 676ms
# 879:	learn: 0.0092061	total: 4.92s	remaining: 670ms
# 880:	learn: 0.0091854	total: 4.92s	remaining: 665ms
# 881:	learn: 0.0091646	total: 4.93s	remaining: 659ms
# 882:	learn: 0.0091513	total: 4.93s	remaining: 654ms
# 883:	learn: 0.0091304	total: 4.94s	remaining: 648ms
# 884:	learn: 0.0091232	total: 4.95s	remaining: 643ms
# 885:	learn: 0.0091217	total: 4.95s	remaining: 637ms
# 886:	learn: 0.0090985	total: 4.96s	remaining: 631ms
# 887:	learn: 0.0090790	total: 4.96s	remaining: 626ms
# 888:	learn: 0.0090562	total: 4.97s	remaining: 620ms
# 889:	learn: 0.0090498	total: 4.97s	remaining: 615ms
# 890:	learn: 0.0090408	total: 4.98s	remaining: 609ms
# 891:	learn: 0.0090242	total: 4.98s	remaining: 603ms
# 892:	learn: 0.0090220	total: 4.99s	remaining: 598ms
# 893:	learn: 0.0089963	total: 4.99s	remaining: 592ms
# 894:	learn: 0.0089802	total: 5s	remaining: 587ms
# 895:	learn: 0.0089632	total: 5s	remaining: 581ms
# 896:	learn: 0.0089496	total: 5.01s	remaining: 575ms
# 897:	learn: 0.0089352	total: 5.01s	remaining: 570ms
# 898:	learn: 0.0089174	total: 5.02s	remaining: 564ms
# 899:	learn: 0.0089001	total: 5.03s	remaining: 558ms
# 900:	learn: 0.0088868	total: 5.03s	remaining: 553ms
# 901:	learn: 0.0088787	total: 5.04s	remaining: 547ms
# 902:	learn: 0.0088498	total: 5.04s	remaining: 542ms
# 903:	learn: 0.0088396	total: 5.05s	remaining: 536ms
# 904:	learn: 0.0088146	total: 5.05s	remaining: 530ms
# 905:	learn: 0.0088036	total: 5.06s	remaining: 525ms
# 906:	learn: 0.0088020	total: 5.07s	remaining: 520ms
# 907:	learn: 0.0087876	total: 5.07s	remaining: 514ms
# 908:	learn: 0.0087687	total: 5.08s	remaining: 508ms
# 909:	learn: 0.0087552	total: 5.08s	remaining: 503ms
# 910:	learn: 0.0087385	total: 5.09s	remaining: 497ms
# 911:	learn: 0.0087149	total: 5.09s	remaining: 491ms
# 912:	learn: 0.0086990	total: 5.1s	remaining: 486ms
# 913:	learn: 0.0086802	total: 5.1s	remaining: 480ms
# 914:	learn: 0.0086657	total: 5.11s	remaining: 475ms
# 915:	learn: 0.0086451	total: 5.11s	remaining: 469ms
# 916:	learn: 0.0086344	total: 5.12s	remaining: 463ms
# 917:	learn: 0.0086151	total: 5.12s	remaining: 458ms
# 918:	learn: 0.0085912	total: 5.13s	remaining: 452ms
# 919:	learn: 0.0085840	total: 5.13s	remaining: 447ms
# 920:	learn: 0.0085729	total: 5.14s	remaining: 441ms
# 921:	learn: 0.0085526	total: 5.14s	remaining: 435ms
# 922:	learn: 0.0085408	total: 5.15s	remaining: 430ms
# 923:	learn: 0.0085233	total: 5.16s	remaining: 424ms
# 924:	learn: 0.0085188	total: 5.16s	remaining: 418ms
# 925:	learn: 0.0085179	total: 5.17s	remaining: 413ms
# 926:	learn: 0.0085044	total: 5.17s	remaining: 407ms
# 927:	learn: 0.0084921	total: 5.18s	remaining: 402ms
# 928:	learn: 0.0084776	total: 5.18s	remaining: 396ms
# 929:	learn: 0.0084641	total: 5.19s	remaining: 390ms
# 930:	learn: 0.0084499	total: 5.19s	remaining: 385ms
# 931:	learn: 0.0084364	total: 5.2s	remaining: 379ms
# 932:	learn: 0.0084250	total: 5.2s	remaining: 374ms
# 933:	learn: 0.0084108	total: 5.21s	remaining: 368ms
# 934:	learn: 0.0084017	total: 5.21s	remaining: 362ms
# 935:	learn: 0.0083885	total: 5.22s	remaining: 357ms
# 936:	learn: 0.0083758	total: 5.22s	remaining: 351ms
# 937:	learn: 0.0083741	total: 5.23s	remaining: 346ms
# 938:	learn: 0.0083644	total: 5.23s	remaining: 340ms
# 939:	learn: 0.0083500	total: 5.24s	remaining: 334ms
# 940:	learn: 0.0083311	total: 5.24s	remaining: 329ms
# 941:	learn: 0.0083292	total: 5.25s	remaining: 323ms
# 942:	learn: 0.0083274	total: 5.25s	remaining: 318ms
# 943:	learn: 0.0083069	total: 5.26s	remaining: 312ms
# 944:	learn: 0.0082926	total: 5.27s	remaining: 307ms
# 945:	learn: 0.0082803	total: 5.27s	remaining: 301ms
# 946:	learn: 0.0082675	total: 5.28s	remaining: 295ms
# 947:	learn: 0.0082539	total: 5.28s	remaining: 290ms
# 948:	learn: 0.0082426	total: 5.29s	remaining: 284ms
# 949:	learn: 0.0082368	total: 5.29s	remaining: 279ms
# 950:	learn: 0.0082240	total: 5.3s	remaining: 273ms
# 951:	learn: 0.0082138	total: 5.3s	remaining: 267ms
# 952:	learn: 0.0081962	total: 5.31s	remaining: 262ms
# 953:	learn: 0.0081734	total: 5.32s	remaining: 256ms
# 954:	learn: 0.0081535	total: 5.32s	remaining: 251ms
# 955:	learn: 0.0081320	total: 5.33s	remaining: 245ms
# 956:	learn: 0.0081137	total: 5.33s	remaining: 240ms
# 957:	learn: 0.0081083	total: 5.34s	remaining: 234ms
# 958:	learn: 0.0080936	total: 5.34s	remaining: 228ms
# 959:	learn: 0.0080870	total: 5.35s	remaining: 223ms
# 960:	learn: 0.0080817	total: 5.35s	remaining: 217ms
# 961:	learn: 0.0080800	total: 5.36s	remaining: 212ms
# 962:	learn: 0.0080678	total: 5.36s	remaining: 206ms
# 963:	learn: 0.0080658	total: 5.37s	remaining: 200ms
# 964:	learn: 0.0080541	total: 5.37s	remaining: 195ms
# 965:	learn: 0.0080412	total: 5.38s	remaining: 189ms
# 966:	learn: 0.0080323	total: 5.38s	remaining: 184ms
# 967:	learn: 0.0080213	total: 5.39s	remaining: 178ms
# 968:	learn: 0.0080039	total: 5.39s	remaining: 173ms
# 969:	learn: 0.0079789	total: 5.4s	remaining: 167ms
# 970:	learn: 0.0079621	total: 5.4s	remaining: 161ms
# 971:	learn: 0.0079468	total: 5.41s	remaining: 156ms
# 972:	learn: 0.0079341	total: 5.41s	remaining: 150ms
# 973:	learn: 0.0079237	total: 5.42s	remaining: 145ms
# 974:	learn: 0.0079229	total: 5.42s	remaining: 139ms
# 975:	learn: 0.0079181	total: 5.43s	remaining: 133ms
# 976:	learn: 0.0079097	total: 5.43s	remaining: 128ms
# 977:	learn: 0.0078860	total: 5.44s	remaining: 122ms
# 978:	learn: 0.0078665	total: 5.44s	remaining: 117ms
# 979:	learn: 0.0078512	total: 5.45s	remaining: 111ms
# 980:	learn: 0.0078412	total: 5.45s	remaining: 106ms
# 981:	learn: 0.0078213	total: 5.46s	remaining: 100ms
# 982:	learn: 0.0078021	total: 5.47s	remaining: 94.6ms
# 983:	learn: 0.0077889	total: 5.47s	remaining: 89ms
# 984:	learn: 0.0077751	total: 5.48s	remaining: 83.4ms
# 985:	learn: 0.0077660	total: 5.48s	remaining: 77.9ms
# 986:	learn: 0.0077544	total: 5.49s	remaining: 72.3ms
# 987:	learn: 0.0077359	total: 5.49s	remaining: 66.7ms
# 988:	learn: 0.0077335	total: 5.5s	remaining: 61.2ms
# 989:	learn: 0.0077170	total: 5.5s	remaining: 55.6ms
# 990:	learn: 0.0077150	total: 5.51s	remaining: 50ms
# 991:	learn: 0.0077004	total: 5.51s	remaining: 44.5ms
# 992:	learn: 0.0076892	total: 5.52s	remaining: 38.9ms
# 993:	learn: 0.0076760	total: 5.53s	remaining: 33.4ms
# 994:	learn: 0.0076699	total: 5.53s	remaining: 27.8ms
# 995:	learn: 0.0076490	total: 5.54s	remaining: 22.2ms
# 996:	learn: 0.0076340	total: 5.54s	remaining: 16.7ms
# 997:	learn: 0.0076210	total: 5.55s	remaining: 11.1ms
# 998:	learn: 0.0076187	total: 5.55s	remaining: 5.56ms
# 999:	learn: 0.0076081	total: 5.56s	remaining: 0us
# Logistic Regression 002: 0.9707602339181286
# Decision tree 002: 0.9298245614035088
# Random forest 002: 0.9590643274853801
# Ada Boosting 002: 0.9473684210526315
# Cat Boosting 002: 0.9590643274853801
# Gradient Boosting 002: 0.9649122807017544
# XG Boosting 002: 0.9649122807017544
#                      No_Tuning  Outlayers_Removed
# Logistic Regression   0.970760           0.970760
# Decision tree         0.970760           0.929825
# Random forest         0.959064           0.959064
# Ada Boosting          0.947368           0.947368
# Cat Boosting          0.959064           0.959064
# Gradient Boosting     0.964912           0.964912
# XG Boosting           0.964912           0.964912

# %%
# FinalPCADF.Target.isnull().sum()
# df_no_outlier[TargetColumn].isnull().sum()

# %%
# PercentageOfVariance = [0.90,0.93,0.95,0.98]
# for VariancePercentage in PercentageOfVariance:
#     print(VariancePercentage)

# %%
# ClearedDataFrame

# PCADF=df_no_outlier.drop(TargetColumn,axis=1)
# PCADF

# %%
from sklearn.decomposition import PCA
noc=[]
PCADFNoTarget=df_no_outlier.drop(TargetColumn,axis=1)
for i in range(len(PCADFNoTarget.columns)):
    if i%3 == 0:
        continue
    if i%2==0:
        noc.append(i)
# len(noc)
PCAnocScoreDataFrame=pd.DataFrame()
for NumberOfComponents in noc:
    pca=PCA(n_components=NumberOfComponents)
    PCADF=pca.fit_transform(PCADFNoTarget)
    PCADF=pd.DataFrame(PCADF,columns=[f'PC{i+1}' for i in range(NumberOfComponents)])
    PCADF['Target']=df_no_outlier[TargetColumn]
    PCADF = PCADF.replace([np.inf, -np.inf], np.nan)
    PCADF.dropna(inplace=True)
    xnoc=PCADF.drop('Target',axis=1)
    ynoc=PCADF['Target']
    xTrainPCAnoc,xTestPCAnoc,yTrainPCAnoc,yTestPCAnoc = train_test_split(xnoc,ynoc,train_size=TrainSize,random_state=44)


    # Training

    from sklearn.linear_model import LinearRegression,LogisticRegression
    from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor,GradientBoostingClassifier,GradientBoostingRegressor,AdaBoostClassifier,AdaBoostRegressor
    from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
    from xgboost import XGBClassifier,XGBRegressor
    from catboost import CatBoostClassifier,CatBoostRegressor
    from sklearn.metrics import r2_score,accuracy_score
    linRegNOC=LinearRegression()
    logRegNOC=LogisticRegression()
    RandomRegNOC=RandomForestRegressor()
    RandomClaNOC=RandomForestClassifier()
    GradBoostClaNOC=GradientBoostingClassifier()
    GradBoostRegNOC=GradientBoostingRegressor()
    AdaBoostRegNOC=AdaBoostRegressor()
    AdaBoostClaNOC=AdaBoostClassifier()
    DecRegNOC=DecisionTreeRegressor()
    DecClaNOC=DecisionTreeClassifier()
    XGBClaNOC=XGBClassifier()
    XGBRegNOC=XGBRegressor()
    CatBoostClaNOC=CatBoostClassifier()
    CatBoostRegNOC=CatBoostRegressor()

    # Training model based on target type

    if ModelType == "Regression":
        # regression training
        linRegNOC.fit(xTrainPCAnoc,yTrainPCAnoc)
        DecRegNOC.fit(xTrainPCAnoc,yTrainPCAnoc)
        RandomRegNOC.fit(xTrainPCAnoc,yTrainPCAnoc)
        AdaBoostRegNOC.fit(xTrainPCAnoc,yTrainPCAnoc)
        CatBoostRegNOC.fit(xTrainPCAnoc,yTrainPCAnoc)
        GradBoostRegNOC.fit(xTrainPCAnoc,yTrainPCAnoc)
        XGBRegNOC.fit(xTrainPCAnoc,yTrainPCAnoc)

        Predictions["linRegPredit003"] = linRegNOC.predict(xTestPCAnoc)
        Predictions["DecRegPredit003"] = DecRegNOC.predict(xTestPCAnoc)
        Predictions["RandomRegPredit003"] = RandomRegNOC.predict(xTestPCAnoc)
        Predictions["AdaBoostRegPredit003"] = AdaBoostRegNOC.predict(xTestPCAnoc)
        Predictions["CatBoostRegPredit003"] = CatBoostRegNOC.predict(xTestPCAnoc)
        Predictions["GradBoostRegPredit003"] = GradBoostRegNOC.predict(xTestPCAnoc)
        Predictions["XGBRegPredit003"] = XGBRegNOC.predict(xTestPCAnoc)





        # R2 score
        linRegR2ScorePCAnoc=r2_score(yTestPCAnoc,Predictions["linRegPredit003"])
        DecRegR2ScorePCAnoc=r2_score(yTestPCAnoc,Predictions["DecRegPredit003"])
        RandomRegR2ScorePCAnoc=r2_score(yTestPCAnoc,Predictions["RandomRegPredit003"])
        AdaBoostRegR2ScorePCAnoc=r2_score(yTestPCAnoc,Predictions["AdaBoostRegPredit003"])
        CatBoostRegR2ScorePCAnoc=r2_score(yTestPCAnoc,Predictions["CatBoostRegPredit003"])
        GradBoostRegR2ScorePCAnoc=r2_score(yTestPCAnoc,Predictions["GradBoostRegPredit003"])
        XGBRegR2ScorePCAnoc=r2_score(yTestPCAnoc,Predictions["XGBRegPredit003"])

        PCAnocScoreDataFrame.index=['Logistic Regression','Decision tree','Random forest','Ada Boosting','Cat Boosting','Gradient Boosting','XG Boosting']
        PCAnocScoreDataFrame[NumberOfComponents]=[linRegR2ScorePCAnoc,DecRegR2ScorePCAnoc,RandomRegR2ScorePCAnoc,AdaBoostRegR2ScorePCAnoc,CatBoostRegR2ScorePCAnoc,GradBoostRegR2ScorePCAnoc,XGBRegR2ScorePCAnoc]


    if ModelType == "Classification":

        # Balancing the classification data
        print("Performing Over sampling")
        print(f"Before SMOTE:\n{yTrainPCAnoc.value_counts()}")
        from imblearn.over_sampling import SMOTE
        smote=SMOTE(random_state=42)
        xTrainPCAnoc,yTrainPCAnoc = smote.fit_resample(xTrainPCAnoc,yTrainPCAnoc)
        print(f"✅ After SMOTE:\n{yTrainPCAnoc.value_counts()}")



        # regression training
        logRegNOC.fit(xTrainPCAnoc,yTrainPCAnoc)
        DecClaNOC.fit(xTrainPCAnoc,yTrainPCAnoc)
        RandomClaNOC.fit(xTrainPCAnoc,yTrainPCAnoc)
        AdaBoostClaNOC.fit(xTrainPCAnoc,yTrainPCAnoc)
        CatBoostClaNOC.fit(xTrainPCAnoc,yTrainPCAnoc)
        GradBoostClaNOC.fit(xTrainPCAnoc,yTrainPCAnoc)
        XGBClaNOC.fit(xTrainPCAnoc,yTrainPCAnoc)

        # Claression Y predit
        Predictions["logRegPredit003"] = logRegNOC.predict(xTestPCAnoc)
        Predictions["DecClaPredit003"] = DecClaNOC.predict(xTestPCAnoc)
        Predictions["RandomClaPredit003"] = RandomClaNOC.predict(xTestPCAnoc)
        Predictions["AdaBoostClaPredit003"] = AdaBoostClaNOC.predict(xTestPCAnoc)
        Predictions["CatBoostClaPredit003"] = CatBoostClaNOC.predict(xTestPCAnoc)
        Predictions["GradBoostClaPredit003"] = GradBoostClaNOC.predict(xTestPCAnoc)
        Predictions["XGBClaPredit003"] = XGBClaNOC.predict(xTestPCAnoc)



        # Accuracy score
        logRegAccuracyScorePCAnoc=accuracy_score(yTestPCAnoc,Predictions["logRegPredit003"])
        DecClaAccuracyScorePCAnoc=accuracy_score(yTestPCAnoc,Predictions['DecClaPredit003'])
        RandomClaAccuracyScorePCAnoc=accuracy_score(yTestPCAnoc,Predictions['RandomClaPredit003'])
        AdaBoostClaAccuracyScorePCAnoc=accuracy_score(yTestPCAnoc,Predictions['AdaBoostClaPredit003'])
        CatBoostClaAccuracyScorePCAnoc=accuracy_score(yTestPCAnoc,Predictions['CatBoostClaPredit003'])
        GradBoostClaAccuracyScorePCAnoc=accuracy_score(yTestPCAnoc,Predictions['GradBoostClaPredit003'])
        XGBClaAccuracyScorePCAnoc=accuracy_score(yTestPCAnoc,Predictions['XGBClaPredit003'])


        PCAnocScoreDataFrame.index=['Logistic Regression','Decision tree','Random forest','Ada Boosting','Cat Boosting','Gradient Boosting','XG Boosting']
        PCAnocScoreDataFrame[NumberOfComponents]= [logRegAccuracyScorePCAnoc,DecClaAccuracyScorePCAnoc,RandomClaAccuracyScorePCAnoc,AdaBoostClaAccuracyScorePCAnoc,CatBoostClaAccuracyScorePCAnoc,GradBoostClaAccuracyScorePCAnoc,XGBClaAccuracyScorePCAnoc]
# Out:
# Performing Over sampling
# Before SMOTE:
# Target
# 1.0    249
# 0.0    149
# Name: count, dtype: int64
# ✅ After SMOTE:
# Target
# 1.0    249
# 0.0    249
# Name: count, dtype: int64
# Learning rate set to 0.00765
# 0:	learn: 0.6824412	total: 908us	remaining: 907ms
# 1:	learn: 0.6726563	total: 1.65ms	remaining: 822ms
# 2:	learn: 0.6639620	total: 2.35ms	remaining: 780ms
# 3:	learn: 0.6536566	total: 3.01ms	remaining: 750ms
# 4:	learn: 0.6449624	total: 3.71ms	remaining: 739ms
# 5:	learn: 0.6351210	total: 4.39ms	remaining: 727ms
# 6:	learn: 0.6254795	total: 5.05ms	remaining: 716ms
# 7:	learn: 0.6159006	total: 5.71ms	remaining: 708ms
# 8:	learn: 0.6063674	total: 6.39ms	remaining: 704ms
# 9:	learn: 0.5983678	total: 7.05ms	remaining: 698ms
# 10:	learn: 0.5901601	total: 7.69ms	remaining: 691ms
# 11:	learn: 0.5813559	total: 8.35ms	remaining: 687ms
# 12:	learn: 0.5734899	total: 9.01ms	remaining: 684ms
# 13:	learn: 0.5648704	total: 9.67ms	remaining: 681ms
# 14:	learn: 0.5579837	total: 10.3ms	remaining: 678ms
# 15:	learn: 0.5500194	total: 11ms	remaining: 676ms
# 16:	learn: 0.5428072	total: 11.5ms	remaining: 665ms
# 17:	learn: 0.5352754	total: 12.2ms	remaining: 664ms
# 18:	learn: 0.5283222	total: 12.8ms	remaining: 662ms
# 19:	learn: 0.5214151	total: 13.5ms	remaining: 660ms
# 20:	learn: 0.5141595	total: 14.1ms	remaining: 659ms
# 21:	learn: 0.5073973	total: 14.8ms	remaining: 658ms
# 22:	learn: 0.5005086	total: 15.5ms	remaining: 657ms
# 23:	learn: 0.4953269	total: 16.1ms	remaining: 657ms
# 24:	learn: 0.4886389	total: 16.8ms	remaining: 656ms
# 25:	learn: 0.4835303	total: 17.5ms	remaining: 656ms
# 26:	learn: 0.4770286	total: 18.1ms	remaining: 654ms
# 27:	learn: 0.4710035	total: 18.8ms	remaining: 654ms
# 28:	learn: 0.4652561	total: 19.5ms	remaining: 653ms
# 29:	learn: 0.4596863	total: 20.1ms	remaining: 651ms
# 30:	learn: 0.4544622	total: 20.8ms	remaining: 650ms
# 31:	learn: 0.4505914	total: 21.5ms	remaining: 650ms
# 32:	learn: 0.4453901	total: 22.1ms	remaining: 648ms
# 33:	learn: 0.4407442	total: 22.8ms	remaining: 647ms
# 34:	learn: 0.4367571	total: 23.4ms	remaining: 646ms
# 35:	learn: 0.4317793	total: 24.1ms	remaining: 646ms
# 36:	learn: 0.4267418	total: 24.8ms	remaining: 645ms
# 37:	learn: 0.4219009	total: 25.5ms	remaining: 645ms
# 38:	learn: 0.4172197	total: 26.2ms	remaining: 644ms
# 39:	learn: 0.4128430	total: 26.8ms	remaining: 643ms
# 40:	learn: 0.4084169	total: 27.5ms	remaining: 642ms
# 41:	learn: 0.4040079	total: 28.2ms	remaining: 642ms
# 42:	learn: 0.4001962	total: 28.8ms	remaining: 641ms
# 43:	learn: 0.3956488	total: 29.5ms	remaining: 640ms
# 44:	learn: 0.3909756	total: 30.7ms	remaining: 652ms
# 45:	learn: 0.3866847	total: 31.5ms	remaining: 654ms
# 46:	learn: 0.3833688	total: 32.3ms	remaining: 654ms
# 47:	learn: 0.3793514	total: 33ms	remaining: 655ms
# 48:	learn: 0.3753285	total: 33.7ms	remaining: 655ms
# 49:	learn: 0.3722360	total: 34.4ms	remaining: 654ms
# 50:	learn: 0.3692176	total: 35.1ms	remaining: 653ms
# 51:	learn: 0.3657363	total: 35.8ms	remaining: 652ms
# 52:	learn: 0.3624231	total: 36.4ms	remaining: 651ms
# 53:	learn: 0.3596260	total: 37.1ms	remaining: 650ms
# 54:	learn: 0.3563451	total: 37.8ms	remaining: 649ms
# 55:	learn: 0.3530503	total: 38.4ms	remaining: 648ms
# 56:	learn: 0.3500112	total: 39.1ms	remaining: 647ms
# 57:	learn: 0.3476306	total: 39.9ms	remaining: 647ms
# 58:	learn: 0.3457343	total: 40.5ms	remaining: 647ms
# 59:	learn: 0.3430561	total: 41.2ms	remaining: 645ms
# 60:	learn: 0.3396156	total: 41.9ms	remaining: 645ms
# 61:	learn: 0.3365831	total: 42.5ms	remaining: 644ms
# 62:	learn: 0.3336872	total: 43.2ms	remaining: 643ms
# 63:	learn: 0.3309217	total: 43.9ms	remaining: 641ms
# 64:	learn: 0.3279409	total: 44.5ms	remaining: 641ms
# 65:	learn: 0.3258467	total: 45.2ms	remaining: 640ms
# 66:	learn: 0.3230666	total: 45.8ms	remaining: 638ms
# 67:	learn: 0.3207871	total: 46.5ms	remaining: 637ms
# 68:	learn: 0.3183489	total: 47.2ms	remaining: 636ms
# 69:	learn: 0.3163101	total: 47.8ms	remaining: 635ms
# 70:	learn: 0.3137098	total: 49.2ms	remaining: 643ms
# 71:	learn: 0.3113921	total: 50.1ms	remaining: 646ms
# 72:	learn: 0.3087822	total: 50.8ms	remaining: 645ms
# 73:	learn: 0.3064623	total: 51.5ms	remaining: 644ms
# 74:	learn: 0.3042686	total: 52.2ms	remaining: 644ms
# 75:	learn: 0.3020599	total: 52.9ms	remaining: 643ms
# 76:	learn: 0.2999112	total: 53.6ms	remaining: 642ms
# 77:	learn: 0.2977227	total: 54.2ms	remaining: 641ms
# 78:	learn: 0.2958156	total: 54.9ms	remaining: 640ms
# 79:	learn: 0.2934246	total: 55.6ms	remaining: 639ms
# 80:	learn: 0.2914353	total: 56.2ms	remaining: 638ms
# 81:	learn: 0.2892095	total: 56.9ms	remaining: 637ms
# 82:	learn: 0.2871427	total: 57.6ms	remaining: 636ms
# 83:	learn: 0.2852726	total: 58.2ms	remaining: 635ms
# 84:	learn: 0.2835239	total: 58.9ms	remaining: 634ms
# 85:	learn: 0.2817340	total: 59.6ms	remaining: 633ms
# 86:	learn: 0.2801938	total: 60.2ms	remaining: 632ms
# 87:	learn: 0.2782819	total: 60.9ms	remaining: 631ms
# 88:	learn: 0.2771022	total: 61.6ms	remaining: 630ms
# 89:	learn: 0.2753499	total: 62.2ms	remaining: 629ms
# 90:	learn: 0.2737855	total: 62.9ms	remaining: 628ms
# 91:	learn: 0.2723389	total: 63.5ms	remaining: 627ms
# 92:	learn: 0.2708426	total: 64.2ms	remaining: 627ms
# 93:	learn: 0.2694461	total: 64.9ms	remaining: 625ms
# 94:	learn: 0.2678964	total: 65.6ms	remaining: 625ms
# 95:	learn: 0.2662113	total: 66.2ms	remaining: 623ms
# 96:	learn: 0.2647690	total: 66.9ms	remaining: 623ms
# 97:	learn: 0.2635399	total: 67.5ms	remaining: 621ms
# 98:	learn: 0.2622236	total: 68.2ms	remaining: 620ms
# 99:	learn: 0.2607480	total: 68.8ms	remaining: 620ms
# 100:	learn: 0.2593103	total: 69.5ms	remaining: 618ms
# 101:	learn: 0.2579945	total: 70.1ms	remaining: 618ms
# 102:	learn: 0.2572429	total: 70.8ms	remaining: 617ms
# 103:	learn: 0.2561535	total: 71.5ms	remaining: 616ms
# 104:	learn: 0.2548253	total: 72.7ms	remaining: 620ms
# 105:	learn: 0.2535745	total: 73.5ms	remaining: 620ms
# 106:	learn: 0.2521332	total: 74.2ms	remaining: 619ms
# 107:	learn: 0.2508083	total: 74.9ms	remaining: 619ms
# 108:	learn: 0.2497237	total: 75.6ms	remaining: 618ms
# 109:	learn: 0.2485752	total: 76.3ms	remaining: 617ms
# 110:	learn: 0.2475995	total: 76.9ms	remaining: 616ms
# 111:	learn: 0.2464175	total: 77.6ms	remaining: 615ms
# 112:	learn: 0.2455043	total: 78.3ms	remaining: 615ms
# 113:	learn: 0.2444070	total: 79ms	remaining: 614ms
# 114:	learn: 0.2432481	total: 79.7ms	remaining: 613ms
# 115:	learn: 0.2423948	total: 80.3ms	remaining: 612ms
# 116:	learn: 0.2413045	total: 81ms	remaining: 611ms
# 117:	learn: 0.2404039	total: 81.7ms	remaining: 610ms
# 118:	learn: 0.2393967	total: 82.3ms	remaining: 609ms
# 119:	learn: 0.2383410	total: 83ms	remaining: 609ms
# 120:	learn: 0.2375278	total: 83.7ms	remaining: 608ms
# 121:	learn: 0.2365093	total: 84.4ms	remaining: 607ms
# 122:	learn: 0.2358293	total: 85ms	remaining: 606ms
# 123:	learn: 0.2351514	total: 85.7ms	remaining: 605ms
# 124:	learn: 0.2342667	total: 86.4ms	remaining: 604ms
# 125:	learn: 0.2332790	total: 87ms	remaining: 604ms
# 126:	learn: 0.2324177	total: 87.7ms	remaining: 603ms
# 127:	learn: 0.2316001	total: 88.3ms	remaining: 602ms
# 128:	learn: 0.2309799	total: 89ms	remaining: 601ms
# 129:	learn: 0.2300098	total: 89.7ms	remaining: 600ms
# 130:	learn: 0.2289489	total: 90.4ms	remaining: 599ms
# 131:	learn: 0.2281967	total: 91ms	remaining: 599ms
# 132:	learn: 0.2273449	total: 91.7ms	remaining: 598ms
# 133:	learn: 0.2265731	total: 92.4ms	remaining: 597ms
# 134:	learn: 0.2257615	total: 93ms	remaining: 596ms
# 135:	learn: 0.2249723	total: 93.7ms	remaining: 595ms
# 136:	learn: 0.2241990	total: 94.4ms	remaining: 595ms
# 137:	learn: 0.2234880	total: 95.1ms	remaining: 594ms
# 138:	learn: 0.2226000	total: 95.7ms	remaining: 593ms
# 139:	learn: 0.2218123	total: 96.4ms	remaining: 592ms
# 140:	learn: 0.2211375	total: 97.1ms	remaining: 592ms
# 141:	learn: 0.2205031	total: 97.7ms	remaining: 591ms
# 142:	learn: 0.2199052	total: 98.4ms	remaining: 590ms
# 143:	learn: 0.2194116	total: 99.1ms	remaining: 589ms
# 144:	learn: 0.2187942	total: 99.7ms	remaining: 588ms
# 145:	learn: 0.2181144	total: 100ms	remaining: 587ms
# 146:	learn: 0.2175951	total: 101ms	remaining: 586ms
# 147:	learn: 0.2168288	total: 102ms	remaining: 586ms
# 148:	learn: 0.2162261	total: 102ms	remaining: 585ms
# 149:	learn: 0.2157369	total: 103ms	remaining: 584ms
# 150:	learn: 0.2150491	total: 104ms	remaining: 583ms
# 151:	learn: 0.2142577	total: 104ms	remaining: 582ms
# 152:	learn: 0.2136401	total: 105ms	remaining: 581ms
# 153:	learn: 0.2131047	total: 106ms	remaining: 581ms
# 154:	learn: 0.2125900	total: 106ms	remaining: 580ms
# 155:	learn: 0.2119712	total: 107ms	remaining: 579ms
# 156:	learn: 0.2114891	total: 108ms	remaining: 578ms
# 157:	learn: 0.2110030	total: 108ms	remaining: 577ms
# 158:	learn: 0.2104056	total: 109ms	remaining: 576ms
# 159:	learn: 0.2099681	total: 110ms	remaining: 576ms
# 160:	learn: 0.2095866	total: 110ms	remaining: 575ms
# 161:	learn: 0.2090657	total: 111ms	remaining: 574ms
# 162:	learn: 0.2086213	total: 112ms	remaining: 573ms
# 163:	learn: 0.2081631	total: 112ms	remaining: 572ms
# 164:	learn: 0.2077267	total: 113ms	remaining: 571ms
# 165:	learn: 0.2074723	total: 114ms	remaining: 570ms
# 166:	learn: 0.2070137	total: 114ms	remaining: 569ms
# 167:	learn: 0.2066999	total: 115ms	remaining: 569ms
# 168:	learn: 0.2061705	total: 115ms	remaining: 568ms
# 169:	learn: 0.2056581	total: 116ms	remaining: 567ms
# 170:	learn: 0.2052095	total: 117ms	remaining: 566ms
# 171:	learn: 0.2048257	total: 118ms	remaining: 566ms
# 172:	learn: 0.2044556	total: 118ms	remaining: 565ms
# 173:	learn: 0.2039924	total: 119ms	remaining: 565ms
# 174:	learn: 0.2035069	total: 120ms	remaining: 564ms
# 175:	learn: 0.2030883	total: 120ms	remaining: 563ms
# 176:	learn: 0.2025749	total: 121ms	remaining: 563ms
# 177:	learn: 0.2020780	total: 122ms	remaining: 562ms
# 178:	learn: 0.2017419	total: 122ms	remaining: 561ms
# 179:	learn: 0.2014217	total: 123ms	remaining: 560ms
# 180:	learn: 0.2011100	total: 124ms	remaining: 559ms
# 181:	learn: 0.2006862	total: 124ms	remaining: 559ms
# 182:	learn: 0.2003192	total: 125ms	remaining: 558ms
# 183:	learn: 0.1999647	total: 126ms	remaining: 557ms
# 184:	learn: 0.1994633	total: 126ms	remaining: 556ms
# 185:	learn: 0.1991847	total: 127ms	remaining: 556ms
# 186:	learn: 0.1989378	total: 128ms	remaining: 555ms
# 187:	learn: 0.1986262	total: 128ms	remaining: 554ms
# 188:	learn: 0.1982441	total: 129ms	remaining: 554ms
# 189:	learn: 0.1980082	total: 130ms	remaining: 552ms
# 190:	learn: 0.1976280	total: 130ms	remaining: 552ms
# 191:	learn: 0.1971048	total: 131ms	remaining: 551ms
# 192:	learn: 0.1966967	total: 132ms	remaining: 550ms
# 193:	learn: 0.1963432	total: 132ms	remaining: 549ms
# 194:	learn: 0.1958941	total: 133ms	remaining: 549ms
# 195:	learn: 0.1956558	total: 134ms	remaining: 548ms
# 196:	learn: 0.1953257	total: 134ms	remaining: 547ms
# 197:	learn: 0.1949062	total: 135ms	remaining: 547ms
# 198:	learn: 0.1945482	total: 136ms	remaining: 546ms
# 199:	learn: 0.1942151	total: 136ms	remaining: 545ms
# 200:	learn: 0.1938319	total: 137ms	remaining: 544ms
# 201:	learn: 0.1935808	total: 138ms	remaining: 544ms
# 202:	learn: 0.1932279	total: 138ms	remaining: 543ms
# 203:	learn: 0.1928608	total: 139ms	remaining: 542ms
# 204:	learn: 0.1925677	total: 140ms	remaining: 542ms
# 205:	learn: 0.1923348	total: 140ms	remaining: 541ms
# 206:	learn: 0.1919800	total: 141ms	remaining: 540ms
# 207:	learn: 0.1916155	total: 142ms	remaining: 539ms
# 208:	learn: 0.1913849	total: 142ms	remaining: 539ms
# 209:	learn: 0.1909963	total: 143ms	remaining: 538ms
# 210:	learn: 0.1905892	total: 144ms	remaining: 537ms
# 211:	learn: 0.1902616	total: 144ms	remaining: 537ms
# 212:	learn: 0.1899192	total: 145ms	remaining: 536ms
# 213:	learn: 0.1895013	total: 146ms	remaining: 535ms
# 214:	learn: 0.1891920	total: 146ms	remaining: 534ms
# 215:	learn: 0.1889525	total: 147ms	remaining: 534ms
# 216:	learn: 0.1886583	total: 148ms	remaining: 533ms
# 217:	learn: 0.1882441	total: 148ms	remaining: 532ms
# 218:	learn: 0.1880273	total: 149ms	remaining: 531ms
# 219:	learn: 0.1878606	total: 150ms	remaining: 533ms
# 220:	learn: 0.1875316	total: 151ms	remaining: 533ms
# 221:	learn: 0.1872801	total: 152ms	remaining: 533ms
# 222:	learn: 0.1870531	total: 153ms	remaining: 532ms
# 223:	learn: 0.1867313	total: 154ms	remaining: 532ms
# 224:	learn: 0.1865303	total: 154ms	remaining: 531ms
# 225:	learn: 0.1862334	total: 155ms	remaining: 530ms
# 226:	learn: 0.1858271	total: 156ms	remaining: 530ms
# 227:	learn: 0.1856100	total: 156ms	remaining: 529ms
# 228:	learn: 0.1852198	total: 157ms	remaining: 529ms
# 229:	learn: 0.1850900	total: 158ms	remaining: 528ms
# 230:	learn: 0.1847259	total: 158ms	remaining: 527ms
# 231:	learn: 0.1844358	total: 159ms	remaining: 527ms
# 232:	learn: 0.1841472	total: 160ms	remaining: 526ms
# 233:	learn: 0.1838995	total: 160ms	remaining: 525ms
# 234:	learn: 0.1837303	total: 161ms	remaining: 524ms
# 235:	learn: 0.1834623	total: 162ms	remaining: 524ms
# 236:	learn: 0.1831649	total: 163ms	remaining: 523ms
# 237:	learn: 0.1830206	total: 163ms	remaining: 522ms
# 238:	learn: 0.1827645	total: 164ms	remaining: 522ms
# 239:	learn: 0.1824870	total: 165ms	remaining: 521ms
# 240:	learn: 0.1823141	total: 165ms	remaining: 520ms
# 241:	learn: 0.1820073	total: 166ms	remaining: 520ms
# 242:	learn: 0.1818458	total: 167ms	remaining: 519ms
# 243:	learn: 0.1816412	total: 167ms	remaining: 518ms
# 244:	learn: 0.1814095	total: 168ms	remaining: 518ms
# 245:	learn: 0.1812008	total: 169ms	remaining: 517ms
# 246:	learn: 0.1809488	total: 169ms	remaining: 516ms
# 247:	learn: 0.1806291	total: 170ms	remaining: 515ms
# 248:	learn: 0.1805025	total: 171ms	remaining: 515ms
# 249:	learn: 0.1801686	total: 171ms	remaining: 514ms
# 250:	learn: 0.1799599	total: 172ms	remaining: 513ms
# 251:	learn: 0.1797185	total: 173ms	remaining: 512ms
# 252:	learn: 0.1795031	total: 173ms	remaining: 512ms
# 253:	learn: 0.1792790	total: 174ms	remaining: 511ms
# 254:	learn: 0.1791093	total: 175ms	remaining: 510ms
# 255:	learn: 0.1787794	total: 175ms	remaining: 510ms
# 256:	learn: 0.1786545	total: 176ms	remaining: 509ms
# 257:	learn: 0.1785205	total: 177ms	remaining: 508ms
# 258:	learn: 0.1783468	total: 177ms	remaining: 508ms
# 259:	learn: 0.1780944	total: 178ms	remaining: 507ms
# 260:	learn: 0.1778137	total: 179ms	remaining: 506ms
# 261:	learn: 0.1775457	total: 180ms	remaining: 506ms
# 262:	learn: 0.1773724	total: 180ms	remaining: 505ms
# 263:	learn: 0.1771551	total: 181ms	remaining: 504ms
# 264:	learn: 0.1769561	total: 182ms	remaining: 504ms
# 265:	learn: 0.1767894	total: 182ms	remaining: 503ms
# 266:	learn: 0.1766098	total: 183ms	remaining: 502ms
# 267:	learn: 0.1763857	total: 184ms	remaining: 501ms
# 268:	learn: 0.1762341	total: 184ms	remaining: 501ms
# 269:	learn: 0.1760975	total: 185ms	remaining: 500ms
# 270:	learn: 0.1759025	total: 186ms	remaining: 499ms
# 271:	learn: 0.1756999	total: 186ms	remaining: 499ms
# 272:	learn: 0.1755141	total: 187ms	remaining: 498ms
# 273:	learn: 0.1753449	total: 188ms	remaining: 497ms
# 274:	learn: 0.1752576	total: 188ms	remaining: 496ms
# 275:	learn: 0.1751051	total: 189ms	remaining: 496ms
# 276:	learn: 0.1749058	total: 190ms	remaining: 497ms
# 277:	learn: 0.1744531	total: 192ms	remaining: 497ms
# 278:	learn: 0.1743002	total: 192ms	remaining: 497ms
# 279:	learn: 0.1741621	total: 196ms	remaining: 504ms
# 280:	learn: 0.1739447	total: 197ms	remaining: 503ms
# 281:	learn: 0.1737867	total: 197ms	remaining: 503ms
# 282:	learn: 0.1736058	total: 198ms	remaining: 502ms
# 283:	learn: 0.1733954	total: 199ms	remaining: 501ms
# 284:	learn: 0.1732383	total: 199ms	remaining: 500ms
# 285:	learn: 0.1731695	total: 200ms	remaining: 500ms
# 286:	learn: 0.1729836	total: 201ms	remaining: 499ms
# 287:	learn: 0.1727737	total: 201ms	remaining: 498ms
# 288:	learn: 0.1725950	total: 202ms	remaining: 497ms
# 289:	learn: 0.1725323	total: 203ms	remaining: 496ms
# 290:	learn: 0.1722736	total: 203ms	remaining: 496ms
# 291:	learn: 0.1720801	total: 204ms	remaining: 495ms
# 292:	learn: 0.1717837	total: 205ms	remaining: 494ms
# 293:	learn: 0.1716531	total: 206ms	remaining: 494ms
# 294:	learn: 0.1714738	total: 206ms	remaining: 493ms
# 295:	learn: 0.1712931	total: 207ms	remaining: 492ms
# 296:	learn: 0.1711642	total: 208ms	remaining: 491ms
# 297:	learn: 0.1709697	total: 208ms	remaining: 491ms
# 298:	learn: 0.1708411	total: 209ms	remaining: 490ms
# 299:	learn: 0.1707288	total: 210ms	remaining: 489ms
# 300:	learn: 0.1705714	total: 210ms	remaining: 488ms
# 301:	learn: 0.1704359	total: 211ms	remaining: 487ms
# 302:	learn: 0.1702219	total: 212ms	remaining: 487ms
# 303:	learn: 0.1699387	total: 212ms	remaining: 486ms
# 304:	learn: 0.1697770	total: 213ms	remaining: 485ms
# 305:	learn: 0.1696481	total: 215ms	remaining: 487ms
# 306:	learn: 0.1695840	total: 216ms	remaining: 487ms
# 307:	learn: 0.1694477	total: 217ms	remaining: 487ms
# 308:	learn: 0.1693319	total: 218ms	remaining: 487ms
# 309:	learn: 0.1691418	total: 218ms	remaining: 486ms
# 310:	learn: 0.1690495	total: 219ms	remaining: 485ms
# 311:	learn: 0.1689612	total: 220ms	remaining: 484ms
# 312:	learn: 0.1688103	total: 220ms	remaining: 484ms
# 313:	learn: 0.1686725	total: 221ms	remaining: 483ms
# 314:	learn: 0.1685461	total: 222ms	remaining: 482ms
# 315:	learn: 0.1684160	total: 222ms	remaining: 481ms
# 316:	learn: 0.1682198	total: 223ms	remaining: 480ms
# 317:	learn: 0.1681823	total: 224ms	remaining: 480ms
# 318:	learn: 0.1680222	total: 224ms	remaining: 479ms
# 319:	learn: 0.1679158	total: 225ms	remaining: 478ms
# 320:	learn: 0.1676749	total: 226ms	remaining: 477ms
# 321:	learn: 0.1676121	total: 226ms	remaining: 477ms
# 322:	learn: 0.1674406	total: 227ms	remaining: 476ms
# 323:	learn: 0.1672868	total: 228ms	remaining: 475ms
# 324:	learn: 0.1671966	total: 228ms	remaining: 474ms
# 325:	learn: 0.1671153	total: 229ms	remaining: 473ms
# 326:	learn: 0.1669439	total: 230ms	remaining: 473ms
# 327:	learn: 0.1668228	total: 230ms	remaining: 472ms
# 328:	learn: 0.1665887	total: 231ms	remaining: 471ms
# 329:	learn: 0.1664085	total: 232ms	remaining: 470ms
# 330:	learn: 0.1662652	total: 232ms	remaining: 469ms
# 331:	learn: 0.1661255	total: 233ms	remaining: 469ms
# 332:	learn: 0.1659915	total: 234ms	remaining: 468ms
# 333:	learn: 0.1657610	total: 234ms	remaining: 467ms
# 334:	learn: 0.1656575	total: 235ms	remaining: 466ms
# 335:	learn: 0.1654928	total: 236ms	remaining: 465ms
# 336:	learn: 0.1653653	total: 236ms	remaining: 465ms
# 337:	learn: 0.1651748	total: 237ms	remaining: 464ms
# 338:	learn: 0.1650783	total: 238ms	remaining: 463ms
# 339:	learn: 0.1649574	total: 238ms	remaining: 463ms
# 340:	learn: 0.1647640	total: 239ms	remaining: 462ms
# 341:	learn: 0.1646512	total: 240ms	remaining: 461ms
# 342:	learn: 0.1645119	total: 240ms	remaining: 460ms
# 343:	learn: 0.1643757	total: 241ms	remaining: 460ms
# 344:	learn: 0.1641467	total: 242ms	remaining: 459ms
# 345:	learn: 0.1640625	total: 242ms	remaining: 458ms
# 346:	learn: 0.1639150	total: 243ms	remaining: 457ms
# 347:	learn: 0.1638410	total: 244ms	remaining: 456ms
# 348:	learn: 0.1637392	total: 244ms	remaining: 456ms
# 349:	learn: 0.1636004	total: 245ms	remaining: 455ms
# 350:	learn: 0.1633839	total: 246ms	remaining: 454ms
# 351:	learn: 0.1631333	total: 246ms	remaining: 453ms
# 352:	learn: 0.1630035	total: 247ms	remaining: 453ms
# 353:	learn: 0.1627419	total: 248ms	remaining: 452ms
# 354:	learn: 0.1625288	total: 248ms	remaining: 451ms
# 355:	learn: 0.1624260	total: 249ms	remaining: 450ms
# 356:	learn: 0.1622621	total: 250ms	remaining: 450ms
# 357:	learn: 0.1621537	total: 250ms	remaining: 449ms
# 358:	learn: 0.1619571	total: 251ms	remaining: 448ms
# 359:	learn: 0.1618436	total: 252ms	remaining: 448ms
# 360:	learn: 0.1615235	total: 252ms	remaining: 447ms
# 361:	learn: 0.1614374	total: 253ms	remaining: 446ms
# 362:	learn: 0.1613799	total: 254ms	remaining: 445ms
# 363:	learn: 0.1611665	total: 254ms	remaining: 444ms
# 364:	learn: 0.1610836	total: 255ms	remaining: 444ms
# 365:	learn: 0.1609686	total: 256ms	remaining: 443ms
# 366:	learn: 0.1608116	total: 256ms	remaining: 442ms
# 367:	learn: 0.1606643	total: 257ms	remaining: 441ms
# 368:	learn: 0.1605645	total: 258ms	remaining: 441ms
# 369:	learn: 0.1603933	total: 258ms	remaining: 440ms
# 370:	learn: 0.1603362	total: 259ms	remaining: 439ms
# 371:	learn: 0.1602414	total: 260ms	remaining: 439ms
# 372:	learn: 0.1600852	total: 260ms	remaining: 438ms
# 373:	learn: 0.1599961	total: 261ms	remaining: 437ms
# 374:	learn: 0.1599091	total: 262ms	remaining: 436ms
# 375:	learn: 0.1598555	total: 263ms	remaining: 436ms
# 376:	learn: 0.1596238	total: 263ms	remaining: 435ms
# 377:	learn: 0.1595621	total: 264ms	remaining: 434ms
# 378:	learn: 0.1592941	total: 265ms	remaining: 434ms
# 379:	learn: 0.1590946	total: 265ms	remaining: 433ms
# 380:	learn: 0.1590174	total: 266ms	remaining: 432ms
# 381:	learn: 0.1588738	total: 267ms	remaining: 431ms
# 382:	learn: 0.1587341	total: 267ms	remaining: 431ms
# 383:	learn: 0.1586450	total: 268ms	remaining: 430ms
# 384:	learn: 0.1584868	total: 269ms	remaining: 429ms
# 385:	learn: 0.1584108	total: 270ms	remaining: 429ms
# 386:	learn: 0.1582479	total: 271ms	remaining: 429ms
# 387:	learn: 0.1579613	total: 272ms	remaining: 429ms
# 388:	learn: 0.1578479	total: 273ms	remaining: 428ms
# 389:	learn: 0.1577606	total: 273ms	remaining: 428ms
# 390:	learn: 0.1575432	total: 274ms	remaining: 427ms
# 391:	learn: 0.1574344	total: 275ms	remaining: 427ms
# 392:	learn: 0.1573502	total: 276ms	remaining: 426ms
# 393:	learn: 0.1572279	total: 276ms	remaining: 425ms
# 394:	learn: 0.1571558	total: 277ms	remaining: 424ms
# 395:	learn: 0.1570837	total: 278ms	remaining: 424ms
# 396:	learn: 0.1569050	total: 278ms	remaining: 423ms
# 397:	learn: 0.1568536	total: 279ms	remaining: 422ms
# 398:	learn: 0.1567742	total: 280ms	remaining: 422ms
# 399:	learn: 0.1566636	total: 281ms	remaining: 421ms
# 400:	learn: 0.1564240	total: 281ms	remaining: 420ms
# 401:	learn: 0.1561869	total: 282ms	remaining: 420ms
# 402:	learn: 0.1560924	total: 283ms	remaining: 419ms
# 403:	learn: 0.1559135	total: 283ms	remaining: 418ms
# 404:	learn: 0.1558309	total: 284ms	remaining: 417ms
# 405:	learn: 0.1557332	total: 285ms	remaining: 417ms
# 406:	learn: 0.1556430	total: 285ms	remaining: 416ms
# 407:	learn: 0.1553862	total: 286ms	remaining: 415ms
# 408:	learn: 0.1552277	total: 287ms	remaining: 414ms
# 409:	learn: 0.1551399	total: 287ms	remaining: 414ms
# 410:	learn: 0.1549809	total: 288ms	remaining: 413ms
# 411:	learn: 0.1547652	total: 289ms	remaining: 412ms
# 412:	learn: 0.1546192	total: 289ms	remaining: 411ms
# 413:	learn: 0.1544774	total: 290ms	remaining: 411ms
# 414:	learn: 0.1543731	total: 291ms	remaining: 410ms
# 415:	learn: 0.1543038	total: 291ms	remaining: 409ms
# 416:	learn: 0.1541851	total: 292ms	remaining: 408ms
# 417:	learn: 0.1540205	total: 293ms	remaining: 408ms
# 418:	learn: 0.1539140	total: 293ms	remaining: 407ms
# 419:	learn: 0.1537316	total: 294ms	remaining: 406ms
# 420:	learn: 0.1535821	total: 295ms	remaining: 405ms
# 421:	learn: 0.1534704	total: 295ms	remaining: 405ms
# 422:	learn: 0.1533917	total: 296ms	remaining: 404ms
# 423:	learn: 0.1531254	total: 297ms	remaining: 403ms
# 424:	learn: 0.1530397	total: 297ms	remaining: 402ms
# 425:	learn: 0.1529472	total: 298ms	remaining: 402ms
# 426:	learn: 0.1526641	total: 299ms	remaining: 401ms
# 427:	learn: 0.1525701	total: 299ms	remaining: 400ms
# 428:	learn: 0.1524707	total: 300ms	remaining: 399ms
# 429:	learn: 0.1523998	total: 301ms	remaining: 399ms
# 430:	learn: 0.1521731	total: 301ms	remaining: 398ms
# 431:	learn: 0.1521006	total: 302ms	remaining: 397ms
# 432:	learn: 0.1519776	total: 303ms	remaining: 397ms
# 433:	learn: 0.1517792	total: 303ms	remaining: 396ms
# 434:	learn: 0.1515061	total: 304ms	remaining: 395ms
# 435:	learn: 0.1513359	total: 305ms	remaining: 394ms
# 436:	learn: 0.1512443	total: 305ms	remaining: 394ms
# 437:	learn: 0.1511373	total: 306ms	remaining: 393ms
# 438:	learn: 0.1510430	total: 307ms	remaining: 392ms
# 439:	learn: 0.1509159	total: 307ms	remaining: 391ms
# 440:	learn: 0.1508764	total: 308ms	remaining: 391ms
# 441:	learn: 0.1508004	total: 309ms	remaining: 390ms
# 442:	learn: 0.1506720	total: 309ms	remaining: 389ms
# 443:	learn: 0.1505994	total: 310ms	remaining: 388ms
# 444:	learn: 0.1504589	total: 311ms	remaining: 388ms
# 445:	learn: 0.1502654	total: 311ms	remaining: 387ms
# 446:	learn: 0.1501249	total: 312ms	remaining: 386ms
# 447:	learn: 0.1499531	total: 313ms	remaining: 385ms
# 448:	learn: 0.1498303	total: 313ms	remaining: 385ms
# 449:	learn: 0.1497143	total: 314ms	remaining: 384ms
# 450:	learn: 0.1496085	total: 315ms	remaining: 383ms
# 451:	learn: 0.1494945	total: 316ms	remaining: 383ms
# 452:	learn: 0.1493722	total: 316ms	remaining: 382ms
# 453:	learn: 0.1492419	total: 317ms	remaining: 381ms
# 454:	learn: 0.1491483	total: 318ms	remaining: 380ms
# 455:	learn: 0.1490384	total: 318ms	remaining: 380ms
# 456:	learn: 0.1489569	total: 319ms	remaining: 379ms
# 457:	learn: 0.1488053	total: 320ms	remaining: 378ms
# 458:	learn: 0.1486551	total: 320ms	remaining: 378ms
# 459:	learn: 0.1485831	total: 321ms	remaining: 377ms
# 460:	learn: 0.1484979	total: 322ms	remaining: 376ms
# 461:	learn: 0.1484176	total: 322ms	remaining: 375ms
# 462:	learn: 0.1482903	total: 323ms	remaining: 375ms
# 463:	learn: 0.1482224	total: 324ms	remaining: 374ms
# 464:	learn: 0.1480714	total: 324ms	remaining: 373ms
# 465:	learn: 0.1479726	total: 325ms	remaining: 373ms
# 466:	learn: 0.1478195	total: 326ms	remaining: 372ms
# 467:	learn: 0.1477163	total: 326ms	remaining: 371ms
# 468:	learn: 0.1476899	total: 327ms	remaining: 370ms
# 469:	learn: 0.1476057	total: 328ms	remaining: 369ms
# 470:	learn: 0.1475131	total: 328ms	remaining: 369ms
# 471:	learn: 0.1474480	total: 329ms	remaining: 368ms
# 472:	learn: 0.1473252	total: 330ms	remaining: 368ms
# 473:	learn: 0.1471608	total: 331ms	remaining: 367ms
# 474:	learn: 0.1470197	total: 331ms	remaining: 366ms
# 475:	learn: 0.1468287	total: 332ms	remaining: 365ms
# 476:	learn: 0.1467658	total: 333ms	remaining: 365ms
# 477:	learn: 0.1466702	total: 333ms	remaining: 364ms
# 478:	learn: 0.1465173	total: 334ms	remaining: 363ms
# 479:	learn: 0.1464374	total: 335ms	remaining: 363ms
# 480:	learn: 0.1462040	total: 335ms	remaining: 362ms
# 481:	learn: 0.1461628	total: 336ms	remaining: 361ms
# 482:	learn: 0.1460532	total: 337ms	remaining: 360ms
# 483:	learn: 0.1459879	total: 337ms	remaining: 360ms
# 484:	learn: 0.1457618	total: 338ms	remaining: 359ms
# 485:	learn: 0.1456866	total: 339ms	remaining: 358ms
# 486:	learn: 0.1455708	total: 339ms	remaining: 358ms
# 487:	learn: 0.1455222	total: 340ms	remaining: 357ms
# 488:	learn: 0.1454173	total: 341ms	remaining: 356ms
# 489:	learn: 0.1452888	total: 341ms	remaining: 355ms
# 490:	learn: 0.1451471	total: 342ms	remaining: 355ms
# 491:	learn: 0.1450068	total: 343ms	remaining: 354ms
# 492:	learn: 0.1448278	total: 343ms	remaining: 353ms
# 493:	learn: 0.1447453	total: 344ms	remaining: 352ms
# 494:	learn: 0.1446757	total: 345ms	remaining: 352ms
# 495:	learn: 0.1445720	total: 345ms	remaining: 351ms
# 496:	learn: 0.1444928	total: 346ms	remaining: 350ms
# 497:	learn: 0.1443833	total: 347ms	remaining: 350ms
# 498:	learn: 0.1442587	total: 348ms	remaining: 349ms
# 499:	learn: 0.1441710	total: 348ms	remaining: 348ms
# 500:	learn: 0.1440508	total: 349ms	remaining: 347ms
# 501:	learn: 0.1439304	total: 350ms	remaining: 347ms
# 502:	learn: 0.1437790	total: 350ms	remaining: 346ms
# 503:	learn: 0.1437370	total: 351ms	remaining: 345ms
# 504:	learn: 0.1436825	total: 352ms	remaining: 345ms
# 505:	learn: 0.1436104	total: 352ms	remaining: 344ms
# 506:	learn: 0.1435393	total: 353ms	remaining: 343ms
# 507:	learn: 0.1433499	total: 354ms	remaining: 342ms
# 508:	learn: 0.1433318	total: 354ms	remaining: 341ms
# 509:	learn: 0.1432657	total: 355ms	remaining: 341ms
# 510:	learn: 0.1432181	total: 355ms	remaining: 340ms
# 511:	learn: 0.1431297	total: 356ms	remaining: 339ms
# 512:	learn: 0.1430499	total: 357ms	remaining: 339ms
# 513:	learn: 0.1429224	total: 357ms	remaining: 338ms
# 514:	learn: 0.1427705	total: 358ms	remaining: 337ms
# 515:	learn: 0.1427295	total: 359ms	remaining: 337ms
# 516:	learn: 0.1425478	total: 360ms	remaining: 336ms
# 517:	learn: 0.1424314	total: 360ms	remaining: 335ms
# 518:	learn: 0.1423055	total: 361ms	remaining: 335ms
# 519:	learn: 0.1422240	total: 362ms	remaining: 334ms
# 520:	learn: 0.1421163	total: 362ms	remaining: 333ms
# 521:	learn: 0.1419667	total: 363ms	remaining: 332ms
# 522:	learn: 0.1418887	total: 364ms	remaining: 332ms
# 523:	learn: 0.1418350	total: 364ms	remaining: 331ms
# 524:	learn: 0.1416761	total: 365ms	remaining: 330ms
# 525:	learn: 0.1415115	total: 366ms	remaining: 330ms
# 526:	learn: 0.1414344	total: 366ms	remaining: 329ms
# 527:	learn: 0.1413702	total: 367ms	remaining: 328ms
# 528:	learn: 0.1411869	total: 368ms	remaining: 327ms
# 529:	learn: 0.1411268	total: 368ms	remaining: 327ms
# 530:	learn: 0.1410423	total: 369ms	remaining: 326ms
# 531:	learn: 0.1409889	total: 370ms	remaining: 325ms
# 532:	learn: 0.1409233	total: 370ms	remaining: 324ms
# 533:	learn: 0.1408598	total: 371ms	remaining: 324ms
# 534:	learn: 0.1407811	total: 372ms	remaining: 323ms
# 535:	learn: 0.1406360	total: 372ms	remaining: 322ms
# 536:	learn: 0.1404703	total: 373ms	remaining: 321ms
# 537:	learn: 0.1403946	total: 374ms	remaining: 321ms
# 538:	learn: 0.1403165	total: 374ms	remaining: 320ms
# 539:	learn: 0.1402269	total: 375ms	remaining: 319ms
# 540:	learn: 0.1401205	total: 376ms	remaining: 319ms
# 541:	learn: 0.1400794	total: 376ms	remaining: 318ms
# 542:	learn: 0.1399974	total: 377ms	remaining: 317ms
# 543:	learn: 0.1398729	total: 378ms	remaining: 317ms
# 544:	learn: 0.1398048	total: 378ms	remaining: 316ms
# 545:	learn: 0.1397197	total: 379ms	remaining: 315ms
# 546:	learn: 0.1396694	total: 380ms	remaining: 314ms
# 547:	learn: 0.1395924	total: 380ms	remaining: 314ms
# 548:	learn: 0.1394816	total: 381ms	remaining: 313ms
# 549:	learn: 0.1394200	total: 383ms	remaining: 313ms
# 550:	learn: 0.1392599	total: 386ms	remaining: 314ms
# 551:	learn: 0.1392073	total: 387ms	remaining: 314ms
# 552:	learn: 0.1391248	total: 389ms	remaining: 315ms
# 553:	learn: 0.1391185	total: 390ms	remaining: 314ms
# 554:	learn: 0.1390601	total: 391ms	remaining: 313ms
# 555:	learn: 0.1388245	total: 392ms	remaining: 313ms
# 556:	learn: 0.1386502	total: 392ms	remaining: 312ms
# 557:	learn: 0.1385526	total: 393ms	remaining: 311ms
# 558:	learn: 0.1384602	total: 394ms	remaining: 311ms
# 559:	learn: 0.1383859	total: 394ms	remaining: 310ms
# 560:	learn: 0.1383055	total: 395ms	remaining: 309ms
# 561:	learn: 0.1381873	total: 396ms	remaining: 308ms
# 562:	learn: 0.1380792	total: 396ms	remaining: 308ms
# 563:	learn: 0.1378814	total: 397ms	remaining: 307ms
# 564:	learn: 0.1377987	total: 398ms	remaining: 306ms
# 565:	learn: 0.1377283	total: 398ms	remaining: 306ms
# 566:	learn: 0.1376486	total: 399ms	remaining: 305ms
# 567:	learn: 0.1375400	total: 400ms	remaining: 304ms
# 568:	learn: 0.1373250	total: 400ms	remaining: 303ms
# 569:	learn: 0.1371405	total: 401ms	remaining: 303ms
# 570:	learn: 0.1370251	total: 402ms	remaining: 302ms
# 571:	learn: 0.1369561	total: 402ms	remaining: 301ms
# 572:	learn: 0.1368901	total: 403ms	remaining: 300ms
# 573:	learn: 0.1367824	total: 404ms	remaining: 300ms
# 574:	learn: 0.1367235	total: 404ms	remaining: 299ms
# 575:	learn: 0.1365711	total: 405ms	remaining: 298ms
# 576:	learn: 0.1364446	total: 406ms	remaining: 297ms
# 577:	learn: 0.1363308	total: 406ms	remaining: 297ms
# 578:	learn: 0.1362369	total: 407ms	remaining: 296ms
# 579:	learn: 0.1361810	total: 408ms	remaining: 295ms
# 580:	learn: 0.1361247	total: 408ms	remaining: 295ms
# 581:	learn: 0.1359944	total: 409ms	remaining: 294ms
# 582:	learn: 0.1359409	total: 410ms	remaining: 293ms
# 583:	learn: 0.1358931	total: 410ms	remaining: 292ms
# 584:	learn: 0.1357876	total: 411ms	remaining: 292ms
# 585:	learn: 0.1355235	total: 412ms	remaining: 291ms
# 586:	learn: 0.1353494	total: 412ms	remaining: 290ms
# 587:	learn: 0.1351622	total: 413ms	remaining: 289ms
# 588:	learn: 0.1349601	total: 414ms	remaining: 289ms
# 589:	learn: 0.1349342	total: 414ms	remaining: 288ms
# 590:	learn: 0.1346973	total: 415ms	remaining: 287ms
# 591:	learn: 0.1346211	total: 416ms	remaining: 287ms
# 592:	learn: 0.1345036	total: 416ms	remaining: 286ms
# 593:	learn: 0.1342778	total: 417ms	remaining: 285ms
# 594:	learn: 0.1342223	total: 418ms	remaining: 284ms
# 595:	learn: 0.1340909	total: 418ms	remaining: 284ms
# 596:	learn: 0.1340333	total: 419ms	remaining: 283ms
# 597:	learn: 0.1339412	total: 420ms	remaining: 282ms
# 598:	learn: 0.1337961	total: 420ms	remaining: 281ms
# 599:	learn: 0.1337079	total: 421ms	remaining: 281ms
# 600:	learn: 0.1335973	total: 422ms	remaining: 280ms
# 601:	learn: 0.1335652	total: 422ms	remaining: 279ms
# 602:	learn: 0.1334699	total: 423ms	remaining: 279ms
# 603:	learn: 0.1333731	total: 424ms	remaining: 278ms
# 604:	learn: 0.1333078	total: 424ms	remaining: 277ms
# 605:	learn: 0.1332607	total: 425ms	remaining: 276ms
# 606:	learn: 0.1331693	total: 426ms	remaining: 276ms
# 607:	learn: 0.1330889	total: 426ms	remaining: 275ms
# 608:	learn: 0.1329479	total: 427ms	remaining: 274ms
# 609:	learn: 0.1327148	total: 428ms	remaining: 273ms
# 610:	learn: 0.1326615	total: 428ms	remaining: 273ms
# 611:	learn: 0.1325767	total: 429ms	remaining: 272ms
# 612:	learn: 0.1325191	total: 430ms	remaining: 271ms
# 613:	learn: 0.1324298	total: 430ms	remaining: 270ms
# 614:	learn: 0.1323684	total: 431ms	remaining: 270ms
# 615:	learn: 0.1322936	total: 432ms	remaining: 269ms
# 616:	learn: 0.1322779	total: 432ms	remaining: 268ms
# 617:	learn: 0.1322398	total: 432ms	remaining: 267ms
# 618:	learn: 0.1321569	total: 433ms	remaining: 267ms
# 619:	learn: 0.1319841	total: 434ms	remaining: 266ms
# 620:	learn: 0.1319310	total: 434ms	remaining: 265ms
# 621:	learn: 0.1318602	total: 435ms	remaining: 264ms
# 622:	learn: 0.1317498	total: 436ms	remaining: 264ms
# 623:	learn: 0.1317055	total: 436ms	remaining: 263ms
# 624:	learn: 0.1315074	total: 437ms	remaining: 262ms
# 625:	learn: 0.1314689	total: 438ms	remaining: 262ms
# 626:	learn: 0.1313890	total: 438ms	remaining: 261ms
# 627:	learn: 0.1312407	total: 439ms	remaining: 260ms
# 628:	learn: 0.1311863	total: 440ms	remaining: 259ms
# 629:	learn: 0.1310850	total: 440ms	remaining: 259ms
# 630:	learn: 0.1310370	total: 441ms	remaining: 258ms
# 631:	learn: 0.1309127	total: 442ms	remaining: 257ms
# 632:	learn: 0.1308720	total: 443ms	remaining: 257ms
# 633:	learn: 0.1307770	total: 443ms	remaining: 256ms
# 634:	learn: 0.1306932	total: 444ms	remaining: 255ms
# 635:	learn: 0.1306371	total: 445ms	remaining: 254ms
# 636:	learn: 0.1304999	total: 445ms	remaining: 254ms
# 637:	learn: 0.1304116	total: 446ms	remaining: 253ms
# 638:	learn: 0.1303263	total: 447ms	remaining: 252ms
# 639:	learn: 0.1302039	total: 447ms	remaining: 252ms
# 640:	learn: 0.1301551	total: 448ms	remaining: 251ms
# 641:	learn: 0.1300867	total: 449ms	remaining: 250ms
# 642:	learn: 0.1300078	total: 449ms	remaining: 249ms
# 643:	learn: 0.1298839	total: 450ms	remaining: 249ms
# 644:	learn: 0.1297039	total: 451ms	remaining: 248ms
# 645:	learn: 0.1296397	total: 451ms	remaining: 247ms
# 646:	learn: 0.1295204	total: 452ms	remaining: 247ms
# 647:	learn: 0.1294580	total: 453ms	remaining: 246ms
# 648:	learn: 0.1293777	total: 453ms	remaining: 245ms
# 649:	learn: 0.1292674	total: 454ms	remaining: 244ms
# 650:	learn: 0.1291758	total: 455ms	remaining: 244ms
# 651:	learn: 0.1290394	total: 455ms	remaining: 243ms
# 652:	learn: 0.1289829	total: 456ms	remaining: 242ms
# 653:	learn: 0.1289052	total: 457ms	remaining: 242ms
# 654:	learn: 0.1287167	total: 457ms	remaining: 241ms
# 655:	learn: 0.1286620	total: 458ms	remaining: 240ms
# 656:	learn: 0.1285826	total: 459ms	remaining: 239ms
# 657:	learn: 0.1284199	total: 459ms	remaining: 239ms
# 658:	learn: 0.1282858	total: 460ms	remaining: 238ms
# 659:	learn: 0.1282182	total: 461ms	remaining: 237ms
# 660:	learn: 0.1281674	total: 461ms	remaining: 237ms
# 661:	learn: 0.1281171	total: 462ms	remaining: 236ms
# 662:	learn: 0.1280557	total: 463ms	remaining: 235ms
# 663:	learn: 0.1279909	total: 463ms	remaining: 234ms
# 664:	learn: 0.1279388	total: 464ms	remaining: 234ms
# 665:	learn: 0.1278725	total: 465ms	remaining: 233ms
# 666:	learn: 0.1278187	total: 465ms	remaining: 232ms
# 667:	learn: 0.1277851	total: 466ms	remaining: 232ms
# 668:	learn: 0.1276484	total: 467ms	remaining: 231ms
# 669:	learn: 0.1275732	total: 467ms	remaining: 230ms
# 670:	learn: 0.1274229	total: 468ms	remaining: 229ms
# 671:	learn: 0.1273728	total: 469ms	remaining: 229ms
# 672:	learn: 0.1273097	total: 469ms	remaining: 228ms
# 673:	learn: 0.1272688	total: 470ms	remaining: 227ms
# 674:	learn: 0.1271354	total: 470ms	remaining: 227ms
# 675:	learn: 0.1270862	total: 471ms	remaining: 226ms
# 676:	learn: 0.1269788	total: 472ms	remaining: 225ms
# 677:	learn: 0.1268923	total: 473ms	remaining: 224ms
# 678:	learn: 0.1268467	total: 473ms	remaining: 224ms
# 679:	learn: 0.1267054	total: 474ms	remaining: 223ms
# 680:	learn: 0.1266296	total: 475ms	remaining: 222ms
# 681:	learn: 0.1265817	total: 475ms	remaining: 222ms
# 682:	learn: 0.1265375	total: 476ms	remaining: 221ms
# 683:	learn: 0.1265008	total: 477ms	remaining: 220ms
# 684:	learn: 0.1264517	total: 477ms	remaining: 219ms
# 685:	learn: 0.1263611	total: 478ms	remaining: 219ms
# 686:	learn: 0.1262100	total: 479ms	remaining: 218ms
# 687:	learn: 0.1260433	total: 479ms	remaining: 217ms
# 688:	learn: 0.1259796	total: 480ms	remaining: 217ms
# 689:	learn: 0.1259358	total: 481ms	remaining: 216ms
# 690:	learn: 0.1259063	total: 481ms	remaining: 215ms
# 691:	learn: 0.1258666	total: 482ms	remaining: 214ms
# 692:	learn: 0.1258254	total: 483ms	remaining: 214ms
# 693:	learn: 0.1257820	total: 483ms	remaining: 213ms
# 694:	learn: 0.1257010	total: 484ms	remaining: 212ms
# 695:	learn: 0.1256422	total: 485ms	remaining: 212ms
# 696:	learn: 0.1255281	total: 485ms	remaining: 211ms
# 697:	learn: 0.1254175	total: 486ms	remaining: 210ms
# 698:	learn: 0.1253678	total: 487ms	remaining: 210ms
# 699:	learn: 0.1252491	total: 487ms	remaining: 209ms
# 700:	learn: 0.1252113	total: 488ms	remaining: 208ms
# 701:	learn: 0.1250543	total: 489ms	remaining: 207ms
# 702:	learn: 0.1249828	total: 489ms	remaining: 207ms
# 703:	learn: 0.1249354	total: 490ms	remaining: 206ms
# 704:	learn: 0.1248731	total: 490ms	remaining: 205ms
# 705:	learn: 0.1248318	total: 491ms	remaining: 205ms
# 706:	learn: 0.1247644	total: 492ms	remaining: 204ms
# 707:	learn: 0.1246473	total: 492ms	remaining: 203ms
# 708:	learn: 0.1245135	total: 493ms	remaining: 202ms
# 709:	learn: 0.1244623	total: 494ms	remaining: 202ms
# 710:	learn: 0.1242849	total: 494ms	remaining: 201ms
# 711:	learn: 0.1241479	total: 495ms	remaining: 200ms
# 712:	learn: 0.1241060	total: 496ms	remaining: 200ms
# 713:	learn: 0.1239649	total: 496ms	remaining: 199ms
# 714:	learn: 0.1239130	total: 497ms	remaining: 198ms
# 715:	learn: 0.1238495	total: 498ms	remaining: 197ms
# 716:	learn: 0.1237971	total: 498ms	remaining: 197ms
# 717:	learn: 0.1237477	total: 499ms	remaining: 196ms
# 718:	learn: 0.1236855	total: 500ms	remaining: 195ms
# 719:	learn: 0.1236354	total: 500ms	remaining: 195ms
# 720:	learn: 0.1235929	total: 501ms	remaining: 194ms
# 721:	learn: 0.1235200	total: 502ms	remaining: 193ms
# 722:	learn: 0.1234242	total: 502ms	remaining: 193ms
# 723:	learn: 0.1232652	total: 503ms	remaining: 192ms
# 724:	learn: 0.1232145	total: 504ms	remaining: 191ms
# 725:	learn: 0.1231631	total: 505ms	remaining: 190ms
# 726:	learn: 0.1230871	total: 505ms	remaining: 190ms
# 727:	learn: 0.1229564	total: 506ms	remaining: 189ms
# 728:	learn: 0.1229121	total: 507ms	remaining: 188ms
# 729:	learn: 0.1228422	total: 507ms	remaining: 188ms
# 730:	learn: 0.1227607	total: 508ms	remaining: 187ms
# 731:	learn: 0.1227030	total: 509ms	remaining: 186ms
# 732:	learn: 0.1226535	total: 509ms	remaining: 185ms
# 733:	learn: 0.1225939	total: 510ms	remaining: 185ms
# 734:	learn: 0.1225533	total: 510ms	remaining: 184ms
# 735:	learn: 0.1225146	total: 511ms	remaining: 183ms
# 736:	learn: 0.1224892	total: 512ms	remaining: 183ms
# 737:	learn: 0.1224142	total: 513ms	remaining: 182ms
# 738:	learn: 0.1223715	total: 513ms	remaining: 181ms
# 739:	learn: 0.1223053	total: 514ms	remaining: 181ms
# 740:	learn: 0.1222047	total: 515ms	remaining: 180ms
# 741:	learn: 0.1221441	total: 515ms	remaining: 179ms
# 742:	learn: 0.1220843	total: 516ms	remaining: 178ms
# 743:	learn: 0.1219892	total: 517ms	remaining: 178ms
# 744:	learn: 0.1219341	total: 517ms	remaining: 177ms
# 745:	learn: 0.1218566	total: 518ms	remaining: 176ms
# 746:	learn: 0.1218044	total: 519ms	remaining: 176ms
# 747:	learn: 0.1217157	total: 519ms	remaining: 175ms
# 748:	learn: 0.1216951	total: 520ms	remaining: 174ms
# 749:	learn: 0.1216354	total: 521ms	remaining: 174ms
# 750:	learn: 0.1214879	total: 524ms	remaining: 174ms
# 751:	learn: 0.1214217	total: 525ms	remaining: 173ms
# 752:	learn: 0.1213755	total: 528ms	remaining: 173ms
# 753:	learn: 0.1212320	total: 531ms	remaining: 173ms
# 754:	learn: 0.1211279	total: 533ms	remaining: 173ms
# 755:	learn: 0.1210795	total: 534ms	remaining: 172ms
# 756:	learn: 0.1210185	total: 537ms	remaining: 172ms
# 757:	learn: 0.1209722	total: 539ms	remaining: 172ms
# 758:	learn: 0.1209185	total: 540ms	remaining: 172ms
# 759:	learn: 0.1208474	total: 542ms	remaining: 171ms
# 760:	learn: 0.1206782	total: 543ms	remaining: 171ms
# 761:	learn: 0.1206403	total: 544ms	remaining: 170ms
# 762:	learn: 0.1205637	total: 545ms	remaining: 169ms
# 763:	learn: 0.1205519	total: 545ms	remaining: 168ms
# 764:	learn: 0.1204071	total: 546ms	remaining: 168ms
# 765:	learn: 0.1203564	total: 547ms	remaining: 167ms
# 766:	learn: 0.1202976	total: 547ms	remaining: 166ms
# 767:	learn: 0.1202547	total: 548ms	remaining: 166ms
# 768:	learn: 0.1202222	total: 549ms	remaining: 165ms
# 769:	learn: 0.1201290	total: 549ms	remaining: 164ms
# 770:	learn: 0.1201041	total: 550ms	remaining: 163ms
# 771:	learn: 0.1199549	total: 551ms	remaining: 163ms
# 772:	learn: 0.1199147	total: 551ms	remaining: 162ms
# 773:	learn: 0.1198009	total: 552ms	remaining: 161ms
# 774:	learn: 0.1196823	total: 553ms	remaining: 160ms
# 775:	learn: 0.1196470	total: 553ms	remaining: 160ms
# 776:	learn: 0.1195323	total: 554ms	remaining: 159ms
# 777:	learn: 0.1194704	total: 555ms	remaining: 158ms
# 778:	learn: 0.1194372	total: 555ms	remaining: 158ms
# 779:	learn: 0.1193071	total: 556ms	remaining: 157ms
# 780:	learn: 0.1191933	total: 557ms	remaining: 156ms
# 781:	learn: 0.1190166	total: 557ms	remaining: 155ms
# 782:	learn: 0.1189296	total: 558ms	remaining: 155ms
# 783:	learn: 0.1188855	total: 559ms	remaining: 154ms
# 784:	learn: 0.1187766	total: 559ms	remaining: 153ms
# 785:	learn: 0.1187474	total: 560ms	remaining: 152ms
# 786:	learn: 0.1187047	total: 561ms	remaining: 152ms
# 787:	learn: 0.1186497	total: 561ms	remaining: 151ms
# 788:	learn: 0.1185863	total: 562ms	remaining: 150ms
# 789:	learn: 0.1185638	total: 563ms	remaining: 150ms
# 790:	learn: 0.1184764	total: 563ms	remaining: 149ms
# 791:	learn: 0.1183985	total: 564ms	remaining: 148ms
# 792:	learn: 0.1183528	total: 565ms	remaining: 147ms
# 793:	learn: 0.1183072	total: 565ms	remaining: 147ms
# 794:	learn: 0.1182534	total: 566ms	remaining: 146ms
# 795:	learn: 0.1181868	total: 567ms	remaining: 145ms
# 796:	learn: 0.1181266	total: 567ms	remaining: 145ms
# 797:	learn: 0.1180024	total: 568ms	remaining: 144ms
# 798:	learn: 0.1179440	total: 569ms	remaining: 143ms
# 799:	learn: 0.1178929	total: 569ms	remaining: 142ms
# 800:	learn: 0.1177997	total: 570ms	remaining: 142ms
# 801:	learn: 0.1177289	total: 571ms	remaining: 141ms
# 802:	learn: 0.1176445	total: 571ms	remaining: 140ms
# 803:	learn: 0.1175069	total: 572ms	remaining: 139ms
# 804:	learn: 0.1174567	total: 573ms	remaining: 139ms
# 805:	learn: 0.1173858	total: 575ms	remaining: 138ms
# 806:	learn: 0.1173182	total: 576ms	remaining: 138ms
# 807:	learn: 0.1172655	total: 578ms	remaining: 137ms
# 808:	learn: 0.1171938	total: 578ms	remaining: 137ms
# 809:	learn: 0.1171750	total: 579ms	remaining: 136ms
# 810:	learn: 0.1171142	total: 580ms	remaining: 135ms
# 811:	learn: 0.1170198	total: 581ms	remaining: 135ms
# 812:	learn: 0.1169603	total: 582ms	remaining: 134ms
# 813:	learn: 0.1168845	total: 583ms	remaining: 133ms
# 814:	learn: 0.1168648	total: 584ms	remaining: 133ms
# 815:	learn: 0.1168165	total: 584ms	remaining: 132ms
# 816:	learn: 0.1167547	total: 585ms	remaining: 131ms
# 817:	learn: 0.1166014	total: 586ms	remaining: 130ms
# 818:	learn: 0.1165315	total: 587ms	remaining: 130ms
# 819:	learn: 0.1165018	total: 588ms	remaining: 129ms
# 820:	learn: 0.1164615	total: 588ms	remaining: 128ms
# 821:	learn: 0.1164216	total: 589ms	remaining: 128ms
# 822:	learn: 0.1163440	total: 590ms	remaining: 127ms
# 823:	learn: 0.1162313	total: 590ms	remaining: 126ms
# 824:	learn: 0.1161888	total: 591ms	remaining: 125ms
# 825:	learn: 0.1161409	total: 592ms	remaining: 125ms
# 826:	learn: 0.1160839	total: 593ms	remaining: 124ms
# 827:	learn: 0.1159150	total: 593ms	remaining: 123ms
# 828:	learn: 0.1158638	total: 594ms	remaining: 123ms
# 829:	learn: 0.1157880	total: 595ms	remaining: 122ms
# 830:	learn: 0.1157271	total: 596ms	remaining: 121ms
# 831:	learn: 0.1155467	total: 596ms	remaining: 120ms
# 832:	learn: 0.1154468	total: 597ms	remaining: 120ms
# 833:	learn: 0.1153815	total: 598ms	remaining: 119ms
# 834:	learn: 0.1152737	total: 598ms	remaining: 118ms
# 835:	learn: 0.1152287	total: 599ms	remaining: 118ms
# 836:	learn: 0.1151177	total: 600ms	remaining: 117ms
# 837:	learn: 0.1150867	total: 601ms	remaining: 116ms
# 838:	learn: 0.1150447	total: 601ms	remaining: 115ms
# 839:	learn: 0.1149130	total: 602ms	remaining: 115ms
# 840:	learn: 0.1148658	total: 603ms	remaining: 114ms
# 841:	learn: 0.1148262	total: 603ms	remaining: 113ms
# 842:	learn: 0.1147943	total: 604ms	remaining: 112ms
# 843:	learn: 0.1147628	total: 605ms	remaining: 112ms
# 844:	learn: 0.1146552	total: 605ms	remaining: 111ms
# 845:	learn: 0.1146218	total: 606ms	remaining: 110ms
# 846:	learn: 0.1144818	total: 607ms	remaining: 110ms
# 847:	learn: 0.1144396	total: 607ms	remaining: 109ms
# 848:	learn: 0.1143715	total: 608ms	remaining: 108ms
# 849:	learn: 0.1142593	total: 609ms	remaining: 107ms
# 850:	learn: 0.1141567	total: 609ms	remaining: 107ms
# 851:	learn: 0.1140873	total: 610ms	remaining: 106ms
# 852:	learn: 0.1139852	total: 611ms	remaining: 105ms
# 853:	learn: 0.1138464	total: 611ms	remaining: 105ms
# 854:	learn: 0.1137359	total: 612ms	remaining: 104ms
# 855:	learn: 0.1136992	total: 613ms	remaining: 103ms
# 856:	learn: 0.1136189	total: 613ms	remaining: 102ms
# 857:	learn: 0.1135390	total: 614ms	remaining: 102ms
# 858:	learn: 0.1134884	total: 615ms	remaining: 101ms
# 859:	learn: 0.1134365	total: 615ms	remaining: 100ms
# 860:	learn: 0.1133809	total: 616ms	remaining: 99.5ms
# 861:	learn: 0.1133341	total: 617ms	remaining: 98.7ms
# 862:	learn: 0.1132443	total: 617ms	remaining: 98ms
# 863:	learn: 0.1131995	total: 618ms	remaining: 97.3ms
# 864:	learn: 0.1130859	total: 619ms	remaining: 96.6ms
# 865:	learn: 0.1130051	total: 619ms	remaining: 95.8ms
# 866:	learn: 0.1129566	total: 620ms	remaining: 95.2ms
# 867:	learn: 0.1128738	total: 621ms	remaining: 94.5ms
# 868:	learn: 0.1128299	total: 622ms	remaining: 93.8ms
# 869:	learn: 0.1127825	total: 623ms	remaining: 93.1ms
# 870:	learn: 0.1126743	total: 624ms	remaining: 92.4ms
# 871:	learn: 0.1126246	total: 624ms	remaining: 91.6ms
# 872:	learn: 0.1125554	total: 625ms	remaining: 90.9ms
# 873:	learn: 0.1125054	total: 626ms	remaining: 90.2ms
# 874:	learn: 0.1124552	total: 626ms	remaining: 89.5ms
# 875:	learn: 0.1123769	total: 627ms	remaining: 88.7ms
# 876:	learn: 0.1123363	total: 628ms	remaining: 88ms
# 877:	learn: 0.1122710	total: 628ms	remaining: 87.3ms
# 878:	learn: 0.1122287	total: 629ms	remaining: 86.6ms
# 879:	learn: 0.1121734	total: 630ms	remaining: 85.9ms
# 880:	learn: 0.1119511	total: 630ms	remaining: 85.1ms
# 881:	learn: 0.1118383	total: 631ms	remaining: 84.4ms
# 882:	learn: 0.1118017	total: 632ms	remaining: 83.7ms
# 883:	learn: 0.1117559	total: 632ms	remaining: 83ms
# 884:	learn: 0.1117079	total: 633ms	remaining: 82.2ms
# 885:	learn: 0.1116501	total: 634ms	remaining: 81.5ms
# 886:	learn: 0.1115168	total: 634ms	remaining: 80.8ms
# 887:	learn: 0.1114774	total: 635ms	remaining: 80.1ms
# 888:	learn: 0.1114386	total: 636ms	remaining: 79.4ms
# 889:	learn: 0.1113210	total: 636ms	remaining: 78.6ms
# 890:	learn: 0.1112675	total: 637ms	remaining: 77.9ms
# 891:	learn: 0.1111900	total: 638ms	remaining: 77.2ms
# 892:	learn: 0.1111646	total: 638ms	remaining: 76.5ms
# 893:	learn: 0.1111535	total: 639ms	remaining: 75.7ms
# 894:	learn: 0.1110898	total: 639ms	remaining: 75ms
# 895:	learn: 0.1110285	total: 640ms	remaining: 74.3ms
# 896:	learn: 0.1110080	total: 641ms	remaining: 73.6ms
# 897:	learn: 0.1109034	total: 641ms	remaining: 72.8ms
# 898:	learn: 0.1107662	total: 642ms	remaining: 72.1ms
# 899:	learn: 0.1107102	total: 643ms	remaining: 71.4ms
# 900:	learn: 0.1106245	total: 643ms	remaining: 70.7ms
# 901:	learn: 0.1105824	total: 644ms	remaining: 70ms
# 902:	learn: 0.1105273	total: 645ms	remaining: 69.2ms
# 903:	learn: 0.1103492	total: 645ms	remaining: 68.5ms
# 904:	learn: 0.1102654	total: 646ms	remaining: 67.8ms
# 905:	learn: 0.1102403	total: 647ms	remaining: 67.1ms
# 906:	learn: 0.1101405	total: 647ms	remaining: 66.4ms
# 907:	learn: 0.1100139	total: 648ms	remaining: 65.6ms
# 908:	learn: 0.1099699	total: 649ms	remaining: 64.9ms
# 909:	learn: 0.1099256	total: 649ms	remaining: 64.2ms
# 910:	learn: 0.1098637	total: 650ms	remaining: 63.5ms
# 911:	learn: 0.1098120	total: 651ms	remaining: 62.8ms
# 912:	learn: 0.1097789	total: 651ms	remaining: 62.1ms
# 913:	learn: 0.1097380	total: 652ms	remaining: 61.3ms
# 914:	learn: 0.1096865	total: 653ms	remaining: 60.6ms
# 915:	learn: 0.1096227	total: 653ms	remaining: 59.9ms
# 916:	learn: 0.1095155	total: 654ms	remaining: 59.2ms
# 917:	learn: 0.1094573	total: 655ms	remaining: 58.5ms
# ...
# 692:	learn: 0.0227700	total: 4.18s	remaining: 1.85s
# 693:	learn: 0.0227417	total: 4.18s	remaining: 1.84s
# 694:	learn: 0.0226837	total: 4.18s	remaining: 1.84s
# 695:	learn: 0.0226462	total: 4.19s	remaining: 1.83s
# 696:	learn: 0.0226031	total: 4.2s	remaining: 1.82s
# 697:	learn: 0.0225260	total: 4.2s	remaining: 1.82s
# 698:	learn: 0.0224842	total: 4.21s	remaining: 1.81s
# 699:	learn: 0.0224488	total: 4.21s	remaining: 1.8s
# 700:	learn: 0.0223892	total: 4.21s	remaining: 1.8s
# 701:	learn: 0.0223355	total: 4.22s	remaining: 1.79s
# 702:	learn: 0.0222916	total: 4.22s	remaining: 1.78s
# 703:	learn: 0.0222387	total: 4.23s	remaining: 1.78s
# 704:	learn: 0.0221465	total: 4.23s	remaining: 1.77s
# 705:	learn: 0.0220907	total: 4.24s	remaining: 1.76s
# 706:	learn: 0.0220083	total: 4.24s	remaining: 1.76s
# 707:	learn: 0.0219420	total: 4.25s	remaining: 1.75s
# 708:	learn: 0.0219112	total: 4.25s	remaining: 1.75s
# 709:	learn: 0.0218573	total: 4.26s	remaining: 1.74s
# 710:	learn: 0.0218140	total: 4.26s	remaining: 1.73s
# 711:	learn: 0.0217601	total: 4.27s	remaining: 1.73s
# 712:	learn: 0.0217401	total: 4.27s	remaining: 1.72s
# 713:	learn: 0.0217214	total: 4.28s	remaining: 1.71s
# 714:	learn: 0.0216539	total: 4.28s	remaining: 1.71s
# 715:	learn: 0.0216232	total: 4.29s	remaining: 1.7s
# 716:	learn: 0.0215659	total: 4.3s	remaining: 1.7s
# 717:	learn: 0.0215214	total: 4.3s	remaining: 1.69s
# 718:	learn: 0.0214778	total: 4.31s	remaining: 1.68s
# 719:	learn: 0.0214372	total: 4.31s	remaining: 1.68s
# 720:	learn: 0.0213820	total: 4.32s	remaining: 1.67s
# 721:	learn: 0.0213025	total: 4.32s	remaining: 1.66s
# 722:	learn: 0.0212608	total: 4.33s	remaining: 1.66s
# 723:	learn: 0.0212073	total: 4.33s	remaining: 1.65s
# 724:	learn: 0.0211754	total: 4.34s	remaining: 1.64s
# 725:	learn: 0.0211365	total: 4.34s	remaining: 1.64s
# 726:	learn: 0.0210741	total: 4.34s	remaining: 1.63s
# 727:	learn: 0.0210370	total: 4.35s	remaining: 1.63s
# 728:	learn: 0.0210159	total: 4.36s	remaining: 1.62s
# 729:	learn: 0.0209406	total: 4.36s	remaining: 1.61s
# 730:	learn: 0.0208988	total: 4.36s	remaining: 1.61s
# 731:	learn: 0.0208342	total: 4.37s	remaining: 1.6s
# 732:	learn: 0.0208030	total: 4.37s	remaining: 1.59s
# 733:	learn: 0.0207366	total: 4.38s	remaining: 1.59s
# 734:	learn: 0.0206795	total: 4.38s	remaining: 1.58s
# 735:	learn: 0.0206319	total: 4.39s	remaining: 1.57s
# 736:	learn: 0.0205857	total: 4.39s	remaining: 1.57s
# 737:	learn: 0.0205666	total: 4.4s	remaining: 1.56s
# 738:	learn: 0.0205275	total: 4.4s	remaining: 1.55s
# 739:	learn: 0.0204847	total: 4.41s	remaining: 1.55s
# 740:	learn: 0.0204242	total: 4.41s	remaining: 1.54s
# 741:	learn: 0.0203894	total: 4.42s	remaining: 1.53s
# 742:	learn: 0.0203678	total: 4.42s	remaining: 1.53s
# 743:	learn: 0.0203515	total: 4.43s	remaining: 1.52s
# 744:	learn: 0.0203161	total: 4.43s	remaining: 1.52s
# 745:	learn: 0.0202831	total: 4.43s	remaining: 1.51s
# 746:	learn: 0.0202232	total: 4.44s	remaining: 1.5s
# 747:	learn: 0.0201884	total: 4.44s	remaining: 1.5s
# 748:	learn: 0.0201624	total: 4.45s	remaining: 1.49s
# 749:	learn: 0.0201216	total: 4.45s	remaining: 1.48s
# 750:	learn: 0.0200758	total: 4.46s	remaining: 1.48s
# 751:	learn: 0.0200612	total: 4.46s	remaining: 1.47s
# 752:	learn: 0.0200200	total: 4.47s	remaining: 1.47s
# 753:	learn: 0.0199614	total: 4.47s	remaining: 1.46s
# 754:	learn: 0.0199036	total: 4.48s	remaining: 1.45s
# 755:	learn: 0.0198631	total: 4.48s	remaining: 1.45s
# 756:	learn: 0.0198154	total: 4.49s	remaining: 1.44s
# 757:	learn: 0.0197933	total: 4.5s	remaining: 1.44s
# 758:	learn: 0.0197351	total: 4.5s	remaining: 1.43s
# 759:	learn: 0.0196894	total: 4.51s	remaining: 1.42s
# 760:	learn: 0.0196605	total: 4.51s	remaining: 1.42s
# 761:	learn: 0.0196020	total: 4.52s	remaining: 1.41s
# 762:	learn: 0.0195557	total: 4.52s	remaining: 1.4s
# 763:	learn: 0.0195243	total: 4.53s	remaining: 1.4s
# 764:	learn: 0.0194712	total: 4.53s	remaining: 1.39s
# 765:	learn: 0.0194446	total: 4.54s	remaining: 1.39s
# 766:	learn: 0.0193740	total: 4.54s	remaining: 1.38s
# 767:	learn: 0.0193319	total: 4.54s	remaining: 1.37s
# 768:	learn: 0.0192839	total: 4.55s	remaining: 1.37s
# 769:	learn: 0.0192384	total: 4.55s	remaining: 1.36s
# 770:	learn: 0.0191816	total: 4.56s	remaining: 1.35s
# 771:	learn: 0.0191349	total: 4.56s	remaining: 1.35s
# 772:	learn: 0.0191120	total: 4.57s	remaining: 1.34s
# 773:	learn: 0.0190586	total: 4.57s	remaining: 1.33s
# 774:	learn: 0.0190361	total: 4.58s	remaining: 1.33s
# 775:	learn: 0.0189791	total: 4.58s	remaining: 1.32s
# 776:	learn: 0.0189337	total: 4.59s	remaining: 1.32s
# 777:	learn: 0.0188750	total: 4.59s	remaining: 1.31s
# 778:	learn: 0.0188322	total: 4.6s	remaining: 1.3s
# 779:	learn: 0.0187892	total: 4.6s	remaining: 1.3s
# 780:	learn: 0.0187373	total: 4.61s	remaining: 1.29s
# 781:	learn: 0.0187144	total: 4.61s	remaining: 1.28s
# 782:	learn: 0.0186752	total: 4.62s	remaining: 1.28s
# 783:	learn: 0.0186473	total: 4.62s	remaining: 1.27s
# 784:	learn: 0.0186114	total: 4.63s	remaining: 1.27s
# 785:	learn: 0.0185531	total: 4.63s	remaining: 1.26s
# 786:	learn: 0.0185016	total: 4.63s	remaining: 1.25s
# 787:	learn: 0.0184489	total: 4.64s	remaining: 1.25s
# 788:	learn: 0.0184038	total: 4.64s	remaining: 1.24s
# 789:	learn: 0.0183545	total: 4.65s	remaining: 1.24s
# 790:	learn: 0.0183198	total: 4.66s	remaining: 1.23s
# 791:	learn: 0.0182798	total: 4.66s	remaining: 1.22s
# 792:	learn: 0.0182530	total: 4.66s	remaining: 1.22s
# 793:	learn: 0.0182191	total: 4.67s	remaining: 1.21s
# 794:	learn: 0.0181664	total: 4.67s	remaining: 1.21s
# 795:	learn: 0.0181263	total: 4.68s	remaining: 1.2s
# 796:	learn: 0.0180959	total: 4.68s	remaining: 1.19s
# 797:	learn: 0.0180523	total: 4.7s	remaining: 1.19s
# 798:	learn: 0.0180102	total: 4.7s	remaining: 1.18s
# 799:	learn: 0.0179573	total: 4.71s	remaining: 1.18s
# 800:	learn: 0.0179208	total: 4.71s	remaining: 1.17s
# 801:	learn: 0.0178642	total: 4.72s	remaining: 1.17s
# 802:	learn: 0.0178552	total: 4.72s	remaining: 1.16s
# 803:	learn: 0.0178226	total: 4.73s	remaining: 1.15s
# 804:	learn: 0.0177672	total: 4.73s	remaining: 1.15s
# 805:	learn: 0.0177211	total: 4.74s	remaining: 1.14s
# 806:	learn: 0.0176891	total: 4.74s	remaining: 1.13s
# 807:	learn: 0.0176257	total: 4.75s	remaining: 1.13s
# 808:	learn: 0.0175939	total: 4.75s	remaining: 1.12s
# 809:	learn: 0.0175502	total: 4.76s	remaining: 1.11s
# 810:	learn: 0.0174950	total: 4.76s	remaining: 1.11s
# 811:	learn: 0.0174286	total: 4.77s	remaining: 1.1s
# 812:	learn: 0.0173812	total: 4.77s	remaining: 1.1s
# 813:	learn: 0.0173353	total: 4.78s	remaining: 1.09s
# 814:	learn: 0.0173012	total: 4.79s	remaining: 1.09s
# 815:	learn: 0.0172703	total: 4.79s	remaining: 1.08s
# 816:	learn: 0.0172377	total: 4.8s	remaining: 1.07s
# 817:	learn: 0.0171903	total: 4.8s	remaining: 1.07s
# 818:	learn: 0.0171547	total: 4.81s	remaining: 1.06s
# 819:	learn: 0.0171261	total: 4.81s	remaining: 1.06s
# 820:	learn: 0.0170717	total: 4.82s	remaining: 1.05s
# 821:	learn: 0.0170317	total: 4.82s	remaining: 1.04s
# 822:	learn: 0.0169998	total: 4.83s	remaining: 1.04s
# 823:	learn: 0.0169551	total: 4.83s	remaining: 1.03s
# 824:	learn: 0.0169205	total: 4.83s	remaining: 1.02s
# 825:	learn: 0.0168720	total: 4.84s	remaining: 1.02s
# 826:	learn: 0.0168347	total: 4.84s	remaining: 1.01s
# 827:	learn: 0.0168022	total: 4.85s	remaining: 1.01s
# 828:	learn: 0.0167628	total: 4.85s	remaining: 1s
# 829:	learn: 0.0167199	total: 4.86s	remaining: 995ms
# 830:	learn: 0.0166442	total: 4.86s	remaining: 989ms
# 831:	learn: 0.0166081	total: 4.87s	remaining: 983ms
# 832:	learn: 0.0165624	total: 4.87s	remaining: 977ms
# 833:	learn: 0.0165284	total: 4.88s	remaining: 971ms
# 834:	learn: 0.0164877	total: 4.89s	remaining: 966ms
# 835:	learn: 0.0164548	total: 4.89s	remaining: 960ms
# 836:	learn: 0.0164270	total: 4.9s	remaining: 954ms
# 837:	learn: 0.0163901	total: 4.9s	remaining: 948ms
# 838:	learn: 0.0163575	total: 4.91s	remaining: 942ms
# 839:	learn: 0.0163230	total: 4.91s	remaining: 936ms
# 840:	learn: 0.0162771	total: 4.92s	remaining: 930ms
# 841:	learn: 0.0162093	total: 4.92s	remaining: 924ms
# 842:	learn: 0.0161707	total: 4.93s	remaining: 918ms
# 843:	learn: 0.0161258	total: 4.93s	remaining: 912ms
# 844:	learn: 0.0160979	total: 4.94s	remaining: 906ms
# 845:	learn: 0.0160483	total: 4.94s	remaining: 900ms
# 846:	learn: 0.0160022	total: 4.95s	remaining: 894ms
# 847:	learn: 0.0159516	total: 4.95s	remaining: 888ms
# 848:	learn: 0.0159128	total: 4.96s	remaining: 882ms
# 849:	learn: 0.0158706	total: 4.97s	remaining: 877ms
# 850:	learn: 0.0158384	total: 4.98s	remaining: 871ms
# 851:	learn: 0.0158113	total: 4.98s	remaining: 866ms
# 852:	learn: 0.0157740	total: 4.99s	remaining: 860ms
# 853:	learn: 0.0157200	total: 4.99s	remaining: 854ms
# 854:	learn: 0.0156689	total: 5s	remaining: 847ms
# 855:	learn: 0.0156205	total: 5s	remaining: 841ms
# 856:	learn: 0.0155703	total: 5.01s	remaining: 835ms
# 857:	learn: 0.0155330	total: 5.01s	remaining: 829ms
# 858:	learn: 0.0154839	total: 5.01s	remaining: 823ms
# 859:	learn: 0.0154443	total: 5.02s	remaining: 817ms
# 860:	learn: 0.0154017	total: 5.02s	remaining: 811ms
# 861:	learn: 0.0153741	total: 5.03s	remaining: 805ms
# 862:	learn: 0.0153353	total: 5.03s	remaining: 799ms
# 863:	learn: 0.0153027	total: 5.04s	remaining: 793ms
# 864:	learn: 0.0152756	total: 5.04s	remaining: 787ms
# 865:	learn: 0.0152440	total: 5.05s	remaining: 781ms
# 866:	learn: 0.0152088	total: 5.05s	remaining: 775ms
# 867:	learn: 0.0151561	total: 5.06s	remaining: 769ms
# 868:	learn: 0.0151106	total: 5.06s	remaining: 763ms
# 869:	learn: 0.0150649	total: 5.07s	remaining: 757ms
# 870:	learn: 0.0150247	total: 5.07s	remaining: 751ms
# 871:	learn: 0.0149857	total: 5.08s	remaining: 745ms
# 872:	learn: 0.0149505	total: 5.08s	remaining: 739ms
# 873:	learn: 0.0149259	total: 5.09s	remaining: 733ms
# 874:	learn: 0.0148888	total: 5.09s	remaining: 727ms
# 875:	learn: 0.0148501	total: 5.1s	remaining: 722ms
# 876:	learn: 0.0148288	total: 5.11s	remaining: 716ms
# 877:	learn: 0.0147946	total: 5.11s	remaining: 710ms
# 878:	learn: 0.0147693	total: 5.11s	remaining: 704ms
# 879:	learn: 0.0147463	total: 5.12s	remaining: 698ms
# 880:	learn: 0.0147207	total: 5.12s	remaining: 692ms
# 881:	learn: 0.0146925	total: 5.13s	remaining: 686ms
# 882:	learn: 0.0146702	total: 5.13s	remaining: 680ms
# 883:	learn: 0.0146085	total: 5.14s	remaining: 674ms
# 884:	learn: 0.0145706	total: 5.14s	remaining: 668ms
# 885:	learn: 0.0145543	total: 5.15s	remaining: 662ms
# 886:	learn: 0.0145476	total: 5.15s	remaining: 656ms
# 887:	learn: 0.0145233	total: 5.16s	remaining: 650ms
# 888:	learn: 0.0144894	total: 5.16s	remaining: 644ms
# 889:	learn: 0.0144684	total: 5.17s	remaining: 638ms
# 890:	learn: 0.0144357	total: 5.17s	remaining: 633ms
# 891:	learn: 0.0144198	total: 5.17s	remaining: 627ms
# 892:	learn: 0.0143879	total: 5.18s	remaining: 621ms
# 893:	learn: 0.0143531	total: 5.18s	remaining: 615ms
# 894:	learn: 0.0143260	total: 5.19s	remaining: 609ms
# 895:	learn: 0.0142770	total: 5.19s	remaining: 603ms
# 896:	learn: 0.0142469	total: 5.2s	remaining: 597ms
# 897:	learn: 0.0142128	total: 5.2s	remaining: 591ms
# 898:	learn: 0.0142051	total: 5.21s	remaining: 585ms
# 899:	learn: 0.0141820	total: 5.21s	remaining: 579ms
# 900:	learn: 0.0141537	total: 5.22s	remaining: 573ms
# 901:	learn: 0.0141198	total: 5.22s	remaining: 567ms
# 902:	learn: 0.0140933	total: 5.23s	remaining: 562ms
# 903:	learn: 0.0140690	total: 5.23s	remaining: 556ms
# 904:	learn: 0.0140301	total: 5.24s	remaining: 550ms
# 905:	learn: 0.0139890	total: 5.24s	remaining: 544ms
# 906:	learn: 0.0139511	total: 5.25s	remaining: 538ms
# 907:	learn: 0.0139280	total: 5.25s	remaining: 532ms
# 908:	learn: 0.0138829	total: 5.26s	remaining: 526ms
# 909:	learn: 0.0138530	total: 5.26s	remaining: 520ms
# 910:	learn: 0.0138256	total: 5.26s	remaining: 514ms
# 911:	learn: 0.0137854	total: 5.27s	remaining: 509ms
# 912:	learn: 0.0137668	total: 5.27s	remaining: 503ms
# 913:	learn: 0.0137545	total: 5.28s	remaining: 497ms
# 914:	learn: 0.0137234	total: 5.29s	remaining: 491ms
# 915:	learn: 0.0136899	total: 5.29s	remaining: 485ms
# 916:	learn: 0.0136536	total: 5.3s	remaining: 480ms
# 917:	learn: 0.0136267	total: 5.3s	remaining: 474ms
# 918:	learn: 0.0135876	total: 5.31s	remaining: 468ms
# 919:	learn: 0.0135694	total: 5.31s	remaining: 462ms
# 920:	learn: 0.0135469	total: 5.32s	remaining: 456ms
# 921:	learn: 0.0135126	total: 5.32s	remaining: 450ms
# 922:	learn: 0.0134903	total: 5.33s	remaining: 444ms
# 923:	learn: 0.0134661	total: 5.33s	remaining: 439ms
# 924:	learn: 0.0134257	total: 5.34s	remaining: 433ms
# 925:	learn: 0.0133954	total: 5.34s	remaining: 427ms
# 926:	learn: 0.0133608	total: 5.34s	remaining: 421ms
# 927:	learn: 0.0133311	total: 5.35s	remaining: 415ms
# 928:	learn: 0.0133125	total: 5.36s	remaining: 409ms
# 929:	learn: 0.0132804	total: 5.36s	remaining: 403ms
# 930:	learn: 0.0132461	total: 5.37s	remaining: 398ms
# 931:	learn: 0.0132021	total: 5.37s	remaining: 392ms
# 932:	learn: 0.0131653	total: 5.38s	remaining: 386ms
# 933:	learn: 0.0131438	total: 5.38s	remaining: 380ms
# 934:	learn: 0.0131076	total: 5.38s	remaining: 374ms
# 935:	learn: 0.0130787	total: 5.39s	remaining: 369ms
# 936:	learn: 0.0130479	total: 5.39s	remaining: 363ms
# 937:	learn: 0.0130148	total: 5.4s	remaining: 357ms
# 938:	learn: 0.0129843	total: 5.4s	remaining: 351ms
# 939:	learn: 0.0129658	total: 5.41s	remaining: 345ms
# 940:	learn: 0.0129604	total: 5.41s	remaining: 339ms
# 941:	learn: 0.0129295	total: 5.42s	remaining: 334ms
# 942:	learn: 0.0129033	total: 5.42s	remaining: 328ms
# 943:	learn: 0.0128810	total: 5.43s	remaining: 322ms
# 944:	learn: 0.0128545	total: 5.43s	remaining: 316ms
# 945:	learn: 0.0128219	total: 5.44s	remaining: 310ms
# 946:	learn: 0.0128062	total: 5.44s	remaining: 305ms
# 947:	learn: 0.0127856	total: 5.45s	remaining: 299ms
# 948:	learn: 0.0127546	total: 5.45s	remaining: 293ms
# 949:	learn: 0.0127181	total: 5.46s	remaining: 287ms
# 950:	learn: 0.0127052	total: 5.46s	remaining: 281ms
# 951:	learn: 0.0126790	total: 5.46s	remaining: 276ms
# 952:	learn: 0.0126534	total: 5.47s	remaining: 270ms
# 953:	learn: 0.0126407	total: 5.47s	remaining: 264ms
# 954:	learn: 0.0126100	total: 5.48s	remaining: 258ms
# 955:	learn: 0.0125676	total: 5.49s	remaining: 252ms
# 956:	learn: 0.0125450	total: 5.49s	remaining: 247ms
# 957:	learn: 0.0125196	total: 5.5s	remaining: 241ms
# 958:	learn: 0.0124943	total: 5.5s	remaining: 235ms
# 959:	learn: 0.0124704	total: 5.51s	remaining: 230ms
# 960:	learn: 0.0124491	total: 5.51s	remaining: 224ms
# 961:	learn: 0.0124125	total: 5.52s	remaining: 218ms
# 962:	learn: 0.0123837	total: 5.52s	remaining: 212ms
# 963:	learn: 0.0123613	total: 5.53s	remaining: 206ms
# 964:	learn: 0.0123300	total: 5.53s	remaining: 201ms
# 965:	learn: 0.0122826	total: 5.54s	remaining: 195ms
# 966:	learn: 0.0122698	total: 5.54s	remaining: 189ms
# 967:	learn: 0.0122332	total: 5.55s	remaining: 183ms
# 968:	learn: 0.0121972	total: 5.55s	remaining: 178ms
# 969:	learn: 0.0121808	total: 5.56s	remaining: 172ms
# 970:	learn: 0.0121575	total: 5.56s	remaining: 166ms
# 971:	learn: 0.0121320	total: 5.57s	remaining: 160ms
# 972:	learn: 0.0120949	total: 5.57s	remaining: 155ms
# 973:	learn: 0.0120740	total: 5.58s	remaining: 149ms
# 974:	learn: 0.0120489	total: 5.58s	remaining: 143ms
# 975:	learn: 0.0120099	total: 5.59s	remaining: 137ms
# 976:	learn: 0.0119786	total: 5.59s	remaining: 132ms
# 977:	learn: 0.0119609	total: 5.6s	remaining: 126ms
# 978:	learn: 0.0119474	total: 5.6s	remaining: 120ms
# 979:	learn: 0.0119159	total: 5.61s	remaining: 114ms
# 980:	learn: 0.0118967	total: 5.61s	remaining: 109ms
# 981:	learn: 0.0118711	total: 5.62s	remaining: 103ms
# 982:	learn: 0.0118597	total: 5.62s	remaining: 97.2ms
# 983:	learn: 0.0118447	total: 5.62s	remaining: 91.4ms
# 984:	learn: 0.0118090	total: 5.63s	remaining: 85.7ms
# 985:	learn: 0.0117943	total: 5.63s	remaining: 80ms
# 986:	learn: 0.0117665	total: 5.64s	remaining: 74.3ms
# 987:	learn: 0.0117334	total: 5.64s	remaining: 68.6ms
# 988:	learn: 0.0117057	total: 5.65s	remaining: 62.8ms
# 989:	learn: 0.0116983	total: 5.65s	remaining: 57.1ms
# 990:	learn: 0.0116656	total: 5.66s	remaining: 51.4ms
# 991:	learn: 0.0116348	total: 5.66s	remaining: 45.7ms
# 992:	learn: 0.0116141	total: 5.67s	remaining: 39.9ms
# 993:	learn: 0.0115850	total: 5.67s	remaining: 34.2ms
# 994:	learn: 0.0115560	total: 5.68s	remaining: 28.5ms
# 995:	learn: 0.0115315	total: 5.68s	remaining: 22.8ms
# 996:	learn: 0.0115102	total: 5.69s	remaining: 17.1ms
# 997:	learn: 0.0114924	total: 5.7s	remaining: 11.4ms
# 998:	learn: 0.0114692	total: 5.7s	remaining: 5.71ms
# 999:	learn: 0.0114499	total: 5.71s	remaining: 0us

# %%
# for i,v in Predictions.items():
#     print(i)
PCAnocScoreDataFrame
# Out:
#                            2         4         8         10        14  \
# Logistic Regression  0.959064  0.953216  0.964912  0.970760  0.970760
# Decision tree        0.883041  0.894737  0.906433  0.888889  0.883041
# Random forest        0.929825  0.947368  0.947368  0.947368  0.947368
# Ada Boosting         0.923977  0.953216  0.970760  0.970760  0.964912
# Cat Boosting         0.935673  0.941520  0.964912  0.959064  0.964912
# Gradient Boosting    0.941520  0.941520  0.953216  0.941520  0.941520
# XG Boosting          0.947368  0.929825  0.947368  0.953216  0.959064
#
#                            16        20        22        26        28
# Logistic Regression  0.970760  0.970760  0.970760  0.970760  0.970760
# Decision tree        0.877193  0.929825  0.894737  0.900585  0.900585
# Random forest        0.935673  0.941520  0.953216  0.941520  0.935673
# Ada Boosting         0.964912  0.964912  0.970760  0.959064  0.953216
# Cat Boosting         0.953216  0.964912  0.959064  0.959064  0.959064
# Gradient Boosting    0.935673  0.941520  0.935673  0.929825  0.929825
# XG Boosting          0.941520  0.959064  0.964912  0.959064  0.964912

# %%
MaximumScore003=PCAnocScoreDataFrame.values.max()
for i in PCAnocScoreDataFrame.index:
    for j in PCAnocScoreDataFrame.columns:
        for col in PCAnocScoreDataFrame.columns:
            if PCAnocScoreDataFrame.loc[i][j] == MaximumScore003:
                max= PCAnocScoreDataFrame.loc[i][j]
                if  PCAnocScoreDataFrame.loc[i][j] >= max:
                    max= PCAnocScoreDataFrame.loc[i][j]
                    # print(max)
for i in PCAnocScoreDataFrame.index:
    for j in PCAnocScoreDataFrame.columns:
        if max == PCAnocScoreDataFrame.loc[i][j]:
            # print(j)
            BestVariance=j
PerfomanceDF["No_OF_Components_PCA"]=PCAnocScoreDataFrame[BestVariance]

# %%
PerfomanceDF
# Out:
#                      No_Tuning  Outlayers_Removed  No_OF_Components_PCA
# Logistic Regression   0.970760           0.970760              0.970760
# Decision tree         0.970760           0.929825              0.894737
# Random forest         0.959064           0.959064              0.953216
# Ada Boosting          0.947368           0.947368              0.970760
# Cat Boosting          0.959064           0.959064              0.959064
# Gradient Boosting     0.964912           0.964912              0.935673
# XG Boosting           0.964912           0.964912              0.964912

# %%
PercentageOfVariance = [0.93,0.95,0.98]
PCAScoreDataFrame=pd.DataFrame()
for VariancePercentage in PercentageOfVariance:
    from sklearn.decomposition import PCA
    PCADataFrame=ClearedDataFrame.drop([TargetColumn],axis=1)
    pca = PCA().fit(PCADataFrame)
    cum_var = np.cumsum(pca.explained_variance_ratio_)
    NComponents = np.argmax(cum_var >= VariancePercentage) + 1
    pca=PCA(n_components=NComponents)
    FinalPCADF=pca.fit_transform(PCADataFrame)
    FinalPCADF=pd.DataFrame(FinalPCADF,columns=[f'PC{i+1}' for i in range(NComponents)])
    FinalPCADF["Target"]= ClearedDataFrame[TargetColumn]
    # for col in FinalPCADF.columns:
    #             if np.issubdtype(FinalPCADF[col].dtype, np.number):
    #                 # print(col, df[col].dtype)
    #                 FinalPCADF[col]=FinalPCADF[col].fillna(FinalPCADF[col].median())
    #                 print(f"mean for {FinalPCADF[col].head(0)} value filled ✅ ")
                # if df[col].dtype == 'object' or df[col].dtype == 'string':
                #     # print(col, df[col].dtype)
                #     df[col]=df[col].fillna(df[col].mode().iloc[0])
                #     print(f"mode for {df[col].head(0)} value filled ✅")
    FinalPCADF = FinalPCADF.replace([np.inf, -np.inf], np.nan)
    FinalPCADF.dropna(inplace=True)
    # for i in FinalPCADF.index:
    #     for j in FinalPCADF.columns:
    #         if FinalPCADF.loc[i][j] == "-inf":
    #             FinalPCADF=FinalPCADF.drop(i,axis=0)
    #         if FinalPCADF.loc[i][j] == "inf":
    #             FinalPCADF=FinalPCADF.drop(i,axis=0)
    xpca=FinalPCADF.drop('Target',axis=1)
    ypca=FinalPCADF.Target
    xTrainPCA,xTestPCA,yTrainPCA,yTestPCA = train_test_split(xpca,ypca,train_size=TrainSize,random_state=44)


    # Training

    from sklearn.linear_model import LinearRegression,LogisticRegression
    from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor,GradientBoostingClassifier,GradientBoostingRegressor,AdaBoostClassifier,AdaBoostRegressor
    from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
    from xgboost import XGBClassifier,XGBRegressor
    from catboost import CatBoostClassifier,CatBoostRegressor
    from sklearn.metrics import r2_score,accuracy_score
    linRegVariance=LinearRegression()
    logRegVariance=LogisticRegression()
    RandomRegVariance=RandomForestRegressor()
    RandomClaVariance=RandomForestClassifier()
    GradBoostClaVariance=GradientBoostingClassifier()
    GradBoostRegVariance=GradientBoostingRegressor()
    AdaBoostRegVariance=AdaBoostRegressor()
    AdaBoostClaVariance=AdaBoostClassifier()
    DecRegVariance=DecisionTreeRegressor()
    DecClaVariance=DecisionTreeClassifier()
    XGBClaVariance=XGBClassifier()
    XGBRegVariance=XGBRegressor()
    CatBoostClaVariance=CatBoostClassifier()
    CatBoostRegVariance=CatBoostRegressor()

    # Training model based on target type

    if ModelType == "Regression":
        # regression training
        linRegVariance.fit(xTrainPCA,yTrainPCA)
        DecRegVariance.fit(xTrainPCA,yTrainPCA)
        RandomRegVariance.fit(xTrainPCA,yTrainPCA)
        AdaBoostRegVariance.fit(xTrainPCA,yTrainPCA)
        CatBoostRegVariance.fit(xTrainPCA,yTrainPCA)
        GradBoostRegVariance.fit(xTrainPCA,yTrainPCA)
        XGBRegVariance.fit(xTrainPCA,yTrainPCA)

        # regression Y predit
        Predictions['linRegPredit004']=linRegVariance.predict(xTestPCA)
        Predictions['DecRegPredit004']=DecRegVariance.predict(xTestPCA)
        Predictions['RandomRegPredit004']=RandomRegVariance.predict(xTestPCA)
        Predictions['AdaBoostRegPredit004']=AdaBoostRegVariance.predict(xTestPCA)
        Predictions['CatBoostRegPredit004']=CatBoostRegVariance.predict(xTestPCA)
        Predictions['GradBoostRegPredit004']=GradBoostRegVariance.predict(xTestPCA)
        Predictions['XGBRegPredit004']=XGBRegVariance.predict(xTestPCA)


        # R2 score
        linRegR2ScorePCA=r2_score(yTestPCA,Predictions['linRegPredit004'])
        DecRegR2ScorePCA=r2_score(yTestPCA,Predictions['DecRegPredit004'])
        RandomRegR2ScorePCA=r2_score(yTestPCA,Predictions['RandomRegPredit004'])
        AdaBoostRegR2ScorePCA=r2_score(yTestPCA,Predictions['AdaBoostRegPredit004'])
        CatBoostRegR2ScorePCA=r2_score(yTestPCA,Predictions['CatBoostRegPredit004'])
        GradBoostRegR2ScorePCA=r2_score(yTestPCA,Predictions['GradBoostRegPredit004'])
        XGBRegR2ScorePCA=r2_score(yTestPCA,Predictions['XGBRegPredit004'])

        PCAScoreDataFrame.index=['Logistic Regression','Decision tree','Random forest','Ada Boosting','Cat Boosting','Gradient Boosting','XG Boosting']
        PCAScoreDataFrame[VariancePercentage]=[linRegR2ScorePCA,DecRegR2ScorePCA,RandomRegR2ScorePCA,AdaBoostRegR2ScorePCA,CatBoostRegR2ScorePCA,GradBoostRegR2ScorePCA,XGBRegR2ScorePCA]


    if ModelType == "Classification":

        # Balancing the classification data
        print("Performing Over sampling")
        print(f"Before SMOTE:\n{yTrainPCA.value_counts()}")
        from imblearn.over_sampling import SMOTE
        smote=SMOTE(random_state=42)
        xTrainPCA,yTrainPCA = smote.fit_resample(xTrainPCA,yTrainPCA)
        print(f"✅ After SMOTE:\n{yTrainPCA.value_counts()}")



        # regression training
        logRegVariance.fit(xTrainPCA,yTrainPCA)
        DecClaVariance.fit(xTrainPCA,yTrainPCA)
        RandomClaVariance.fit(xTrainPCA,yTrainPCA)
        AdaBoostClaVariance.fit(xTrainPCA,yTrainPCA)
        CatBoostClaVariance.fit(xTrainPCA,yTrainPCA)
        GradBoostClaVariance.fit(xTrainPCA,yTrainPCA)
        XGBClaVariance.fit(xTrainPCA,yTrainPCA)

        # Claression Y predit
        Predictions['logRegPredit004']=logRegVariance.predict(xTestPCA)
        Predictions['DecClaPredit004']=DecClaVariance.predict(xTestPCA)
        Predictions['RandomClaPredit004']=RandomClaVariance.predict(xTestPCA)
        Predictions['AdaBoostClaPredit004']=AdaBoostClaVariance.predict(xTestPCA)
        Predictions['CatBoostClaPredit004']=CatBoostClaVariance.predict(xTestPCA)
        Predictions['GradBoostClaPredit004']=GradBoostClaVariance.predict(xTestPCA)
        Predictions['XGBClaPredit004']=XGBClaVariance.predict(xTestPCA)


        # Accuracy score
        logRegAccuracyScorePCA=accuracy_score(yTestPCA,Predictions['logRegPredit004'])
        DecClaAccuracyScorePCA=accuracy_score(yTestPCA,Predictions['DecClaPredit004'])
        RandomClaAccuracyScorePCA=accuracy_score(yTestPCA,Predictions['RandomClaPredit004'])
        AdaBoostClaAccuracyScorePCA=accuracy_score(yTestPCA,Predictions['AdaBoostClaPredit004'])
        CatBoostClaAccuracyScorePCA=accuracy_score(yTestPCA,Predictions['CatBoostClaPredit004'])
        GradBoostClaAccuracyScorePCA=accuracy_score(yTestPCA,Predictions['GradBoostClaPredit004'])
        XGBClaAccuracyScorePCA=accuracy_score(yTestPCA,Predictions['XGBClaPredit004'])


        PCAScoreDataFrame.index=['Logistic Regression','Decision tree','Random forest','Ada Boosting','Cat Boosting','Gradient Boosting','XG Boosting']
        PCAScoreDataFrame[VariancePercentage]= [logRegAccuracyScorePCA,DecClaAccuracyScorePCA,RandomClaAccuracyScorePCA,AdaBoostClaAccuracyScorePCA,CatBoostClaAccuracyScorePCA,GradBoostClaAccuracyScorePCA,XGBClaAccuracyScorePCA]
# Out:
# Performing Over sampling
# Before SMOTE:
# Target
# 1.0    249
# 0.0    149
# Name: count, dtype: int64
# ✅ After SMOTE:
# Target
# 1.0    249
# 0.0    249
# Name: count, dtype: int64
# Learning rate set to 0.00765
# 0:	learn: 0.6824412	total: 1.59ms	remaining: 1.59s
# 1:	learn: 0.6726563	total: 2.36ms	remaining: 1.18s
# 2:	learn: 0.6639620	total: 3.12ms	remaining: 1.04s
# 3:	learn: 0.6536566	total: 3.8ms	remaining: 946ms
# 4:	learn: 0.6449624	total: 4.49ms	remaining: 893ms
# 5:	learn: 0.6351210	total: 5.17ms	remaining: 857ms
# 6:	learn: 0.6254795	total: 5.85ms	remaining: 830ms
# 7:	learn: 0.6159006	total: 6.49ms	remaining: 805ms
# 8:	learn: 0.6063674	total: 7.18ms	remaining: 791ms
# 9:	learn: 0.5983678	total: 7.84ms	remaining: 777ms
# 10:	learn: 0.5901601	total: 8.48ms	remaining: 763ms
# 11:	learn: 0.5813559	total: 9.13ms	remaining: 752ms
# 12:	learn: 0.5734899	total: 9.78ms	remaining: 743ms
# 13:	learn: 0.5648704	total: 10.4ms	remaining: 736ms
# 14:	learn: 0.5579837	total: 11.1ms	remaining: 728ms
# 15:	learn: 0.5500194	total: 11.8ms	remaining: 724ms
# 16:	learn: 0.5428072	total: 12.3ms	remaining: 710ms
# 17:	learn: 0.5352754	total: 12.9ms	remaining: 706ms
# 18:	learn: 0.5283222	total: 13.6ms	remaining: 703ms
# 19:	learn: 0.5214151	total: 14.3ms	remaining: 699ms
# 20:	learn: 0.5141595	total: 14.9ms	remaining: 696ms
# 21:	learn: 0.5073973	total: 15.6ms	remaining: 694ms
# 22:	learn: 0.5005086	total: 16.3ms	remaining: 692ms
# 23:	learn: 0.4953269	total: 17ms	remaining: 690ms
# 24:	learn: 0.4886389	total: 17.6ms	remaining: 688ms
# 25:	learn: 0.4835303	total: 18.3ms	remaining: 686ms
# 26:	learn: 0.4770286	total: 19ms	remaining: 683ms
# 27:	learn: 0.4710035	total: 19.6ms	remaining: 682ms
# 28:	learn: 0.4652561	total: 20.3ms	remaining: 680ms
# 29:	learn: 0.4596863	total: 21ms	remaining: 678ms
# 30:	learn: 0.4544622	total: 21.6ms	remaining: 677ms
# 31:	learn: 0.4505914	total: 22.3ms	remaining: 675ms
# 32:	learn: 0.4453901	total: 23ms	remaining: 674ms
# 33:	learn: 0.4407442	total: 23.7ms	remaining: 672ms
# 34:	learn: 0.4367571	total: 24.3ms	remaining: 670ms
# 35:	learn: 0.4317793	total: 25ms	remaining: 670ms
# 36:	learn: 0.4267418	total: 25.7ms	remaining: 668ms
# 37:	learn: 0.4219009	total: 26.4ms	remaining: 668ms
# 38:	learn: 0.4172197	total: 27.1ms	remaining: 667ms
# 39:	learn: 0.4128430	total: 27.8ms	remaining: 668ms
# 40:	learn: 0.4084169	total: 28.5ms	remaining: 666ms
# 41:	learn: 0.4040079	total: 29.1ms	remaining: 665ms
# 42:	learn: 0.4001962	total: 29.8ms	remaining: 664ms
# 43:	learn: 0.3956488	total: 30.5ms	remaining: 663ms
# 44:	learn: 0.3909756	total: 31.1ms	remaining: 661ms
# 45:	learn: 0.3866847	total: 31.8ms	remaining: 660ms
# 46:	learn: 0.3833688	total: 32.5ms	remaining: 659ms
# 47:	learn: 0.3793514	total: 33.2ms	remaining: 658ms
# 48:	learn: 0.3753285	total: 33.8ms	remaining: 656ms
# 49:	learn: 0.3722360	total: 34.5ms	remaining: 655ms
# 50:	learn: 0.3692176	total: 35.2ms	remaining: 654ms
# 51:	learn: 0.3657363	total: 35.8ms	remaining: 653ms
# 52:	learn: 0.3624231	total: 36.5ms	remaining: 653ms
# 53:	learn: 0.3596260	total: 37.2ms	remaining: 652ms
# 54:	learn: 0.3563451	total: 37.9ms	remaining: 651ms
# 55:	learn: 0.3530503	total: 38.5ms	remaining: 650ms
# 56:	learn: 0.3500112	total: 39.3ms	remaining: 649ms
# 57:	learn: 0.3476306	total: 39.9ms	remaining: 648ms
# 58:	learn: 0.3457343	total: 40.6ms	remaining: 648ms
# 59:	learn: 0.3430561	total: 41.3ms	remaining: 647ms
# 60:	learn: 0.3396156	total: 42ms	remaining: 646ms
# 61:	learn: 0.3365831	total: 42.6ms	remaining: 645ms
# 62:	learn: 0.3336872	total: 43.3ms	remaining: 644ms
# 63:	learn: 0.3309217	total: 43.9ms	remaining: 643ms
# 64:	learn: 0.3279409	total: 44.6ms	remaining: 642ms
# 65:	learn: 0.3258467	total: 45.3ms	remaining: 641ms
# 66:	learn: 0.3230666	total: 45.9ms	remaining: 640ms
# 67:	learn: 0.3207871	total: 46.6ms	remaining: 639ms
# 68:	learn: 0.3183489	total: 47.3ms	remaining: 638ms
# 69:	learn: 0.3163101	total: 47.9ms	remaining: 636ms
# 70:	learn: 0.3137098	total: 48.6ms	remaining: 635ms
# 71:	learn: 0.3113921	total: 49.2ms	remaining: 634ms
# 72:	learn: 0.3087822	total: 49.9ms	remaining: 633ms
# 73:	learn: 0.3064623	total: 50.5ms	remaining: 633ms
# 74:	learn: 0.3042686	total: 51.2ms	remaining: 631ms
# 75:	learn: 0.3020599	total: 51.9ms	remaining: 631ms
# 76:	learn: 0.2999112	total: 52.5ms	remaining: 630ms
# 77:	learn: 0.2977227	total: 53.2ms	remaining: 629ms
# 78:	learn: 0.2958156	total: 53.8ms	remaining: 628ms
# 79:	learn: 0.2934246	total: 54.5ms	remaining: 627ms
# 80:	learn: 0.2914353	total: 55.2ms	remaining: 626ms
# 81:	learn: 0.2892095	total: 55.8ms	remaining: 625ms
# 82:	learn: 0.2871427	total: 56.5ms	remaining: 624ms
# 83:	learn: 0.2852726	total: 57.3ms	remaining: 624ms
# 84:	learn: 0.2835239	total: 57.9ms	remaining: 624ms
# 85:	learn: 0.2817340	total: 58.6ms	remaining: 623ms
# 86:	learn: 0.2801938	total: 59.3ms	remaining: 622ms
# 87:	learn: 0.2782819	total: 59.9ms	remaining: 621ms
# 88:	learn: 0.2771022	total: 60.6ms	remaining: 620ms
# 89:	learn: 0.2753499	total: 61.3ms	remaining: 620ms
# 90:	learn: 0.2737855	total: 62ms	remaining: 620ms
# 91:	learn: 0.2723389	total: 62.7ms	remaining: 619ms
# 92:	learn: 0.2708426	total: 63.4ms	remaining: 618ms
# 93:	learn: 0.2694461	total: 64.1ms	remaining: 617ms
# 94:	learn: 0.2678964	total: 65ms	remaining: 619ms
# 95:	learn: 0.2662113	total: 66ms	remaining: 621ms
# 96:	learn: 0.2647690	total: 66.8ms	remaining: 621ms
# 97:	learn: 0.2635399	total: 67.5ms	remaining: 621ms
# 98:	learn: 0.2622236	total: 68.2ms	remaining: 620ms
# 99:	learn: 0.2607480	total: 68.8ms	remaining: 620ms
# 100:	learn: 0.2593103	total: 69.6ms	remaining: 619ms
# 101:	learn: 0.2579945	total: 70.3ms	remaining: 619ms
# 102:	learn: 0.2572429	total: 70.9ms	remaining: 618ms
# 103:	learn: 0.2561535	total: 71.6ms	remaining: 617ms
# 104:	learn: 0.2548253	total: 72.3ms	remaining: 616ms
# 105:	learn: 0.2535745	total: 73ms	remaining: 616ms
# 106:	learn: 0.2521332	total: 73.7ms	remaining: 615ms
# 107:	learn: 0.2508083	total: 74.4ms	remaining: 615ms
# 108:	learn: 0.2497237	total: 75.1ms	remaining: 614ms
# 109:	learn: 0.2485752	total: 75.8ms	remaining: 613ms
# 110:	learn: 0.2475995	total: 76.5ms	remaining: 612ms
# 111:	learn: 0.2464175	total: 77.1ms	remaining: 612ms
# 112:	learn: 0.2455043	total: 77.8ms	remaining: 611ms
# 113:	learn: 0.2444070	total: 78.5ms	remaining: 610ms
# 114:	learn: 0.2432481	total: 79.2ms	remaining: 609ms
# 115:	learn: 0.2423948	total: 79.9ms	remaining: 609ms
# 116:	learn: 0.2413045	total: 80.5ms	remaining: 608ms
# 117:	learn: 0.2404039	total: 81.2ms	remaining: 607ms
# 118:	learn: 0.2393967	total: 81.9ms	remaining: 606ms
# 119:	learn: 0.2383410	total: 82.6ms	remaining: 606ms
# 120:	learn: 0.2375278	total: 83.4ms	remaining: 606ms
# 121:	learn: 0.2365093	total: 84.1ms	remaining: 605ms
# 122:	learn: 0.2358293	total: 84.7ms	remaining: 604ms
# 123:	learn: 0.2351514	total: 85.4ms	remaining: 603ms
# 124:	learn: 0.2342667	total: 86.1ms	remaining: 603ms
# 125:	learn: 0.2332790	total: 86.8ms	remaining: 602ms
# 126:	learn: 0.2324177	total: 87.6ms	remaining: 602ms
# 127:	learn: 0.2316001	total: 88.3ms	remaining: 602ms
# 128:	learn: 0.2309799	total: 89ms	remaining: 601ms
# 129:	learn: 0.2300098	total: 89.7ms	remaining: 600ms
# 130:	learn: 0.2289489	total: 90.4ms	remaining: 599ms
# 131:	learn: 0.2281967	total: 91ms	remaining: 598ms
# 132:	learn: 0.2273449	total: 91.7ms	remaining: 598ms
# 133:	learn: 0.2265731	total: 92.4ms	remaining: 597ms
# 134:	learn: 0.2257615	total: 93ms	remaining: 596ms
# 135:	learn: 0.2249723	total: 93.7ms	remaining: 595ms
# 136:	learn: 0.2241990	total: 94.4ms	remaining: 595ms
# 137:	learn: 0.2234880	total: 95.1ms	remaining: 594ms
# 138:	learn: 0.2226000	total: 95.7ms	remaining: 593ms
# 139:	learn: 0.2218123	total: 96.4ms	remaining: 592ms
# 140:	learn: 0.2211375	total: 97.1ms	remaining: 592ms
# 141:	learn: 0.2205031	total: 97.8ms	remaining: 591ms
# 142:	learn: 0.2199052	total: 98.5ms	remaining: 590ms
# 143:	learn: 0.2194116	total: 99.1ms	remaining: 589ms
# 144:	learn: 0.2187942	total: 99.8ms	remaining: 589ms
# 145:	learn: 0.2181144	total: 100ms	remaining: 588ms
# 146:	learn: 0.2175951	total: 101ms	remaining: 587ms
# 147:	learn: 0.2168288	total: 102ms	remaining: 586ms
# 148:	learn: 0.2162261	total: 102ms	remaining: 585ms
# 149:	learn: 0.2157369	total: 103ms	remaining: 584ms
# 150:	learn: 0.2150491	total: 104ms	remaining: 584ms
# 151:	learn: 0.2142577	total: 104ms	remaining: 583ms
# 152:	learn: 0.2136401	total: 105ms	remaining: 582ms
# 153:	learn: 0.2131047	total: 106ms	remaining: 581ms
# 154:	learn: 0.2125900	total: 107ms	remaining: 581ms
# 155:	learn: 0.2119712	total: 107ms	remaining: 580ms
# 156:	learn: 0.2114891	total: 108ms	remaining: 579ms
# 157:	learn: 0.2110030	total: 108ms	remaining: 578ms
# 158:	learn: 0.2104056	total: 109ms	remaining: 577ms
# 159:	learn: 0.2099681	total: 110ms	remaining: 576ms
# 160:	learn: 0.2095866	total: 110ms	remaining: 576ms
# 161:	learn: 0.2090657	total: 111ms	remaining: 575ms
# 162:	learn: 0.2086213	total: 112ms	remaining: 574ms
# 163:	learn: 0.2081631	total: 112ms	remaining: 573ms
# 164:	learn: 0.2077267	total: 113ms	remaining: 573ms
# 165:	learn: 0.2074723	total: 114ms	remaining: 572ms
# 166:	learn: 0.2070137	total: 114ms	remaining: 571ms
# 167:	learn: 0.2066999	total: 115ms	remaining: 570ms
# 168:	learn: 0.2061705	total: 116ms	remaining: 570ms
# 169:	learn: 0.2056581	total: 117ms	remaining: 569ms
# 170:	learn: 0.2052095	total: 117ms	remaining: 568ms
# 171:	learn: 0.2048257	total: 118ms	remaining: 568ms
# 172:	learn: 0.2044556	total: 119ms	remaining: 567ms
# 173:	learn: 0.2039924	total: 119ms	remaining: 566ms
# 174:	learn: 0.2035069	total: 120ms	remaining: 566ms
# 175:	learn: 0.2030883	total: 121ms	remaining: 565ms
# 176:	learn: 0.2025749	total: 121ms	remaining: 564ms
# 177:	learn: 0.2020780	total: 122ms	remaining: 563ms
# 178:	learn: 0.2017419	total: 123ms	remaining: 563ms
# 179:	learn: 0.2014217	total: 123ms	remaining: 562ms
# 180:	learn: 0.2011100	total: 124ms	remaining: 561ms
# 181:	learn: 0.2006862	total: 125ms	remaining: 560ms
# 182:	learn: 0.2003192	total: 125ms	remaining: 560ms
# 183:	learn: 0.1999647	total: 126ms	remaining: 559ms
# 184:	learn: 0.1994633	total: 127ms	remaining: 558ms
# 185:	learn: 0.1991847	total: 127ms	remaining: 558ms
# 186:	learn: 0.1989378	total: 128ms	remaining: 557ms
# 187:	learn: 0.1986262	total: 129ms	remaining: 556ms
# 188:	learn: 0.1982441	total: 129ms	remaining: 555ms
# 189:	learn: 0.1980082	total: 130ms	remaining: 554ms
# 190:	learn: 0.1976280	total: 131ms	remaining: 553ms
# 191:	learn: 0.1971048	total: 131ms	remaining: 553ms
# 192:	learn: 0.1966967	total: 132ms	remaining: 552ms
# 193:	learn: 0.1963432	total: 133ms	remaining: 551ms
# 194:	learn: 0.1958941	total: 133ms	remaining: 550ms
# 195:	learn: 0.1956558	total: 134ms	remaining: 550ms
# 196:	learn: 0.1953257	total: 135ms	remaining: 549ms
# 197:	learn: 0.1949062	total: 135ms	remaining: 548ms
# 198:	learn: 0.1945482	total: 136ms	remaining: 547ms
# 199:	learn: 0.1942151	total: 137ms	remaining: 547ms
# 200:	learn: 0.1938319	total: 137ms	remaining: 546ms
# 201:	learn: 0.1935808	total: 138ms	remaining: 545ms
# 202:	learn: 0.1932279	total: 139ms	remaining: 545ms
# 203:	learn: 0.1928608	total: 139ms	remaining: 544ms
# 204:	learn: 0.1925677	total: 140ms	remaining: 543ms
# 205:	learn: 0.1923348	total: 141ms	remaining: 542ms
# 206:	learn: 0.1919800	total: 141ms	remaining: 542ms
# 207:	learn: 0.1916155	total: 142ms	remaining: 541ms
# 208:	learn: 0.1913849	total: 143ms	remaining: 540ms
# 209:	learn: 0.1909963	total: 143ms	remaining: 540ms
# 210:	learn: 0.1905892	total: 144ms	remaining: 539ms
# 211:	learn: 0.1902616	total: 145ms	remaining: 538ms
# 212:	learn: 0.1899192	total: 145ms	remaining: 537ms
# 213:	learn: 0.1895013	total: 146ms	remaining: 537ms
# 214:	learn: 0.1891920	total: 147ms	remaining: 536ms
# 215:	learn: 0.1889525	total: 148ms	remaining: 535ms
# 216:	learn: 0.1886583	total: 148ms	remaining: 535ms
# 217:	learn: 0.1882441	total: 149ms	remaining: 534ms
# 218:	learn: 0.1880273	total: 150ms	remaining: 533ms
# 219:	learn: 0.1878606	total: 150ms	remaining: 533ms
# 220:	learn: 0.1875316	total: 151ms	remaining: 533ms
# 221:	learn: 0.1872801	total: 152ms	remaining: 534ms
# 222:	learn: 0.1870531	total: 153ms	remaining: 533ms
# 223:	learn: 0.1867313	total: 154ms	remaining: 534ms
# 224:	learn: 0.1865303	total: 155ms	remaining: 534ms
# 225:	learn: 0.1862334	total: 156ms	remaining: 534ms
# 226:	learn: 0.1858271	total: 157ms	remaining: 533ms
# 227:	learn: 0.1856100	total: 157ms	remaining: 532ms
# 228:	learn: 0.1852198	total: 158ms	remaining: 532ms
# 229:	learn: 0.1850900	total: 159ms	remaining: 531ms
# 230:	learn: 0.1847259	total: 159ms	remaining: 531ms
# 231:	learn: 0.1844358	total: 160ms	remaining: 530ms
# 232:	learn: 0.1841472	total: 161ms	remaining: 529ms
# 233:	learn: 0.1838995	total: 161ms	remaining: 528ms
# 234:	learn: 0.1837303	total: 162ms	remaining: 528ms
# 235:	learn: 0.1834623	total: 163ms	remaining: 527ms
# 236:	learn: 0.1831649	total: 163ms	remaining: 526ms
# 237:	learn: 0.1830206	total: 164ms	remaining: 525ms
# 238:	learn: 0.1827645	total: 165ms	remaining: 524ms
# 239:	learn: 0.1824870	total: 165ms	remaining: 524ms
# 240:	learn: 0.1823141	total: 166ms	remaining: 523ms
# 241:	learn: 0.1820073	total: 167ms	remaining: 522ms
# 242:	learn: 0.1818458	total: 167ms	remaining: 521ms
# 243:	learn: 0.1816412	total: 168ms	remaining: 521ms
# 244:	learn: 0.1814095	total: 169ms	remaining: 520ms
# 245:	learn: 0.1812008	total: 169ms	remaining: 519ms
# 246:	learn: 0.1809488	total: 170ms	remaining: 519ms
# 247:	learn: 0.1806291	total: 171ms	remaining: 518ms
# 248:	learn: 0.1805025	total: 171ms	remaining: 517ms
# 249:	learn: 0.1801686	total: 172ms	remaining: 516ms
# 250:	learn: 0.1799599	total: 173ms	remaining: 516ms
# 251:	learn: 0.1797185	total: 174ms	remaining: 515ms
# 252:	learn: 0.1795031	total: 174ms	remaining: 514ms
# 253:	learn: 0.1792790	total: 175ms	remaining: 514ms
# 254:	learn: 0.1791093	total: 176ms	remaining: 513ms
# 255:	learn: 0.1787794	total: 176ms	remaining: 512ms
# 256:	learn: 0.1786545	total: 177ms	remaining: 511ms
# 257:	learn: 0.1785205	total: 178ms	remaining: 511ms
# 258:	learn: 0.1783468	total: 178ms	remaining: 510ms
# 259:	learn: 0.1780944	total: 179ms	remaining: 509ms
# 260:	learn: 0.1778137	total: 180ms	remaining: 508ms
# 261:	learn: 0.1775457	total: 180ms	remaining: 508ms
# 262:	learn: 0.1773724	total: 181ms	remaining: 507ms
# 263:	learn: 0.1771551	total: 182ms	remaining: 506ms
# 264:	learn: 0.1769561	total: 182ms	remaining: 505ms
# 265:	learn: 0.1767894	total: 183ms	remaining: 505ms
# 266:	learn: 0.1766098	total: 184ms	remaining: 504ms
# 267:	learn: 0.1763857	total: 187ms	remaining: 511ms
# 268:	learn: 0.1762341	total: 188ms	remaining: 511ms
# 269:	learn: 0.1760975	total: 189ms	remaining: 511ms
# 270:	learn: 0.1759025	total: 190ms	remaining: 511ms
# 271:	learn: 0.1756999	total: 191ms	remaining: 511ms
# 272:	learn: 0.1755141	total: 193ms	remaining: 513ms
# 273:	learn: 0.1753449	total: 194ms	remaining: 514ms
# 274:	learn: 0.1752576	total: 197ms	remaining: 520ms
# 275:	learn: 0.1751051	total: 200ms	remaining: 524ms
# 276:	learn: 0.1749058	total: 202ms	remaining: 528ms
# 277:	learn: 0.1744531	total: 203ms	remaining: 528ms
# 278:	learn: 0.1743002	total: 204ms	remaining: 528ms
# 279:	learn: 0.1741621	total: 205ms	remaining: 528ms
# 280:	learn: 0.1739447	total: 206ms	remaining: 527ms
# 281:	learn: 0.1737867	total: 207ms	remaining: 527ms
# 282:	learn: 0.1736058	total: 208ms	remaining: 526ms
# 283:	learn: 0.1733954	total: 209ms	remaining: 526ms
# 284:	learn: 0.1732383	total: 210ms	remaining: 526ms
# 285:	learn: 0.1731695	total: 210ms	remaining: 525ms
# 286:	learn: 0.1729836	total: 211ms	remaining: 524ms
# 287:	learn: 0.1727737	total: 212ms	remaining: 523ms
# 288:	learn: 0.1725950	total: 212ms	remaining: 522ms
# 289:	learn: 0.1725323	total: 213ms	remaining: 522ms
# 290:	learn: 0.1722736	total: 214ms	remaining: 521ms
# 291:	learn: 0.1720801	total: 215ms	remaining: 521ms
# 292:	learn: 0.1717837	total: 216ms	remaining: 521ms
# 293:	learn: 0.1716531	total: 217ms	remaining: 521ms
# 294:	learn: 0.1714738	total: 217ms	remaining: 520ms
# 295:	learn: 0.1712931	total: 218ms	remaining: 519ms
# 296:	learn: 0.1711642	total: 219ms	remaining: 519ms
# 297:	learn: 0.1709697	total: 220ms	remaining: 519ms
# 298:	learn: 0.1708411	total: 221ms	remaining: 518ms
# 299:	learn: 0.1707288	total: 221ms	remaining: 517ms
# 300:	learn: 0.1705714	total: 222ms	remaining: 516ms
# 301:	learn: 0.1704359	total: 223ms	remaining: 516ms
# 302:	learn: 0.1702219	total: 224ms	remaining: 515ms
# 303:	learn: 0.1699387	total: 225ms	remaining: 515ms
# 304:	learn: 0.1697770	total: 226ms	remaining: 514ms
# 305:	learn: 0.1696481	total: 227ms	remaining: 514ms
# 306:	learn: 0.1695840	total: 228ms	remaining: 514ms
# 307:	learn: 0.1694477	total: 228ms	remaining: 513ms
# 308:	learn: 0.1693319	total: 229ms	remaining: 512ms
# 309:	learn: 0.1691418	total: 230ms	remaining: 512ms
# 310:	learn: 0.1690495	total: 231ms	remaining: 512ms
# 311:	learn: 0.1689612	total: 232ms	remaining: 511ms
# 312:	learn: 0.1688103	total: 232ms	remaining: 510ms
# 313:	learn: 0.1686725	total: 233ms	remaining: 509ms
# 314:	learn: 0.1685461	total: 234ms	remaining: 508ms
# 315:	learn: 0.1684160	total: 234ms	remaining: 507ms
# 316:	learn: 0.1682198	total: 235ms	remaining: 507ms
# 317:	learn: 0.1681823	total: 236ms	remaining: 506ms
# 318:	learn: 0.1680222	total: 236ms	remaining: 505ms
# 319:	learn: 0.1679158	total: 237ms	remaining: 504ms
# 320:	learn: 0.1676749	total: 238ms	remaining: 503ms
# 321:	learn: 0.1676121	total: 238ms	remaining: 502ms
# 322:	learn: 0.1674406	total: 239ms	remaining: 501ms
# 323:	learn: 0.1672868	total: 240ms	remaining: 500ms
# 324:	learn: 0.1671966	total: 240ms	remaining: 499ms
# 325:	learn: 0.1671153	total: 241ms	remaining: 498ms
# 326:	learn: 0.1669439	total: 242ms	remaining: 498ms
# 327:	learn: 0.1668228	total: 242ms	remaining: 497ms
# 328:	learn: 0.1665887	total: 243ms	remaining: 496ms
# 329:	learn: 0.1664085	total: 244ms	remaining: 495ms
# 330:	learn: 0.1662652	total: 244ms	remaining: 494ms
# 331:	learn: 0.1661255	total: 245ms	remaining: 493ms
# 332:	learn: 0.1659915	total: 246ms	remaining: 492ms
# 333:	learn: 0.1657610	total: 246ms	remaining: 491ms
# 334:	learn: 0.1656575	total: 247ms	remaining: 490ms
# 335:	learn: 0.1654928	total: 248ms	remaining: 490ms
# 336:	learn: 0.1653653	total: 248ms	remaining: 489ms
# 337:	learn: 0.1651748	total: 249ms	remaining: 488ms
# 338:	learn: 0.1650783	total: 250ms	remaining: 487ms
# 339:	learn: 0.1649574	total: 250ms	remaining: 486ms
# 340:	learn: 0.1647640	total: 251ms	remaining: 485ms
# 341:	learn: 0.1646512	total: 252ms	remaining: 484ms
# 342:	learn: 0.1645119	total: 252ms	remaining: 483ms
# 343:	learn: 0.1643757	total: 253ms	remaining: 483ms
# 344:	learn: 0.1641467	total: 254ms	remaining: 482ms
# 345:	learn: 0.1640625	total: 254ms	remaining: 481ms
# 346:	learn: 0.1639150	total: 255ms	remaining: 480ms
# 347:	learn: 0.1638410	total: 256ms	remaining: 479ms
# 348:	learn: 0.1637392	total: 256ms	remaining: 478ms
# 349:	learn: 0.1636004	total: 257ms	remaining: 478ms
# 350:	learn: 0.1633839	total: 258ms	remaining: 477ms
# 351:	learn: 0.1631333	total: 258ms	remaining: 476ms
# 352:	learn: 0.1630035	total: 259ms	remaining: 475ms
# 353:	learn: 0.1627419	total: 260ms	remaining: 474ms
# 354:	learn: 0.1625288	total: 261ms	remaining: 473ms
# 355:	learn: 0.1624260	total: 261ms	remaining: 473ms
# 356:	learn: 0.1622621	total: 262ms	remaining: 472ms
# 357:	learn: 0.1621537	total: 263ms	remaining: 471ms
# 358:	learn: 0.1619571	total: 263ms	remaining: 470ms
# 359:	learn: 0.1618436	total: 264ms	remaining: 469ms
# 360:	learn: 0.1615235	total: 265ms	remaining: 468ms
# 361:	learn: 0.1614374	total: 265ms	remaining: 467ms
# 362:	learn: 0.1613799	total: 266ms	remaining: 467ms
# 363:	learn: 0.1611665	total: 267ms	remaining: 466ms
# 364:	learn: 0.1610836	total: 267ms	remaining: 465ms
# 365:	learn: 0.1609686	total: 268ms	remaining: 464ms
# 366:	learn: 0.1608116	total: 269ms	remaining: 463ms
# 367:	learn: 0.1606643	total: 269ms	remaining: 462ms
# 368:	learn: 0.1605645	total: 270ms	remaining: 462ms
# 369:	learn: 0.1603933	total: 271ms	remaining: 461ms
# 370:	learn: 0.1603362	total: 271ms	remaining: 460ms
# 371:	learn: 0.1602414	total: 272ms	remaining: 459ms
# 372:	learn: 0.1600852	total: 273ms	remaining: 458ms
# 373:	learn: 0.1599961	total: 273ms	remaining: 457ms
# 374:	learn: 0.1599091	total: 274ms	remaining: 457ms
# 375:	learn: 0.1598555	total: 275ms	remaining: 456ms
# 376:	learn: 0.1596238	total: 275ms	remaining: 455ms
# 377:	learn: 0.1595621	total: 276ms	remaining: 454ms
# 378:	learn: 0.1592941	total: 277ms	remaining: 453ms
# 379:	learn: 0.1590946	total: 277ms	remaining: 452ms
# 380:	learn: 0.1590174	total: 278ms	remaining: 452ms
# 381:	learn: 0.1588738	total: 279ms	remaining: 451ms
# 382:	learn: 0.1587341	total: 279ms	remaining: 450ms
# 383:	learn: 0.1586450	total: 280ms	remaining: 449ms
# 384:	learn: 0.1584868	total: 281ms	remaining: 448ms
# 385:	learn: 0.1584108	total: 281ms	remaining: 448ms
# 386:	learn: 0.1582479	total: 282ms	remaining: 447ms
# 387:	learn: 0.1579613	total: 283ms	remaining: 446ms
# 388:	learn: 0.1578479	total: 283ms	remaining: 445ms
# 389:	learn: 0.1577606	total: 284ms	remaining: 444ms
# 390:	learn: 0.1575432	total: 285ms	remaining: 443ms
# 391:	learn: 0.1574344	total: 285ms	remaining: 443ms
# 392:	learn: 0.1573502	total: 286ms	remaining: 442ms
# 393:	learn: 0.1572279	total: 287ms	remaining: 441ms
# 394:	learn: 0.1571558	total: 287ms	remaining: 440ms
# 395:	learn: 0.1570837	total: 288ms	remaining: 439ms
# 396:	learn: 0.1569050	total: 289ms	remaining: 439ms
# 397:	learn: 0.1568536	total: 289ms	remaining: 438ms
# 398:	learn: 0.1567742	total: 290ms	remaining: 437ms
# 399:	learn: 0.1566636	total: 291ms	remaining: 436ms
# 400:	learn: 0.1564240	total: 291ms	remaining: 435ms
# 401:	learn: 0.1561869	total: 292ms	remaining: 434ms
# 402:	learn: 0.1560924	total: 293ms	remaining: 434ms
# 403:	learn: 0.1559135	total: 293ms	remaining: 433ms
# 404:	learn: 0.1558309	total: 294ms	remaining: 432ms
# 405:	learn: 0.1557332	total: 295ms	remaining: 431ms
# 406:	learn: 0.1556430	total: 295ms	remaining: 430ms
# 407:	learn: 0.1553862	total: 296ms	remaining: 429ms
# 408:	learn: 0.1552277	total: 297ms	remaining: 429ms
# 409:	learn: 0.1551399	total: 297ms	remaining: 428ms
# 410:	learn: 0.1549809	total: 298ms	remaining: 427ms
# 411:	learn: 0.1547652	total: 299ms	remaining: 426ms
# 412:	learn: 0.1546192	total: 299ms	remaining: 425ms
# 413:	learn: 0.1544774	total: 300ms	remaining: 425ms
# 414:	learn: 0.1543731	total: 301ms	remaining: 424ms
# 415:	learn: 0.1543038	total: 301ms	remaining: 423ms
# 416:	learn: 0.1541851	total: 302ms	remaining: 422ms
# 417:	learn: 0.1540205	total: 303ms	remaining: 421ms
# 418:	learn: 0.1539140	total: 303ms	remaining: 421ms
# 419:	learn: 0.1537316	total: 304ms	remaining: 420ms
# 420:	learn: 0.1535821	total: 305ms	remaining: 419ms
# 421:	learn: 0.1534704	total: 305ms	remaining: 418ms
# 422:	learn: 0.1533917	total: 306ms	remaining: 417ms
# 423:	learn: 0.1531254	total: 307ms	remaining: 417ms
# 424:	learn: 0.1530397	total: 307ms	remaining: 416ms
# 425:	learn: 0.1529472	total: 308ms	remaining: 415ms
# 426:	learn: 0.1526641	total: 309ms	remaining: 414ms
# 427:	learn: 0.1525701	total: 309ms	remaining: 413ms
# 428:	learn: 0.1524707	total: 310ms	remaining: 413ms
# 429:	learn: 0.1523998	total: 311ms	remaining: 412ms
# 430:	learn: 0.1521731	total: 311ms	remaining: 411ms
# 431:	learn: 0.1521006	total: 312ms	remaining: 410ms
# 432:	learn: 0.1519776	total: 313ms	remaining: 409ms
# 433:	learn: 0.1517792	total: 313ms	remaining: 409ms
# 434:	learn: 0.1515061	total: 314ms	remaining: 408ms
# 435:	learn: 0.1513359	total: 315ms	remaining: 408ms
# 436:	learn: 0.1512443	total: 316ms	remaining: 407ms
# 437:	learn: 0.1511373	total: 317ms	remaining: 407ms
# 438:	learn: 0.1510430	total: 318ms	remaining: 406ms
# 439:	learn: 0.1509159	total: 319ms	remaining: 406ms
# 440:	learn: 0.1508764	total: 320ms	remaining: 405ms
# 441:	learn: 0.1508004	total: 321ms	remaining: 405ms
# 442:	learn: 0.1506720	total: 321ms	remaining: 404ms
# 443:	learn: 0.1505994	total: 322ms	remaining: 403ms
# 444:	learn: 0.1504589	total: 323ms	remaining: 402ms
# 445:	learn: 0.1502654	total: 323ms	remaining: 402ms
# 446:	learn: 0.1501249	total: 324ms	remaining: 401ms
# 447:	learn: 0.1499531	total: 325ms	remaining: 400ms
# 448:	learn: 0.1498303	total: 326ms	remaining: 399ms
# 449:	learn: 0.1497143	total: 326ms	remaining: 399ms
# 450:	learn: 0.1496085	total: 327ms	remaining: 398ms
# 451:	learn: 0.1494945	total: 328ms	remaining: 397ms
# 452:	learn: 0.1493722	total: 328ms	remaining: 396ms
# 453:	learn: 0.1492419	total: 329ms	remaining: 396ms
# 454:	learn: 0.1491483	total: 330ms	remaining: 395ms
# 455:	learn: 0.1490384	total: 330ms	remaining: 394ms
# 456:	learn: 0.1489569	total: 331ms	remaining: 393ms
# 457:	learn: 0.1488053	total: 332ms	remaining: 393ms
# 458:	learn: 0.1486551	total: 332ms	remaining: 392ms
# 459:	learn: 0.1485831	total: 333ms	remaining: 391ms
# 460:	learn: 0.1484979	total: 334ms	remaining: 390ms
# 461:	learn: 0.1484176	total: 334ms	remaining: 389ms
# 462:	learn: 0.1482903	total: 335ms	remaining: 388ms
# 463:	learn: 0.1482224	total: 336ms	remaining: 388ms
# 464:	learn: 0.1480714	total: 336ms	remaining: 387ms
# 465:	learn: 0.1479726	total: 337ms	remaining: 386ms
# 466:	learn: 0.1478195	total: 338ms	remaining: 385ms
# 467:	learn: 0.1477163	total: 338ms	remaining: 385ms
# 468:	learn: 0.1476899	total: 339ms	remaining: 384ms
# 469:	learn: 0.1476057	total: 339ms	remaining: 383ms
# 470:	learn: 0.1475131	total: 340ms	remaining: 382ms
# 471:	learn: 0.1474480	total: 341ms	remaining: 381ms
# 472:	learn: 0.1473252	total: 341ms	remaining: 380ms
# 473:	learn: 0.1471608	total: 342ms	remaining: 380ms
# 474:	learn: 0.1470197	total: 343ms	remaining: 379ms
# 475:	learn: 0.1468287	total: 343ms	remaining: 378ms
# 476:	learn: 0.1467658	total: 344ms	remaining: 377ms
# 477:	learn: 0.1466702	total: 345ms	remaining: 376ms
# 478:	learn: 0.1465173	total: 345ms	remaining: 376ms
# 479:	learn: 0.1464374	total: 346ms	remaining: 375ms
# 480:	learn: 0.1462040	total: 347ms	remaining: 374ms
# 481:	learn: 0.1461628	total: 347ms	remaining: 373ms
# 482:	learn: 0.1460532	total: 348ms	remaining: 373ms
# 483:	learn: 0.1459879	total: 349ms	remaining: 372ms
# 484:	learn: 0.1457618	total: 349ms	remaining: 371ms
# 485:	learn: 0.1456866	total: 350ms	remaining: 370ms
# 486:	learn: 0.1455708	total: 351ms	remaining: 370ms
# 487:	learn: 0.1455222	total: 352ms	remaining: 369ms
# 488:	learn: 0.1454173	total: 352ms	remaining: 368ms
# 489:	learn: 0.1452888	total: 353ms	remaining: 367ms
# 490:	learn: 0.1451471	total: 354ms	remaining: 366ms
# 491:	learn: 0.1450068	total: 354ms	remaining: 366ms
# 492:	learn: 0.1448278	total: 355ms	remaining: 365ms
# 493:	learn: 0.1447453	total: 356ms	remaining: 364ms
# 494:	learn: 0.1446757	total: 356ms	remaining: 363ms
# 495:	learn: 0.1445720	total: 357ms	remaining: 363ms
# 496:	learn: 0.1444928	total: 358ms	remaining: 362ms
# 497:	learn: 0.1443833	total: 358ms	remaining: 361ms
# 498:	learn: 0.1442587	total: 359ms	remaining: 360ms
# 499:	learn: 0.1441710	total: 360ms	remaining: 360ms
# 500:	learn: 0.1440508	total: 360ms	remaining: 359ms
# 501:	learn: 0.1439304	total: 361ms	remaining: 358ms
# 502:	learn: 0.1437790	total: 362ms	remaining: 357ms
# 503:	learn: 0.1437370	total: 362ms	remaining: 357ms
# 504:	learn: 0.1436825	total: 363ms	remaining: 356ms
# 505:	learn: 0.1436104	total: 364ms	remaining: 355ms
# 506:	learn: 0.1435393	total: 364ms	remaining: 354ms
# 507:	learn: 0.1433499	total: 365ms	remaining: 353ms
# 508:	learn: 0.1433318	total: 365ms	remaining: 352ms
# 509:	learn: 0.1432657	total: 366ms	remaining: 352ms
# 510:	learn: 0.1432181	total: 367ms	remaining: 351ms
# 511:	learn: 0.1431297	total: 367ms	remaining: 350ms
# 512:	learn: 0.1430499	total: 368ms	remaining: 349ms
# 513:	learn: 0.1429224	total: 369ms	remaining: 349ms
# 514:	learn: 0.1427705	total: 369ms	remaining: 348ms
# 515:	learn: 0.1427295	total: 370ms	remaining: 347ms
# 516:	learn: 0.1425478	total: 371ms	remaining: 346ms
# 517:	learn: 0.1424314	total: 371ms	remaining: 346ms
# 518:	learn: 0.1423055	total: 372ms	remaining: 345ms
# 519:	learn: 0.1422240	total: 373ms	remaining: 344ms
# 520:	learn: 0.1421163	total: 373ms	remaining: 343ms
# 521:	learn: 0.1419667	total: 374ms	remaining: 343ms
# 522:	learn: 0.1418887	total: 375ms	remaining: 342ms
# 523:	learn: 0.1418350	total: 375ms	remaining: 341ms
# 524:	learn: 0.1416761	total: 376ms	remaining: 340ms
# 525:	learn: 0.1415115	total: 377ms	remaining: 340ms
# 526:	learn: 0.1414344	total: 377ms	remaining: 339ms
# 527:	learn: 0.1413702	total: 378ms	remaining: 338ms
# 528:	learn: 0.1411869	total: 379ms	remaining: 337ms
# 529:	learn: 0.1411268	total: 379ms	remaining: 336ms
# 530:	learn: 0.1410423	total: 380ms	remaining: 336ms
# 531:	learn: 0.1409889	total: 381ms	remaining: 335ms
# 532:	learn: 0.1409233	total: 382ms	remaining: 334ms
# 533:	learn: 0.1408598	total: 384ms	remaining: 335ms
# 534:	learn: 0.1407811	total: 386ms	remaining: 336ms
# 535:	learn: 0.1406360	total: 387ms	remaining: 335ms
# 536:	learn: 0.1404703	total: 388ms	remaining: 335ms
# 537:	learn: 0.1403946	total: 389ms	remaining: 334ms
# 538:	learn: 0.1403165	total: 390ms	remaining: 333ms
# 539:	learn: 0.1402269	total: 390ms	remaining: 333ms
# 540:	learn: 0.1401205	total: 391ms	remaining: 332ms
# 541:	learn: 0.1400794	total: 392ms	remaining: 331ms
# 542:	learn: 0.1399974	total: 392ms	remaining: 330ms
# 543:	learn: 0.1398729	total: 393ms	remaining: 330ms
# 544:	learn: 0.1398048	total: 394ms	remaining: 329ms
# 545:	learn: 0.1397197	total: 395ms	remaining: 328ms
# 546:	learn: 0.1396694	total: 395ms	remaining: 327ms
# 547:	learn: 0.1395924	total: 396ms	remaining: 327ms
# 548:	learn: 0.1394816	total: 397ms	remaining: 326ms
# 549:	learn: 0.1394200	total: 397ms	remaining: 325ms
# 550:	learn: 0.1392599	total: 398ms	remaining: 324ms
# 551:	learn: 0.1392073	total: 399ms	remaining: 324ms
# 552:	learn: 0.1391248	total: 399ms	remaining: 323ms
# 553:	learn: 0.1391185	total: 400ms	remaining: 322ms
# 554:	learn: 0.1390601	total: 400ms	remaining: 321ms
# 555:	learn: 0.1388245	total: 401ms	remaining: 320ms
# 556:	learn: 0.1386502	total: 402ms	remaining: 320ms
# 557:	learn: 0.1385526	total: 402ms	remaining: 319ms
# 558:	learn: 0.1384602	total: 403ms	remaining: 318ms
# 559:	learn: 0.1383859	total: 404ms	remaining: 317ms
# 560:	learn: 0.1383055	total: 404ms	remaining: 316ms
# 561:	learn: 0.1381873	total: 405ms	remaining: 316ms
# 562:	learn: 0.1380792	total: 406ms	remaining: 315ms
# 563:	learn: 0.1378814	total: 406ms	remaining: 314ms
# 564:	learn: 0.1377987	total: 407ms	remaining: 313ms
# 565:	learn: 0.1377283	total: 408ms	remaining: 313ms
# 566:	learn: 0.1376486	total: 408ms	remaining: 312ms
# 567:	learn: 0.1375400	total: 409ms	remaining: 311ms
# 568:	learn: 0.1373250	total: 410ms	remaining: 310ms
# 569:	learn: 0.1371405	total: 410ms	remaining: 310ms
# 570:	learn: 0.1370251	total: 411ms	remaining: 309ms
# 571:	learn: 0.1369561	total: 412ms	remaining: 308ms
# 572:	learn: 0.1368901	total: 412ms	remaining: 307ms
# 573:	learn: 0.1367824	total: 413ms	remaining: 307ms
# 574:	learn: 0.1367235	total: 414ms	remaining: 306ms
# 575:	learn: 0.1365711	total: 414ms	remaining: 305ms
# 576:	learn: 0.1364446	total: 415ms	remaining: 304ms
# 577:	learn: 0.1363308	total: 416ms	remaining: 304ms
# 578:	learn: 0.1362369	total: 417ms	remaining: 303ms
# 579:	learn: 0.1361810	total: 420ms	remaining: 304ms
# 580:	learn: 0.1361247	total: 421ms	remaining: 304ms
# 581:	learn: 0.1359944	total: 422ms	remaining: 303ms
# 582:	learn: 0.1359409	total: 422ms	remaining: 302ms
# 583:	learn: 0.1358931	total: 423ms	remaining: 302ms
# 584:	learn: 0.1357876	total: 424ms	remaining: 301ms
# 585:	learn: 0.1355235	total: 425ms	remaining: 300ms
# 586:	learn: 0.1353494	total: 426ms	remaining: 300ms
# 587:	learn: 0.1351622	total: 427ms	remaining: 299ms
# 588:	learn: 0.1349601	total: 428ms	remaining: 299ms
# 589:	learn: 0.1349342	total: 430ms	remaining: 299ms
# 590:	learn: 0.1346973	total: 431ms	remaining: 298ms
# 591:	learn: 0.1346211	total: 433ms	remaining: 299ms
# 592:	learn: 0.1345036	total: 435ms	remaining: 298ms
# 593:	learn: 0.1342778	total: 438ms	remaining: 299ms
# 594:	learn: 0.1342223	total: 439ms	remaining: 299ms
# 595:	learn: 0.1340909	total: 440ms	remaining: 298ms
# 596:	learn: 0.1340333	total: 440ms	remaining: 297ms
# 597:	learn: 0.1339412	total: 443ms	remaining: 298ms
# 598:	learn: 0.1337961	total: 444ms	remaining: 297ms
# 599:	learn: 0.1337079	total: 445ms	remaining: 297ms
# 600:	learn: 0.1335973	total: 446ms	remaining: 296ms
# 601:	learn: 0.1335652	total: 447ms	remaining: 296ms
# 602:	learn: 0.1334699	total: 448ms	remaining: 295ms
# 603:	learn: 0.1333731	total: 450ms	remaining: 295ms
# 604:	learn: 0.1333078	total: 452ms	remaining: 295ms
# 605:	learn: 0.1332607	total: 454ms	remaining: 295ms
# 606:	learn: 0.1331693	total: 455ms	remaining: 295ms
# 607:	learn: 0.1330889	total: 456ms	remaining: 294ms
# 608:	learn: 0.1329479	total: 457ms	remaining: 294ms
# 609:	learn: 0.1327148	total: 458ms	remaining: 293ms
# 610:	learn: 0.1326615	total: 459ms	remaining: 292ms
# 611:	learn: 0.1325767	total: 460ms	remaining: 291ms
# 612:	learn: 0.1325191	total: 461ms	remaining: 291ms
# 613:	learn: 0.1324298	total: 462ms	remaining: 290ms
# 614:	learn: 0.1323684	total: 463ms	remaining: 290ms
# 615:	learn: 0.1322936	total: 464ms	remaining: 289ms
# 616:	learn: 0.1322779	total: 466ms	remaining: 289ms
# 617:	learn: 0.1322398	total: 466ms	remaining: 288ms
# 618:	learn: 0.1321569	total: 469ms	remaining: 288ms
# 619:	learn: 0.1319841	total: 470ms	remaining: 288ms
# 620:	learn: 0.1319310	total: 473ms	remaining: 288ms
# 621:	learn: 0.1318602	total: 474ms	remaining: 288ms
# 622:	learn: 0.1317498	total: 477ms	remaining: 288ms
# 623:	learn: 0.1317055	total: 478ms	remaining: 288ms
# 624:	learn: 0.1315074	total: 480ms	remaining: 288ms
# 625:	learn: 0.1314689	total: 483ms	remaining: 289ms
# 626:	learn: 0.1313890	total: 484ms	remaining: 288ms
# 627:	learn: 0.1312407	total: 486ms	remaining: 288ms
# 628:	learn: 0.1311863	total: 489ms	remaining: 288ms
# 629:	learn: 0.1310850	total: 491ms	remaining: 288ms
# 630:	learn: 0.1310370	total: 492ms	remaining: 288ms
# 631:	learn: 0.1309127	total: 495ms	remaining: 288ms
# 632:	learn: 0.1308720	total: 496ms	remaining: 287ms
# 633:	learn: 0.1307770	total: 500ms	remaining: 289ms
# 634:	learn: 0.1306932	total: 502ms	remaining: 288ms
# 635:	learn: 0.1306371	total: 504ms	remaining: 288ms
# 636:	learn: 0.1304999	total: 506ms	remaining: 288ms
# 637:	learn: 0.1304116	total: 507ms	remaining: 288ms
# 638:	learn: 0.1303263	total: 508ms	remaining: 287ms
# 639:	learn: 0.1302039	total: 511ms	remaining: 287ms
# 640:	learn: 0.1301551	total: 513ms	remaining: 287ms
# 641:	learn: 0.1300867	total: 514ms	remaining: 287ms
# 642:	learn: 0.1300078	total: 517ms	remaining: 287ms
# 643:	learn: 0.1298839	total: 519ms	remaining: 287ms
# 644:	learn: 0.1297039	total: 520ms	remaining: 286ms
# 645:	learn: 0.1296397	total: 523ms	remaining: 287ms
# 646:	learn: 0.1295204	total: 525ms	remaining: 286ms
# 647:	learn: 0.1294580	total: 527ms	remaining: 286ms
# 648:	learn: 0.1293777	total: 529ms	remaining: 286ms
# 649:	learn: 0.1292674	total: 531ms	remaining: 286ms
# 650:	learn: 0.1291758	total: 534ms	remaining: 286ms
# 651:	learn: 0.1290394	total: 535ms	remaining: 285ms
# 652:	learn: 0.1289829	total: 537ms	remaining: 286ms
# 653:	learn: 0.1289052	total: 540ms	remaining: 286ms
# 654:	learn: 0.1287167	total: 542ms	remaining: 286ms
# 655:	learn: 0.1286620	total: 543ms	remaining: 285ms
# 656:	learn: 0.1285826	total: 546ms	remaining: 285ms
# 657:	learn: 0.1284199	total: 548ms	remaining: 285ms
# 658:	learn: 0.1282858	total: 550ms	remaining: 285ms
# 659:	learn: 0.1282182	total: 553ms	remaining: 285ms
# 660:	learn: 0.1281674	total: 554ms	remaining: 284ms
# 661:	learn: 0.1281171	total: 557ms	remaining: 285ms
# 662:	learn: 0.1280557	total: 558ms	remaining: 284ms
# 663:	learn: 0.1279909	total: 559ms	remaining: 283ms
# 664:	learn: 0.1279388	total: 560ms	remaining: 282ms
# 665:	learn: 0.1278725	total: 560ms	remaining: 281ms
# 666:	learn: 0.1278187	total: 563ms	remaining: 281ms
# 667:	learn: 0.1277851	total: 564ms	remaining: 280ms
# 668:	learn: 0.1276484	total: 567ms	remaining: 281ms
# 669:	learn: 0.1275732	total: 568ms	remaining: 280ms
# 670:	learn: 0.1274229	total: 571ms	remaining: 280ms
# 671:	learn: 0.1273728	total: 572ms	remaining: 279ms
# 672:	learn: 0.1273097	total: 575ms	remaining: 280ms
# 673:	learn: 0.1272688	total: 576ms	remaining: 279ms
# 674:	learn: 0.1271354	total: 580ms	remaining: 279ms
# 675:	learn: 0.1270862	total: 583ms	remaining: 279ms
# 676:	learn: 0.1269788	total: 585ms	remaining: 279ms
# 677:	learn: 0.1268923	total: 587ms	remaining: 279ms
# 678:	learn: 0.1268467	total: 590ms	remaining: 279ms
# 679:	learn: 0.1267054	total: 591ms	remaining: 278ms
# 680:	learn: 0.1266296	total: 593ms	remaining: 278ms
# 681:	learn: 0.1265817	total: 594ms	remaining: 277ms
# 682:	learn: 0.1265375	total: 597ms	remaining: 277ms
# 683:	learn: 0.1265008	total: 600ms	remaining: 277ms
# 684:	learn: 0.1264517	total: 601ms	remaining: 277ms
# 685:	learn: 0.1263611	total: 603ms	remaining: 276ms
# 686:	learn: 0.1262100	total: 606ms	remaining: 276ms
# 687:	learn: 0.1260433	total: 607ms	remaining: 275ms
# 688:	learn: 0.1259796	total: 610ms	remaining: 275ms
# 689:	learn: 0.1259358	total: 613ms	remaining: 275ms
# 690:	learn: 0.1259063	total: 615ms	remaining: 275ms
# 691:	learn: 0.1258666	total: 617ms	remaining: 275ms
# 692:	learn: 0.1258254	total: 619ms	remaining: 274ms
# 693:	learn: 0.1257820	total: 621ms	remaining: 274ms
# 694:	learn: 0.1257010	total: 623ms	remaining: 273ms
# 695:	learn: 0.1256422	total: 624ms	remaining: 273ms
# 696:	learn: 0.1255281	total: 627ms	remaining: 273ms
# 697:	learn: 0.1254175	total: 628ms	remaining: 272ms
# 698:	learn: 0.1253678	total: 631ms	remaining: 272ms
# 699:	learn: 0.1252491	total: 632ms	remaining: 271ms
# 700:	learn: 0.1252113	total: 635ms	remaining: 271ms
# 701:	learn: 0.1250543	total: 636ms	remaining: 270ms
# 702:	learn: 0.1249828	total: 638ms	remaining: 270ms
# 703:	learn: 0.1249354	total: 639ms	remaining: 269ms
# 704:	learn: 0.1248731	total: 640ms	remaining: 268ms
# 705:	learn: 0.1248318	total: 641ms	remaining: 267ms
# 706:	learn: 0.1247644	total: 642ms	remaining: 266ms
# 707:	learn: 0.1246473	total: 643ms	remaining: 265ms
# 708:	learn: 0.1245135	total: 643ms	remaining: 264ms
# 709:	learn: 0.1244623	total: 644ms	remaining: 263ms
# 710:	learn: 0.1242849	total: 645ms	remaining: 262ms
# 711:	learn: 0.1241479	total: 646ms	remaining: 261ms
# 712:	learn: 0.1241060	total: 647ms	remaining: 260ms
# 713:	learn: 0.1239649	total: 648ms	remaining: 260ms
# 714:	learn: 0.1239130	total: 649ms	remaining: 259ms
# 715:	learn: 0.1238495	total: 649ms	remaining: 258ms
# 716:	learn: 0.1237971	total: 650ms	remaining: 257ms
# 717:	learn: 0.1237477	total: 651ms	remaining: 256ms
# 718:	learn: 0.1236855	total: 652ms	remaining: 255ms
# 719:	learn: 0.1236354	total: 653ms	remaining: 254ms
# 720:	learn: 0.1235929	total: 654ms	remaining: 253ms
# 721:	learn: 0.1235200	total: 655ms	remaining: 252ms
# 722:	learn: 0.1234242	total: 656ms	remaining: 251ms
# 723:	learn: 0.1232652	total: 656ms	remaining: 250ms
# 724:	learn: 0.1232145	total: 657ms	remaining: 249ms
# 725:	learn: 0.1231631	total: 658ms	remaining: 248ms
# 726:	learn: 0.1230871	total: 659ms	remaining: 247ms
# 727:	learn: 0.1229564	total: 659ms	remaining: 246ms
# 728:	learn: 0.1229121	total: 660ms	remaining: 245ms
# 729:	learn: 0.1228422	total: 661ms	remaining: 245ms
# 730:	learn: 0.1227607	total: 662ms	remaining: 244ms
# 731:	learn: 0.1227030	total: 663ms	remaining: 243ms
# 732:	learn: 0.1226535	total: 664ms	remaining: 242ms
# 733:	learn: 0.1225939	total: 664ms	remaining: 241ms
# 734:	learn: 0.1225533	total: 665ms	remaining: 240ms
# 735:	learn: 0.1225146	total: 666ms	remaining: 239ms
# 736:	learn: 0.1224892	total: 667ms	remaining: 238ms
# 737:	learn: 0.1224142	total: 668ms	remaining: 237ms
# 738:	learn: 0.1223715	total: 668ms	remaining: 236ms
# 739:	learn: 0.1223053	total: 669ms	remaining: 235ms
# 740:	learn: 0.1222047	total: 670ms	remaining: 234ms
# 741:	learn: 0.1221441	total: 671ms	remaining: 233ms
# 742:	learn: 0.1220843	total: 672ms	remaining: 232ms
# 743:	learn: 0.1219892	total: 673ms	remaining: 231ms
# 744:	learn: 0.1219341	total: 673ms	remaining: 230ms
# 745:	learn: 0.1218566	total: 674ms	remaining: 230ms
# 746:	learn: 0.1218044	total: 675ms	remaining: 229ms
# 747:	learn: 0.1217157	total: 676ms	remaining: 228ms
# 748:	learn: 0.1216951	total: 677ms	remaining: 227ms
# 749:	learn: 0.1216354	total: 677ms	remaining: 226ms
# 750:	learn: 0.1214879	total: 678ms	remaining: 225ms
# 751:	learn: 0.1214217	total: 679ms	remaining: 224ms
# 752:	learn: 0.1213755	total: 680ms	remaining: 223ms
# 753:	learn: 0.1212320	total: 681ms	remaining: 222ms
# 754:	learn: 0.1211279	total: 684ms	remaining: 222ms
# 755:	learn: 0.1210795	total: 685ms	remaining: 221ms
# 756:	learn: 0.1210185	total: 686ms	remaining: 220ms
# 757:	learn: 0.1209722	total: 686ms	remaining: 219ms
# 758:	learn: 0.1209185	total: 687ms	remaining: 218ms
# 759:	learn: 0.1208474	total: 688ms	remaining: 217ms
# 760:	learn: 0.1206782	total: 689ms	remaining: 216ms
# 761:	learn: 0.1206403	total: 689ms	remaining: 215ms
# 762:	learn: 0.1205637	total: 690ms	remaining: 214ms
# 763:	learn: 0.1205519	total: 691ms	remaining: 213ms
# 764:	learn: 0.1204071	total: 692ms	remaining: 213ms
# 765:	learn: 0.1203564	total: 693ms	remaining: 212ms
# 766:	learn: 0.1202976	total: 694ms	remaining: 211ms
# 767:	learn: 0.1202547	total: 694ms	remaining: 210ms
# 768:	learn: 0.1202222	total: 695ms	remaining: 209ms
# 769:	learn: 0.1201290	total: 696ms	remaining: 208ms
# 770:	learn: 0.1201041	total: 697ms	remaining: 207ms
# 771:	learn: 0.1199549	total: 697ms	remaining: 206ms
# 772:	learn: 0.1199147	total: 698ms	remaining: 205ms
# 773:	learn: 0.1198009	total: 699ms	remaining: 204ms
# 774:	learn: 0.1196823	total: 700ms	remaining: 203ms
# 775:	learn: 0.1196470	total: 701ms	remaining: 202ms
# 776:	learn: 0.1195323	total: 702ms	remaining: 201ms
# 777:	learn: 0.1194704	total: 702ms	remaining: 200ms
# 778:	learn: 0.1194372	total: 703ms	remaining: 199ms
# 779:	learn: 0.1193071	total: 704ms	remaining: 198ms
# 780:	learn: 0.1191933	total: 705ms	remaining: 198ms
# 781:	learn: 0.1190166	total: 706ms	remaining: 197ms
# 782:	learn: 0.1189296	total: 706ms	remaining: 196ms
# 783:	learn: 0.1188855	total: 707ms	remaining: 195ms
# 784:	learn: 0.1187766	total: 708ms	remaining: 194ms
# 785:	learn: 0.1187474	total: 709ms	remaining: 193ms
# 786:	learn: 0.1187047	total: 709ms	remaining: 192ms
# 787:	learn: 0.1186497	total: 710ms	remaining: 191ms
# 788:	learn: 0.1185863	total: 711ms	remaining: 190ms
# 789:	learn: 0.1185638	total: 712ms	remaining: 189ms
# 790:	learn: 0.1184764	total: 713ms	remaining: 188ms
# 791:	learn: 0.1183985	total: 714ms	remaining: 187ms
# 792:	learn: 0.1183528	total: 714ms	remaining: 186ms
# 793:	learn: 0.1183072	total: 715ms	remaining: 186ms
# 794:	learn: 0.1182534	total: 716ms	remaining: 185ms
# 795:	learn: 0.1181868	total: 717ms	remaining: 184ms
# 796:	learn: 0.1181266	total: 717ms	remaining: 183ms
# 797:	learn: 0.1180024	total: 718ms	remaining: 182ms
# 798:	learn: 0.1179440	total: 719ms	remaining: 181ms
# 799:	learn: 0.1178929	total: 720ms	remaining: 180ms
# 800:	learn: 0.1177997	total: 721ms	remaining: 179ms
# 801:	learn: 0.1177289	total: 722ms	remaining: 178ms
# 802:	learn: 0.1176445	total: 722ms	remaining: 177ms
# 803:	learn: 0.1175069	total: 723ms	remaining: 176ms
# 804:	learn: 0.1174567	total: 724ms	remaining: 175ms
# 805:	learn: 0.1173858	total: 725ms	remaining: 174ms
# 806:	learn: 0.1173182	total: 726ms	remaining: 174ms
# 807:	learn: 0.1172655	total: 726ms	remaining: 173ms
# 808:	learn: 0.1171938	total: 727ms	remaining: 172ms
# 809:	learn: 0.1171750	total: 728ms	remaining: 171ms
# 810:	learn: 0.1171142	total: 729ms	remaining: 170ms
# 811:	learn: 0.1170198	total: 729ms	remaining: 169ms
# 812:	learn: 0.1169603	total: 730ms	remaining: 168ms
# 813:	learn: 0.1168845	total: 731ms	remaining: 167ms
# 814:	learn: 0.1168648	total: 732ms	remaining: 166ms
# 815:	learn: 0.1168165	total: 733ms	remaining: 165ms
# 816:	learn: 0.1167547	total: 735ms	remaining: 165ms
# 817:	learn: 0.1166014	total: 737ms	remaining: 164ms
# 818:	learn: 0.1165315	total: 738ms	remaining: 163ms
# 819:	learn: 0.1165018	total: 739ms	remaining: 162ms
# 820:	learn: 0.1164615	total: 739ms	remaining: 161ms
# 821:	learn: 0.1164216	total: 740ms	remaining: 160ms
# 822:	learn: 0.1163440	total: 741ms	remaining: 159ms
# 823:	learn: 0.1162313	total: 742ms	remaining: 158ms
# 824:	learn: 0.1161888	total: 745ms	remaining: 158ms
# 825:	learn: 0.1161409	total: 746ms	remaining: 157ms
# 826:	learn: 0.1160839	total: 748ms	remaining: 156ms
# 827:	learn: 0.1159150	total: 749ms	remaining: 156ms
# 828:	learn: 0.1158638	total: 750ms	remaining: 155ms
# 829:	learn: 0.1157880	total: 751ms	remaining: 154ms
# 830:	learn: 0.1157271	total: 752ms	remaining: 153ms
# 831:	learn: 0.1155467	total: 752ms	remaining: 152ms
# 832:	learn: 0.1154468	total: 753ms	remaining: 151ms
# 833:	learn: 0.1153815	total: 754ms	remaining: 150ms
# 834:	learn: 0.1152737	total: 755ms	remaining: 149ms
# 835:	learn: 0.1152287	total: 756ms	remaining: 148ms
# 836:	learn: 0.1151177	total: 757ms	remaining: 147ms
# 837:	learn: 0.1150867	total: 757ms	remaining: 146ms
# 838:	learn: 0.1150447	total: 758ms	remaining: 145ms
# 839:	learn: 0.1149130	total: 759ms	remaining: 145ms
# 840:	learn: 0.1148658	total: 760ms	remaining: 144ms
# 841:	learn: 0.1148262	total: 761ms	remaining: 143ms
# 842:	learn: 0.1147943	total: 762ms	remaining: 142ms
# 843:	learn: 0.1147628	total: 763ms	remaining: 141ms
# 844:	learn: 0.1146552	total: 763ms	remaining: 140ms
# 845:	learn: 0.1146218	total: 764ms	remaining: 139ms
# 846:	learn: 0.1144818	total: 765ms	remaining: 138ms
# 847:	learn: 0.1144396	total: 766ms	remaining: 137ms
# 848:	learn: 0.1143715	total: 767ms	remaining: 136ms
# 849:	learn: 0.1142593	total: 768ms	remaining: 136ms
# 850:	learn: 0.1141567	total: 769ms	remaining: 135ms
# 851:	learn: 0.1140873	total: 770ms	remaining: 134ms
# 852:	learn: 0.1139852	total: 771ms	remaining: 133ms
# 853:	learn: 0.1138464	total: 772ms	remaining: 132ms
# 854:	learn: 0.1137359	total: 773ms	remaining: 131ms
# 855:	learn: 0.1136992	total: 774ms	remaining: 130ms
# 856:	learn: 0.1136189	total: 775ms	remaining: 129ms
# 857:	learn: 0.1135390	total: 776ms	remaining: 128ms
# 858:	learn: 0.1134884	total: 777ms	remaining: 128ms
# 859:	learn: 0.1134365	total: 777ms	remaining: 127ms
# 860:	learn: 0.1133809	total: 778ms	remaining: 126ms
# 861:	learn: 0.1133341	total: 779ms	remaining: 125ms
# 862:	learn: 0.1132443	total: 780ms	remaining: 124ms
# 863:	learn: 0.1131995	total: 781ms	remaining: 123ms
# 864:	learn: 0.1130859	total: 782ms	remaining: 122ms
# 865:	learn: 0.1130051	total: 783ms	remaining: 121ms
# 866:	learn: 0.1129566	total: 784ms	remaining: 120ms
# 867:	learn: 0.1128738	total: 785ms	remaining: 119ms
# 868:	learn: 0.1128299	total: 785ms	remaining: 118ms
# 869:	learn: 0.1127825	total: 787ms	remaining: 118ms
# 870:	learn: 0.1126743	total: 788ms	remaining: 117ms
# 871:	learn: 0.1126246	total: 789ms	remaining: 116ms
# 872:	learn: 0.1125554	total: 790ms	remaining: 115ms
# 873:	learn: 0.1125054	total: 791ms	remaining: 114ms
# 874:	learn: 0.1124552	total: 792ms	remaining: 113ms
# 875:	learn: 0.1123769	total: 793ms	remaining: 112ms
# 876:	learn: 0.1123363	total: 793ms	remaining: 111ms
# 877:	learn: 0.1122710	total: 794ms	remaining: 110ms
# 878:	learn: 0.1122287	total: 795ms	remaining: 109ms
# 879:	learn: 0.1121734	total: 796ms	remaining: 109ms
# 880:	learn: 0.1119511	total: 797ms	remaining: 108ms
# 881:	learn: 0.1118383	total: 798ms	remaining: 107ms
# 882:	learn: 0.1118017	total: 799ms	remaining: 106ms
# 883:	learn: 0.1117559	total: 799ms	remaining: 105ms
# 884:	learn: 0.1117079	total: 800ms	remaining: 104ms
# 885:	learn: 0.1116501	total: 801ms	remaining: 103ms
# 886:	learn: 0.1115168	total: 802ms	remaining: 102ms
# 887:	learn: 0.1114774	total: 803ms	remaining: 101ms
# 888:	learn: 0.1114386	total: 804ms	remaining: 100ms
# 889:	learn: 0.1113210	total: 805ms	remaining: 99.4ms
# 890:	learn: 0.1112675	total: 805ms	remaining: 98.5ms
# 891:	learn: 0.1111900	total: 806ms	remaining: 97.6ms
# 892:	learn: 0.1111646	total: 807ms	remaining: 96.7ms
# 893:	learn: 0.1111535	total: 808ms	remaining: 95.8ms
# 894:	learn: 0.1110898	total: 809ms	remaining: 94.9ms
# 895:	learn: 0.1110285	total: 810ms	remaining: 94ms
# 896:	learn: 0.1110080	total: 810ms	remaining: 93.1ms
# 897:	learn: 0.1109034	total: 811ms	remaining: 92.1ms
# 898:	learn: 0.1107662	total: 812ms	remaining: 91.2ms
# 899:	learn: 0.1107102	total: 813ms	remaining: 90.3ms
# 900:	learn: 0.1106245	total: 814ms	remaining: 89.4ms
# 901:	learn: 0.1105824	total: 815ms	remaining: 88.5ms
# 902:	learn: 0.1105273	total: 816ms	remaining: 87.6ms
# 903:	learn: 0.1103492	total: 816ms	remaining: 86.7ms
# 904:	learn: 0.1102654	total: 817ms	remaining: 85.8ms
# 905:	learn: 0.1102403	total: 818ms	remaining: 84.9ms
# 906:	learn: 0.1101405	total: 819ms	remaining: 84ms
# 907:	learn: 0.1100139	total: 820ms	remaining: 83.1ms
# 908:	learn: 0.1099699	total: 821ms	remaining: 82.2ms
# 909:	learn: 0.1099256	total: 822ms	remaining: 81.3ms
# 910:	learn: 0.1098637	total: 822ms	remaining: 80.4ms
# 911:	learn: 0.1098120	total: 823ms	remaining: 79.5ms
# 912:	learn: 0.1097789	total: 824ms	remaining: 78.6ms
# 913:	learn: 0.1097380	total: 825ms	remaining: 77.6ms
# 914:	learn: 0.1096865	total: 826ms	remaining: 76.7ms
# 915:	learn: 0.1096227	total: 827ms	remaining: 75.8ms
# 916:	learn: 0.1095155	total: 828ms	remaining: 74.9ms
# 917:	learn: 0.1094573	total: 829ms	remaining: 74ms
# ...
# 695:	learn: 0.1256422	total: 506ms	remaining: 221ms
# 696:	learn: 0.1255281	total: 506ms	remaining: 220ms
# 697:	learn: 0.1254175	total: 507ms	remaining: 219ms
# 698:	learn: 0.1253678	total: 508ms	remaining: 219ms
# 699:	learn: 0.1252491	total: 508ms	remaining: 218ms
# 700:	learn: 0.1252113	total: 509ms	remaining: 217ms
# 701:	learn: 0.1250543	total: 510ms	remaining: 216ms
# 702:	learn: 0.1249828	total: 510ms	remaining: 216ms
# 703:	learn: 0.1249354	total: 511ms	remaining: 215ms
# 704:	learn: 0.1248731	total: 512ms	remaining: 214ms
# 705:	learn: 0.1248318	total: 512ms	remaining: 213ms
# 706:	learn: 0.1247644	total: 513ms	remaining: 213ms
# 707:	learn: 0.1246473	total: 514ms	remaining: 212ms
# 708:	learn: 0.1245135	total: 514ms	remaining: 211ms
# 709:	learn: 0.1244623	total: 515ms	remaining: 210ms
# 710:	learn: 0.1242849	total: 515ms	remaining: 210ms
# 711:	learn: 0.1241479	total: 516ms	remaining: 209ms
# 712:	learn: 0.1241060	total: 517ms	remaining: 208ms
# 713:	learn: 0.1239649	total: 518ms	remaining: 207ms
# 714:	learn: 0.1239130	total: 518ms	remaining: 207ms
# 715:	learn: 0.1238495	total: 519ms	remaining: 206ms
# 716:	learn: 0.1237971	total: 520ms	remaining: 205ms
# 717:	learn: 0.1237477	total: 520ms	remaining: 204ms
# 718:	learn: 0.1236855	total: 521ms	remaining: 204ms
# 719:	learn: 0.1236354	total: 522ms	remaining: 203ms
# 720:	learn: 0.1235929	total: 523ms	remaining: 202ms
# 721:	learn: 0.1235200	total: 523ms	remaining: 201ms
# 722:	learn: 0.1234242	total: 524ms	remaining: 201ms
# 723:	learn: 0.1232652	total: 525ms	remaining: 200ms
# 724:	learn: 0.1232145	total: 525ms	remaining: 199ms
# 725:	learn: 0.1231631	total: 526ms	remaining: 199ms
# 726:	learn: 0.1230871	total: 527ms	remaining: 198ms
# 727:	learn: 0.1229564	total: 527ms	remaining: 197ms
# 728:	learn: 0.1229121	total: 528ms	remaining: 196ms
# 729:	learn: 0.1228422	total: 529ms	remaining: 196ms
# 730:	learn: 0.1227607	total: 529ms	remaining: 195ms
# 731:	learn: 0.1227030	total: 530ms	remaining: 194ms
# 732:	learn: 0.1226535	total: 531ms	remaining: 193ms
# 733:	learn: 0.1225939	total: 531ms	remaining: 193ms
# 734:	learn: 0.1225533	total: 532ms	remaining: 192ms
# 735:	learn: 0.1225146	total: 533ms	remaining: 191ms
# 736:	learn: 0.1224892	total: 534ms	remaining: 190ms
# 737:	learn: 0.1224142	total: 534ms	remaining: 190ms
# 738:	learn: 0.1223715	total: 535ms	remaining: 189ms
# 739:	learn: 0.1223053	total: 536ms	remaining: 188ms
# 740:	learn: 0.1222047	total: 536ms	remaining: 187ms
# 741:	learn: 0.1221441	total: 537ms	remaining: 187ms
# 742:	learn: 0.1220843	total: 538ms	remaining: 186ms
# 743:	learn: 0.1219892	total: 538ms	remaining: 185ms
# 744:	learn: 0.1219341	total: 539ms	remaining: 184ms
# 745:	learn: 0.1218566	total: 540ms	remaining: 184ms
# 746:	learn: 0.1218044	total: 540ms	remaining: 183ms
# 747:	learn: 0.1217157	total: 541ms	remaining: 182ms
# 748:	learn: 0.1216951	total: 542ms	remaining: 181ms
# 749:	learn: 0.1216354	total: 542ms	remaining: 181ms
# 750:	learn: 0.1214879	total: 543ms	remaining: 180ms
# 751:	learn: 0.1214217	total: 544ms	remaining: 179ms
# 752:	learn: 0.1213755	total: 544ms	remaining: 179ms
# 753:	learn: 0.1212320	total: 545ms	remaining: 178ms
# 754:	learn: 0.1211279	total: 546ms	remaining: 177ms
# 755:	learn: 0.1210795	total: 546ms	remaining: 176ms
# 756:	learn: 0.1210185	total: 547ms	remaining: 176ms
# 757:	learn: 0.1209722	total: 548ms	remaining: 175ms
# 758:	learn: 0.1209185	total: 548ms	remaining: 174ms
# 759:	learn: 0.1208474	total: 549ms	remaining: 173ms
# 760:	learn: 0.1206782	total: 550ms	remaining: 173ms
# 761:	learn: 0.1206403	total: 550ms	remaining: 172ms
# 762:	learn: 0.1205637	total: 551ms	remaining: 171ms
# 763:	learn: 0.1205519	total: 552ms	remaining: 170ms
# 764:	learn: 0.1204071	total: 552ms	remaining: 170ms
# 765:	learn: 0.1203564	total: 553ms	remaining: 169ms
# 766:	learn: 0.1202976	total: 554ms	remaining: 168ms
# 767:	learn: 0.1202547	total: 554ms	remaining: 167ms
# 768:	learn: 0.1202222	total: 555ms	remaining: 167ms
# 769:	learn: 0.1201290	total: 556ms	remaining: 166ms
# 770:	learn: 0.1201041	total: 556ms	remaining: 165ms
# 771:	learn: 0.1199549	total: 557ms	remaining: 164ms
# 772:	learn: 0.1199147	total: 558ms	remaining: 164ms
# 773:	learn: 0.1198009	total: 558ms	remaining: 163ms
# 774:	learn: 0.1196823	total: 559ms	remaining: 162ms
# 775:	learn: 0.1196470	total: 560ms	remaining: 162ms
# 776:	learn: 0.1195323	total: 560ms	remaining: 161ms
# 777:	learn: 0.1194704	total: 561ms	remaining: 160ms
# 778:	learn: 0.1194372	total: 562ms	remaining: 159ms
# 779:	learn: 0.1193071	total: 562ms	remaining: 159ms
# 780:	learn: 0.1191933	total: 563ms	remaining: 158ms
# 781:	learn: 0.1190166	total: 564ms	remaining: 157ms
# 782:	learn: 0.1189296	total: 564ms	remaining: 156ms
# 783:	learn: 0.1188855	total: 565ms	remaining: 156ms
# 784:	learn: 0.1187766	total: 566ms	remaining: 155ms
# 785:	learn: 0.1187474	total: 566ms	remaining: 154ms
# 786:	learn: 0.1187047	total: 567ms	remaining: 153ms
# 787:	learn: 0.1186497	total: 568ms	remaining: 153ms
# 788:	learn: 0.1185863	total: 568ms	remaining: 152ms
# 789:	learn: 0.1185638	total: 569ms	remaining: 151ms
# 790:	learn: 0.1184764	total: 570ms	remaining: 151ms
# 791:	learn: 0.1183985	total: 570ms	remaining: 150ms
# 792:	learn: 0.1183528	total: 571ms	remaining: 149ms
# 793:	learn: 0.1183072	total: 572ms	remaining: 148ms
# 794:	learn: 0.1182534	total: 573ms	remaining: 148ms
# 795:	learn: 0.1181868	total: 574ms	remaining: 147ms
# 796:	learn: 0.1181266	total: 575ms	remaining: 146ms
# 797:	learn: 0.1180024	total: 577ms	remaining: 146ms
# 798:	learn: 0.1179440	total: 578ms	remaining: 145ms
# 799:	learn: 0.1178929	total: 579ms	remaining: 145ms
# 800:	learn: 0.1177997	total: 581ms	remaining: 144ms
# 801:	learn: 0.1177289	total: 582ms	remaining: 144ms
# 802:	learn: 0.1176445	total: 583ms	remaining: 143ms
# 803:	learn: 0.1175069	total: 583ms	remaining: 142ms
# 804:	learn: 0.1174567	total: 584ms	remaining: 141ms
# 805:	learn: 0.1173858	total: 585ms	remaining: 141ms
# 806:	learn: 0.1173182	total: 585ms	remaining: 140ms
# 807:	learn: 0.1172655	total: 586ms	remaining: 139ms
# 808:	learn: 0.1171938	total: 587ms	remaining: 138ms
# 809:	learn: 0.1171750	total: 587ms	remaining: 138ms
# 810:	learn: 0.1171142	total: 588ms	remaining: 137ms
# 811:	learn: 0.1170198	total: 589ms	remaining: 136ms
# 812:	learn: 0.1169603	total: 589ms	remaining: 136ms
# 813:	learn: 0.1168845	total: 590ms	remaining: 135ms
# 814:	learn: 0.1168648	total: 591ms	remaining: 134ms
# 815:	learn: 0.1168165	total: 591ms	remaining: 133ms
# 816:	learn: 0.1167547	total: 592ms	remaining: 133ms
# 817:	learn: 0.1166014	total: 593ms	remaining: 132ms
# 818:	learn: 0.1165315	total: 593ms	remaining: 131ms
# 819:	learn: 0.1165018	total: 594ms	remaining: 130ms
# 820:	learn: 0.1164615	total: 595ms	remaining: 130ms
# 821:	learn: 0.1164216	total: 595ms	remaining: 129ms
# 822:	learn: 0.1163440	total: 596ms	remaining: 128ms
# 823:	learn: 0.1162313	total: 597ms	remaining: 127ms
# 824:	learn: 0.1161888	total: 597ms	remaining: 127ms
# 825:	learn: 0.1161409	total: 598ms	remaining: 126ms
# 826:	learn: 0.1160839	total: 599ms	remaining: 125ms
# 827:	learn: 0.1159150	total: 599ms	remaining: 124ms
# 828:	learn: 0.1158638	total: 600ms	remaining: 124ms
# 829:	learn: 0.1157880	total: 601ms	remaining: 123ms
# 830:	learn: 0.1157271	total: 601ms	remaining: 122ms
# 831:	learn: 0.1155467	total: 602ms	remaining: 122ms
# 832:	learn: 0.1154468	total: 603ms	remaining: 121ms
# 833:	learn: 0.1153815	total: 603ms	remaining: 120ms
# 834:	learn: 0.1152737	total: 604ms	remaining: 119ms
# 835:	learn: 0.1152287	total: 605ms	remaining: 119ms
# 836:	learn: 0.1151177	total: 605ms	remaining: 118ms
# 837:	learn: 0.1150867	total: 606ms	remaining: 117ms
# 838:	learn: 0.1150447	total: 607ms	remaining: 116ms
# 839:	learn: 0.1149130	total: 607ms	remaining: 116ms
# 840:	learn: 0.1148658	total: 608ms	remaining: 115ms
# 841:	learn: 0.1148262	total: 609ms	remaining: 114ms
# 842:	learn: 0.1147943	total: 609ms	remaining: 113ms
# 843:	learn: 0.1147628	total: 610ms	remaining: 113ms
# 844:	learn: 0.1146552	total: 611ms	remaining: 112ms
# 845:	learn: 0.1146218	total: 611ms	remaining: 111ms
# 846:	learn: 0.1144818	total: 612ms	remaining: 111ms
# 847:	learn: 0.1144396	total: 613ms	remaining: 110ms
# 848:	learn: 0.1143715	total: 613ms	remaining: 109ms
# 849:	learn: 0.1142593	total: 614ms	remaining: 108ms
# 850:	learn: 0.1141567	total: 615ms	remaining: 108ms
# 851:	learn: 0.1140873	total: 615ms	remaining: 107ms
# 852:	learn: 0.1139852	total: 616ms	remaining: 106ms
# 853:	learn: 0.1138464	total: 617ms	remaining: 105ms
# 854:	learn: 0.1137359	total: 617ms	remaining: 105ms
# 855:	learn: 0.1136992	total: 618ms	remaining: 104ms
# 856:	learn: 0.1136189	total: 619ms	remaining: 103ms
# 857:	learn: 0.1135390	total: 619ms	remaining: 102ms
# 858:	learn: 0.1134884	total: 620ms	remaining: 102ms
# 859:	learn: 0.1134365	total: 621ms	remaining: 101ms
# 860:	learn: 0.1133809	total: 621ms	remaining: 100ms
# 861:	learn: 0.1133341	total: 622ms	remaining: 99.6ms
# 862:	learn: 0.1132443	total: 623ms	remaining: 98.8ms
# 863:	learn: 0.1131995	total: 623ms	remaining: 98.1ms
# 864:	learn: 0.1130859	total: 624ms	remaining: 97.4ms
# 865:	learn: 0.1130051	total: 625ms	remaining: 96.6ms
# 866:	learn: 0.1129566	total: 625ms	remaining: 95.9ms
# 867:	learn: 0.1128738	total: 626ms	remaining: 95.2ms
# 868:	learn: 0.1128299	total: 626ms	remaining: 94.4ms
# 869:	learn: 0.1127825	total: 627ms	remaining: 93.7ms
# 870:	learn: 0.1126743	total: 628ms	remaining: 93ms
# 871:	learn: 0.1126246	total: 628ms	remaining: 92.3ms
# 872:	learn: 0.1125554	total: 629ms	remaining: 91.5ms
# 873:	learn: 0.1125054	total: 630ms	remaining: 90.8ms
# 874:	learn: 0.1124552	total: 630ms	remaining: 90.1ms
# 875:	learn: 0.1123769	total: 631ms	remaining: 89.3ms
# 876:	learn: 0.1123363	total: 632ms	remaining: 88.6ms
# 877:	learn: 0.1122710	total: 632ms	remaining: 87.9ms
# 878:	learn: 0.1122287	total: 633ms	remaining: 87.1ms
# 879:	learn: 0.1121734	total: 634ms	remaining: 86.4ms
# 880:	learn: 0.1119511	total: 634ms	remaining: 85.7ms
# 881:	learn: 0.1118383	total: 635ms	remaining: 85ms
# 882:	learn: 0.1118017	total: 636ms	remaining: 84.2ms
# 883:	learn: 0.1117559	total: 636ms	remaining: 83.5ms
# 884:	learn: 0.1117079	total: 637ms	remaining: 82.8ms
# 885:	learn: 0.1116501	total: 638ms	remaining: 82ms
# 886:	learn: 0.1115168	total: 638ms	remaining: 81.3ms
# 887:	learn: 0.1114774	total: 639ms	remaining: 80.6ms
# 888:	learn: 0.1114386	total: 640ms	remaining: 79.9ms
# 889:	learn: 0.1113210	total: 640ms	remaining: 79.1ms
# 890:	learn: 0.1112675	total: 641ms	remaining: 78.4ms
# 891:	learn: 0.1111900	total: 642ms	remaining: 77.7ms
# 892:	learn: 0.1111646	total: 642ms	remaining: 77ms
# 893:	learn: 0.1111535	total: 643ms	remaining: 76.2ms
# 894:	learn: 0.1110898	total: 643ms	remaining: 75.5ms
# 895:	learn: 0.1110285	total: 644ms	remaining: 74.8ms
# 896:	learn: 0.1110080	total: 645ms	remaining: 74ms
# 897:	learn: 0.1109034	total: 645ms	remaining: 73.3ms
# 898:	learn: 0.1107662	total: 646ms	remaining: 72.6ms
# 899:	learn: 0.1107102	total: 647ms	remaining: 71.8ms
# 900:	learn: 0.1106245	total: 647ms	remaining: 71.1ms
# 901:	learn: 0.1105824	total: 648ms	remaining: 70.4ms
# 902:	learn: 0.1105273	total: 649ms	remaining: 69.7ms
# 903:	learn: 0.1103492	total: 649ms	remaining: 68.9ms
# 904:	learn: 0.1102654	total: 650ms	remaining: 68.2ms
# 905:	learn: 0.1102403	total: 651ms	remaining: 67.5ms
# 906:	learn: 0.1101405	total: 651ms	remaining: 66.8ms
# 907:	learn: 0.1100139	total: 652ms	remaining: 66.1ms
# 908:	learn: 0.1099699	total: 653ms	remaining: 65.3ms
# 909:	learn: 0.1099256	total: 653ms	remaining: 64.6ms
# 910:	learn: 0.1098637	total: 654ms	remaining: 63.9ms
# 911:	learn: 0.1098120	total: 655ms	remaining: 63.2ms
# 912:	learn: 0.1097789	total: 655ms	remaining: 62.4ms
# 913:	learn: 0.1097380	total: 656ms	remaining: 61.7ms
# 914:	learn: 0.1096865	total: 658ms	remaining: 61.1ms
# 915:	learn: 0.1096227	total: 658ms	remaining: 60.4ms
# 916:	learn: 0.1095155	total: 659ms	remaining: 59.6ms
# 917:	learn: 0.1094573	total: 660ms	remaining: 58.9ms
# 918:	learn: 0.1094014	total: 660ms	remaining: 58.2ms
# 919:	learn: 0.1093582	total: 661ms	remaining: 57.5ms
# 920:	learn: 0.1092671	total: 662ms	remaining: 56.7ms
# 921:	learn: 0.1092296	total: 662ms	remaining: 56ms
# 922:	learn: 0.1092050	total: 663ms	remaining: 55.3ms
# 923:	learn: 0.1091486	total: 664ms	remaining: 54.6ms
# 924:	learn: 0.1090360	total: 664ms	remaining: 53.9ms
# 925:	learn: 0.1089319	total: 665ms	remaining: 53.1ms
# 926:	learn: 0.1087396	total: 666ms	remaining: 52.4ms
# 927:	learn: 0.1086851	total: 666ms	remaining: 51.7ms
# 928:	learn: 0.1085600	total: 667ms	remaining: 51ms
# 929:	learn: 0.1085221	total: 668ms	remaining: 50.2ms
# 930:	learn: 0.1084611	total: 668ms	remaining: 49.5ms
# 931:	learn: 0.1084225	total: 669ms	remaining: 48.8ms
# 932:	learn: 0.1083596	total: 669ms	remaining: 48.1ms
# 933:	learn: 0.1083418	total: 670ms	remaining: 47.4ms
# 934:	learn: 0.1082638	total: 671ms	remaining: 46.6ms
# 935:	learn: 0.1082283	total: 672ms	remaining: 45.9ms
# 936:	learn: 0.1081767	total: 672ms	remaining: 45.2ms
# 937:	learn: 0.1080377	total: 673ms	remaining: 44.5ms
# 938:	learn: 0.1079759	total: 674ms	remaining: 43.8ms
# 939:	learn: 0.1079383	total: 674ms	remaining: 43ms
# 940:	learn: 0.1079253	total: 675ms	remaining: 42.3ms
# 941:	learn: 0.1078735	total: 676ms	remaining: 41.6ms
# 942:	learn: 0.1078316	total: 676ms	remaining: 40.9ms
# 943:	learn: 0.1077073	total: 677ms	remaining: 40.2ms
# 944:	learn: 0.1076478	total: 677ms	remaining: 39.4ms
# 945:	learn: 0.1075629	total: 678ms	remaining: 38.7ms
# 946:	learn: 0.1074042	total: 679ms	remaining: 38ms
# 947:	learn: 0.1073497	total: 679ms	remaining: 37.3ms
# 948:	learn: 0.1073157	total: 680ms	remaining: 36.5ms
# 949:	learn: 0.1072880	total: 681ms	remaining: 35.8ms
# 950:	learn: 0.1072353	total: 681ms	remaining: 35.1ms
# 951:	learn: 0.1071984	total: 682ms	remaining: 34.4ms
# 952:	learn: 0.1070464	total: 683ms	remaining: 33.7ms
# 953:	learn: 0.1069872	total: 683ms	remaining: 32.9ms
# 954:	learn: 0.1069377	total: 684ms	remaining: 32.2ms
# 955:	learn: 0.1068962	total: 685ms	remaining: 31.5ms
# 956:	learn: 0.1067707	total: 685ms	remaining: 30.8ms
# 957:	learn: 0.1066972	total: 686ms	remaining: 30.1ms
# 958:	learn: 0.1065938	total: 687ms	remaining: 29.4ms
# 959:	learn: 0.1065250	total: 687ms	remaining: 28.6ms
# 960:	learn: 0.1064916	total: 688ms	remaining: 27.9ms
# 961:	learn: 0.1063970	total: 689ms	remaining: 27.2ms
# 962:	learn: 0.1063609	total: 690ms	remaining: 26.5ms
# 963:	learn: 0.1062982	total: 691ms	remaining: 25.8ms
# 964:	learn: 0.1062370	total: 691ms	remaining: 25.1ms
# 965:	learn: 0.1061275	total: 692ms	remaining: 24.4ms
# 966:	learn: 0.1060914	total: 693ms	remaining: 23.6ms
# 967:	learn: 0.1060481	total: 693ms	remaining: 22.9ms
# 968:	learn: 0.1060356	total: 694ms	remaining: 22.2ms
# 969:	learn: 0.1059374	total: 695ms	remaining: 21.5ms
# 970:	learn: 0.1058350	total: 695ms	remaining: 20.8ms
# 971:	learn: 0.1058012	total: 696ms	remaining: 20.1ms
# 972:	learn: 0.1057458	total: 697ms	remaining: 19.3ms
# 973:	learn: 0.1057030	total: 697ms	remaining: 18.6ms
# 974:	learn: 0.1056657	total: 698ms	remaining: 17.9ms
# 975:	learn: 0.1056323	total: 699ms	remaining: 17.2ms
# 976:	learn: 0.1054866	total: 699ms	remaining: 16.5ms
# 977:	learn: 0.1053715	total: 700ms	remaining: 15.7ms
# 978:	learn: 0.1053269	total: 701ms	remaining: 15ms
# 979:	learn: 0.1052766	total: 701ms	remaining: 14.3ms
# 980:	learn: 0.1051890	total: 702ms	remaining: 13.6ms
# 981:	learn: 0.1050199	total: 703ms	remaining: 12.9ms
# 982:	learn: 0.1049864	total: 703ms	remaining: 12.2ms
# 983:	learn: 0.1049279	total: 704ms	remaining: 11.4ms
# 984:	learn: 0.1048932	total: 705ms	remaining: 10.7ms
# 985:	learn: 0.1048509	total: 705ms	remaining: 10ms
# 986:	learn: 0.1048057	total: 706ms	remaining: 9.3ms
# 987:	learn: 0.1047289	total: 707ms	remaining: 8.58ms
# 988:	learn: 0.1046980	total: 707ms	remaining: 7.87ms
# 989:	learn: 0.1046426	total: 708ms	remaining: 7.15ms
# 990:	learn: 0.1045592	total: 709ms	remaining: 6.43ms
# 991:	learn: 0.1045266	total: 709ms	remaining: 5.72ms
# 992:	learn: 0.1044749	total: 710ms	remaining: 5ms
# 993:	learn: 0.1044429	total: 711ms	remaining: 4.29ms
# 994:	learn: 0.1043620	total: 711ms	remaining: 3.57ms
# 995:	learn: 0.1043320	total: 712ms	remaining: 2.86ms
# 996:	learn: 0.1042963	total: 713ms	remaining: 2.14ms
# 997:	learn: 0.1042670	total: 713ms	remaining: 1.43ms
# 998:	learn: 0.1042358	total: 714ms	remaining: 714us
# 999:	learn: 0.1041904	total: 715ms	remaining: 0us

# %%
# for i in FinalPCADF.index:
#      for j in FinalPCADF.columns:
#         if FinalPCADF.loc[i][j] == "-inf":
#             FinalPCADF=FinalPCADF.drop(i,axis=0)

# %%
PCAScoreDataFrame
# Out:
#                          0.93      0.95      0.98
# Logistic Regression  0.959064  0.959064  0.959064
# Decision tree        0.883041  0.883041  0.883041
# Random forest        0.929825  0.929825  0.929825
# Ada Boosting         0.923977  0.923977  0.923977
# Cat Boosting         0.935673  0.935673  0.935673
# Gradient Boosting    0.941520  0.941520  0.941520
# XG Boosting          0.947368  0.947368  0.947368

# %%
# for i,v in Predictions.items():
#     print(i)

# %%
MaximumScore004=PCAScoreDataFrame.values.max()
for i in PCAScoreDataFrame.index:
    for j in PCAScoreDataFrame.columns:
        for col in PCAScoreDataFrame.columns:
            if PCAScoreDataFrame.loc[i][j] == MaximumScore004:
                max= PCAScoreDataFrame.loc[i][j]
                if  PCAScoreDataFrame.loc[i][j] >= max:
                    max= PCAScoreDataFrame.loc[i][j]
                    # print(max)
for i in PCAScoreDataFrame.index:
    for j in PCAScoreDataFrame.columns:
        if max == PCAScoreDataFrame.loc[i][j]:
            # print(j)
            BestVariance=j
PerfomanceDF["Best_PCA_%Of_variance"]=PCAScoreDataFrame[BestVariance]

# %%
# pca = PCA().fit(ClearedDataFrame)
# cum_var = np.cumsum(pca.explained_variance_ratio_)
# NComponents = np.argmax(cum_var >= 0.95) + 1
# print(n_components)

# %%
# PCAnocScoreDataFrame

# %%
# for ind in PCAnocScoreDataFrame.index:
#     for col in PCAnocScoreDataFrame.columns:
#         if PCAnocScoreDataFrame.loc[ind][col] == PCAnocScoreDataFrame[col].max():
#             maximum=PCAnocScoreDataFrame.loc[ind][col]
#             PCAnocScoreDataFrame["No_OF_Components_PCA"]=PCAnocScoreDataFrame[col]
#             BestNoOfComponents=pd.DataFrame()
#             BestNoOfComponents[col]=PCAnocScoreDataFrame[col]
#             # print(maximum)
# PerfomanceDF["No_OF_Components_PCA"]=PCAnocScoreDataFrame["No_OF_Components_PCA"]
# display(PerfomanceDF)

# %%
display(PerfomanceDF)
BestScoreDF=pd.DataFrame()
# BestModelDF=pd.DataFrame()
for i in PerfomanceDF.index:
    for j in PerfomanceDF.columns:
        if PerfomanceDF.loc[i][j] == PerfomanceDF['No_Tuning'].max():
            if ModelType ==  "Regression":
                R2="R2_Score"
                # BestScoreDF.index=[i]
                # BestScoreDF.columns=[R2]
                BestScoreDF.loc["1 - " +i,R2]=round(PerfomanceDF['No_Tuning'].max(),3)
                print(f"The {i} Model performs well in No_Tuning with the {R2} : {round(PerfomanceDF['No_Tuning'].max(),3)}")
        # print(a.loc[i],[j])
            if ModelType ==  "Classification":
                Cla="Accuracy_Score"
                BestScoreDF.loc["1 - " +i,Cla]=round(PerfomanceDF['No_Tuning'].max(),3)
                print(f"The {i} Model performs well in No_Tuning with the {Cla} : {round(PerfomanceDF['No_Tuning'].max(),3)}")
for i in PerfomanceDF.index:
    for j in PerfomanceDF.columns:
        if PerfomanceDF.loc[i][j] == PerfomanceDF['Best_PCA_%Of_variance'].max():
            if ModelType ==  "Regression":
                R2="R2_Score"
                BestScoreDF.loc["4 - " +i,R2]=round(PerfomanceDF['Best_PCA_%Of_variance'].max(),3)
                print(f"The {i} Model performs well in PCA % of Variance with the {R2} : {round(PerfomanceDF['Best_PCA_%Of_variance'].max(),3)}")
        # print(a.loc[i],[j])
            if ModelType ==  "Classification":
                Cla="Accuracy_Score"
                BestScoreDF.loc["4 - " +i,Cla]=round(PerfomanceDF['Best_PCA_%Of_variance'].max(),3)
                print(f"The {i} Model performs well in PCA % of Variancewith the {Cla} : {round(PerfomanceDF['Best_PCA_%Of_variance'].max(),3)}")
for i in PerfomanceDF.index:
    for j in PerfomanceDF.columns:
        if ModelType ==  "Regression":
            if PerfomanceDF.loc[i][j] == PerfomanceDF['LOG_Applyed_&_Outlayers_Removed'].max():
                # if ModelType ==  "Regression":
                    R2="R2_Score"
                    BestScoreDF.loc["2 - " +i,R2]=round(PerfomanceDF['LOG_Applyed_&_Outlayers_Removed'].max(),3)
                    print(f"The {i} Model performs well after LOG_Applyed_&_Outlayers_Removed with the {R2} : {round(PerfomanceDF['LOG_Applyed_&_Outlayers_Removed'].max(),3)}")
            # print(a.loc[i],[j])
        if ModelType ==  "Classification":
            if PerfomanceDF.loc[i][j] == PerfomanceDF['Outlayers_Removed'].max():
                    Cla="Accuracy_Score"
                    BestScoreDF.loc["2 - " +i,Cla]=round(PerfomanceDF['Outlayers_Removed'].max(),3)
                    print(f"The {i} Model performs well after Outlayers_Removed with the {Cla} : {round(PerfomanceDF['Outlayers_Removed'].max(),3)}")
for i in PerfomanceDF.index:
    for j in PerfomanceDF.columns:
        if PerfomanceDF.loc[i][j] == PerfomanceDF['No_OF_Components_PCA'].max():
            if ModelType ==  "Regression":
                R2="R2_Score"
                BestScoreDF.loc["3 - " +i,R2]=round(PerfomanceDF['No_OF_Components_PCA'].max(),3)
                print(f"The {i} Model performs well in Best_PCA with the {R2} : {round(PerfomanceDF['No_OF_Components_PCA'].max(),3)}")
            if ModelType ==  "Classification":
                Cla="Accuracy_Score"
                BestScoreDF.loc["3 - " +i,Cla]=round(PerfomanceDF['No_OF_Components_PCA'].max(),3)
                print(f"The {i} Model performs well in Best_PCA with the {Cla} : {round(PerfomanceDF['No_OF_Components_PCA'].max(),3)}")

if ModelType ==  "Classification":
    display(BestScoreDF.sort_values(by=Cla,ascending=False))
    BestModelDF = BestScoreDF.sort_values(by=Cla,ascending=False).head(1)
elif ModelType ==  "Regression":
    display(BestScoreDF.sort_values(by=R2,ascending=False))
    BestModelDF = BestScoreDF.sort_values(by=R2,ascending=False).head(1)
# Out:
#                      No_Tuning  Outlayers_Removed  No_OF_Components_PCA  \
# Logistic Regression   0.970760           0.970760              0.970760
# Decision tree         0.970760           0.929825              0.894737
# Random forest         0.959064           0.959064              0.953216
# Ada Boosting          0.947368           0.947368              0.970760
# Cat Boosting          0.959064           0.959064              0.959064
# Gradient Boosting     0.964912           0.964912              0.935673
# XG Boosting           0.964912           0.964912              0.964912
#
#                      Best_PCA_%Of_variance
# Logistic Regression               0.959064
# Decision tree                     0.883041
# Random forest                     0.929825
# Ada Boosting                      0.923977
# Cat Boosting                      0.935673
# Gradient Boosting                 0.941520
# XG Boosting                       0.947368
# The Logistic Regression Model performs well in No_Tuning with the Accuracy_Score : 0.971
# The Logistic Regression Model performs well in No_Tuning with the Accuracy_Score : 0.971
# The Logistic Regression Model performs well in No_Tuning with the Accuracy_Score : 0.971
# The Decision tree Model performs well in No_Tuning with the Accuracy_Score : 0.971
# The Ada Boosting Model performs well in No_Tuning with the Accuracy_Score : 0.971
# The Logistic Regression Model performs well in PCA % of Variancewith the Accuracy_Score : 0.959
# The Random forest Model performs well in PCA % of Variancewith the Accuracy_Score : 0.959
# The Random forest Model performs well in PCA % of Variancewith the Accuracy_Score : 0.959
# The Cat Boosting Model performs well in PCA % of Variancewith the Accuracy_Score : 0.959
# The Cat Boosting Model performs well in PCA % of Variancewith the Accuracy_Score : 0.959
# The Cat Boosting Model performs well in PCA % of Variancewith the Accuracy_Score : 0.959
# The Logistic Regression Model performs well after Outlayers_Removed with the Accuracy_Score : 0.971
# The Logistic Regression Model performs well after Outlayers_Removed with the Accuracy_Score : 0.971
# The Logistic Regression Model performs well after Outlayers_Removed with the Accuracy_Score : 0.971
# The Decision tree Model performs well after Outlayers_Removed with the Accuracy_Score : 0.971
# The Ada Boosting Model performs well after Outlayers_Removed with the Accuracy_Score : 0.971
# The Logistic Regression Model performs well in Best_PCA with the Accuracy_Score : 0.971
# The Logistic Regression Model performs well in Best_PCA with the Accuracy_Score : 0.971
# The Logistic Regression Model performs well in Best_PCA with the Accuracy_Score : 0.971
# The Decision tree Model performs well in Best_PCA with the Accuracy_Score : 0.971
# The Ada Boosting Model performs well in Best_PCA with the Accuracy_Score : 0.971
#                          Accuracy_Score
# 1 - Logistic Regression           0.971
# 1 - Decision tree                 0.971
# 1 - Ada Boosting                  0.971
# 2 - Decision tree                 0.971
# 3 - Decision tree                 0.971
# 2 - Logistic Regression           0.971
# 3 - Logistic Regression           0.971
# 2 - Ada Boosting                  0.971
# 3 - Ada Boosting                  0.971
# 4 - Logistic Regression           0.959
# 4 - Random forest                 0.959
# 4 - Cat Boosting                  0.959

# %%
a=BestModelDF.index[0]
a=a.split(" - ")
for i in a:
    print(i)
# Out:
# 1
# Logistic Regression

# %%
# for i,v in Predictions.items():
#     print(i)

# %%
# AllModels=[]
if ModelType == "Regression":
    from sklearn.metrics import mean_absolute_error, mean_squared_error,median_absolute_error

    # Extract best model info
    best_index = BestModelDF.index[0]    # "2 - Random forest"
    split_info = best_index.split(" - ") # ["2", "Random forest"]
    dataset_id, model_name = split_info[0], split_info[1]

    # Choose suffix
    if dataset_id == "1":
        sufix = ""
        Predit="Predit001"
        x_train,x_test,y_train,y_test=ORGxTrain,ORGxTest,ORGyTrain,ORGyTest
    elif dataset_id == "2":
        sufix = "RawData"
        Predit="Predit002"
        x_train,x_test,y_train,y_test=xTrainLog,xTestLog,yTrainLog,yTestLog
    elif dataset_id == "3":
        sufix = "NOC"
        Predit="Predit003"
        x_train,x_test,y_train,y_test=xTrainPCAnoc,xTestPCAnoc,yTrainPCAnoc,yTestPCAnoc
    elif dataset_id == "4":
        sufix = "Variance"
        Predit="Predit004"
        x_train,x_test,y_train,y_test= xTrainPCA,xTestPCA,yTrainPCA,yTestPCA

    model_map = {
        "Linear Regression": eval("linReg" + sufix),
        "Decision tree": eval("DecReg" + sufix),
        "Random forest": eval("RandomReg" + sufix),
        "Ada Boosting": eval("AdaBoostReg" + sufix),
        "Cat Boosting": eval("CatBoostReg" + sufix),
        "Gradient Boosting": eval("GradBoostReg" + sufix),
        "XG Boosting": eval("XGBReg" + sufix)
    }




    Best_Model = model_map[model_name]
    display('Best Model:')
    display(Best_Model)

    Predit_map = {
        "Logistic Regression": Predictions[f"linReg{Predit}"],
        "Decision tree": Predictions[f"DecReg{Predit}"],
        "Random forest": Predictions[f"RandomReg{Predit}"],
        "Ada Boosting": Predictions[f"AdaBoostReg{Predit}"],
        "Cat Boosting": Predictions[f"CatBoostReg{Predit}"],
        "Gradient Boosting": Predictions[f"GradBoostReg{Predit}"],
        "XG Boosting": Predictions[f"XGBReg{Predit}"]
    }
    print("RESULT : \n\nThis Model Performs:\n")
    for i,v in RESULT.items():
        print(i,v)

    print("\n\nRegression Metrics:\n")
    print(f"R2 Score: {round(r2_score(y_test,Predit_map[model_name]),3)}\nAbsolute Mean Error: {round(mean_absolute_error(y_test,Predit_map[model_name]),3)}\nMean Square Error: {round(mean_squared_error(y_test,Predit_map[model_name]),3)}\nMedian Absolute Error: {round(median_absolute_error(y_test,Predit_map[model_name]),3)}")



if ModelType == "Classification":
    from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score,cohen_kappa_score

    # Extract best model info
    best_index = BestModelDF.index[0]   # "2 - Logistic Regression"
    split_info = best_index.split(" - ")  # ["2", "Logistic Regression"]
    dataset_id, model_name = split_info[0], split_info[1]

    # Choose suffix and model set
    if dataset_id == "1":
        sufix = ""
        Predit="Predit001"
        x_train,x_test,y_train,y_test=ORGxTrain,ORGxTest,ORGyTrain,ORGyTest
    elif dataset_id == "2":
        sufix = "RawData"
        Predit="Predit002"
        x_train,x_test,y_train,y_test=xTrainLog,xTestLog,yTrainLog,yTestLog
    elif dataset_id == "3":
        sufix = "NOC"
        Predit="Predit003"
        x_train,x_test,y_train,y_test=xTrainPCAnoc,xTestPCAnoc,yTrainPCAnoc,yTestPCAnoc
    elif dataset_id == "4":
        sufix = "Variance"
        Predit="Predit004"
        x_train,x_test,y_train,y_test= xTrainPCA,xTestPCA,yTrainPCA,yTestPCA

    model_map = {
        "Logistic Regression": eval("logReg" + sufix),
        "Decision tree": eval("DecCla" + sufix),
        "Random forest": eval("RandomCla" + sufix),
        "Ada Boosting": eval("AdaBoostCla" + sufix),
        "Cat Boosting": eval("CatBoostCla" + sufix),
        "Gradient Boosting": eval("GradBoostCla" + sufix),
        "XG Boosting": eval("XGBCla" + sufix)
    }

    Best_Model = model_map[model_name]
    display('Best Model:')
    display(Best_Model)


    Predit_map = {
        "Logistic Regression": Predictions[f"logReg{Predit}"],
        "Decision tree": Predictions[f"DecCla{Predit}"],
        "Random forest": Predictions[f"RandomCla{Predit}"],
        "Ada Boosting": Predictions[f"AdaBoostCla{Predit}"],
        "Cat Boosting": Predictions[f"CatBoostCla{Predit}"],
        "Gradient Boosting": Predictions[f"GradBoostCla{Predit}"],
        "XG Boosting": Predictions[f"XGBCla{Predit}"]
    }
    # print(Predit_map[model_name])
    # print(f"Accuracy Score: {accuracy_score(yTest, Predit_map[model_name])}")
    print("RESULT : \n\nThis Model Performs:\n")
    for i,v in RESULT.items():
        print(i,v)

    print("\n\nClassification Metrics:\n")

    print(f"Accuracy Score: {round(accuracy_score(y_test,Predit_map[model_name]),3)}\nPrecision Score: {round(precision_score(y_test,Predit_map[model_name]),3)}\nRecall Score: {round(recall_score(y_test,Predit_map[model_name]),3)}\nF1 Score: {round(f1_score(y_test,Predit_map[model_name]),3)}\nROC AUC Score: {round(roc_auc_score(y_test,Predit_map[model_name]),3)}\nKappa Score: {round(cohen_kappa_score(y_test,Predit_map[model_name]),3)}")


a=len(df.columns)/2
a=int(a+1)
plt.figure(figsize=(20,a*5))
for i,col in enumerate(df,1):
    plt.subplot(a,3,i)
    sns.histplot(data=df,x=col,kde=True,color="skyblue")
    # plt.hist(df[col], color=plt.cm.viridis(np.linspace(0,1,30)))
    plt.xlabel(col)
    plt.ylabel('count')
plt.tight_layout()  # adjust spacing
plt.show()
# Out:
# 'Best Model:'
# LogisticRegression()
# RESULT :
#
# This Model Performs:
#
# FILE NAME:  breast_cancer_dataframe.csv
# NULL VALUES:  NO NULL VALUES. ✅
# UNWANTED COLUMNS:  NO COLUMNS REMOVED. ✅
# ENCODING TYPE:  NO ENCODING PERFORMED. ✅
# TARGET:  target
# TRAINING DATA:  70.0
# TESTING DATA:  30.0
# MODEL TYPE:  Classification
#
#
# Classification Metrics:
#
# Accuracy Score: 0.971
# Precision Score: 0.981
# Recall Score: 0.972
# F1 Score: 0.977
# ROC AUC Score: 0.97
# Kappa Score: 0.937
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3708535740.py in <cell line: 0>()
#     124 a=len(df.columns)/2
#     125 a=int(a+1)
# --> 126 plt.figure(figsize=(20,a*5))
#     127 for i,col in enumerate(df,1):
#     128     plt.subplot(a,3,i)
#
# NameError: name 'plt' is not defined
